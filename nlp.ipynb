# %%
import numpy as np
import pandas as pd
from pycaret.nlp import *
import nltk
from nltk.corpus import stopwords
import unicodedata
import unidecode
import re
import spacy
import pprint
from gensim import corpora

# %%
# download das stopwords para o idioma português
nltk.download('stopwords')
stop_words = stopwords.words('portuguese')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bruno\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# montagem do dataset
df_covid = pd.read_csv('data/exemplos-treinamento-covid.csv', delimiter=';')
df_seloturismo = pd.read_csv('data/exemplos-treinamento-seloturismo.csv', delimiter=';')
df_tuberculose = pd.read_csv('data/exemplos-treinamento-tuberculose.csv', delimiter=';')
df_teste = pd.read_csv('data/dados-testes-experimentos.csv', delimiter=';')

df_all = pd.concat([df_covid, df_seloturismo, df_tuberculose, df_teste], axis=0)
df_all.reset_index(drop=True, inplace=True)
df_all
# Out:
#                                                   input     category
# 0                               dor no abdomen é covid?        covid
# 1            Pego covid tocando numa objeto_contaminado        covid
# 2                            Pego covid através de meio        covid
# 3                                  onde começou o covid        covid
# 4                    onde coemçou a infestação do covid        covid
# ...                                                 ...          ...
# 1194  Para os setores de Meios de Hospedagem as prem...  seloturismo
# 1195  Ao final da estada do hóspede, deverá ser real...  seloturismo
# 1196                 É proibido pernoitar na embarcação  seloturismo
# 1197  Fornecer Equipamentos de Proteção Individual (...  seloturismo
# 1198  orientar o consumidor a dar preferência aos es...  seloturismo
#
# [1199 rows x 2 columns]

# %%
# Normalização string de entrada 
# retira pontuação
df_all.input = df_all.input.str.replace(r'[^\w\s]+', '')

# remove numeração
df_all.input = df_all.input.str.replace(r'[0-9]+', '')

# remove underscore
df_all.input = df_all.input.str.replace('_', ' ')
df_all
# Out:
# C:\Users\bruno\AppData\Local\Temp\ipykernel_8560\1748041250.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_all.input = df_all.input.str.replace(r'[^\w\s]+', '')
# C:\Users\bruno\AppData\Local\Temp\ipykernel_8560\1748041250.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_all.input = df_all.input.str.replace(r'[0-9]+', '')
#                                                   input     category
# 0                                dor no abdomen é covid        covid
# 1            Pego covid tocando numa objeto contaminado        covid
# 2                            Pego covid através de meio        covid
# 3                                  onde começou o covid        covid
# 4                    onde coemçou a infestação do covid        covid
# ...                                                 ...          ...
# 1194  Para os setores de Meios de Hospedagem as prem...  seloturismo
# 1195  Ao final da estada do hóspede deverá ser reali...  seloturismo
# 1196                 É proibido pernoitar na embarcação  seloturismo
# 1197  Fornecer Equipamentos de Proteção Individual E...  seloturismo
# 1198  orientar o consumidor a dar preferência aos es...  seloturismo
#
# [1199 rows x 2 columns]

# %%
# Lematização string de entrada
## Verificar o uso do spacy pois tem em português
nlp = spacy.load("pt_core_news_lg")
lem = nlp.get_pipe("lemmatizer")

inputs = []
for doc in df_all.input:
    d = nlp(doc)
    s = ' '.join([token.lemma_ for token in d])       
    inputs.append(s)
df_all['input'] = inputs
df_all
# Out:
# C:\Users\bruno\AppData\Roaming\Python\Python38\site-packages\spacy\util.py:865: UserWarning: [W095] Model 'pt_core_news_lg' (3.3.0) was trained with spaCy v3.3 and may not be 100% compatible with the current version (3.4.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
#                                                   input     category
# 0                            dor em o abdomen ser Covid        covid
# 1              pego Covid tocar em um objeto contaminar        covid
# 2                            pego Covid através de meio        covid
# 3                                  onde começar o Covid        covid
# 4                  onde coemçar o infestação de o Covid        covid
# ...                                                 ...          ...
# 1194  para o setor de Meios de Hospedagem o premissa...  seloturismo
# 1195  a o final de o estada de o hóspede dever ser r...  seloturismo
# 1196              ser proibir pernoitar em o embarcação  seloturismo
# 1197  Fornecer Equipamentos de Proteção Individual E...  seloturismo
# 1198  orientar o consumidor a dar preferência a o es...  seloturismo
#
# [1199 rows x 2 columns]

# %%
# geração de corpus com dataset, remoção de stopwords e tokenização
text_corpus = df_all.input.to_numpy()
# Lowercase each document, split it by white space and filter out stopwords
texts = [[word for word in document.lower().split() if word not in stop_words]
         for document in text_corpus]
# Count word frequencies
from collections import defaultdict
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1
# Only keep words that appear more than once
processed_corpus = [[token for token in text if frequency[token] > 1] for text in texts]
pprint.pprint(processed_corpus)
# Out:
# [['covid'],
#  ['pego', 'covid', 'tocar', 'objeto', 'contaminar'],
#  ['pego', 'covid', 'através', 'meio'],
#  ['onde', 'começar', 'covid'],
#  ['onde', 'covid'],
#  ['vírus', 'transmitir', 'através', 'meio'],
#  ['significar', 'covid'],
#  ['comorbidade', 'poder', 'tomar', 'vacina'],
#  ['covid', 'família', 'vírus'],
#  ['vacina', 'disponível', 'covid'],
#  ['criança', 'poder', 'vacinar', 'contra', 'covid'],
#  ['bom', 'vacina'],
#  ['vacina', 'contra', 'covid', 'seguro'],
#  ['ter', 'tomar', 'quanto', 'dose', 'vacina'],
#  ['prevenir', 'contagio'],
#  ['covid', 'começar', 'china'],
#  ['covid', 'doença', 'grave'],
#  ['covid', 'grave'],
#  ['covid', 'virus', 'sarscov'],
#  ['covid', 'vírus', 'grave'],
#  ['covid'],
#  ['covid', 'doença', 'grave'],
#  ['covid', 'gripe'],
#  ['covid', 'criar', 'laboratorio'],
#  ['covid', 'vir'],
#  ['covid', 'vir'],
#  ['covid'],
#  ['falar', 'covid'],
#  ['covid'],
#  ['querer', 'dizer', 'covid'],
#  ['virus', 'família', 'covid'],
#  ['covid', 'vir', 'china'],
#  ['virus', 'comum', 'família', 'covid'],
#  ['pegar', 'forma', 'covid'],
#  ['virus', 'comum', 'infectar', 'humano'],
#  ['covid', 'comum'],
#  ['posso', 'pegar'],
#  ['poder', 'dizer', 'covid'],
#  ['meio', 'transmissão', 'covid'],
#  ['pegar', 'covid'],
#  ['covid'],
#  ['poder', 'contaminar'],
#  ['prevenir', 'covid'],
#  ['prevenir'],
#  ['exame', 'covid'],
#  ['diagnóstico', 'covid'],
#  ['saber', 'ter', 'covid'],
#  ['saber', 'contaminado'],
#  ['sintoma', 'covid'],
#  ['covid', 'poder', 'reduzir'],
#  ['ter', 'hiv', 'corrar', 'risco'],
#  ['hiv', 'covid', 'poder', 'grave'],
#  ['hiv', 'correr', 'risco'],
#  ['pandemia', 'ter', 'cobertura', 'laboratório', 'covid'],
#  ['pandemia', 'ter', 'cobertura', 'laboratório', 'diagnostico', 'covid'],
#  ['laboratorio', 'atuar', 'comprovação', 'diagnostico', 'covid'],
#  ['laboratório', 'fazer', 'exame', 'comprovação'],
#  ['laboratorio', 'realizar', 'exame', 'covid'],
#  ['laboratorio', 'realizar', 'exame', 'covid'],
#  ['laboratorio', 'fazer', 'exame', 'identificar', 'covid'],
#  ['laboratorio', 'fazer', 'exame', 'covid'],
#  ['teste', 'ir', 'exame', 'comprovação', 'laboratorio'],
#  ['posso', 'próprio', 'álcool', 'gel'],
#  ['produzir', 'álcool', 'gel'],
#  ['fazer', 'álcool', 'gel'],
#  ['receita', 'álcool', 'gel', 'oms'],
#  ['onde', 'começar', 'pandemia'],
#  ['oms', 'divulgar', 'receita', 'gel', 'pra', 'fazer', 'casa'],
#  ['oximetria', 'baixo'],
#  ['ficar', 'doente', 'fazer'],
#  ['sentir', 'gripar', 'fazer'],
#  ['sintoma', 'fazer'],
#  ['coisa'],
#  ['sentir', 'coisa'],
#  ['funcionário', 'doente', 'trabalho'],
#  ['poder', 'fazer', 'evitar', 'covid', 'local', 'trabalho'],
#  ['prevenir', 'coronavírus'],
#  ['evitar', 'covid', 'trabalho'],
#  ['pegar', 'covid', 'trabalho'],
#  ['identificar', 'covid'],
#  ['principal', 'sintoma'],
#  ['onde', 'pegar', 'covid'],
#  ['pegar', 'covid'],
#  ['pessoa', 'trabalho', 'diagnosticar', 'covid', 'poder', 'ter', 'contaminar'],
#  ['contato', 'paciente', 'covid', 'poder', 'contaminado'],
#  ['pessoa', 'covid', 'poder', 'pegar'],
#  ['sintoma', 'covid'],
#  ['principal', 'sintoma', 'covid'],
#  ['sintoma', 'ter', 'covid'],
#  ['poder', 'saber', 'covid'],
#  ['sintoma', 'covid'],
#  ['dinheiro', 'transmitir', 'covid'],
#  ['dar', 'pra', 'pegar', 'covid', 'dinheiro'],
#  ['poder', 'pegar', 'virus', 'supermercado'],
#  ['pessoa', 'contaminar', 'poder', 'pegar', 'ar'],
#  ['poder', 'pegar', 'virus', 'conta', 'água', 'luz'],
#  ['poder', 'pegar', 'virus', 'embalagem', 'correio'],
#  ['limpar', 'ambiente', 'contaminar', 'poder', 'pegar', 'virus'],
#  ['poder', 'conter', 'virus', 'contaminar'],
#  ['ar', 'poder', 'provocar', 'contaminação', 'virus'],
#  ['poder', 'pegar', 'covid', 'água', 'trabalho'],
#  ['poder', 'pegar', 'covid'],
#  ['poder', 'contrair', 'covid'],
#  ['sempre', 'máscara', 'poder', 'pegar', 'pele'],
#  ['poder', 'pegar', 'covid', 'outro', 'pessoa'],
#  ['máscara', 'corrar', 'risco', 'contagiar'],
#  ['possível', 'pegar', 'covid', 'pessoa', 'apresentar', 'sintoma'],
#  ['posso', 'pegar', 'covid', 'doença'],
#  ['posso', 'pegar', 'coronavírus', 'utilizar', 'público'],
#  ['poder', 'pegar'],
#  ['posso', 'pegar', 'covid', 'mão', 'rosto'],
#  ['poder', 'transmitir', 'covid'],
#  ['pegar', 'covid', 'assintomático'],
#  ['assintomático', 'transmiter', 'covid'],
#  ['parente', 'ter', 'covid', 'ter', 'sintoma'],
#  ['ter', 'sintoma', 'poder', 'transmitir', 'covid'],
#  ['poder', 'ficar', 'contaminar', 'passar'],
#  ['parente', 'ter', 'covid', 'ter', 'sintoma'],
#  ['dar', 'pra', 'pegar', 'covid'],
#  ['dar', 'pra', 'pegar', 'covid'],
#  ['sintoma', 'coronavírus'],
#  ['vírus', 'responsável', 'covid'],
#  ['poder', 'transmitir', 'pessoa', 'pessoa'],
#  ['distância', 'seguro', 'contaminar'],
#  ['distância', 'pequeno', 'contaminar'],
#  ['distância', 'dever', 'manter', 'contaminar'],
#  ['acontecer', 'circulação', 'virus'],
#  ['acontecer', 'circulação', 'coronavírus'],
#  ['encomenda', 'china', 'dever', 'tomar', 'cuidado'],
#  ['seguro', 'receber', 'pacote', 'área', 'covid', 'ter', 'notificar'],
#  ['seguro', 'comprar', 'coisa', 'china'],
#  ['seguro', 'país', 'covid'],
#  ['encomenda', 'área', 'risco', 'ver', 'poder', 'vir', 'contaminar'],
#  ['compra', 'área', 'risco', 'poder', 'vir', 'contaminar'],
#  ['compra', 'ver', 'área', 'risco', 'poder', 'chegar', 'contaminar'],
#  ['encomenda', 'postal', 'área', 'risco', 'poder', 'contaminar'],
#  ['encomenda', 'área', 'infectar', 'ver', 'correio', 'poder', 'contaminar'],
#  ['entrega', 'postal', 'risco', 'poder', 'conter', 'virus'],
#  ['embalagem',
#   'sedex',
#   'produto',
#   'oriundo',
#   'china',
#   'poder',
#   'conter',
#   'virus'],
#  ['embalagem', 'sedex', 'produto', 'poder', 'contaminado'],
#  ['encomenda',
#   'produto',
#   'produzir',
#   'china',
#   'poder',
#   'chegar',
#   'embalagem',
#   'contaminar'],
#  ['risco', 'desenvolver', 'doença', 'grave'],
#  ['produto', 'correr', 'grande', 'risco', 'infecção', 'covid'],
#  ['covid', 'risco', 'grave'],
#  ['poder', 'levar', 'virus', 'pra', 'dentro', 'casa', 'após', 'espaço'],
#  ['poder', 'virus', 'após', 'uso', 'gel'],
#  ['poder', 'manter', 'virus', 'vivo', 'ativo'],
#  ['pele', 'manter', 'virus', 'vivo', 'ativo'],
#  ['roupa', 'poder', 'manter', 'virus', 'vivo', 'ativo'],
#  ['preciso', 'sacola', 'supermercado'],
#  ['quanto', 'tempo', 'virus', 'sobreviver', 'objeto'],
#  ['preciso', 'limpar', 'embalagem', 'comida'],
#  ['deixar', 'roupa', 'coronavírus'],
#  ['preciso', 'lavar', 'embalagem'],
#  ['quanto', 'tempo', 'vírus', 'sobreviver', 'superfície'],
#  ['virus', 'ambiente', 'fechar', 'tempo'],
#  ['tocar', 'superfície', 'corrar', 'risco', 'pegar', 'covid'],
#  ['rosto', 'compartilhar', 'poder', 'passar', 'covid'],
#  ['devo', 'lavar', 'roupa', 'chegar', 'casa'],
#  ['poder', 'infectado'],
#  ['produto', 'supermercado', 'poder', 'infectado'],
#  ['preciso', 'passar', 'álcool', 'gel', 'sacola', 'supermercado'],
#  ['poder',
#   'levar',
#   'virus',
#   'pra',
#   'dentro',
#   'casa',
#   'após',
#   'tocar',
#   'espaço'],
#  ['cadastrar', 'cadastur'],
#  ['gerar', 'cadastro', 'cadastur'],
#  ['novo'],
#  ['cadastur'],
#  ['finalidade', 'cadastur'],
#  ['cadastur', 'obrigatório'],
#  ['cadastur'],
#  ['registro', 'cadastur'],
#  ['cadastur'],
#  ['cadastur'],
#  ['cadastur'],
#  [],
#  [],
#  [],
#  [],
#  ['expliqueme', 'registro', 'cadastur'],
#  ['definame', 'registro', 'cadastur'],
#  ['registro', 'cadastur'],
#  ['cadastur'],
#  ['querer', 'cadastrar'],
#  ['cadastrar'],
#  ['gerar', 'cadastro'],
#  ['cadastro'],
#  ['cadastro'],
#  ['cadastro'],
#  ['preencher', 'cadastro'],
#  ['fazer', 'cadastro'],
#  ['querer', 'cadastrar'],
#  ['querer', 'fazer', 'cadastro'],
#  ['cadastrar', 'agora'],
#  ['fazer', 'cadastro'],
#  ['fazer', 'cadastro'],
#  ['cadastro'],
#  ['querer', 'gerar', 'cadastro'],
#  ['fazer', 'cadastrar'],
#  ['cadastrar'],
#  ['preencher', 'cadastramento'],
#  ['fazer', 'cadastramento'],
#  ['cadastramento'],
#  ['criar', 'cadastro'],
#  ['falabr'],
#  ['denunciar', 'ouvidorio'],
#  ['ouvidorio'],
#  ['falar', 'ouvidoria', 'acesso', 'informação'],
#  ['ouvidorio'],
#  ['ouvidorio', 'acesso', 'informação'],
#  ['geral'],
#  [],
#  ['central', 'atendimento', 'cidadão'],
#  ['falabr', 'ouvidoria', 'acesso', 'informação'],
#  ['atendimento', 'cidadão'],
#  ['atendimento'],
#  ['atendimento'],
#  ['querer',
#   'denunciar',
#   'descumprimento',
#   'protocolo',
#   'higiente',
#   'orientar',
#   'selo'],
#  ['poder',
#   'denunciar',
#   'descumprimento',
#   'medida',
#   'higiente',
#   'orientar',
#   'selo'],
#  ['descumprimento',
#   'protocolo',
#   'medida',
#   'proteção',
#   'segurança',
#   'sanitário'],
#  ['denunciar',
#   'descumprimento',
#   'medida',
#   'proteção',
#   'segurança',
#   'sanitário',
#   'recomendar',
#   'selo'],
#  ['querer',
#   'denunciar',
#   'descumprimento',
#   'medida',
#   'higiente',
#   'orientar',
#   'selo'],
#  ['fazer', 'denúncia', 'referente', 'estabelecimento', 'cumprir', 'saúde'],
#  ['denúncia',
#   'referente',
#   'estabelecimento',
#   'descumprimento',
#   'medida',
#   'proteção',
#   'segurança',
#   'sanitário'],
#  ['estabelecimento', 'querer', 'continuar', 'responsavel'],
#  ['estabelecimento', 'querer', 'cancelar', 'selo'],
#  ['ter', 'adesão', 'selo'],
#  ['querer', 'retirar', 'adesão', 'selo', 'turismo', 'responsavel'],
#  ['possível', 'prestador', 'serviço', 'turístico', 'retirar', 'adesão', 'selo'],
#  ['ter', 'interesse', 'usar', 'selo', 'estabelecimento'],
#  ['querer', 'programa', 'selo', 'turismo'],
#  ['participar', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['ir', 'cancelar', 'selo', 'fazer'],
#  ['querer', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['querer', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['querer', 'sair', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['fazer', 'cancelar', 'selo', 'turismo', 'reponsavel'],
#  ['estabelecimento', 'querer', 'sair', 'programa', 'selo', 'turismo'],
#  ['conseguir', 'ter', 'acesso', 'todo', 'publicitário'],
#  ['dar', 'erro', 'emissão', 'selo'],
#  ['aparecer', 'nada', 'exportar', 'peça', 'promocional'],
#  ['após', 'emissão', 'exportar', 'peça', 'promocional', 'nada', 'aparecer'],
#  ['selo', 'ocorrer', 'erro'],
#  ['selo', 'aparecer', 'proceder'],
#  ['aderir', 'selo', 'preciso', 'peça', 'promocional', 'fazer'],
#  ['aparecer', 'opção', 'exportar', 'peça', 'promocional'],
#  ['exportar', 'peça', 'promocional'],
#  ['selo', 'continua', 'ativo', 'verifico'],
#  ['saber', 'selo', 'continua', 'ativado'],
#  ['saber', 'selo'],
#  ['preciso', 'saber', 'situação', 'selo', 'ativado'],
#  ['ver', 'selo'],
#  ['verificar', 'selo', 'empreendimento', 'continua', 'ativo'],
#  ['verificar', 'selo', 'empreendimento', 'ativo'],
#  ['quero', 'ver', 'selo', 'ativo', 'turistas'],
#  ['saber', 'selo', 'continua', 'ativo'],
#  ['verifico', 'selo', 'ativo'],
#  ['faço', 'saber', 'selo', 'ativo'],
#  ['saber', 'selo', 'ativo', 'prestador'],
#  ['vejo', 'selo', 'ativado'],
#  ['saber', 'selo', 'ativado', 'proceder'],
#  ['protocolo', 'garantir', 'proteção', 'segurança', 'sanitário'],
#  ['protocolo', 'necessário', 'tipo', 'estabelecimento'],
#  ['protocolo', 'necessário'],
#  ['protocolo', 'praticar', 'programa', 'selo', 'turista', 'responsavel'],
#  ['protocolo', 'estabelecir', 'programa', 'selo', 'turista', 'responsavel'],
#  ['protocolo', 'exigir', 'empreendimento', 'turistico'],
#  ['protocolo', 'devo', 'seguir'],
#  ['protocolo', 'recomendar'],
#  ['protocolo', 'geral'],
#  ['protocolo', 'especifico'],
#  ['protocolo'],
#  ['protocolo'],
#  ['onde', 'pesquiso', 'protocolo', 'hotel'],
#  ['protocolo', 'medida', 'proteção', 'segurança', 'hospedagem'],
#  ['ter', 'hotel', 'protocolo', 'dever', 'seguir'],
#  ['ter', 'hotel', 'protocolo', 'praticar'],
#  ['protocolo', 'ter', 'adotar', 'hotel'],
#  ['hotel', 'dever', 'seguir', 'protocolo'],
#  ['protocolo', 'bom', 'pratica', 'hospedagem'],
#  ['medida', 'especifico', 'protocolo', 'hospedagem'],
#  ['hotel', 'dever', 'seguir', 'medida', 'especifico', 'protocolo'],
#  ['hotel', 'ter', 'protocolo', 'especifico'],
#  ['existir', 'protocolo', 'especifico', 'meio', 'hospedagem'],
#  ['meio', 'hospedagem'],
#  ['setor', 'hoteleiro', 'possuira', 'protocolo', 'especifico'],
#  ['recomendaçoes', 'hotel'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['resorts'],
#  ['pensão'],
#  ['pousada'],
#  ['estalagem'],
#  ['estalagem', 'pensão'],
#  ['hotel'],
#  ['protocolo', 'hotelaria', 'hospedagem'],
#  ['protocolo', 'rede', 'hotel'],
#  ['protocolo', 'hotel'],
#  ['protocolo', 'hospedagem'],
#  ['recomendação'],
#  ['recomendação', 'hospedagem'],
#  ['recomendação', 'hotel'],
#  ['recomendaçoes', 'meio', 'hospedagem'],
#  ['onde', 'achar', 'protocolo', 'setor', 'hoteleiro'],
#  ['onde', 'pesquiso', 'protocolo', 'setor', 'hoteleito'],
#  ['onde', 'ver', 'protocolo', 'setor', 'hoteleito'],
#  ['setor', 'hoteleiro', 'protocolo', 'dever', 'seguir'],
#  ['protocolo', 'seguir', 'hotel'],
#  ['protocolo', 'setor', 'hoteleiro'],
#  ['setor', 'hoteleiro', 'possuira', 'protocolo'],
#  ['setor', 'hoteleiro', 'cumprir', 'protocolo', 'especifico'],
#  ['protocolo', 'recomendar', 'meio', 'hospedagem'],
#  ['protocolo', 'recomendar', 'hotel', 'pousada', 'resorts'],
#  ['protocolo', 'estabelecer', 'hotelaria'],
#  ['protocolo', 'setor', 'meios', 'hospedagem'],
#  ['interessado',
#   'dever',
#   'atender',
#   'orientação',
#   'protocolo',
#   'destinar',
#   'atividade',
#   'turistico',
#   'atuar'],
#  ['meio', 'atender', 'prérequisito', 'solicitar', 'adesão', 'selo'],
#  ['empreendimentos', 'poderão', 'aderir', 'ter', 'acesso', 'selo'],
#  ['dar', 'novo', 'orientação', 'higiene', 'farei', 'atualizar'],
#  ['dar', 'atualização', 'protocolo'],
#  ['protocolo', 'atualização', 'frequente'],
#  ['protocolo', 'sera', 'atualizar'],
#  ['protocolo', 'mudar'],
#  ['protocolo', 'documento', 'único', 'poder', 'atualizar'],
#  ['ter', 'outro', 'higiene', 'atualizar'],
#  ['sera', 'atualização', 'informar', 'novo', 'medida', 'higiene'],
#  ['atualizar', 'informar', 'novo', 'medida', 'higiene'],
#  ['informar', 'novo', 'recomendaçoes', 'higiene', 'atualizar'],
#  ['ir',
#   'manter',
#   'atualizar',
#   'novo',
#   'orientaçoes',
#   'higiene',
#   'divulgar',
#   'mtur'],
#  ['sair', 'novo', 'orientaçoes', 'higiene', 'ir', 'atualizar', 'selo'],
#  ['ficar', 'saber', 'novo', 'orientação', 'tipo', 'estabelecimento'],
#  ['ficar', 'saber', 'novo', 'orientação', 'higiene', 'tipo', 'estabelecimento'],
#  ['sempre',
#   'ministerio',
#   'turismo',
#   'divulgar',
#   'novo',
#   'orientação',
#   'higiene',
#   'devo',
#   'atualizar',
#   'selo'],
#  ['novo', 'orientação', 'higiene', 'divulgar', 'mtur', 'fazer'],
#  ['selo', 'sempre', 'atualizar', 'surgir', 'novo', 'orientação', 'higiene'],
#  ['caso', 'surgir', 'novo', 'orientação', 'higiene', 'atualizar', 'selo'],
#  ['caso', 'surgir', 'novo', 'orientação', 'higiene', 'preciso', 'novo', 'selo'],
#  ['medida', 'higiene', 'sanitar', 'atualização', 'preciso', 'fazer', 'selo'],
#  ['medida',
#   'higiene',
#   'sanitar',
#   'atualização',
#   'preciso',
#   'baixar',
#   'novo',
#   'selo'],
#  ['medida',
#   'higiene',
#   'sanitaria',
#   'protocolo',
#   'ter',
#   'atualização',
#   'frequente'],
#  ['medida',
#   'higiene',
#   'sanitar',
#   'recomendar',
#   'selo',
#   'ter',
#   'atualização',
#   'frequente'],
#  ['medida',
#   'higiene',
#   'sanitar',
#   'estabelecir',
#   'selo',
#   'ter',
#   'atualização',
#   'frequente'],
#  ['protocolo', 'estabelecer', 'selo', 'ter', 'atualização'],
#  ['protocolo', 'documento', 'único'],
#  ['quais',
#   'critérios',
#   'ministério',
#   'turismo',
#   'formulação',
#   'desses',
#   'protocolos'],
#  ['quais',
#   'critérios',
#   'utilizados',
#   'ministério',
#   'turismo',
#   'formulação',
#   'desses',
#   'protocolos'],
#  ['quais',
#   'critérios',
#   'utilizados',
#   'mtur',
#   'formulação',
#   'desses',
#   'protocolos'],
#  ['protocolo',
#   'propor',
#   'submetir',
#   'crivo',
#   'técnico',
#   'agência',
#   'nacional',
#   'vigilância',
#   'sanitária',
#   'anvisa',
#   'ministério',
#   'saúde'],
#  ['protocolo',
#   'validados',
#   'agência',
#   'nacional',
#   'vigilância',
#   'sanitária',
#   'anvisa'],
#  ['adoção',
#   'protocolo',
#   'selo',
#   'levar',
#   'consideração',
#   'medida',
#   'adotar',
#   'entidade',
#   'internacional',
#   'similar'],
#  ['adoção',
#   'protocolo',
#   'levar',
#   'conta',
#   'protocolo',
#   'medida',
#   'adotar',
#   'entidade',
#   'internacional'],
#  ['protocolo', 'propor', 'validados', 'ministério', 'saúde'],
#  ['critérios', 'formulação', 'protocolos', 'validar', 'anvisa'],
#  ['protocolo'],
#  ['protocolo', 'propor', 'validar', 'anvisa'],
#  ['protocolo', 'profissional', 'setor'],
#  ['protocolo', 'selo', 'ter', 'anvisa'],
#  ['protocolo',
#   'levar',
#   'consideração',
#   'medida',
#   'adotar',
#   'entidade',
#   'internacional',
#   'similar'],
#  ['protocolo',
#   'submetir',
#   'crivo',
#   'técnico',
#   'agência',
#   'nacional',
#   'vigilância',
#   'sanitária',
#   'anvisa'],
#  ['uso',
#   'selo',
#   'representa',
#   'custo',
#   'adicional',
#   'valor',
#   'serviços',
#   'turísticos'],
#  ['selo', 'representará', 'custo', 'valor', 'serviços', 'turísticos'],
#  ['ter',
#   'custo',
#   'adicional',
#   'medida',
#   'impor',
#   'selo',
#   'poder',
#   'cobrar',
#   'serviço'],
#  ['ter',
#   'custo',
#   'adicional',
#   'medida',
#   'impor',
#   'selo',
#   'poder',
#   'embutir',
#   'serviço',
#   'turistico'],
#  ['despesa',
#   'adicional',
#   'protocolo',
#   'higiente',
#   'poder',
#   'embutir',
#   'custo',
#   'serviço',
#   'turistico'],
#  ['selo', 'poder', 'ratear', 'despesa', 'higiene', 'taxa', 'serviço'],
#  ['poder',
#   'ratear',
#   'despesa',
#   'higiene',
#   'taxa',
#   'serviço',
#   'aderir',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['poder',
#   'ratear',
#   'despesa',
#   'higiene',
#   'taxa',
#   'serviço',
#   'empreendimento',
#   'aderir',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['ter', 'selo', 'farei', 'compensar', 'despesa', 'extro', 'medida', 'higiene'],
#  ['selo',
#   'exigir',
#   'vario',
#   'controle',
#   'higiene',
#   'fazer',
#   'compensar',
#   'despesa',
#   'extro'],
#  ['selo',
#   'exigir',
#   'vario',
#   'medida',
#   'segurança',
#   'higiene',
#   'fazer',
#   'compensar',
#   'despesa',
#   'extro'],
#  ['farei', 'despesa', 'extraordinario', 'selo', 'turismo', 'responsavel'],
#  ['governo',
#   'reduzira',
#   'imposto',
#   'compensar',
#   'despesa',
#   'extraordinario',
#   'impor',
#   'uso',
#   'selo'],
#  ['diária', 'valor', 'maior', 'aderir', 'selo', 'turismo', 'responsavel'],
#  ['diária', 'valor', 'maior', 'despesa', 'medida', 'higiene'],
#  ['diária', 'valor', 'maior', 'compensar', 'despesa', 'medida', 'higiene'],
#  ['posso',
#   'aumentar',
#   'valor',
#   'diária',
#   'custo',
#   'medida',
#   'segurança',
#   'selo'],
#  ['posso',
#   'aumentar',
#   'valor',
#   'taxa',
#   'serviço',
#   'medida',
#   'higiene',
#   'impor',
#   'selo'],
#  ['medida',
#   'higiene',
#   'impor',
#   'selo',
#   'posso',
#   'aumentar',
#   'valor',
#   'taxa',
#   'serviço'],
#  ['governo',
#   'reduzira',
#   'imposto',
#   'compensar',
#   'despesa',
#   'extro',
#   'medida',
#   'higiene',
#   'exigir',
#   'selo'],
#  ['perspectiva',
#   'acréscimo',
#   'valor',
#   'serviço',
#   'prestar',
#   'adoção',
#   'medida'],
#  ['após',
#   'adoção',
#   'medida',
#   'recomendar',
#   'perspectiva',
#   'acréscimo',
#   'valor',
#   'serviço',
#   'prestar'],
#  ['após',
#   'adoção',
#   'medida',
#   'recomendar',
#   'previsão',
#   'aumento',
#   'valor',
#   'serviço',
#   'prestar'],
#  ['variação',
#   'taxas',
#   'serviços',
#   'devido',
#   'custo',
#   'adicional',
#   'imposto',
#   'protocolo'],
#  ['variação',
#   'taxas',
#   'serviços',
#   'devido',
#   'custo',
#   'adicional',
#   'imposto',
#   'medidas',
#   'higiene'],
#  ['preços', 'acrescimos', 'devido', 'implementação', 'medidas'],
#  ['preços', 'acrescimos', 'devido', 'implementação', 'medidas', 'higiene'],
#  ['preços', 'devido', 'custo', 'higiene', 'sanitaria'],
#  ['preços',
#   'comprometidos',
#   'maior',
#   'gasto',
#   'produtos',
#   'higiene',
#   'sanitaria'],
#  ['preços',
#   'comprometidos',
#   'maior',
#   'gasto',
#   'produtos',
#   'limpeza',
#   'higiene'],
#  ['preços', 'aumento', 'devido', 'maior', 'produtos', 'limpeza', 'higiene'],
#  ['diária', 'valor', 'maior', 'estabelecimentos', 'selo'],
#  ['havera',
#   'variação',
#   'taxas',
#   'serviços',
#   'devido',
#   'custo',
#   'medidas',
#   'impostas',
#   'selo'],
#  ['variação',
#   'taxas',
#   'serviços',
#   'devido',
#   'custo',
#   'adicional',
#   'imposto',
#   'selo'],
#  ['selo', 'representará', 'custo', 'valor', 'taxas', 'serviços', 'turísticos'],
#  ['selo', 'aumento', 'taxas', 'serviços'],
#  ['selo', 'estabelecimentos', 'taxas', 'serviços'],
#  ['taxas', 'serviços', 'adoção', 'selo'],
#  ['havera',
#   'variação',
#   'taxas',
#   'serviços',
#   'devido',
#   'medidas',
#   'impostas',
#   'selo'],
#  ['onde', 'vejo', 'medida', 'especifico', 'tipo', 'estabelecimento'],
#  ['clientes', 'saber', 'exigir', 'estabelecimento', 'relação', 'higiene'],
#  ['clientes', 'poderão', 'exigir', 'estabelecimento', 'relação', 'higiene'],
#  ['clientes',
#   'poderão',
#   'bom',
#   'prática',
#   'higienização',
#   'cada',
#   'segmento',
#   'setor',
#   'turistico'],
#  ['clientes',
#   'poderão',
#   'exigir',
#   'conformidade',
#   'bom',
#   'prática',
#   'higienização'],
#  ['bom', 'prática', 'higienização', 'poderão', 'clientes'],
#  ['saber', 'conformidade', 'medida', 'tipo', 'estabelecimento'],
#  ['exigir', 'conformidade', 'estabelecimentos', 'protocolos'],
#  ['qto', 'custar', 'selo'],
#  ['qto', 'custar', 'selo'],
#  ['precisa', 'pagar'],
#  [],
#  ['gratuito'],
#  ['ter', 'algum', 'custo'],
#  ['ter', 'custo'],
#  ['taxa', 'cobrar', 'selo', 'turista', 'responsavel'],
#  ['preciso',
#   'pagar',
#   'pedir',
#   'selo',
#   'turista',
#   'responsavel',
#   'estabelecimento'],
#  ['ter', 'taxa', 'obter', 'selo', 'turista', 'responsavel'],
#  ['ter', 'taxa', 'usar', 'selo', 'turista', 'responsavel'],
#  ['ter', 'pagar', 'ter', 'selo', 'turista', 'responsavel', 'empreendimento'],
#  ['preciso',
#   'recolher',
#   'alguma',
#   'taxa',
#   'aderir',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['preciso',
#   'recolher',
#   'alguma',
#   'taxa',
#   'ter',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['preciso', 'pagar', 'ter', 'selo', 'turista', 'responsavel'],
#  ['taxas', 'aderir', 'programa', 'selo', 'turista', 'responsável'],
#  ['interessado', 'usar', 'selo', 'precisa', 'pagar', 'alguma', 'coisa'],
#  ['pagar', 'algum', 'taxa', 'usar', 'selo', 'turista', 'responsavel'],
#  ['ter', 'selo', 'turista', 'responsavel', 'quanto', 'ter', 'pagar'],
#  ['pedir', 'selo', 'turista', 'responsavel', 'quanto', 'ter', 'pagar'],
#  ['requerer', 'selo', 'turista', 'responsavel', 'quanto', 'ter', 'pagar'],
#  ['querer', 'ter', 'selo', 'valor', 'selo', 'turista', 'responsavel'],
#  ['valor', 'cobrar', 'selo', 'turista', 'responsavel'],
#  ['interessado', 'tirar', 'selo', 'precisar', 'pagar', 'algum', 'coisa'],
#  ['quanto', 'custar', 'pra', 'tirar'],
#  ['quanto', 'pagar', 'pra', 'tirar'],
#  ['quanto', 'ter', 'pagar', 'tirar'],
#  ['quanto', 'custar', 'selo'],
#  ['valor', 'selo'],
#  ['quanto', 'custar', 'selo'],
#  ['quanto', 'custar', 'selo'],
#  ['quanto', 'custar', 'dois', 'selo'],
#  ['quanto', 'custar', 'selo'],
#  ['qto', 'pagar'],
#  ['quanto', 'pagar'],
#  ['qto', 'pagar'],
#  ['quanto', 'pagar'],
#  ['segue', 'protocolo', 'higiene'],
#  ['selo', 'visivel', 'segue', 'medidas', 'higiene'],
#  ['selo', 'visivel', 'segue', 'protocolo', 'segurança'],
#  ['pra', 'selo', 'cumprindo', 'protocolo'],
#  ['irregularidade', 'controle', 'empreendimentos', 'selo'],
#  ['turista', 'identificar', 'alguma', 'irregularidade', 'local', 'usa', 'selo'],
#  ['turista',
#   'identificar',
#   'alguma',
#   'irregularidade',
#   'deverá',
#   'feito',
#   'proceder'],
#  ['turista',
#   'identificar',
#   'alguma',
#   'conformidade',
#   'local',
#   'usa',
#   'selo',
#   'deverá',
#   'feito'],
#  ['local', 'onde', 'hospedei', 'selo', 'cheio', 'irregularidade', 'faço'],
#  ['local', 'onde', 'hospedei', 'selo', 'cheio', 'irregularidade', 'proceder'],
#  ['selo', 'adiantou', 'nada', 'empreendimento'],
#  ['selo', 'adiantou', 'nada', 'empreendimento', 'cumprindo', 'protocolos'],
#  ['selo', 'adiantou', 'nada', 'empreendimento', 'cumprindo', 'recomendações'],
#  ['ter', 'selo', 'lugar', 'cumprindo', 'medidas', 'higiene'],
#  ['obrigatório', 'uso', 'selo', 'turismo', 'responsável'],
#  ['ministério', 'turismo', 'tornar', 'obrigatório', 'uso', 'selo'],
#  ['selo', 'obrigatorior'],
#  ['obrigar', 'usar', 'selo', 'estabelecimento'],
#  ['obrigatoriedade'],
#  ['obrigatorior'],
#  ['multar', 'ter', 'selo', 'turista', 'responsavel'],
#  ['aderir', 'selo', 'turista', 'responsavel', 'acontecer'],
#  ['lei', 'obrigar', 'ter', 'selo', 'turista', 'responsavel'],
#  ['ter', 'algum', 'lei', 'obrigar', 'uso', 'selo'],
#  ['ter', 'algum', 'lei', 'obrigar', 'uso', 'selo', 'turismo', 'responsavel'],
#  ['punição',
#   'empreendimento',
#   'aderir',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['punição',
#   'estabelecimento',
#   'aderir',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['obrigar', 'selo'],
#  ['uso', 'selo', 'obrigatorior'],
#  ['obrigatorio', 'usar', 'selo'],
#  ['nao', 'ter', 'selo', 'turista', 'responsavel', 'ter', 'pagar'],
#  ['nao', 'ter', 'selo', 'turista', 'responsavel', 'ter', 'punição', 'punição'],
#  ['selo', 'turista', 'responsavel', 'ter', 'punição', 'punição'],
#  ['ter', 'selo', 'turista', 'responsavel', 'visivel', 'turista'],
#  ['poder', 'multar', 'ter', 'selo', 'turismo', 'responsavel'],
#  ['poder', 'fiscalizar', 'ter', 'selo', 'turismo', 'responsavel'],
#  ['estabelecimento', 'voltar', 'funcionar', 'preciso', 'ter', 'selo'],
#  ['obrigatorio',
#   'usar',
#   'selo',
#   'turismo',
#   'responsavel',
#   'voltar',
#   'atividade'],
#  ['obrigatorio', 'usar', 'selo', 'turismo', 'responsavel', 'funcionar'],
#  ['obrigar', 'usar', 'selo', 'empreendimento'],
#  ['selo', 'turismo'],
#  ['programa', 'selo', 'turismo', 'responsável'],
#  ['definer', 'selo', 'turismo', 'responsavel'],
#  ['selo'],
#  ['servir', 'selo', 'turismo', 'responsavel'],
#  ['papel', 'selo', 'turismo', 'responsavel'],
#  ['finalidade', 'selo'],
#  ['finalidade', 'selo', 'turismo'],
#  ['papel', 'selo', 'turismo', 'retomada', 'atividade', 'turistico', 'brasil'],
#  ['programa', 'selo', 'turismo', 'responsavel', 'adotar', 'medida', 'eficaz'],
#  ['destinar', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['finalidade', 'programa', 'estabelecer', 'selo', 'turismo', 'responsavel'],
#  ['finalidade', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['governo', 'brasileiro', 'esperar', 'selo'],
#  ['brasil',
#   'incentivar',
#   'adesão',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['governo', 'incentivar', 'uso', 'selo', 'turista', 'responsavel'],
#  ['programa',
#   'selo',
#   'turista',
#   'responsavel',
#   'seguir',
#   'bom',
#   'pratica',
#   'higienização',
#   'ambiente'],
#  ['selo', 'turismo', 'responsavel'],
#  ['selo', 'responsavel'],
#  ['selo'],
#  ['selo', 'turismo', 'responsavel'],
#  ['selo'],
#  ['selo', 'turismo'],
#  ['selo', 'responsavel', 'seguro'],
#  ['programa', 'turismo', 'responsavel'],
#  ['programa'],
#  ['pra', 'servir'],
#  ['servir', 'selo'],
#  ['onde', 'vejer', 'ja', 'protocolo', 'selo'],
#  ['existir', 'algum', 'onde', 'poder', 'ver', 'empresa', 'adotar', 'selo'],
#  ['ter', 'algum', 'painel', 'dizer', 'empresa', 'ja', 'aderir', 'selo'],
#  ['onde',
#   'achar',
#   'relação',
#   'empreendimento',
#   'turistico',
#   'aderir',
#   'selo',
#   'turismo'],
#  ['onde', 'achar', 'relação', 'empresa', 'aderir', 'selo', 'turismo'],
#  ['onde',
#   'consulto',
#   'estabelecimento',
#   'ja',
#   'aderir',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['prestador', 'serviço', 'turistico', 'ja', 'aderir', 'selo'],
#  ['ja', 'aderir', 'selo'],
#  ['saber', 'empreendimento', 'aderir', 'selo'],
#  ['pesquiso', 'prestador', 'serviço', 'turistico', 'habilitar', 'selo'],
#  ['pesquiso', 'prestador', 'habilitar'],
#  ['pesquiso', 'hotel', 'ja', 'aderiu', 'selo'],
#  ['pesquiso', 'ja', 'aderiu', 'selo'],
#  ['estado', 'quantos', 'empreendimentos', 'turisticos', 'ja', 'aderiram'],
#  ['onde', 'consulto', 'estabelecimento', 'ja', 'aderir', 'selo'],
#  ['observei', 'aumento', 'número', 'selo', 'painel', 'acompanhamento'],
#  ['observei', 'redução', 'número', 'selo', 'painel', 'acompanhamento'],
#  ['verifico', 'quantos', 'empreendimentos', 'aderiram', 'selo'],
#  ['aderiu', 'selo'],
#  ['empreendimentos', 'aderiram', 'programa', 'selo', 'turismo'],
#  ['faço', 'saber', 'empreendimentos', 'aderiram', 'programa', 'selo'],
#  ['pesquiso',
#   'quais',
#   'empresas',
#   'aderiram',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['consulto',
#   'quais',
#   'empresas',
#   'aderiram',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['funciona', 'painel', 'selo'],
#  ['preciso', 'saber', 'empreendimento', 'fazer', 'selo'],
#  ['ir',
#   'viajar',
#   'querer',
#   'pequisar',
#   'estabelecimento',
#   'habilitar',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['ir',
#   'viajar',
#   'querer',
#   'pequisar',
#   'estabelecimento',
#   'cadastrado',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['preciso', 'saber', 'estabelecimento', 'adotar', 'selo'],
#  ['estabelecimento', 'ja', 'adotar', 'selo'],
#  ['onde', 'vejer', 'ja', 'adotar', 'selo'],
#  ['existir', 'prazo', 'emissão', 'selo'],
#  ['prazo', 'entrega'],
#  ['previsão', 'entrega', 'selo'],
#  ['demor', 'receber', 'selo'],
#  ['quanto', 'tempo', 'solicitação'],
#  ['quanto', 'tempo', 'demor', 'ter', 'selo'],
#  ['quanto', 'tempo', 'levar', 'selo'],
#  ['ter', 'esperar', 'quanto', 'tempo', 'receber', 'selo'],
#  ['previsão', 'entrega', 'selo'],
#  ['ter', 'esperar', 'quanto', 'tempo', 'receber', 'selo'],
#  ['solicitação', 'esperar', 'tempo'],
#  ['previsão', 'prazo', 'ter', 'selo'],
#  ['quanto', 'demor', 'pedido', 'selo', 'ate', 'liberação'],
#  ['quanto', 'tempo', 'gastar', 'pedido', 'ate', 'liberação', 'selo'],
#  ['quanto', 'tempo', 'gastar', 'pedido', 'ate', 'selo'],
#  ['quanto', 'tempo', 'gastar', 'pedido', 'ate', 'selo'],
#  ['pedir', 'selo', 'quanto', 'tempo'],
#  ['cadastro', 'receber', 'selo'],
#  ['cadastro', 'conseguir', 'selo'],
#  ['ter', 'acesso', 'selo'],
#  ['querer', 'solicitar', 'selo', 'turista', 'responsável'],
#  ['querer', 'pedir', 'selo', 'turista', 'responsável'],
#  ['querer', 'inscrever', 'programa', 'selo', 'turista', 'responsável'],
#  ['procedimento', 'solicitar', 'selo', 'turista', 'responsavel'],
#  ['solicitar', 'selo', 'turista', 'responsavel'],
#  ['querer', 'ter', 'selo'],
#  ['fazer', 'adesão', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['fazer', 'solicitar', 'selo', 'turista', 'responsavel'],
#  ['fazer', 'pedir', 'selo', 'turista', 'responsavel'],
#  ['processo', 'solicitação', 'selo', 'turista', 'responsável'],
#  ['querer', 'selo', 'turismo', 'responsavel', 'estabelecimento'],
#  ['querer', 'conseguir', 'turismo', 'responsavel', 'estabelecimento'],
#  ['querer', 'pedir', 'selo', 'turismo', 'responsavel', 'estabelecimento'],
#  [],
#  ['pleitear', 'selo', 'turismo', 'responsavel'],
#  ['preciso', 'selo', 'turismo', 'responsavel', 'fazer', 'pedido'],
#  ['querer', 'solicitar', 'selo', 'turismo'],
#  ['preciso', 'ajuda', 'pedir', 'selo', 'turismo', 'responsavel'],
#  ['ajuda', 'pedir', 'selo', 'turista', 'responsavel'],
#  ['preciso', 'orientação', 'pedir', 'selo', 'turista', 'responsavel'],
#  ['onde', 'poder', 'pedir', 'selo', 'turista', 'responsavel'],
#  ['lugar', 'posso', 'pedir', 'selo', 'turista', 'responsavel'],
#  ['procedimento', 'pedir', 'selo'],
#  ['orientação', 'dever', 'seguir', 'obter', 'selo'],
#  ['cadastrar', 'obter', 'selo'],
#  ['solicitar', 'selo', 'turismo', 'responsável'],
#  ['empresa', 'setor', 'turismo', 'devo', 'pedir', 'selo'],
#  ['devo', 'pedir', 'selo', 'empresa', 'setor', 'turismo'],
#  ['outro',
#   'empresa',
#   'setor',
#   'turistico',
#   'dever',
#   'solicitar',
#   'selo',
#   'cada'],
#  ['ter', 'empresa', 'setor', 'turistico', 'dever', 'solicitar', 'selo', 'cada'],
#  ['ter', 'empreendimento', 'turismo', 'selo', 'cada'],
#  ['ter',
#   'vario',
#   'estabelecimento',
#   'turismo',
#   'preciso',
#   'ter',
#   'selo',
#   'cada'],
#  ['ter', 'empresa', 'setor', 'turistico', 'preciso', 'selo', 'cada'],
#  ['preciso', 'ter', 'selo', 'cada', 'empreendimento'],
#  ['fazer', 'conseguir', 'selo'],
#  ['processo', 'solicitação', 'selo'],
#  ['preciso', 'participar'],
#  ['querer'],
#  ['fazer'],
#  ['necessário'],
#  ['cadastrar', 'receber', 'selo'],
#  ['governo',
#   'fiscalizar',
#   'empreendimentos',
#   'ver',
#   'conformidade',
#   'medidas',
#   'necessárias'],
#  ['interesse', 'cumprimento', 'protocolo', 'proprio', 'empreendedor'],
#  ['interesse',
#   'cumprimento',
#   'medida',
#   'sanitaria',
#   'proteção',
#   'proprio',
#   'empreendedor'],
#  ['avaliar', 'empreendimento', 'seguir', 'protocolo', 'estabelecer'],
#  ['avaliar', 'empreendimento', 'seguir', 'recomendaçoes', 'protocolo'],
#  ['mtur',
#   'verificar',
#   'empreendimentos',
#   'adotando',
#   'medidas',
#   'necessárias',
#   'ter',
#   'acesso',
#   'selo'],
#  ['ministério',
#   'turismo',
#   'pode',
#   'ter',
#   'empreendimentos',
#   'adotando',
#   'medidas',
#   'necessárias',
#   'ter',
#   'acesso',
#   'selo'],
#  ['ministério',
#   'turismo',
#   'empreendimentos',
#   'adotando',
#   'medidas',
#   'necessárias',
#   'protocolo'],
#  ['empreendimentos', 'adotando', 'medidas', 'necessárias'],
#  ['empreendimentos', 'adotando', 'medidas', 'necessárias'],
#  ['empreendimento', 'fiscalizar'],
#  ['empresa', 'fiscalizar'],
#  ['fara', 'fiscalização', 'estabelecimentos'],
#  ['fara', 'fiscalização', 'ver', 'empreendimentos', 'seguindo', 'protocolo'],
#  ['fara', 'fiscalização', 'ver', 'empreendimentos', 'seguindo'],
#  ['fara',
#   'fiscalização',
#   'ver',
#   'empreendimentos',
#   'seguindo',
#   'recomendações'],
#  ['governo', 'ira', 'fiscalizar', 'todos', 'empreendimentos', 'selo'],
#  ['fara', 'vistoria', 'empreendimentos', 'adotaram', 'selo'],
#  ['mtur', 'fiscalizar', 'empreendimentos', 'selo'],
#  ['fiscalizados', 'adotaram', 'selo'],
#  ['empreendimento', 'selo'],
#  ['periodicidade', 'selo'],
#  ['periodicidade', 'selo'],
#  ['quanto', 'quanto', 'tempo', 'estabelecimentos', 'fiscalizados'],
#  ['quanto', 'quanto', 'tempo', 'estabelecimentos', 'vistoria'],
#  ['mtur', 'ira', 'fiscalizar', 'todos', 'empreendimentos', 'selo'],
#  ['sanitaria', 'fara', 'empreendimentos', 'selo'],
#  ['fara', 'fiscalização', 'empreendimentos', 'adotaram', 'selo'],
#  [],
#  ['fiscalização'],
#  ['protocolo'],
#  ['expliquar', 'sobre', 'protocolo'],
#  ['esclareçame', 'sobre', 'protocolo'],
#  ['esclarecer', 'protocolo'],
#  ['definame', 'protocolo'],
#  ['diga', 'protocolo'],
#  ['protocolo'],
#  ['protocolo'],
#  ['protocolo'],
#  ['tirar', 'protocolo'],
#  ['funciona', 'protocolo', 'turistas'],
#  ['mtur', 'selo', 'turismo', 'responsavel'],
#  ['selo',
#   'turismo',
#   'responsável',
#   'representa',
#   'turista',
#   'brasileiro',
#   'estrangeiro'],
#  ['representar', 'selo', 'turismo', 'responsavel', 'turista', 'brasileiro'],
#  ['representar', 'selo', 'turismo', 'responsavel', 'turista', 'estrangeiro'],
#  ['selo', 'brasil', 'destino', 'proteger', 'responsável', 'turista'],
#  ['selo', 'brasil', 'destino', 'proteger', 'responsável', 'turista'],
#  ['turista', 'seguro', 'empreendimento', 'adotar', 'selo'],
#  ['turista',
#   'oriundo',
#   'exterior',
#   'representar',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['turista',
#   'vir',
#   'exterior',
#   'representar',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['pq', 'aderir'],
#  ['turista',
#   'sentir',
#   'seguro',
#   'empreendimento',
#   'adotar',
#   'protocolo',
#   'estabelecir',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['selo',
#   'turismo',
#   'responsavel',
#   'adotar',
#   'medida',
#   'sanitário',
#   'higiene',
#   'seguro',
#   'turista'],
#  ['selo',
#   'turismo',
#   'responsavel',
#   'adotar',
#   'medida',
#   'sanitário',
#   'higiene',
#   'turista'],
#  ['selo',
#   'turismo',
#   'responsavel',
#   'atender',
#   'sanitário',
#   'higiene',
#   'turista'],
#  ['pq', 'importante'],
#  ['beneficio', 'usar', 'selo'],
#  ['usar', 'selo'],
#  ['vantagem', 'usar', 'selo'],
#  ['ganhar', 'uso'],
#  ['motivar', 'usar'],
#  ['pq', 'dever', 'usar'],
#  ['porque', 'dever', 'usar'],
#  ['selo', 'representar', 'turista', 'estrangeiro'],
#  ['selo', 'representar', 'turista', 'brasileiro'],
#  ['selo', 'turismo'],
#  ['adoção',
#   'selo',
#   'turismo',
#   'responsavel',
#   'brasil',
#   'destino',
#   'seguro',
#   'turista'],
#  ['turista',
#   'selo',
#   'turismo',
#   'responsavel',
#   'criar',
#   'novo',
#   'conceito',
#   'destino',
#   'seguro'],
#  ['selo',
#   'turismo',
#   'responsavel',
#   'criar',
#   'novo',
#   'conceito',
#   'destino',
#   'seguro',
#   'turista'],
#  ['turista', 'sentir', 'seguro', 'empreendimento', 'aderir', 'selo', 'turismo'],
#  ['selo',
#   'turismo',
#   'responsavel',
#   'tornar',
#   'empreendimento',
#   'adotar',
#   'turista'],
#  ['selo',
#   'turista',
#   'responsavel',
#   'garantir',
#   'proteção',
#   'segurança',
#   'sanitário',
#   'querer',
#   'visitar',
#   'brasil'],
#  ['protocolo',
#   'estabelecer',
#   'selo',
#   'turista',
#   'responsavel',
#   'garantir',
#   'proteção',
#   'segurança',
#   'sanitário',
#   'querer',
#   'visitar',
#   'brasil'],
#  ['protocolo',
#   'estabelecer',
#   'selo',
#   'turista',
#   'responsavel',
#   'garantir',
#   'proteção',
#   'segurança',
#   'sanitário',
#   'turista'],
#  ['querer',
#   'visitar',
#   'brasil',
#   'poder',
#   'confiar',
#   'medida',
#   'proteção',
#   'segurança',
#   'sanitário',
#   'protocolo',
#   'estabelecer',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['querer',
#   'visitar',
#   'brasil',
#   'poder',
#   'confiar',
#   'medida',
#   'proteção',
#   'segurança',
#   'sanitário',
#   'exigir',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['querer',
#   'visitar',
#   'brasil',
#   'seguro',
#   'medida',
#   'higienização',
#   'adotar',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['querer',
#   'visitar',
#   'brasil',
#   'poder',
#   'confiar',
#   'protocolo',
#   'estabelecir',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['turista',
#   'poder',
#   'confiar',
#   'protocolo',
#   'estabelecir',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['turista',
#   'poder',
#   'confiar',
#   'medida',
#   'estabelecir',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['turista',
#   'brasileiro',
#   'estrangeiro',
#   'motivar',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['porque', 'importante'],
#  ['porque', 'aderir'],
#  ['benefício'],
#  ['ter', 'beneficio'],
#  ['ter', 'algum'],
#  ['vantagem'],
#  ['ganhar', 'selo'],
#  ['ganhar', 'selo'],
#  ['ter', 'impacto', 'negocio'],
#  ['impacto', 'negócio'],
#  ['vantagem', 'negócio'],
#  ['negocio', 'ganhar', 'selo'],
#  ['ir', 'sair', 'ganhar', 'selo'],
#  ['negocio', 'ganhar'],
#  ['vantagem', 'usar', 'selo'],
#  ['ganhar', 'selo'],
#  ['ganhar', 'selo'],
#  ['selo', 'impacto', 'negocio'],
#  ['selo', 'brasil', 'destino', 'seguro', 'turistas'],
#  ['selo', 'contribuir', 'brasil', 'destino', 'seguro'],
#  ['posso',
#   'comprar',
#   'pacote',
#   'viagem',
#   'selo',
#   'garante',
#   'locais',
#   'seguindo',
#   'protocolos'],
#  ['selo', 'contribuir', 'retomada', 'setor', 'turistico', 'brasil'],
#  ['selo', 'diferencial', 'país', 'retomada', 'setor'],
#  ['incentivo', 'retomada', 'turismo', 'brasil'],
#  ['retomada', 'atividade', 'brasil'],
#  ['posso', 'comprar', 'pacote', 'viagem', 'selo', 'garante', 'locais'],
#  ['posso',
#   'comprar',
#   'pacote',
#   'viagem',
#   'selo',
#   'garante',
#   'locais',
#   'seguindo',
#   'medidas',
#   'higiene'],
#  ['selo',
#   'turismo',
#   'brasil',
#   'seguro',
#   'posso',
#   'comprar',
#   'pacote',
#   'viagem'],
#  ['selo', 'turismo', 'brasileiro', 'seguro', 'posso', 'comprar', 'pacote'],
#  ['brasil', 'mostrara', 'destino', 'seguro'],
#  ['brasil', 'mostrara', 'destino', 'seguro', 'turistas'],
#  ['brasil', 'mostrara', 'destino', 'seguro', 'mundo'],
#  ['selo', 'mostrara', 'turistas', 'brasil', 'destino', 'seguro'],
#  ['selo', 'mostrara', 'mundo', 'brasil', 'destino', 'turistico'],
#  ['posso',
#   'comprar',
#   'pacote',
#   'viagem',
#   'selo',
#   'garante',
#   'hotes',
#   'seguindo',
#   'medidas',
#   'higiene'],
#  ['posso',
#   'comprar',
#   'pacote',
#   'viagem',
#   'selo',
#   'garante',
#   'hotes',
#   'seguindo',
#   'protocolo'],
#  ['quero',
#   'comprar',
#   'pacote',
#   'viagem',
#   'posso',
#   'confiar',
#   'adotando',
#   'protocolo'],
#  ['quero',
#   'comprar',
#   'pacote',
#   'viagem',
#   'posso',
#   'confiar',
#   'seguindo',
#   'recomendaçoes',
#   'higiene'],
#  ['faço', 'saber', 'empreendimento', 'seguindo', 'protocolo'],
#  ['suspendi',
#   'atividade',
#   'durante',
#   'pandemia',
#   'poder',
#   'solicitar',
#   'selo',
#   'assim'],
#  ['atividade',
#   'suspenso',
#   'devido',
#   'pandemia',
#   'ainda',
#   'poder',
#   'pedir',
#   'selo'],
#  ['estabelecimento', 'fechar', 'pandemia', 'poder', 'solicitar', 'selo'],
#  ['estabelecimento', 'fechar', 'pandemia', 'poder', 'pedir', 'selo'],
#  ['suspendi',
#   'atividade',
#   'empreendimento',
#   'poder',
#   'solicitar',
#   'selo',
#   'assim'],
#  ['atividade', 'suspenso', 'durante', 'pandemia', 'querer', 'selo', 'assim'],
#  ['estabelecimento',
#   'atividade',
#   'suspenso',
#   'durante',
#   'pandemia',
#   'querer',
#   'selo',
#   'assim'],
#  ['estabelecimento', 'atividade', 'suspenso', 'poder', 'obter', 'selo'],
#  ['atividade', 'suspenso', 'poder', 'solicitar', 'selo'],
#  ['solicitar',
#   'selo',
#   'estando',
#   'atividade',
#   'suspensa',
#   'devido',
#   'pandemia'],
#  ['posso',
#   'solicitar',
#   'selo',
#   'estando',
#   'atividade',
#   'suspensa',
#   'devido',
#   'pandemia'],
#  ['cadastur', 'obrigatorior'],
#  ['conseguir', 'selo', 'empreendimentos', 'turísticos', 'cadastur'],
#  ['registro', 'cadastro', 'cadastur', 'prérequisito', 'pleitar', 'selo'],
#  ['registro', 'cadastro', 'cadastur', 'condição', 'exigida', 'pleitar', 'selo'],
#  ['ter', 'cadastur'],
#  ['ter', 'cadastro', 'cadastur'],
#  ['registro',
#   'cadastro',
#   'cadastur',
#   'condição',
#   'exigida',
#   'solicitar',
#   'selo'],
#  ['registro', 'cadastro', 'cadastur', 'condição', 'exigida', 'pedir', 'selo'],
#  ['preciso', 'cadastrado', 'cadastur', 'ter', 'selo'],
#  ['devo', 'cadastrado', 'cadastur', 'ter', 'selo'],
#  ['necessário', 'cadastrado', 'cadastur', 'ter', 'selo'],
#  ['obrigatorio', 'cadastrado', 'cadastur', 'ter', 'selo'],
#  ['registro', 'cadastro', 'cadastur', 'obrigatório', 'pleitar', 'selo'],
#  ['registro', 'cadastro', 'cadastur', 'obrigatoriedade', 'conseguir', 'selo'],
#  ['nao', 'registro', 'cadastur', 'agora'],
#  ['registro', 'cadastur'],
#  ['registro', 'antigo', 'embratur'],
#  ['posso', 'pedir', 'selo', 'cadastro', 'antigo', 'embratur'],
#  ['registrado', 'cadastur', 'existe', 'outra', 'forma', 'pedir', 'selo'],
#  ['registrado', 'cadastur', 'existe', 'outra', 'forma', 'conseguir', 'selo'],
#  ['registrado', 'cadastur', 'preciso', 'selo'],
#  ['preciso', 'registro', 'cadastur'],
#  ['tipos', 'estabelecimentos', 'pode', 'utilizar', 'selo'],
#  ['fazer', 'saber', 'estabelecimento', 'precisar', 'selo'],
#  ['ter', 'poder', 'pedir', 'selo', 'turismo', 'responsavel'],
#  ['todo',
#   'tipo',
#   'empreendimento',
#   'poder',
#   'aderir',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['tipo',
#   'empreendimento',
#   'poder',
#   'aderir',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['poder', 'pedir', 'selo', 'turismo', 'responsavel'],
#  ['atividade', 'turistico', 'poder', 'pleitear', 'selo'],
#  ['todo',
#   'tipo',
#   'empreendimento',
#   'comercial',
#   'poder',
#   'pedir',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['todo',
#   'tipo',
#   'negocio',
#   'poder',
#   'aderir',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['tipo', 'empreendimento', 'poder', 'solicitar', 'selo'],
#  ['tipo', 'empreendimento', 'poder', 'pleitear', 'selo'],
#  ['tipo', 'empreendimento', 'poder', 'requerer', 'selo'],
#  ['estabelecimento'],
#  ['empreendimento'],
#  ['pra'],
#  ['pra', 'destinar'],
#  [],
#  ['tipo', 'estabelecimento', 'poder', 'pedir', 'selo'],
#  ['tipo', 'estabelecimento', 'poder', 'solicitar', 'selo'],
#  ['ter', 'regra', 'impedir', 'pedir', 'selo', 'turismo', 'responsavel'],
#  ['pedir',
#   'selo',
#   'turismo',
#   'responsavel',
#   'estabelecimento',
#   'poder',
#   'impedir'],
#  ['querer', 'pedir', 'selo', 'estabelecimento', 'regra'],
#  ['querer', 'pedir', 'selo', 'saber', 'poder'],
#  ['fazer',
#   'saber',
#   'estabelecimento',
#   'poder',
#   'inscrever',
#   'programa',
#   'selo',
#   'turismo',
#   'reponsavel'],
#  ['atividade', 'turistico', 'poder', 'utilizar', 'selo'],
#  ['tipo', 'estabelecimento', 'poder', 'solicitar', 'selo'],
#  ['todo',
#   'estabelecimento',
#   'comercial',
#   'poder',
#   'usar',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['estabelecimentos', 'pode', 'utilizar', 'selo'],
#  ['tipo', 'estabelecimentos', 'pode', 'utilizar', 'selo'],
#  ['onde',
#   'pesquiso',
#   'saber',
#   'tipo',
#   'estabelecimento',
#   'pode',
#   'pedir',
#   'selo'],
#  ['onde', 'saber', 'tipo', 'estabelecimento', 'pode', 'pedir', 'selo'],
#  ['onde', 'vejo', 'tipo', 'estabelecimento', 'pode', 'selo'],
#  ['preciso', 'saber', 'natureza', 'estabelecimentos', 'pode', 'usar', 'selo'],
#  ['preciso', 'saber', 'quais', 'tipos', 'estabelecimentos', 'usar', 'selo'],
#  ['saber', 'tipo', 'estabelecimento', 'pode', 'pedir', 'selo'],
#  ['tipo', 'estabelecimento', 'dentro', 'ter', 'selo'],
#  ['tipo', 'estabelecimento', 'pode', 'pleitear', 'selo'],
#  ['tipo', 'estabelecimento', 'pode', 'pedir', 'selo'],
#  ['saber', 'tipo', 'estabelecimento', 'usar', 'selo'],
#  ['saber', 'tipo', 'estabelecimento', 'dentro', 'regra', 'selo'],
#  ['posso',
#   'saber',
#   'tipos',
#   'estabelecimentos',
#   'turisticos',
#   'podem',
#   'usar',
#   'selo'],
#  ['todos', 'estabelecimentos', 'turisticos', 'podem', 'usar', 'selo'],
#  ['quais', 'empreendimentos', 'podem', 'utilizar', 'selo'],
#  ['tipo', 'estabelecimentos', 'podem', 'utilizar', 'selo'],
#  ['tuberculose', 'sistema', 'nervoso'],
#  ['tuberculose'],
#  ['tuberculose'],
#  ['tuberculose', 'cerebral'],
#  ['neurotuberculose'],
#  ['neurotuberculose'],
#  ['tuberculose', 'sistema', 'nervoso', 'central'],
#  ['tuberculose', 'cerebral', 'tratar'],
#  ['tuberculose', 'cerebral', 'diagnostico'],
#  ['tuberculose', 'cerebral', 'principal', 'sintoma'],
#  ['preciso', 'pessoa', 'tuberculose', 'pulmonar', 'garganta', 'falar'],
#  ['transmitir', 'tuberculose'],
#  ['contagio', 'tuberculose'],
#  ['transmissão', 'tuberculose'],
#  ['contagio', 'tuberculose'],
#  ['meio', 'transmissão', 'tuberculose'],
#  ['tuberculose', 'transmitir'],
#  ['pegar', 'tuberculose'],
#  ['poder', 'contaminar', 'tuberculose'],
#  ['transmitir'],
#  ['transmitir', 'tuberculose'],
#  ['contágio', 'doença', 'frequente', 'perto', 'pessoa', 'tuberculose'],
#  ['transmissão', 'tuberculose', 'pessoa'],
#  ['contágio', 'tuberculose', 'acontecer', 'através', 'ar'],
#  ['bacilo',
#   'ficar',
#   'ar',
#   'pessoa',
#   'tuberculose',
#   'pulmonar',
#   'garganta',
#   'falar'],
#  ['tuberculose', 'ficar', 'ar', 'tuberculoso', 'falar', 'tosse'],
#  ['pegar', 'ar', 'contaminar', 'bacilo', 'koch'],
#  ['contágio', 'doença', 'comum', 'perto', 'pessoa', 'tuberculose'],
#  ['impedir', 'contaminação', 'bacilo', 'koch'],
#  ['vacina', 'impedir', 'contaminação', 'bacilo', 'koch'],
#  ['vacina', 'contra', 'tuberculose'],
#  ['prevenir', 'tuberculose'],
#  ['proteger', 'contagio', 'tuberculose'],
#  ['prevenir', 'tuberculose'],
#  ['tuberculose'],
#  ['existir', 'prevenção', 'tuberculose'],
#  ['proteger', 'tuberculose'],
#  ['prevenção', 'tuberculose'],
#  ['fator', 'risco', 'gerar', 'aumento', 'contagio', 'tuberculose'],
#  ['querer', 'saber', 'fator', 'risco', 'tuberculose'],
#  ['fator', 'risco', 'tuberculose'],
#  ['tuberculose', 'risco'],
#  ['fator', 'risco', 'tuberculose'],
#  ['risco', 'contrair', 'tuberculose'],
#  ['existir', 'fator', 'aumentar', 'risco', 'contaminação', 'tuberculose'],
#  ['aumentar', 'risco', 'contrair', 'tuberculose'],
#  ['risco', 'tuberculose'],
#  ['fator', 'risco', 'tuberculose'],
#  ['tuberculose', 'poder', 'tórax'],
#  ['tuberculose', 'ganglio'],
#  ['tuberculose', 'ganglionar'],
#  ['tuberculose', 'ganglionar'],
#  ['tuberculose', 'ganglionar', 'sistema'],
#  ['preciso', 'saber', 'sobre', 'tuberculose', 'ganglionar'],
#  ['tuberculose', 'ganglio'],
#  ['falar', 'sobre', 'tuberculose', 'ganglionar'],
#  ['querer', 'saber', 'sobre', 'tuberculose', 'ganglionar'],
#  ['preciso', 'informação', 'sobre', 'tuberculose', 'ganglionar'],
#  ['explicar', 'sobre', 'tuberculose', 'ganglionar'],
#  ['definer', 'tuberculose', 'ganglionar'],
#  ['tuberculose', 'ganglionar', 'tratar'],
#  ['tuberculose', 'diagnóstico'],
#  ['tuberculose', 'ganglionar', 'principal', 'sintoma'],
#  ['tuberculose', 'tratar'],
#  ['beber',
#   'leite',
#   'animal',
#   'contaminar',
#   'causa',
#   'tuberculose',
#   'intestino'],
#  ['comer',
#   'carne',
#   'animal',
#   'contaminar',
#   'causa',
#   'tuberculose',
#   'intestino'],
#  ['comer',
#   'carne',
#   'beber',
#   'leite',
#   'animal',
#   'contaminar',
#   'causa',
#   'tuberculose',
#   'intestino'],
#  ['tuberculose', 'intestino'],
#  ['tuberculose'],
#  ['falame', 'sobre', 'tuberculose', 'intestinal'],
#  ['existir', 'tuberculose', 'intestinal'],
#  ['tuberculose', 'intestinal'],
#  ['tuberculose', 'intestinal'],
#  ['pessoa',
#   'tuberculose',
#   'pulmonar',
#   'engoler',
#   'secreção',
#   'bacilo',
#   'pegar',
#   'tuberculose',
#   'intestinal'],
#  ['pessoa',
#   'tuberculose',
#   'pulmonar',
#   'engoler',
#   'secreção',
#   'poder',
#   'desenvolver',
#   'tuberculose',
#   'intestinal'],
#  ['tuberculose', 'intestinal', 'diagnostico'],
#  ['tuberculose', 'intestinal', 'principal', 'sintoma'],
#  ['tuberculose'],
#  ['tuberculose', 'miliar', 'meníngea'],
#  ['definer', 'tuberculose', 'miliar', 'meníngea'],
#  ['tuberculose', 'miliar', 'meníngea'],
#  ['tipo', 'tuberculose', 'bactéria', 'disseminar', 'corrente', 'sanguínea'],
#  ['tuberculose', 'miliar', 'bactéria', 'disseminar', 'corrente', 'sanguínea'],
#  ['tuberculose', 'miliar', 'forma', 'grave', 'doença'],
#  ['tuberculose', 'miliar'],
#  ['tuberculose'],
#  ['tuberculose', 'miliar', 'meníngea'],
#  ['tuberculose', 'miliar', 'provocar', 'tecido', 'órgão', 'corpo'],
#  ['tuberculose', 'miliar', 'tratar'],
#  ['tuberculose', 'miliar', 'diagnostico'],
#  ['tuberculose', 'miliar', 'principal', 'sintoma'],
#  ['explicar', 'tuberculose', 'ocular'],
#  ['tuberculose', 'ocular'],
#  ['tuberculose', 'ocular'],
#  ['querer', 'saber', 'sobre', 'tuberculose', 'olho'],
#  ['tuberculose'],
#  ['querer', 'saber', 'sobre', 'tuberculose', 'ocular'],
#  ['tuberculose', 'olho'],
#  ['existir', 'tuberculose', 'olho'],
#  ['existir', 'tuberculose', 'olho'],
#  ['ter', 'tuberculose', 'ocular'],
#  ['chamar', 'tuberculose', 'olho'],
#  ['definame', 'tuberculose', 'ocular'],
#  ['ter', 'tuberculose', 'ocular'],
#  ['tuberculose', 'ocular', 'tratar'],
#  ['tuberculose', 'ocular', 'diagnostico'],
#  ['tuberculose', 'ocular', 'principal'],
#  ['diga', 'tuberculose'],
#  ['tuberculose'],
#  ['tuberculose', 'infecção', 'grave'],
#  ['tuberculose', 'doença', 'grave'],
#  ['tuberculose'],
#  ['tuberculose', 'doença', 'bactéria'],
#  ['tuberculose'],
#  ['tuberculose'],
#  ['definame', 'tuberculose'],
#  ['doença', 'tuberculose'],
#  ['tuberculose'],
#  ['tuberculose'],
#  ['tuberculose'],
#  ['aperto', 'transmite', 'tuberculose'],
#  ['tuberculose', 'transmitir', 'tuberculose'],
#  ['compartilhar', 'comida', 'bebida', 'transmiter', 'tuberculose'],
#  ['tuberculose', 'passar', 'atrave', 'beijo'],
#  ['beijo', 'causar', 'transmissão'],
#  ['passar', 'roupa', 'pessoa', 'infectar'],
#  ['tuberculose', 'passar', 'atrave'],
#  ['tuberculose', 'passar', 'atrave', 'comida'],
#  ['tuberculose', 'passar', 'atrave', 'aperto', 'mão'],
#  ['tuberculose', 'passar', 'atrave'],
#  ['usar', 'roupa', 'pessoa', 'infectar', 'transmite', 'tuberculose'],
#  ['tuberculose', 'osso'],
#  ['tuberculose', 'pegar', 'osso'],
#  ['infecção', 'osso'],
#  ['tuberculose', 'osso'],
#  ['bacilo', 'tuberculose', 'poder', 'alojar', 'osso'],
#  ['querer', 'saber', 'sobre', 'tuberculose', 'osso'],
#  ['poder', 'ter', 'tuberculose'],
#  ['osso', 'poder', 'ter', 'tuberculose'],
#  ['osso', 'poder', 'tuberculose'],
#  ['tuberculose', 'pegar', 'osso', 'corpo'],
#  ['tuberculose', 'ossea'],
#  ['tuberculose', 'ossea'],
#  ['tuberculose', 'osso'],
#  ['tuberculose', 'ossea', 'tratar'],
#  ['tuberculose', 'ossea', 'diagnostico'],
#  ['tuberculose', 'principal', 'sintoma'],
#  ['tuberculose', 'pleural'],
#  ['chamar', 'tuberculose', 'tecido', 'pulmão'],
#  ['uso', 'poder', 'desenvolver', 'tuberculose', 'pleural'],
#  ['pegar', 'tuberculose', 'pleura'],
#  ['tuberculose', 'poder', 'contagiar', 'pleura'],
#  ['preciso', 'orientação', 'sobre', 'tuberculose', 'pleural'],
#  ['tuberculose', 'pleural'],
#  ['existir', 'tuberculose', 'pleural'],
#  ['tuberculose', 'pegar', 'pleura'],
#  ['pleura', 'poder', 'contaminar', 'tuberculose'],
#  ['esclareçame', 'sobre', 'tuberculose', 'pleural'],
#  ['expliquar', 'tuberculose', 'pleural'],
#  ['tuberculose', 'pleural', 'tratar'],
#  ['tuberculose', 'pleural', 'diagnostico'],
#  ['tuberculose', 'pleural', 'principal', 'sintoma'],
#  ['tuberculose'],
#  ['tuberculose', 'pulmão'],
#  ['pulmão', 'tuberculose'],
#  ['tuberculose',
#   'pulmonar',
#   'ocorrer',
#   'devido',
#   'bacilo',
#   'via',
#   'respiratório'],
#  ['tuberculose', 'pulmonar'],
#  ['forma', 'comum', 'doença', 'tuberculose', 'pulmonar'],
#  ['preciso', 'informação', 'sobre', 'tuberculose', 'pulmonar'],
#  ['tuberculose', 'pulmonar'],
#  ['bacteria', 'alojar', 'pulmão', 'tuberculose', 'pulmonar'],
#  ['expliqueme', 'sobre', 'bacteria', 'pulmonar'],
#  ['esclarecer', 'sobre', 'tuberculose', 'pulmonar'],
#  ['tuberculose', 'pulmonar', 'querer', 'saber'],
#  ['querer', 'saber', 'sobre', 'tuberculose', 'pulmonar'],
#  ['preciso', 'informação', 'sobre', 'tuberculose', 'pulmonar'],
#  ['definer', 'tuberculose', 'pulmonar'],
#  ['tuberculose', 'pulmonar', 'tratar'],
#  ['tuberculose', 'pulmonar', 'diagnostico'],
#  ['tuberculose', 'pulmonar', 'principal', 'sintoma'],
#  ['ter', 'sarar', 'tuberculose'],
#  ['tuberculose', 'ter', 'cura'],
#  ['existir', 'cura', 'tuberculose'],
#  ['ir', 'ficar', 'curar', 'tuberculose'],
#  ['poder', 'curar', 'tuberculose'],
#  ['cura', 'tuberculose'],
#  ['tuberculoso', 'poder', 'curar'],
#  ['ir', 'sarar', 'tuberculose'],
#  ['tratamento', 'tuberculose', 'deixar', 'paciente', 'curar'],
#  ['paciente', 'tuberculose', 'poder', 'curar'],
#  ['doente', 'tuberculose', 'poder', 'curar'],
#  ['doença', 'tuberculose', 'ter', 'cura'],
#  ['existir', 'cura', 'pra', 'doença', 'tuberculose'],
#  ['doença', 'tuberculose', 'ja', 'ter', 'cura'],
#  ['existir', 'quanto', 'tipo', 'tuberculose'],
#  ['tuberculose', 'tipo'],
#  ['tipo', 'tuberculose'],
#  ['tipo', 'tuberculose'],
#  ['tipo', 'tuberculose', 'comum'],
#  ['querer', 'saber', 'tipo', 'tuberculose'],
#  ['falar', 'tipo', 'tuberculose'],
#  ['existir', 'quanto', 'tipo', 'tuberculose'],
#  ['tipo', 'tuberculose', 'existir'],
#  ['tuberculose', 'tratamento', 'gratuito'],
#  ['custo', 'tratamento', 'tuberculose'],
#  ['tuberculoso', 'ter', 'dinheiro', 'pagar', 'tratamento'],
#  ['tuberculose', 'ir', 'ter', 'pagar', 'tratamento'],
#  ['sus', 'pagar', 'tratamento', 'tuberculose'],
#  ['ministerio', 'pagar', 'tratamento', 'tuberculose'],
#  ['governo', 'pagar', 'tratamento', 'tuberculose'],
#  ['quanto', 'custar', 'tratamento', 'tuberculose'],
#  ['despesa', 'tuberculose', 'pagar'],
#  ['pagar', 'tratamento', 'tuberculose'],
#  ['tuberculose', 'urinario'],
#  ['querer', 'saber', 'sobre', 'tuberculose', 'urinario'],
#  ['preciso', 'saber', 'sobre', 'tuberculose', 'urinario'],
#  ['tuberculose'],
#  ['querer', 'informação', 'sobre', 'tuberculose', 'urinario'],
#  ['tuberculose'],
#  ['falar', 'sobre', 'tuberculose', 'urinario'],
#  ['tuberculose', 'urinaria'],
#  ['tuberculose', 'urinario'],
#  ['definer', 'tuberculose', 'urinario'],
#  ['esclarecer', 'sobre', 'tuberculose', 'urinario'],
#  ['falame', 'tuberculose', 'urinario'],
#  ['dizer', 'sobre', 'tuberculose', 'urinario'],
#  ['tuberculose', 'urinario'],
#  ['doença', 'tuberculose'],
#  ['tuberculose', 'urinaria', 'tratar'],
#  ['tuberculose', 'urinaria', 'diagnostico'],
#  ['tuberculose', 'urinaria', 'principal', 'sintoma'],
#  ['fazer', 'tuberculoso'],
#  ['tuberculose'],
#  ['oximetria', 'baixo', 'poder', 'tuberculose'],
#  ['sintoma', 'tuberculose', 'fazer'],
#  ['tuberculoso', 'dever', 'fazer'],
#  ['ficar', 'doente', 'tuberculose', 'fazer'],
#  ['sentir', 'gripar', 'achar', 'tuberculose', 'fazer'],
#  ['tuberculoso', 'querer', 'orientação'],
#  ['orientação', 'seguir', 'caso', 'tuberculose'],
#  ['fazer', 'tuberculose'],
#  ['coronavírus'],
#  ['fazer', 'doente'],
#  ['ocorrer', 'primeiro', 'infecção', 'humano', 'novo', 'coronavírus'],
#  ['covid', 'novo', 'coronavírus'],
#  ['pegar', 'covid'],
#  ['vulnerável', 'covid'],
#  ['quanto', 'tempo', 'vírus', 'sobreviver', 'superfície'],
#  ['devo', 'usar', 'máscara', 'proteger'],
#  ['vacina', 'covid', 'seguro'],
#  ['vacinar', 'coronavírus'],
#  ['vacina', 'poder', 'imunizar', 'todo', 'coronavírus'],
#  ['poder', 'normal', 'vacina'],
#  ['necessário', 'tomar', 'vacina', 'todo', 'ano', 'gripe'],
#  ['após', 'tomar', 'vacina'],
#  ['posso', 'voltar', 'frequentar', 'aglomeração'],
#  ['pessoa', 'vacinar', 'poder', 'transmitir', 'vírus'],
#  ['primeiro', 'receber', 'vacina'],
#  ['dever', 'tomar', 'vacina'],
#  ['vacina', 'poder', 'usar', 'criança'],
#  ['covid', 'preciso', 'vacinar'],
#  ['pessoa', 'sintoma', 'poder', 'tomar', 'vacina'],
#  ['após',
#   'teste',
#   'positivo',
#   'covid',
#   'quanto',
#   'tempo',
#   'deveser',
#   'esperar',
#   'tomar',
#   'vacina'],
#  ['existir',
#   'algum',
#   'tipo',
#   'bebida',
#   'comida',
#   'dever',
#   'antes',
#   'tomar',
#   'vacina'],
#  ['vacinação', 'obrigatório'],
#  ['ter', 'tomar', 'dois', 'dose', 'vacina'],
#  ['eficácia'],
#  ['vacina', 'ter', 'diferente', 'eficácia'],
#  ['tomar', 'vacina', 'sus', 'possível'],
#  ['posso', 'tomar', 'todo', 'outro', 'vacina', 'junto', 'vacina', 'covid'],
#  ['posso', 'tomar', 'primeiro', 'dose', 'vacina', 'segundo', 'dose', 'outro'],
#  ['vacina', 'exterior', 'devo', 'vacinar', 'brasil'],
#  ['ter', 'sus', 'posso', 'vacinar'],
#  ['controle', 'dose', 'aplicar'],
#  ['sus', 'ter', 'vacinar', 'tanto'],
#  ['pessoa', 'comorbidade', 'precisar', 'vacinação'],
#  ['poder', 'comprar', 'vacina', 'rede', 'privado'],
#  ['uso', 'risco', 'saúde'],
#  ['anvisa', 'ainda', 'registro', 'sanitário'],
#  ['estado',
#   'poder',
#   'vacinar',
#   'população',
#   'ministério',
#   'saúde',
#   'anvisa',
#   'ter',
#   'aprovar',
#   'vacina'],
#  ['poder', 'tomar', 'vacina'],
#  ['tomar',
#   'vacina',
#   'poder',
#   'sentir',
#   'proteger',
#   'voltar',
#   'circular',
#   'rua',
#   'máscara'],
#  ['procedimento',
#   'dever',
#   'adotar',
#   'caso',
#   'pessoa',
#   'imunizar',
#   'vacina',
#   'diferente',
#   'primeiro',
#   'segundo',
#   'dose'],
#  ['dever', 'receber', 'dose', 'vacina'],
#  ['existir', 'risco', 'pessoa', 'tomar', 'vacina', 'diferente'],
#  ['tempo', 'vacina', 'aplicar', 'brasil', 'oferecer'],
#  ['novo', 'variante', 'sarscov'],
#  ['fazer', 'variante', 'agressivo', 'outro'],
#  ['variante', 'identificar', 'brasil'],
#  ['variante', 'vir', 'causar', 'infecção', 'agressivo', 'circular', 'brasil'],
#  ['variante', 'responsável', 'aumento', 'caso', 'país'],
#  ['fazer', 'variante'],
#  ['todo', 'caso', 'covid', 'dever', 'ter'],
#  ['atualização', 'caso', 'variante', 'ministério', 'saúde'],
#  ['variante', 'encontrar', 'brasil', 'poder', 'afetar', 'eficácia', 'vacina'],
#  ['ministério', 'saúde', 'caso', 'reinfecção'],
#  ['fazer', 'caso', 'reinfecção'],
#  ['ministério',
#   'saúde',
#   'contato',
#   'saber',
#   'realizar',
#   'vacina',
#   'aprovar',
#   'brasil',
#   'eficaz',
#   'contra',
#   'variante',
#   'circular',
#   'país'],
#  ['posso', 'tomar', 'vacina', 'gripe', 'junto', 'covid'],
#  ['ter',
#   'resultado',
#   'negativo',
#   'teste',
#   'realizar',
#   'pesquisa',
#   'significar',
#   'covid'],
#  ['ter', 'covid', 'assim', 'preciso', 'participar', 'pesquisa'],
#  ['vacinar', 'contra', 'covid', 'assim', 'preciso', 'participar', 'pesquisa'],
#  ['preciso', 'esperar', 'dose', 'outro'],
#  ['ter', 'covid', 'precisar', 'vacinar'],
#  ['poder', 'tomar', 'vacina'],
#  ['normal', 'ter', 'algum', 'após', 'tomar', 'vacina'],
#  ['após',
#   'ter',
#   'tomar',
#   'dose',
#   'preciso',
#   'usar',
#   'máscara',
#   'evitar',
#   'aglomeração'],
#  ['quais', 'comorbidade', 'vacinar', 'primeiro'],
#  ['vacinação', 'seguro', 'população'],
#  ['tuberculose'],
#  ['tuberculose',
#   'doença',
#   'causar',
#   'bactéria',
#   'mycobacterium',
#   'tuberculosi',
#   'conhecer',
#   'bacilo',
#   'koch'],
#  ['doença', 'causar', 'bacilo', 'koch'],
#  ['forma',
#   'afetar',
#   'outro',
#   'órgão',
#   'pulmão',
#   'ocorrer',
#   'pessoa',
#   'viver',
#   'hiv'],
#  ['antigo',
#   'tuberculose',
#   'continuar',
#   'importante',
#   'problema',
#   'saúde',
#   'público'],
#  ['mundo', 'cada', 'ano', 'cerca', 'pessoa', 'tuberculose'],
#  ['brasil',
#   'notificar',
#   'mil',
#   'caso',
#   'novo',
#   'ocorrer',
#   'cerca',
#   'mil',
#   'tuberculose'],
#  ['tuberculose', 'transmitir'],
#  ['transmissão', 'tuberculose', 'acontecer', 'via', 'respiratório'],
#  ['pessoa',
#   'tuberculose',
#   'pulmonar',
#   'ativo',
#   'tratamento',
#   'poder',
#   'infectar',
#   'pessoa'],
#  ['tuberculose', 'transmitir', 'objeto', 'compartilhar'],
#  ['roupa', 'ter', 'papel', 'importante', 'transmissão', 'doença'],
#  ['bacilo', 'luz', 'circulação', 'ar'],
#  ['sintoma', 'tuberculose'],
#  ['principal', 'sintoma', 'tuberculose', 'pulmonar', 'tosse', 'tosse', 'poder'],
#  ['todo', 'pessoa', 'sintoma', 'respiratório', 'tosse', 'tuberculose'],
#  ['caso',
#   'pessoa',
#   'apresentar',
#   'sintoma',
#   'tuberculose',
#   'fundamental',
#   'unidade',
#   'saúde',
#   'próximo',
#   'realização',
#   'exame'],
#  ['resultado',
#   'positivo',
#   'tuberculose',
#   'deveser',
#   'tratamento',
#   'rápido',
#   'possível',
#   'final'],
#  ['fazer', 'diagnóstico', 'tuberculose'],
#  ['brasil',
#   'diagnóstico',
#   'tb',
#   'realizar',
#   'recomendações',
#   'controle',
#   'tuberculose',
#   'brasil',
#   'diagnóstico',
#   'diferencial',
#   'outro',
#   'teste',
#   'diagnóstico'],
#  ['diagnóstico',
#   'laboratorial',
#   'tuberculose',
#   'fundamental',
#   'tanto',
#   'caso',
#   'novo',
#   'quanto',
#   'controle',
#   'tratamento'],
#  ['diagnóstico', 'laboratorial', 'tuberculose', 'utilizar', 'exame'],
#  ['teste', 'rápido', 'tuberculose', 'trmtb', 'baciloscopia'],
#  ['teste', 'sensibilidade'],
#  ['realização', 'radiografia', 'tórax', 'diagnóstico'],
#  ['tratamento', 'tuberculose'],
#  ['tratamento',
#   'tuberculose',
#   'pequeno',
#   'gratuito',
#   'disponível',
#   'sistema',
#   'único',
#   'saúde',
#   'sus'],
#  [],
#  ['tuberculose', 'ter', 'cura', 'tratamento', 'fazer', 'forma', 'final'],
#  ['vacina',
#   'bacilo',
#   'sistema',
#   'único',
#   'saúde',
#   'sus',
#   'proteger',
#   'criança',
#   'forma',
#   'grave',
#   'doença'],
#  ['ocorrer',
#   'pessoa',
#   'encontrar',
#   'infectar',
#   'mycobacterium',
#   'tuberculosi',
#   'manifestação',
#   'doença',
#   'ativo'],
#  ['contato', 'pessoa', 'diagnosticar', 'tb'],
#  ['sobre',
#   'protocolo',
#   'vigilância',
#   'infecção',
#   'mycobacterium',
#   'tuberculosi',
#   'brasil'],
#  ['orientação',
#   'geral',
#   'minimizar',
#   'risco',
#   'transmissão',
#   'tuberculose',
#   'ambiente',
#   'público'],
#  ['população', 'risco', 'população', 'geral'],
#  ['população',
#   'vulnerável',
#   'privado',
#   'pessoa',
#   'viver',
#   'hiv',
#   'pessoa',
#   'situação',
#   'rua',
#   'profissional',
#   'saúde'],
#  ['radiografia', 'tórax', 'tuberculose', 'avaliar', 'equipe', 'saúde'],
#  ['baciloscopia', 'trmtb', 'cultura', 'teste', 'sensibilidade'],
#  ['nacional', 'tuberculose', 'problema', 'saúde'],
#  ['situação', 'tuberculose'],
#  ['selo', 'turismo', 'responsável', 'programa', 'ministério', 'turismo'],
#  ['estabelecer',
#   'bom',
#   'prática',
#   'higienização',
#   'cada',
#   'segmento',
#   'setor',
#   'turismo'],
#  ['selo', 'incentivo', 'consumidor', 'seguro', 'viajar'],
#  ['empresa', 'guia', 'turismo', 'precisar', 'cadastur'],
#  ['serviços', 'turísticos', 'situação', 'regular', 'sistema', 'cadastur'],
#  ['prestador', 'serviço', 'turístico', 'situação', 'regular'],
#  ['após', 'adesão', 'selo', 'opção', 'emissão', 'selo'],
#  ['baixar', 'peça', 'publicitário', 'selo', 'baixar', 'peça'],
#  ['informação',
#   'sobre',
#   'condição',
#   'sinalização',
#   'limpeza',
#   'local',
#   'atendimento'],
#  ['ministério', 'turismo', 'selo'],
#  ['protocolo', 'higiênico', 'cada', 'segmento', 'turístico'],
#  ['turismo', 'responsável', 'ambiental', 'grande'],
#  ['incentivar', 'meio', 'ambiente', 'sustentabilidade', 'vir'],
#  ['turismo', 'destino'],
#  ['meio'],
#  ['forma', 'conhecer', 'outro', 'lugar', 'ter', 'objetivo', 'conceito'],
#  ['impacto', 'econômico', 'ambiental', 'negativo'],
#  ['fazer', 'minimizar', 'impacto', 'negativo', 'turismo'],
#  ['diminuir', 'geração'],
#  ['benefício', 'econômico', 'população', 'local'],
#  ['turismo', 'responsável', 'priorizar', 'serviço', 'oferecer', 'próprio'],
#  ['ir', 'além', 'frequentar'],
#  ['guia', 'local', 'prestigiar', 'local', 'priorizar', 'hospedagem', 'local'],
#  ['conservação', 'cultural'],
#  ['adotar',
#   'turismo',
#   'responsável',
#   'vida',
#   'contribuir',
#   'conservação',
#   'local'],
#  ['vida', 'local', 'respeitar', 'cultura'],
#  ['prestigiar', 'manifestação', 'cultural', 'local'],
#  ['além', 'priorizar', 'hospedagem', 'local', 'próximo', 'destino'],
#  ['ajudar',
#   'reduzir',
#   'emissão',
#   'poluente',
#   'além',
#   'tornar',
#   'viagem',
#   'econômico'],
#  ['redução', 'gasto', 'energia', 'água'],
#  ['turismo', 'responsável', 'apenas', 'diminuir', 'geração', 'poluente'],
#  ['cuidado', 'ajudar', 'água', 'energia', 'sustentabilidade'],
#  ['destino', 'pessoa', 'viver', 'local'],
#  ['poder',
#   'turismo',
#   'responsável',
#   'sustentabilidade',
#   'apenas',
#   'aplicar',
#   'destino',
#   'natureza'],
#  ['respeitar', 'evitar', 'bem', 'evitar', 'afetar'],
#  ['atender', 'sanitário', 'caso', 'turista'],
#  ['guia', 'turismo', 'dever', 'informar', 'medida', 'prevenção', 'higiênico'],
#  ['sobre', 'local', 'destino', 'antes', 'viajar'],
#  ['durante', 'viagem', 'saúde', 'poder', 'mudar', 'antes', 'durante', 'viagem'],
#  ['turista', 'responsável', 'controle'],
#  ['cumprimento', 'protocolo', 'poder', 'realizar'],
#  ['equipe',
#   'área',
#   'comum',
#   'público',
#   'funcionário',
#   'bem',
#   'fila',
#   'objetivo',
#   'garantir',
#   'distanciamento',
#   'físico'],
#  ['sinalização',
#   'fila',
#   'bem',
#   'orientar',
#   'garantir',
#   'distanciamento',
#   'físico'],
#  ['setor', 'meios', 'hospedagem', 'recomendar', 'setor'],
#  ['final', 'dever', 'realizar', 'limpeza', 'unidade'],
#  [],
#  ['proteção'],
#  ['orientar', 'consumidor', 'dar', 'aplicar', 'protocolo']]

# %%
# atualização de strings de entrada pós criação de corpus
inputs = []
for arr in processed_corpus:
    s = ' '.join([w for w in arr])         
    inputs.append(s)
inputs
df_all['input'] = inputs
df_all
# Out:
#                                           input     category
# 0                                         covid        covid
# 1            pego covid tocar objeto contaminar        covid
# 2                       pego covid através meio        covid
# 3                            onde começar covid        covid
# 4                                    onde covid        covid
# ...                                         ...          ...
# 1194    setor meios hospedagem recomendar setor  seloturismo
# 1195       final dever realizar limpeza unidade  seloturismo
# 1196                                             seloturismo
# 1197                                   proteção  seloturismo
# 1198  orientar consumidor dar aplicar protocolo  seloturismo
#
# [1199 rows x 2 columns]

# %%
## Continuação da normalização da string de entrada

# retira acentuação
for i in df_all.index:
    df_all.input[i] = unidecode.unidecode(df_all.input[i])

# Remove Emails
df_all.input = [re.sub('\S*@\S*\s?', '', sent) for sent in df_all.input]

# Remove new line characters
df_all.input = [re.sub('\s+', ' ', sent) for sent in df_all.input]

# Remove distracting single quotes
df_all.input = [re.sub("\'", "", sent) for sent in df_all.input]

df_all
# Out:
#                                           input     category
# 0                                         covid        covid
# 1            pego covid tocar objeto contaminar        covid
# 2                       pego covid atraves meio        covid
# 3                            onde comecar covid        covid
# 4                                    onde covid        covid
# ...                                         ...          ...
# 1194    setor meios hospedagem recomendar setor  seloturismo
# 1195       final dever realizar limpeza unidade  seloturismo
# 1196                                             seloturismo
# 1197                                   protecao  seloturismo
# 1198  orientar consumidor dar aplicar protocolo  seloturismo
#
# [1199 rows x 2 columns]

# %%
# atualização do corpus pós término da normalização
text_corpus = df_all.input.to_numpy()
# Lowercase each document, split it by white space and filter out stopwords
texts = [[word for word in document.lower().split() if word not in stop_words]
         for document in text_corpus]
# Count word frequencies
from collections import defaultdict
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

# Only keep words that appear more than once
processed_corpus = [[token for token in text if frequency[token] > 1] for text in texts]
pprint.pprint(processed_corpus)
# Out:
# [['covid'],
#  ['pego', 'covid', 'tocar', 'objeto', 'contaminar'],
#  ['pego', 'covid', 'atraves', 'meio'],
#  ['onde', 'comecar', 'covid'],
#  ['onde', 'covid'],
#  ['virus', 'transmitir', 'atraves', 'meio'],
#  ['significar', 'covid'],
#  ['comorbidade', 'poder', 'tomar', 'vacina'],
#  ['covid', 'familia', 'virus'],
#  ['vacina', 'disponivel', 'covid'],
#  ['crianca', 'poder', 'vacinar', 'contra', 'covid'],
#  ['bom', 'vacina'],
#  ['vacina', 'contra', 'covid', 'seguro'],
#  ['ter', 'tomar', 'quanto', 'dose', 'vacina'],
#  ['prevenir', 'contagio'],
#  ['covid', 'comecar', 'china'],
#  ['covid', 'doenca', 'grave'],
#  ['covid', 'grave'],
#  ['covid', 'virus', 'sarscov'],
#  ['covid', 'virus', 'grave'],
#  ['covid'],
#  ['covid', 'doenca', 'grave'],
#  ['covid', 'gripe'],
#  ['covid', 'criar', 'laboratorio'],
#  ['covid', 'vir'],
#  ['covid', 'vir'],
#  ['covid'],
#  ['falar', 'covid'],
#  ['covid'],
#  ['querer', 'dizer', 'covid'],
#  ['virus', 'familia', 'covid'],
#  ['covid', 'vir', 'china'],
#  ['virus', 'comum', 'familia', 'covid'],
#  ['pegar', 'forma', 'covid'],
#  ['virus', 'comum', 'infectar', 'humano'],
#  ['covid', 'comum'],
#  ['posso', 'pegar'],
#  ['poder', 'dizer', 'covid'],
#  ['meio', 'transmissao', 'covid'],
#  ['pegar', 'covid'],
#  ['covid'],
#  ['poder', 'contaminar'],
#  ['prevenir', 'covid'],
#  ['prevenir'],
#  ['exame', 'covid'],
#  ['diagnostico', 'covid'],
#  ['saber', 'ter', 'covid'],
#  ['saber', 'contaminado'],
#  ['sintoma', 'covid'],
#  ['covid', 'poder', 'reduzir'],
#  ['ter', 'hiv', 'corrar', 'risco'],
#  ['hiv', 'covid', 'poder', 'grave'],
#  ['hiv', 'correr', 'risco'],
#  ['pandemia', 'ter', 'cobertura', 'laboratorio', 'covid'],
#  ['pandemia', 'ter', 'cobertura', 'laboratorio', 'diagnostico', 'covid'],
#  ['laboratorio', 'atuar', 'comprovacao', 'diagnostico', 'covid'],
#  ['laboratorio', 'fazer', 'exame', 'comprovacao'],
#  ['laboratorio', 'realizar', 'exame', 'covid'],
#  ['laboratorio', 'realizar', 'exame', 'covid'],
#  ['laboratorio', 'fazer', 'exame', 'identificar', 'covid'],
#  ['laboratorio', 'fazer', 'exame', 'covid'],
#  ['teste', 'ir', 'exame', 'comprovacao', 'laboratorio'],
#  ['posso', 'proprio', 'alcool', 'gel'],
#  ['produzir', 'alcool', 'gel'],
#  ['fazer', 'alcool', 'gel'],
#  ['receita', 'alcool', 'gel', 'oms'],
#  ['onde', 'comecar', 'pandemia'],
#  ['oms', 'divulgar', 'receita', 'gel', 'pra', 'fazer', 'casa'],
#  ['oximetria', 'baixo'],
#  ['ficar', 'doente', 'fazer'],
#  ['sentir', 'gripar', 'fazer'],
#  ['sintoma', 'fazer'],
#  ['coisa'],
#  ['sentir', 'coisa'],
#  ['funcionario', 'doente', 'trabalho'],
#  ['poder', 'fazer', 'evitar', 'covid', 'local', 'trabalho'],
#  ['prevenir', 'coronavirus'],
#  ['evitar', 'covid', 'trabalho'],
#  ['pegar', 'covid', 'trabalho'],
#  ['identificar', 'covid'],
#  ['principal', 'sintoma'],
#  ['onde', 'pegar', 'covid'],
#  ['pegar', 'covid'],
#  ['pessoa', 'trabalho', 'diagnosticar', 'covid', 'poder', 'ter', 'contaminar'],
#  ['contato', 'paciente', 'covid', 'poder', 'contaminado'],
#  ['pessoa', 'covid', 'poder', 'pegar'],
#  ['sintoma', 'covid'],
#  ['principal', 'sintoma', 'covid'],
#  ['sintoma', 'ter', 'covid'],
#  ['poder', 'saber', 'covid'],
#  ['sintoma', 'covid'],
#  ['dinheiro', 'transmitir', 'covid'],
#  ['dar', 'pra', 'pegar', 'covid', 'dinheiro'],
#  ['poder', 'pegar', 'virus', 'supermercado'],
#  ['pessoa', 'contaminar', 'poder', 'pegar', 'ar'],
#  ['poder', 'pegar', 'virus', 'conta', 'agua', 'luz'],
#  ['poder', 'pegar', 'virus', 'embalagem', 'correio'],
#  ['limpar', 'ambiente', 'contaminar', 'poder', 'pegar', 'virus'],
#  ['poder', 'conter', 'virus', 'contaminar'],
#  ['ar', 'poder', 'provocar', 'contaminacao', 'virus'],
#  ['poder', 'pegar', 'covid', 'agua', 'trabalho'],
#  ['poder', 'pegar', 'covid'],
#  ['poder', 'contrair', 'covid'],
#  ['sempre', 'mascara', 'poder', 'pegar', 'pele'],
#  ['poder', 'pegar', 'covid', 'outro', 'pessoa'],
#  ['mascara', 'corrar', 'risco', 'contagiar'],
#  ['possivel', 'pegar', 'covid', 'pessoa', 'apresentar', 'sintoma'],
#  ['posso', 'pegar', 'covid', 'doenca'],
#  ['posso', 'pegar', 'coronavirus', 'utilizar', 'publico'],
#  ['poder', 'pegar'],
#  ['posso', 'pegar', 'covid', 'mao', 'rosto'],
#  ['poder', 'transmitir', 'covid'],
#  ['pegar', 'covid', 'assintomatico'],
#  ['assintomatico', 'transmiter', 'covid'],
#  ['parente', 'ter', 'covid', 'ter', 'sintoma'],
#  ['ter', 'sintoma', 'poder', 'transmitir', 'covid'],
#  ['poder', 'ficar', 'contaminar', 'passar'],
#  ['parente', 'ter', 'covid', 'ter', 'sintoma'],
#  ['dar', 'pra', 'pegar', 'covid'],
#  ['dar', 'pra', 'pegar', 'covid'],
#  ['sintoma', 'coronavirus'],
#  ['virus', 'responsavel', 'covid'],
#  ['poder', 'transmitir', 'pessoa', 'pessoa'],
#  ['distancia', 'seguro', 'contaminar'],
#  ['distancia', 'pequeno', 'contaminar'],
#  ['distancia', 'dever', 'manter', 'contaminar'],
#  ['acontecer', 'circulacao', 'virus'],
#  ['acontecer', 'circulacao', 'coronavirus'],
#  ['encomenda', 'china', 'dever', 'tomar', 'cuidado'],
#  ['seguro', 'receber', 'pacote', 'area', 'covid', 'ter', 'notificar'],
#  ['seguro', 'comprar', 'coisa', 'china'],
#  ['seguro', 'pais', 'covid'],
#  ['encomenda', 'area', 'risco', 'ver', 'poder', 'vir', 'contaminar'],
#  ['compra', 'area', 'risco', 'poder', 'vir', 'contaminar'],
#  ['compra', 'ver', 'area', 'risco', 'poder', 'chegar', 'contaminar'],
#  ['encomenda', 'postal', 'area', 'risco', 'poder', 'contaminar'],
#  ['encomenda', 'area', 'infectar', 'ver', 'correio', 'poder', 'contaminar'],
#  ['entrega', 'postal', 'risco', 'poder', 'conter', 'virus'],
#  ['embalagem',
#   'sedex',
#   'produto',
#   'oriundo',
#   'china',
#   'poder',
#   'conter',
#   'virus'],
#  ['embalagem', 'sedex', 'produto', 'poder', 'contaminado'],
#  ['encomenda',
#   'produto',
#   'produzir',
#   'china',
#   'poder',
#   'chegar',
#   'embalagem',
#   'contaminar'],
#  ['risco', 'desenvolver', 'doenca', 'grave'],
#  ['produto', 'correr', 'grande', 'risco', 'infeccao', 'covid'],
#  ['covid', 'risco', 'grave'],
#  ['poder', 'levar', 'virus', 'pra', 'dentro', 'casa', 'apos', 'espaco'],
#  ['poder', 'virus', 'apos', 'uso', 'gel'],
#  ['poder', 'manter', 'virus', 'vivo', 'ativo'],
#  ['pele', 'manter', 'virus', 'vivo', 'ativo'],
#  ['roupa', 'poder', 'manter', 'virus', 'vivo', 'ativo'],
#  ['preciso', 'sacola', 'supermercado'],
#  ['quanto', 'tempo', 'virus', 'sobreviver', 'objeto'],
#  ['preciso', 'limpar', 'embalagem', 'comida'],
#  ['deixar', 'roupa', 'coronavirus'],
#  ['preciso', 'lavar', 'embalagem'],
#  ['quanto', 'tempo', 'virus', 'sobreviver', 'superficie'],
#  ['virus', 'ambiente', 'fechar', 'tempo'],
#  ['tocar', 'superficie', 'corrar', 'risco', 'pegar', 'covid'],
#  ['rosto', 'compartilhar', 'poder', 'passar', 'covid'],
#  ['devo', 'lavar', 'roupa', 'chegar', 'casa'],
#  ['poder', 'infectado'],
#  ['produto', 'supermercado', 'poder', 'infectado'],
#  ['preciso', 'passar', 'alcool', 'gel', 'sacola', 'supermercado'],
#  ['poder',
#   'levar',
#   'virus',
#   'pra',
#   'dentro',
#   'casa',
#   'apos',
#   'tocar',
#   'espaco'],
#  ['cadastrar', 'cadastur'],
#  ['gerar', 'cadastro', 'cadastur'],
#  ['novo'],
#  ['cadastur'],
#  ['finalidade', 'cadastur'],
#  ['cadastur', 'obrigatorio'],
#  ['cadastur'],
#  ['registro', 'cadastur'],
#  ['cadastur'],
#  ['cadastur'],
#  ['cadastur'],
#  [],
#  [],
#  [],
#  [],
#  ['expliqueme', 'registro', 'cadastur'],
#  ['definame', 'registro', 'cadastur'],
#  ['registro', 'cadastur'],
#  ['cadastur'],
#  ['querer', 'cadastrar'],
#  ['cadastrar'],
#  ['gerar', 'cadastro'],
#  ['cadastro'],
#  ['cadastro'],
#  ['cadastro'],
#  ['preencher', 'cadastro'],
#  ['fazer', 'cadastro'],
#  ['querer', 'cadastrar'],
#  ['querer', 'fazer', 'cadastro'],
#  ['cadastrar', 'agora'],
#  ['fazer', 'cadastro'],
#  ['fazer', 'cadastro'],
#  ['cadastro'],
#  ['querer', 'gerar', 'cadastro'],
#  ['fazer', 'cadastrar'],
#  ['cadastrar'],
#  ['preencher', 'cadastramento'],
#  ['fazer', 'cadastramento'],
#  ['cadastramento'],
#  ['criar', 'cadastro'],
#  ['falabr'],
#  ['denunciar', 'ouvidorio'],
#  ['ouvidorio'],
#  ['falar', 'ouvidoria', 'acesso', 'informacao'],
#  ['ouvidorio'],
#  ['ouvidorio', 'acesso', 'informacao'],
#  ['geral'],
#  [],
#  ['central', 'atendimento', 'cidadao'],
#  ['falabr', 'ouvidoria', 'acesso', 'informacao'],
#  ['atendimento', 'cidadao'],
#  ['atendimento'],
#  ['atendimento'],
#  ['querer',
#   'denunciar',
#   'descumprimento',
#   'protocolo',
#   'higiente',
#   'orientar',
#   'selo'],
#  ['poder',
#   'denunciar',
#   'descumprimento',
#   'medida',
#   'higiente',
#   'orientar',
#   'selo'],
#  ['descumprimento',
#   'protocolo',
#   'medida',
#   'protecao',
#   'seguranca',
#   'sanitario'],
#  ['denunciar',
#   'descumprimento',
#   'medida',
#   'protecao',
#   'seguranca',
#   'sanitario',
#   'recomendar',
#   'selo'],
#  ['querer',
#   'denunciar',
#   'descumprimento',
#   'medida',
#   'higiente',
#   'orientar',
#   'selo'],
#  ['fazer', 'denuncia', 'referente', 'estabelecimento', 'cumprir', 'saude'],
#  ['denuncia',
#   'referente',
#   'estabelecimento',
#   'descumprimento',
#   'medida',
#   'protecao',
#   'seguranca',
#   'sanitario'],
#  ['estabelecimento', 'querer', 'continuar', 'responsavel'],
#  ['estabelecimento', 'querer', 'cancelar', 'selo'],
#  ['ter', 'adesao', 'selo'],
#  ['querer', 'retirar', 'adesao', 'selo', 'turismo', 'responsavel'],
#  ['possivel', 'prestador', 'servico', 'turistico', 'retirar', 'adesao', 'selo'],
#  ['ter', 'interesse', 'usar', 'selo', 'estabelecimento'],
#  ['querer', 'programa', 'selo', 'turismo'],
#  ['participar', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['ir', 'cancelar', 'selo', 'fazer'],
#  ['querer', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['querer', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['querer', 'sair', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['fazer', 'cancelar', 'selo', 'turismo', 'reponsavel'],
#  ['estabelecimento', 'querer', 'sair', 'programa', 'selo', 'turismo'],
#  ['conseguir', 'ter', 'acesso', 'todo', 'publicitario'],
#  ['dar', 'erro', 'emissao', 'selo'],
#  ['aparecer', 'nada', 'exportar', 'peca', 'promocional'],
#  ['apos', 'emissao', 'exportar', 'peca', 'promocional', 'nada', 'aparecer'],
#  ['selo', 'ocorrer', 'erro'],
#  ['selo', 'aparecer', 'proceder'],
#  ['aderir', 'selo', 'preciso', 'peca', 'promocional', 'fazer'],
#  ['aparecer', 'opcao', 'exportar', 'peca', 'promocional'],
#  ['exportar', 'peca', 'promocional'],
#  ['selo', 'continua', 'ativo', 'verifico'],
#  ['saber', 'selo', 'continua', 'ativado'],
#  ['saber', 'selo'],
#  ['preciso', 'saber', 'situacao', 'selo', 'ativado'],
#  ['ver', 'selo'],
#  ['verificar', 'selo', 'empreendimento', 'continua', 'ativo'],
#  ['verificar', 'selo', 'empreendimento', 'ativo'],
#  ['quero', 'ver', 'selo', 'ativo', 'turistas'],
#  ['saber', 'selo', 'continua', 'ativo'],
#  ['verifico', 'selo', 'ativo'],
#  ['faco', 'saber', 'selo', 'ativo'],
#  ['saber', 'selo', 'ativo', 'prestador'],
#  ['vejo', 'selo', 'ativado'],
#  ['saber', 'selo', 'ativado', 'proceder'],
#  ['protocolo', 'garantir', 'protecao', 'seguranca', 'sanitario'],
#  ['protocolo', 'necessario', 'tipo', 'estabelecimento'],
#  ['protocolo', 'necessario'],
#  ['protocolo', 'praticar', 'programa', 'selo', 'turista', 'responsavel'],
#  ['protocolo', 'estabelecir', 'programa', 'selo', 'turista', 'responsavel'],
#  ['protocolo', 'exigir', 'empreendimento', 'turistico'],
#  ['protocolo', 'devo', 'seguir'],
#  ['protocolo', 'recomendar'],
#  ['protocolo', 'geral'],
#  ['protocolo', 'especifico'],
#  ['protocolo'],
#  ['protocolo'],
#  ['onde', 'pesquiso', 'protocolo', 'hotel'],
#  ['protocolo', 'medida', 'protecao', 'seguranca', 'hospedagem'],
#  ['ter', 'hotel', 'protocolo', 'dever', 'seguir'],
#  ['ter', 'hotel', 'protocolo', 'praticar'],
#  ['protocolo', 'ter', 'adotar', 'hotel'],
#  ['hotel', 'dever', 'seguir', 'protocolo'],
#  ['protocolo', 'bom', 'pratica', 'hospedagem'],
#  ['medida', 'especifico', 'protocolo', 'hospedagem'],
#  ['hotel', 'dever', 'seguir', 'medida', 'especifico', 'protocolo'],
#  ['hotel', 'ter', 'protocolo', 'especifico'],
#  ['existir', 'protocolo', 'especifico', 'meio', 'hospedagem'],
#  ['meio', 'hospedagem'],
#  ['setor', 'hoteleiro', 'possuira', 'protocolo', 'especifico'],
#  ['recomendacoes', 'hotel'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['resorts'],
#  ['pensao'],
#  ['pousada'],
#  ['estalagem'],
#  ['estalagem', 'pensao'],
#  ['hotel'],
#  ['protocolo', 'hotelaria', 'hospedagem'],
#  ['protocolo', 'rede', 'hotel'],
#  ['protocolo', 'hotel'],
#  ['protocolo', 'hospedagem'],
#  ['recomendacao'],
#  ['recomendacao', 'hospedagem'],
#  ['recomendacao', 'hotel'],
#  ['recomendacoes', 'meio', 'hospedagem'],
#  ['onde', 'achar', 'protocolo', 'setor', 'hoteleiro'],
#  ['onde', 'pesquiso', 'protocolo', 'setor', 'hoteleito'],
#  ['onde', 'ver', 'protocolo', 'setor', 'hoteleito'],
#  ['setor', 'hoteleiro', 'protocolo', 'dever', 'seguir'],
#  ['protocolo', 'seguir', 'hotel'],
#  ['protocolo', 'setor', 'hoteleiro'],
#  ['setor', 'hoteleiro', 'possuira', 'protocolo'],
#  ['setor', 'hoteleiro', 'cumprir', 'protocolo', 'especifico'],
#  ['protocolo', 'recomendar', 'meio', 'hospedagem'],
#  ['protocolo', 'recomendar', 'hotel', 'pousada', 'resorts'],
#  ['protocolo', 'estabelecer', 'hotelaria'],
#  ['protocolo', 'setor', 'meios', 'hospedagem'],
#  ['interessado',
#   'dever',
#   'atender',
#   'orientacao',
#   'protocolo',
#   'destinar',
#   'atividade',
#   'turistico',
#   'atuar'],
#  ['meio', 'atender', 'prerequisito', 'solicitar', 'adesao', 'selo'],
#  ['empreendimentos', 'poderao', 'aderir', 'ter', 'acesso', 'selo'],
#  ['dar', 'novo', 'orientacao', 'higiene', 'farei', 'atualizar'],
#  ['dar', 'atualizacao', 'protocolo'],
#  ['protocolo', 'atualizacao', 'frequente'],
#  ['protocolo', 'sera', 'atualizar'],
#  ['protocolo', 'mudar'],
#  ['protocolo', 'documento', 'unico', 'poder', 'atualizar'],
#  ['ter', 'outro', 'higiene', 'atualizar'],
#  ['sera', 'atualizacao', 'informar', 'novo', 'medida', 'higiene'],
#  ['atualizar', 'informar', 'novo', 'medida', 'higiene'],
#  ['informar', 'novo', 'recomendacoes', 'higiene', 'atualizar'],
#  ['ir',
#   'manter',
#   'atualizar',
#   'novo',
#   'orientacoes',
#   'higiene',
#   'divulgar',
#   'mtur'],
#  ['sair', 'novo', 'orientacoes', 'higiene', 'ir', 'atualizar', 'selo'],
#  ['ficar', 'saber', 'novo', 'orientacao', 'tipo', 'estabelecimento'],
#  ['ficar', 'saber', 'novo', 'orientacao', 'higiene', 'tipo', 'estabelecimento'],
#  ['sempre',
#   'ministerio',
#   'turismo',
#   'divulgar',
#   'novo',
#   'orientacao',
#   'higiene',
#   'devo',
#   'atualizar',
#   'selo'],
#  ['novo', 'orientacao', 'higiene', 'divulgar', 'mtur', 'fazer'],
#  ['selo', 'sempre', 'atualizar', 'surgir', 'novo', 'orientacao', 'higiene'],
#  ['caso', 'surgir', 'novo', 'orientacao', 'higiene', 'atualizar', 'selo'],
#  ['caso', 'surgir', 'novo', 'orientacao', 'higiene', 'preciso', 'novo', 'selo'],
#  ['medida', 'higiene', 'sanitar', 'atualizacao', 'preciso', 'fazer', 'selo'],
#  ['medida',
#   'higiene',
#   'sanitar',
#   'atualizacao',
#   'preciso',
#   'baixar',
#   'novo',
#   'selo'],
#  ['medida',
#   'higiene',
#   'sanitaria',
#   'protocolo',
#   'ter',
#   'atualizacao',
#   'frequente'],
#  ['medida',
#   'higiene',
#   'sanitar',
#   'recomendar',
#   'selo',
#   'ter',
#   'atualizacao',
#   'frequente'],
#  ['medida',
#   'higiene',
#   'sanitar',
#   'estabelecir',
#   'selo',
#   'ter',
#   'atualizacao',
#   'frequente'],
#  ['protocolo', 'estabelecer', 'selo', 'ter', 'atualizacao'],
#  ['protocolo', 'documento', 'unico'],
#  ['quais',
#   'criterios',
#   'ministerio',
#   'turismo',
#   'formulacao',
#   'desses',
#   'protocolos'],
#  ['quais',
#   'criterios',
#   'utilizados',
#   'ministerio',
#   'turismo',
#   'formulacao',
#   'desses',
#   'protocolos'],
#  ['quais',
#   'criterios',
#   'utilizados',
#   'mtur',
#   'formulacao',
#   'desses',
#   'protocolos'],
#  ['protocolo',
#   'propor',
#   'submetir',
#   'crivo',
#   'tecnico',
#   'agencia',
#   'nacional',
#   'vigilancia',
#   'sanitaria',
#   'anvisa',
#   'ministerio',
#   'saude'],
#  ['protocolo',
#   'validados',
#   'agencia',
#   'nacional',
#   'vigilancia',
#   'sanitaria',
#   'anvisa'],
#  ['adocao',
#   'protocolo',
#   'selo',
#   'levar',
#   'consideracao',
#   'medida',
#   'adotar',
#   'entidade',
#   'internacional',
#   'similar'],
#  ['adocao',
#   'protocolo',
#   'levar',
#   'conta',
#   'protocolo',
#   'medida',
#   'adotar',
#   'entidade',
#   'internacional'],
#  ['protocolo', 'propor', 'validados', 'ministerio', 'saude'],
#  ['criterios', 'formulacao', 'protocolos', 'validar', 'anvisa'],
#  ['protocolo'],
#  ['protocolo', 'propor', 'validar', 'anvisa'],
#  ['protocolo', 'profissional', 'setor'],
#  ['protocolo', 'selo', 'ter', 'anvisa'],
#  ['protocolo',
#   'levar',
#   'consideracao',
#   'medida',
#   'adotar',
#   'entidade',
#   'internacional',
#   'similar'],
#  ['protocolo',
#   'submetir',
#   'crivo',
#   'tecnico',
#   'agencia',
#   'nacional',
#   'vigilancia',
#   'sanitaria',
#   'anvisa'],
#  ['uso',
#   'selo',
#   'representa',
#   'custo',
#   'adicional',
#   'valor',
#   'servicos',
#   'turisticos'],
#  ['selo', 'representara', 'custo', 'valor', 'servicos', 'turisticos'],
#  ['ter',
#   'custo',
#   'adicional',
#   'medida',
#   'impor',
#   'selo',
#   'poder',
#   'cobrar',
#   'servico'],
#  ['ter',
#   'custo',
#   'adicional',
#   'medida',
#   'impor',
#   'selo',
#   'poder',
#   'embutir',
#   'servico',
#   'turistico'],
#  ['despesa',
#   'adicional',
#   'protocolo',
#   'higiente',
#   'poder',
#   'embutir',
#   'custo',
#   'servico',
#   'turistico'],
#  ['selo', 'poder', 'ratear', 'despesa', 'higiene', 'taxa', 'servico'],
#  ['poder',
#   'ratear',
#   'despesa',
#   'higiene',
#   'taxa',
#   'servico',
#   'aderir',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['poder',
#   'ratear',
#   'despesa',
#   'higiene',
#   'taxa',
#   'servico',
#   'empreendimento',
#   'aderir',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['ter', 'selo', 'farei', 'compensar', 'despesa', 'extro', 'medida', 'higiene'],
#  ['selo',
#   'exigir',
#   'vario',
#   'controle',
#   'higiene',
#   'fazer',
#   'compensar',
#   'despesa',
#   'extro'],
#  ['selo',
#   'exigir',
#   'vario',
#   'medida',
#   'seguranca',
#   'higiene',
#   'fazer',
#   'compensar',
#   'despesa',
#   'extro'],
#  ['farei', 'despesa', 'extraordinario', 'selo', 'turismo', 'responsavel'],
#  ['governo',
#   'reduzira',
#   'imposto',
#   'compensar',
#   'despesa',
#   'extraordinario',
#   'impor',
#   'uso',
#   'selo'],
#  ['diaria', 'valor', 'maior', 'aderir', 'selo', 'turismo', 'responsavel'],
#  ['diaria', 'valor', 'maior', 'despesa', 'medida', 'higiene'],
#  ['diaria', 'valor', 'maior', 'compensar', 'despesa', 'medida', 'higiene'],
#  ['posso',
#   'aumentar',
#   'valor',
#   'diaria',
#   'custo',
#   'medida',
#   'seguranca',
#   'selo'],
#  ['posso',
#   'aumentar',
#   'valor',
#   'taxa',
#   'servico',
#   'medida',
#   'higiene',
#   'impor',
#   'selo'],
#  ['medida',
#   'higiene',
#   'impor',
#   'selo',
#   'posso',
#   'aumentar',
#   'valor',
#   'taxa',
#   'servico'],
#  ['governo',
#   'reduzira',
#   'imposto',
#   'compensar',
#   'despesa',
#   'extro',
#   'medida',
#   'higiene',
#   'exigir',
#   'selo'],
#  ['perspectiva',
#   'acrescimo',
#   'valor',
#   'servico',
#   'prestar',
#   'adocao',
#   'medida'],
#  ['apos',
#   'adocao',
#   'medida',
#   'recomendar',
#   'perspectiva',
#   'acrescimo',
#   'valor',
#   'servico',
#   'prestar'],
#  ['apos',
#   'adocao',
#   'medida',
#   'recomendar',
#   'previsao',
#   'aumento',
#   'valor',
#   'servico',
#   'prestar'],
#  ['variacao',
#   'taxas',
#   'servicos',
#   'devido',
#   'custo',
#   'adicional',
#   'imposto',
#   'protocolo'],
#  ['variacao',
#   'taxas',
#   'servicos',
#   'devido',
#   'custo',
#   'adicional',
#   'imposto',
#   'medidas',
#   'higiene'],
#  ['precos', 'acrescimos', 'devido', 'implementacao', 'medidas'],
#  ['precos', 'acrescimos', 'devido', 'implementacao', 'medidas', 'higiene'],
#  ['precos', 'devido', 'custo', 'higiene', 'sanitaria'],
#  ['precos',
#   'comprometidos',
#   'maior',
#   'gasto',
#   'produtos',
#   'higiene',
#   'sanitaria'],
#  ['precos',
#   'comprometidos',
#   'maior',
#   'gasto',
#   'produtos',
#   'limpeza',
#   'higiene'],
#  ['precos', 'aumento', 'devido', 'maior', 'produtos', 'limpeza', 'higiene'],
#  ['diaria', 'valor', 'maior', 'estabelecimentos', 'selo'],
#  ['havera',
#   'variacao',
#   'taxas',
#   'servicos',
#   'devido',
#   'custo',
#   'medidas',
#   'impostas',
#   'selo'],
#  ['variacao',
#   'taxas',
#   'servicos',
#   'devido',
#   'custo',
#   'adicional',
#   'imposto',
#   'selo'],
#  ['selo', 'representara', 'custo', 'valor', 'taxas', 'servicos', 'turisticos'],
#  ['selo', 'aumento', 'taxas', 'servicos'],
#  ['selo', 'estabelecimentos', 'taxas', 'servicos'],
#  ['taxas', 'servicos', 'adocao', 'selo'],
#  ['havera',
#   'variacao',
#   'taxas',
#   'servicos',
#   'devido',
#   'medidas',
#   'impostas',
#   'selo'],
#  ['onde', 'vejo', 'medida', 'especifico', 'tipo', 'estabelecimento'],
#  ['clientes', 'saber', 'exigir', 'estabelecimento', 'relacao', 'higiene'],
#  ['clientes', 'poderao', 'exigir', 'estabelecimento', 'relacao', 'higiene'],
#  ['clientes',
#   'poderao',
#   'bom',
#   'pratica',
#   'higienizacao',
#   'cada',
#   'segmento',
#   'setor',
#   'turistico'],
#  ['clientes',
#   'poderao',
#   'exigir',
#   'conformidade',
#   'bom',
#   'pratica',
#   'higienizacao'],
#  ['bom', 'pratica', 'higienizacao', 'poderao', 'clientes'],
#  ['saber', 'conformidade', 'medida', 'tipo', 'estabelecimento'],
#  ['exigir', 'conformidade', 'estabelecimentos', 'protocolos'],
#  ['qto', 'custar', 'selo'],
#  ['qto', 'custar', 'selo'],
#  ['precisa', 'pagar'],
#  [],
#  ['gratuito'],
#  ['ter', 'algum', 'custo'],
#  ['ter', 'custo'],
#  ['taxa', 'cobrar', 'selo', 'turista', 'responsavel'],
#  ['preciso',
#   'pagar',
#   'pedir',
#   'selo',
#   'turista',
#   'responsavel',
#   'estabelecimento'],
#  ['ter', 'taxa', 'obter', 'selo', 'turista', 'responsavel'],
#  ['ter', 'taxa', 'usar', 'selo', 'turista', 'responsavel'],
#  ['ter', 'pagar', 'ter', 'selo', 'turista', 'responsavel', 'empreendimento'],
#  ['preciso',
#   'recolher',
#   'alguma',
#   'taxa',
#   'aderir',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['preciso',
#   'recolher',
#   'alguma',
#   'taxa',
#   'ter',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['preciso', 'pagar', 'ter', 'selo', 'turista', 'responsavel'],
#  ['taxas', 'aderir', 'programa', 'selo', 'turista', 'responsavel'],
#  ['interessado', 'usar', 'selo', 'precisa', 'pagar', 'alguma', 'coisa'],
#  ['pagar', 'algum', 'taxa', 'usar', 'selo', 'turista', 'responsavel'],
#  ['ter', 'selo', 'turista', 'responsavel', 'quanto', 'ter', 'pagar'],
#  ['pedir', 'selo', 'turista', 'responsavel', 'quanto', 'ter', 'pagar'],
#  ['requerer', 'selo', 'turista', 'responsavel', 'quanto', 'ter', 'pagar'],
#  ['querer', 'ter', 'selo', 'valor', 'selo', 'turista', 'responsavel'],
#  ['valor', 'cobrar', 'selo', 'turista', 'responsavel'],
#  ['interessado', 'tirar', 'selo', 'precisar', 'pagar', 'algum', 'coisa'],
#  ['quanto', 'custar', 'pra', 'tirar'],
#  ['quanto', 'pagar', 'pra', 'tirar'],
#  ['quanto', 'ter', 'pagar', 'tirar'],
#  ['quanto', 'custar', 'selo'],
#  ['valor', 'selo'],
#  ['quanto', 'custar', 'selo'],
#  ['quanto', 'custar', 'selo'],
#  ['quanto', 'custar', 'dois', 'selo'],
#  ['quanto', 'custar', 'selo'],
#  ['qto', 'pagar'],
#  ['quanto', 'pagar'],
#  ['qto', 'pagar'],
#  ['quanto', 'pagar'],
#  ['segue', 'protocolo', 'higiene'],
#  ['selo', 'visivel', 'segue', 'medidas', 'higiene'],
#  ['selo', 'visivel', 'segue', 'protocolo', 'seguranca'],
#  ['pra', 'selo', 'cumprindo', 'protocolo'],
#  ['irregularidade', 'controle', 'empreendimentos', 'selo'],
#  ['turista', 'identificar', 'alguma', 'irregularidade', 'local', 'usa', 'selo'],
#  ['turista',
#   'identificar',
#   'alguma',
#   'irregularidade',
#   'devera',
#   'feito',
#   'proceder'],
#  ['turista',
#   'identificar',
#   'alguma',
#   'conformidade',
#   'local',
#   'usa',
#   'selo',
#   'devera',
#   'feito'],
#  ['local', 'onde', 'hospedei', 'selo', 'cheio', 'irregularidade', 'faco'],
#  ['local', 'onde', 'hospedei', 'selo', 'cheio', 'irregularidade', 'proceder'],
#  ['selo', 'adiantou', 'nada', 'empreendimento'],
#  ['selo', 'adiantou', 'nada', 'empreendimento', 'cumprindo', 'protocolos'],
#  ['selo', 'adiantou', 'nada', 'empreendimento', 'cumprindo', 'recomendacoes'],
#  ['ter', 'selo', 'lugar', 'cumprindo', 'medidas', 'higiene'],
#  ['obrigatorio', 'uso', 'selo', 'turismo', 'responsavel'],
#  ['ministerio', 'turismo', 'tornar', 'obrigatorio', 'uso', 'selo'],
#  ['selo', 'obrigatorior'],
#  ['obrigar', 'usar', 'selo', 'estabelecimento'],
#  ['obrigatoriedade'],
#  ['obrigatorior'],
#  ['multar', 'ter', 'selo', 'turista', 'responsavel'],
#  ['aderir', 'selo', 'turista', 'responsavel', 'acontecer'],
#  ['lei', 'obrigar', 'ter', 'selo', 'turista', 'responsavel'],
#  ['ter', 'algum', 'lei', 'obrigar', 'uso', 'selo'],
#  ['ter', 'algum', 'lei', 'obrigar', 'uso', 'selo', 'turismo', 'responsavel'],
#  ['punicao',
#   'empreendimento',
#   'aderir',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['punicao',
#   'estabelecimento',
#   'aderir',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['obrigar', 'selo'],
#  ['uso', 'selo', 'obrigatorior'],
#  ['obrigatorio', 'usar', 'selo'],
#  ['nao', 'ter', 'selo', 'turista', 'responsavel', 'ter', 'pagar'],
#  ['nao', 'ter', 'selo', 'turista', 'responsavel', 'ter', 'punicao', 'punicao'],
#  ['selo', 'turista', 'responsavel', 'ter', 'punicao', 'punicao'],
#  ['ter', 'selo', 'turista', 'responsavel', 'visivel', 'turista'],
#  ['poder', 'multar', 'ter', 'selo', 'turismo', 'responsavel'],
#  ['poder', 'fiscalizar', 'ter', 'selo', 'turismo', 'responsavel'],
#  ['estabelecimento', 'voltar', 'funcionar', 'preciso', 'ter', 'selo'],
#  ['obrigatorio',
#   'usar',
#   'selo',
#   'turismo',
#   'responsavel',
#   'voltar',
#   'atividade'],
#  ['obrigatorio', 'usar', 'selo', 'turismo', 'responsavel', 'funcionar'],
#  ['obrigar', 'usar', 'selo', 'empreendimento'],
#  ['selo', 'turismo'],
#  ['programa', 'selo', 'turismo', 'responsavel'],
#  ['definer', 'selo', 'turismo', 'responsavel'],
#  ['selo'],
#  ['servir', 'selo', 'turismo', 'responsavel'],
#  ['papel', 'selo', 'turismo', 'responsavel'],
#  ['finalidade', 'selo'],
#  ['finalidade', 'selo', 'turismo'],
#  ['papel', 'selo', 'turismo', 'retomada', 'atividade', 'turistico', 'brasil'],
#  ['programa', 'selo', 'turismo', 'responsavel', 'adotar', 'medida', 'eficaz'],
#  ['destinar', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['finalidade', 'programa', 'estabelecer', 'selo', 'turismo', 'responsavel'],
#  ['finalidade', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['governo', 'brasileiro', 'esperar', 'selo'],
#  ['brasil',
#   'incentivar',
#   'adesao',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['governo', 'incentivar', 'uso', 'selo', 'turista', 'responsavel'],
#  ['programa',
#   'selo',
#   'turista',
#   'responsavel',
#   'seguir',
#   'bom',
#   'pratica',
#   'higienizacao',
#   'ambiente'],
#  ['selo', 'turismo', 'responsavel'],
#  ['selo', 'responsavel'],
#  ['selo'],
#  ['selo', 'turismo', 'responsavel'],
#  ['selo'],
#  ['selo', 'turismo'],
#  ['selo', 'responsavel', 'seguro'],
#  ['programa', 'turismo', 'responsavel'],
#  ['programa'],
#  ['pra', 'servir'],
#  ['servir', 'selo'],
#  ['onde', 'vejer', 'ja', 'protocolo', 'selo'],
#  ['existir', 'algum', 'onde', 'poder', 'ver', 'empresa', 'adotar', 'selo'],
#  ['ter', 'algum', 'painel', 'dizer', 'empresa', 'ja', 'aderir', 'selo'],
#  ['onde',
#   'achar',
#   'relacao',
#   'empreendimento',
#   'turistico',
#   'aderir',
#   'selo',
#   'turismo'],
#  ['onde', 'achar', 'relacao', 'empresa', 'aderir', 'selo', 'turismo'],
#  ['onde',
#   'consulto',
#   'estabelecimento',
#   'ja',
#   'aderir',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['prestador', 'servico', 'turistico', 'ja', 'aderir', 'selo'],
#  ['ja', 'aderir', 'selo'],
#  ['saber', 'empreendimento', 'aderir', 'selo'],
#  ['pesquiso', 'prestador', 'servico', 'turistico', 'habilitar', 'selo'],
#  ['pesquiso', 'prestador', 'habilitar'],
#  ['pesquiso', 'hotel', 'ja', 'aderiu', 'selo'],
#  ['pesquiso', 'ja', 'aderiu', 'selo'],
#  ['estado', 'quantos', 'empreendimentos', 'turisticos', 'ja', 'aderiram'],
#  ['onde', 'consulto', 'estabelecimento', 'ja', 'aderir', 'selo'],
#  ['observei', 'aumento', 'numero', 'selo', 'painel', 'acompanhamento'],
#  ['observei', 'reducao', 'numero', 'selo', 'painel', 'acompanhamento'],
#  ['verifico', 'quantos', 'empreendimentos', 'aderiram', 'selo'],
#  ['aderiu', 'selo'],
#  ['empreendimentos', 'aderiram', 'programa', 'selo', 'turismo'],
#  ['faco', 'saber', 'empreendimentos', 'aderiram', 'programa', 'selo'],
#  ['pesquiso',
#   'quais',
#   'empresas',
#   'aderiram',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['consulto',
#   'quais',
#   'empresas',
#   'aderiram',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['funciona', 'painel', 'selo'],
#  ['preciso', 'saber', 'empreendimento', 'fazer', 'selo'],
#  ['ir',
#   'viajar',
#   'querer',
#   'pequisar',
#   'estabelecimento',
#   'habilitar',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['ir',
#   'viajar',
#   'querer',
#   'pequisar',
#   'estabelecimento',
#   'cadastrado',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['preciso', 'saber', 'estabelecimento', 'adotar', 'selo'],
#  ['estabelecimento', 'ja', 'adotar', 'selo'],
#  ['onde', 'vejer', 'ja', 'adotar', 'selo'],
#  ['existir', 'prazo', 'emissao', 'selo'],
#  ['prazo', 'entrega'],
#  ['previsao', 'entrega', 'selo'],
#  ['demor', 'receber', 'selo'],
#  ['quanto', 'tempo', 'solicitacao'],
#  ['quanto', 'tempo', 'demor', 'ter', 'selo'],
#  ['quanto', 'tempo', 'levar', 'selo'],
#  ['ter', 'esperar', 'quanto', 'tempo', 'receber', 'selo'],
#  ['previsao', 'entrega', 'selo'],
#  ['ter', 'esperar', 'quanto', 'tempo', 'receber', 'selo'],
#  ['solicitacao', 'esperar', 'tempo'],
#  ['previsao', 'prazo', 'ter', 'selo'],
#  ['quanto', 'demor', 'pedido', 'selo', 'ate', 'liberacao'],
#  ['quanto', 'tempo', 'gastar', 'pedido', 'ate', 'liberacao', 'selo'],
#  ['quanto', 'tempo', 'gastar', 'pedido', 'ate', 'selo'],
#  ['quanto', 'tempo', 'gastar', 'pedido', 'ate', 'selo'],
#  ['pedir', 'selo', 'quanto', 'tempo'],
#  ['cadastro', 'receber', 'selo'],
#  ['cadastro', 'conseguir', 'selo'],
#  ['ter', 'acesso', 'selo'],
#  ['querer', 'solicitar', 'selo', 'turista', 'responsavel'],
#  ['querer', 'pedir', 'selo', 'turista', 'responsavel'],
#  ['querer', 'inscrever', 'programa', 'selo', 'turista', 'responsavel'],
#  ['procedimento', 'solicitar', 'selo', 'turista', 'responsavel'],
#  ['solicitar', 'selo', 'turista', 'responsavel'],
#  ['querer', 'ter', 'selo'],
#  ['fazer', 'adesao', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['fazer', 'solicitar', 'selo', 'turista', 'responsavel'],
#  ['fazer', 'pedir', 'selo', 'turista', 'responsavel'],
#  ['processo', 'solicitacao', 'selo', 'turista', 'responsavel'],
#  ['querer', 'selo', 'turismo', 'responsavel', 'estabelecimento'],
#  ['querer', 'conseguir', 'turismo', 'responsavel', 'estabelecimento'],
#  ['querer', 'pedir', 'selo', 'turismo', 'responsavel', 'estabelecimento'],
#  [],
#  ['pleitear', 'selo', 'turismo', 'responsavel'],
#  ['preciso', 'selo', 'turismo', 'responsavel', 'fazer', 'pedido'],
#  ['querer', 'solicitar', 'selo', 'turismo'],
#  ['preciso', 'ajuda', 'pedir', 'selo', 'turismo', 'responsavel'],
#  ['ajuda', 'pedir', 'selo', 'turista', 'responsavel'],
#  ['preciso', 'orientacao', 'pedir', 'selo', 'turista', 'responsavel'],
#  ['onde', 'poder', 'pedir', 'selo', 'turista', 'responsavel'],
#  ['lugar', 'posso', 'pedir', 'selo', 'turista', 'responsavel'],
#  ['procedimento', 'pedir', 'selo'],
#  ['orientacao', 'dever', 'seguir', 'obter', 'selo'],
#  ['cadastrar', 'obter', 'selo'],
#  ['solicitar', 'selo', 'turismo', 'responsavel'],
#  ['empresa', 'setor', 'turismo', 'devo', 'pedir', 'selo'],
#  ['devo', 'pedir', 'selo', 'empresa', 'setor', 'turismo'],
#  ['outro',
#   'empresa',
#   'setor',
#   'turistico',
#   'dever',
#   'solicitar',
#   'selo',
#   'cada'],
#  ['ter', 'empresa', 'setor', 'turistico', 'dever', 'solicitar', 'selo', 'cada'],
#  ['ter', 'empreendimento', 'turismo', 'selo', 'cada'],
#  ['ter',
#   'vario',
#   'estabelecimento',
#   'turismo',
#   'preciso',
#   'ter',
#   'selo',
#   'cada'],
#  ['ter', 'empresa', 'setor', 'turistico', 'preciso', 'selo', 'cada'],
#  ['preciso', 'ter', 'selo', 'cada', 'empreendimento'],
#  ['fazer', 'conseguir', 'selo'],
#  ['processo', 'solicitacao', 'selo'],
#  ['preciso', 'participar'],
#  ['querer'],
#  ['fazer'],
#  ['necessario'],
#  ['cadastrar', 'receber', 'selo'],
#  ['governo',
#   'fiscalizar',
#   'empreendimentos',
#   'ver',
#   'conformidade',
#   'medidas',
#   'necessarias'],
#  ['interesse', 'cumprimento', 'protocolo', 'proprio', 'empreendedor'],
#  ['interesse',
#   'cumprimento',
#   'medida',
#   'sanitaria',
#   'protecao',
#   'proprio',
#   'empreendedor'],
#  ['avaliar', 'empreendimento', 'seguir', 'protocolo', 'estabelecer'],
#  ['avaliar', 'empreendimento', 'seguir', 'recomendacoes', 'protocolo'],
#  ['mtur',
#   'verificar',
#   'empreendimentos',
#   'adotando',
#   'medidas',
#   'necessarias',
#   'ter',
#   'acesso',
#   'selo'],
#  ['ministerio',
#   'turismo',
#   'pode',
#   'ter',
#   'empreendimentos',
#   'adotando',
#   'medidas',
#   'necessarias',
#   'ter',
#   'acesso',
#   'selo'],
#  ['ministerio',
#   'turismo',
#   'empreendimentos',
#   'adotando',
#   'medidas',
#   'necessarias',
#   'protocolo'],
#  ['empreendimentos', 'adotando', 'medidas', 'necessarias'],
#  ['empreendimentos', 'adotando', 'medidas', 'necessarias'],
#  ['empreendimento', 'fiscalizar'],
#  ['empresa', 'fiscalizar'],
#  ['fara', 'fiscalizacao', 'estabelecimentos'],
#  ['fara', 'fiscalizacao', 'ver', 'empreendimentos', 'seguindo', 'protocolo'],
#  ['fara', 'fiscalizacao', 'ver', 'empreendimentos', 'seguindo'],
#  ['fara',
#   'fiscalizacao',
#   'ver',
#   'empreendimentos',
#   'seguindo',
#   'recomendacoes'],
#  ['governo', 'ira', 'fiscalizar', 'todos', 'empreendimentos', 'selo'],
#  ['fara', 'vistoria', 'empreendimentos', 'adotaram', 'selo'],
#  ['mtur', 'fiscalizar', 'empreendimentos', 'selo'],
#  ['fiscalizados', 'adotaram', 'selo'],
#  ['empreendimento', 'selo'],
#  ['periodicidade', 'selo'],
#  ['periodicidade', 'selo'],
#  ['quanto', 'quanto', 'tempo', 'estabelecimentos', 'fiscalizados'],
#  ['quanto', 'quanto', 'tempo', 'estabelecimentos', 'vistoria'],
#  ['mtur', 'ira', 'fiscalizar', 'todos', 'empreendimentos', 'selo'],
#  ['sanitaria', 'fara', 'empreendimentos', 'selo'],
#  ['fara', 'fiscalizacao', 'empreendimentos', 'adotaram', 'selo'],
#  [],
#  ['fiscalizacao'],
#  ['protocolo'],
#  ['expliquar', 'sobre', 'protocolo'],
#  ['esclarecame', 'sobre', 'protocolo'],
#  ['esclarecer', 'protocolo'],
#  ['definame', 'protocolo'],
#  ['diga', 'protocolo'],
#  ['protocolo'],
#  ['protocolo'],
#  ['protocolo'],
#  ['tirar', 'protocolo'],
#  ['funciona', 'protocolo', 'turistas'],
#  ['mtur', 'selo', 'turismo', 'responsavel'],
#  ['selo',
#   'turismo',
#   'responsavel',
#   'representa',
#   'turista',
#   'brasileiro',
#   'estrangeiro'],
#  ['representar', 'selo', 'turismo', 'responsavel', 'turista', 'brasileiro'],
#  ['representar', 'selo', 'turismo', 'responsavel', 'turista', 'estrangeiro'],
#  ['selo', 'brasil', 'destino', 'proteger', 'responsavel', 'turista'],
#  ['selo', 'brasil', 'destino', 'proteger', 'responsavel', 'turista'],
#  ['turista', 'seguro', 'empreendimento', 'adotar', 'selo'],
#  ['turista',
#   'oriundo',
#   'exterior',
#   'representar',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['turista',
#   'vir',
#   'exterior',
#   'representar',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['pq', 'aderir'],
#  ['turista',
#   'sentir',
#   'seguro',
#   'empreendimento',
#   'adotar',
#   'protocolo',
#   'estabelecir',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['selo',
#   'turismo',
#   'responsavel',
#   'adotar',
#   'medida',
#   'sanitario',
#   'higiene',
#   'seguro',
#   'turista'],
#  ['selo',
#   'turismo',
#   'responsavel',
#   'adotar',
#   'medida',
#   'sanitario',
#   'higiene',
#   'turista'],
#  ['selo',
#   'turismo',
#   'responsavel',
#   'atender',
#   'sanitario',
#   'higiene',
#   'turista'],
#  ['pq', 'importante'],
#  ['beneficio', 'usar', 'selo'],
#  ['usar', 'selo'],
#  ['vantagem', 'usar', 'selo'],
#  ['ganhar', 'uso'],
#  ['motivar', 'usar'],
#  ['pq', 'dever', 'usar'],
#  ['porque', 'dever', 'usar'],
#  ['selo', 'representar', 'turista', 'estrangeiro'],
#  ['selo', 'representar', 'turista', 'brasileiro'],
#  ['selo', 'turismo'],
#  ['adocao',
#   'selo',
#   'turismo',
#   'responsavel',
#   'brasil',
#   'destino',
#   'seguro',
#   'turista'],
#  ['turista',
#   'selo',
#   'turismo',
#   'responsavel',
#   'criar',
#   'novo',
#   'conceito',
#   'destino',
#   'seguro'],
#  ['selo',
#   'turismo',
#   'responsavel',
#   'criar',
#   'novo',
#   'conceito',
#   'destino',
#   'seguro',
#   'turista'],
#  ['turista', 'sentir', 'seguro', 'empreendimento', 'aderir', 'selo', 'turismo'],
#  ['selo',
#   'turismo',
#   'responsavel',
#   'tornar',
#   'empreendimento',
#   'adotar',
#   'turista'],
#  ['selo',
#   'turista',
#   'responsavel',
#   'garantir',
#   'protecao',
#   'seguranca',
#   'sanitario',
#   'querer',
#   'visitar',
#   'brasil'],
#  ['protocolo',
#   'estabelecer',
#   'selo',
#   'turista',
#   'responsavel',
#   'garantir',
#   'protecao',
#   'seguranca',
#   'sanitario',
#   'querer',
#   'visitar',
#   'brasil'],
#  ['protocolo',
#   'estabelecer',
#   'selo',
#   'turista',
#   'responsavel',
#   'garantir',
#   'protecao',
#   'seguranca',
#   'sanitario',
#   'turista'],
#  ['querer',
#   'visitar',
#   'brasil',
#   'poder',
#   'confiar',
#   'medida',
#   'protecao',
#   'seguranca',
#   'sanitario',
#   'protocolo',
#   'estabelecer',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['querer',
#   'visitar',
#   'brasil',
#   'poder',
#   'confiar',
#   'medida',
#   'protecao',
#   'seguranca',
#   'sanitario',
#   'exigir',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['querer',
#   'visitar',
#   'brasil',
#   'seguro',
#   'medida',
#   'higienizacao',
#   'adotar',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['querer',
#   'visitar',
#   'brasil',
#   'poder',
#   'confiar',
#   'protocolo',
#   'estabelecir',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['turista',
#   'poder',
#   'confiar',
#   'protocolo',
#   'estabelecir',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['turista',
#   'poder',
#   'confiar',
#   'medida',
#   'estabelecir',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['turista',
#   'brasileiro',
#   'estrangeiro',
#   'motivar',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['porque', 'importante'],
#  ['porque', 'aderir'],
#  ['beneficio'],
#  ['ter', 'beneficio'],
#  ['ter', 'algum'],
#  ['vantagem'],
#  ['ganhar', 'selo'],
#  ['ganhar', 'selo'],
#  ['ter', 'impacto', 'negocio'],
#  ['impacto', 'negocio'],
#  ['vantagem', 'negocio'],
#  ['negocio', 'ganhar', 'selo'],
#  ['ir', 'sair', 'ganhar', 'selo'],
#  ['negocio', 'ganhar'],
#  ['vantagem', 'usar', 'selo'],
#  ['ganhar', 'selo'],
#  ['ganhar', 'selo'],
#  ['selo', 'impacto', 'negocio'],
#  ['selo', 'brasil', 'destino', 'seguro', 'turistas'],
#  ['selo', 'contribuir', 'brasil', 'destino', 'seguro'],
#  ['posso',
#   'comprar',
#   'pacote',
#   'viagem',
#   'selo',
#   'garante',
#   'locais',
#   'seguindo',
#   'protocolos'],
#  ['selo', 'contribuir', 'retomada', 'setor', 'turistico', 'brasil'],
#  ['selo', 'diferencial', 'pais', 'retomada', 'setor'],
#  ['incentivo', 'retomada', 'turismo', 'brasil'],
#  ['retomada', 'atividade', 'brasil'],
#  ['posso', 'comprar', 'pacote', 'viagem', 'selo', 'garante', 'locais'],
#  ['posso',
#   'comprar',
#   'pacote',
#   'viagem',
#   'selo',
#   'garante',
#   'locais',
#   'seguindo',
#   'medidas',
#   'higiene'],
#  ['selo',
#   'turismo',
#   'brasil',
#   'seguro',
#   'posso',
#   'comprar',
#   'pacote',
#   'viagem'],
#  ['selo', 'turismo', 'brasileiro', 'seguro', 'posso', 'comprar', 'pacote'],
#  ['brasil', 'mostrara', 'destino', 'seguro'],
#  ['brasil', 'mostrara', 'destino', 'seguro', 'turistas'],
#  ['brasil', 'mostrara', 'destino', 'seguro', 'mundo'],
#  ['selo', 'mostrara', 'turistas', 'brasil', 'destino', 'seguro'],
#  ['selo', 'mostrara', 'mundo', 'brasil', 'destino', 'turistico'],
#  ['posso',
#   'comprar',
#   'pacote',
#   'viagem',
#   'selo',
#   'garante',
#   'hotes',
#   'seguindo',
#   'medidas',
#   'higiene'],
#  ['posso',
#   'comprar',
#   'pacote',
#   'viagem',
#   'selo',
#   'garante',
#   'hotes',
#   'seguindo',
#   'protocolo'],
#  ['quero',
#   'comprar',
#   'pacote',
#   'viagem',
#   'posso',
#   'confiar',
#   'adotando',
#   'protocolo'],
#  ['quero',
#   'comprar',
#   'pacote',
#   'viagem',
#   'posso',
#   'confiar',
#   'seguindo',
#   'recomendacoes',
#   'higiene'],
#  ['faco', 'saber', 'empreendimento', 'seguindo', 'protocolo'],
#  ['suspendi',
#   'atividade',
#   'durante',
#   'pandemia',
#   'poder',
#   'solicitar',
#   'selo',
#   'assim'],
#  ['atividade',
#   'suspenso',
#   'devido',
#   'pandemia',
#   'ainda',
#   'poder',
#   'pedir',
#   'selo'],
#  ['estabelecimento', 'fechar', 'pandemia', 'poder', 'solicitar', 'selo'],
#  ['estabelecimento', 'fechar', 'pandemia', 'poder', 'pedir', 'selo'],
#  ['suspendi',
#   'atividade',
#   'empreendimento',
#   'poder',
#   'solicitar',
#   'selo',
#   'assim'],
#  ['atividade', 'suspenso', 'durante', 'pandemia', 'querer', 'selo', 'assim'],
#  ['estabelecimento',
#   'atividade',
#   'suspenso',
#   'durante',
#   'pandemia',
#   'querer',
#   'selo',
#   'assim'],
#  ['estabelecimento', 'atividade', 'suspenso', 'poder', 'obter', 'selo'],
#  ['atividade', 'suspenso', 'poder', 'solicitar', 'selo'],
#  ['solicitar',
#   'selo',
#   'estando',
#   'atividade',
#   'suspensa',
#   'devido',
#   'pandemia'],
#  ['posso',
#   'solicitar',
#   'selo',
#   'estando',
#   'atividade',
#   'suspensa',
#   'devido',
#   'pandemia'],
#  ['cadastur', 'obrigatorior'],
#  ['conseguir', 'selo', 'empreendimentos', 'turisticos', 'cadastur'],
#  ['registro', 'cadastro', 'cadastur', 'prerequisito', 'pleitar', 'selo'],
#  ['registro', 'cadastro', 'cadastur', 'condicao', 'exigida', 'pleitar', 'selo'],
#  ['ter', 'cadastur'],
#  ['ter', 'cadastro', 'cadastur'],
#  ['registro',
#   'cadastro',
#   'cadastur',
#   'condicao',
#   'exigida',
#   'solicitar',
#   'selo'],
#  ['registro', 'cadastro', 'cadastur', 'condicao', 'exigida', 'pedir', 'selo'],
#  ['preciso', 'cadastrado', 'cadastur', 'ter', 'selo'],
#  ['devo', 'cadastrado', 'cadastur', 'ter', 'selo'],
#  ['necessario', 'cadastrado', 'cadastur', 'ter', 'selo'],
#  ['obrigatorio', 'cadastrado', 'cadastur', 'ter', 'selo'],
#  ['registro', 'cadastro', 'cadastur', 'obrigatorio', 'pleitar', 'selo'],
#  ['registro', 'cadastro', 'cadastur', 'obrigatoriedade', 'conseguir', 'selo'],
#  ['nao', 'registro', 'cadastur', 'agora'],
#  ['registro', 'cadastur'],
#  ['registro', 'antigo', 'embratur'],
#  ['posso', 'pedir', 'selo', 'cadastro', 'antigo', 'embratur'],
#  ['registrado', 'cadastur', 'existe', 'outra', 'forma', 'pedir', 'selo'],
#  ['registrado', 'cadastur', 'existe', 'outra', 'forma', 'conseguir', 'selo'],
#  ['registrado', 'cadastur', 'preciso', 'selo'],
#  ['preciso', 'registro', 'cadastur'],
#  ['tipos', 'estabelecimentos', 'pode', 'utilizar', 'selo'],
#  ['fazer', 'saber', 'estabelecimento', 'precisar', 'selo'],
#  ['ter', 'poder', 'pedir', 'selo', 'turismo', 'responsavel'],
#  ['todo',
#   'tipo',
#   'empreendimento',
#   'poder',
#   'aderir',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['tipo',
#   'empreendimento',
#   'poder',
#   'aderir',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['poder', 'pedir', 'selo', 'turismo', 'responsavel'],
#  ['atividade', 'turistico', 'poder', 'pleitear', 'selo'],
#  ['todo',
#   'tipo',
#   'empreendimento',
#   'comercial',
#   'poder',
#   'pedir',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['todo',
#   'tipo',
#   'negocio',
#   'poder',
#   'aderir',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['tipo', 'empreendimento', 'poder', 'solicitar', 'selo'],
#  ['tipo', 'empreendimento', 'poder', 'pleitear', 'selo'],
#  ['tipo', 'empreendimento', 'poder', 'requerer', 'selo'],
#  ['estabelecimento'],
#  ['empreendimento'],
#  ['pra'],
#  ['pra', 'destinar'],
#  [],
#  ['tipo', 'estabelecimento', 'poder', 'pedir', 'selo'],
#  ['tipo', 'estabelecimento', 'poder', 'solicitar', 'selo'],
#  ['ter', 'regra', 'impedir', 'pedir', 'selo', 'turismo', 'responsavel'],
#  ['pedir',
#   'selo',
#   'turismo',
#   'responsavel',
#   'estabelecimento',
#   'poder',
#   'impedir'],
#  ['querer', 'pedir', 'selo', 'estabelecimento', 'regra'],
#  ['querer', 'pedir', 'selo', 'saber', 'poder'],
#  ['fazer',
#   'saber',
#   'estabelecimento',
#   'poder',
#   'inscrever',
#   'programa',
#   'selo',
#   'turismo',
#   'reponsavel'],
#  ['atividade', 'turistico', 'poder', 'utilizar', 'selo'],
#  ['tipo', 'estabelecimento', 'poder', 'solicitar', 'selo'],
#  ['todo',
#   'estabelecimento',
#   'comercial',
#   'poder',
#   'usar',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['estabelecimentos', 'pode', 'utilizar', 'selo'],
#  ['tipo', 'estabelecimentos', 'pode', 'utilizar', 'selo'],
#  ['onde',
#   'pesquiso',
#   'saber',
#   'tipo',
#   'estabelecimento',
#   'pode',
#   'pedir',
#   'selo'],
#  ['onde', 'saber', 'tipo', 'estabelecimento', 'pode', 'pedir', 'selo'],
#  ['onde', 'vejo', 'tipo', 'estabelecimento', 'pode', 'selo'],
#  ['preciso', 'saber', 'natureza', 'estabelecimentos', 'pode', 'usar', 'selo'],
#  ['preciso', 'saber', 'quais', 'tipos', 'estabelecimentos', 'usar', 'selo'],
#  ['saber', 'tipo', 'estabelecimento', 'pode', 'pedir', 'selo'],
#  ['tipo', 'estabelecimento', 'dentro', 'ter', 'selo'],
#  ['tipo', 'estabelecimento', 'pode', 'pleitear', 'selo'],
#  ['tipo', 'estabelecimento', 'pode', 'pedir', 'selo'],
#  ['saber', 'tipo', 'estabelecimento', 'usar', 'selo'],
#  ['saber', 'tipo', 'estabelecimento', 'dentro', 'regra', 'selo'],
#  ['posso',
#   'saber',
#   'tipos',
#   'estabelecimentos',
#   'turisticos',
#   'podem',
#   'usar',
#   'selo'],
#  ['todos', 'estabelecimentos', 'turisticos', 'podem', 'usar', 'selo'],
#  ['quais', 'empreendimentos', 'podem', 'utilizar', 'selo'],
#  ['tipo', 'estabelecimentos', 'podem', 'utilizar', 'selo'],
#  ['tuberculose', 'sistema', 'nervoso'],
#  ['tuberculose'],
#  ['tuberculose'],
#  ['tuberculose', 'cerebral'],
#  ['neurotuberculose'],
#  ['neurotuberculose'],
#  ['tuberculose', 'sistema', 'nervoso', 'central'],
#  ['tuberculose', 'cerebral', 'tratar'],
#  ['tuberculose', 'cerebral', 'diagnostico'],
#  ['tuberculose', 'cerebral', 'principal', 'sintoma'],
#  ['preciso', 'pessoa', 'tuberculose', 'pulmonar', 'garganta', 'falar'],
#  ['transmitir', 'tuberculose'],
#  ['contagio', 'tuberculose'],
#  ['transmissao', 'tuberculose'],
#  ['contagio', 'tuberculose'],
#  ['meio', 'transmissao', 'tuberculose'],
#  ['tuberculose', 'transmitir'],
#  ['pegar', 'tuberculose'],
#  ['poder', 'contaminar', 'tuberculose'],
#  ['transmitir'],
#  ['transmitir', 'tuberculose'],
#  ['contagio', 'doenca', 'frequente', 'perto', 'pessoa', 'tuberculose'],
#  ['transmissao', 'tuberculose', 'pessoa'],
#  ['contagio', 'tuberculose', 'acontecer', 'atraves', 'ar'],
#  ['bacilo',
#   'ficar',
#   'ar',
#   'pessoa',
#   'tuberculose',
#   'pulmonar',
#   'garganta',
#   'falar'],
#  ['tuberculose', 'ficar', 'ar', 'tuberculoso', 'falar', 'tosse'],
#  ['pegar', 'ar', 'contaminar', 'bacilo', 'koch'],
#  ['contagio', 'doenca', 'comum', 'perto', 'pessoa', 'tuberculose'],
#  ['impedir', 'contaminacao', 'bacilo', 'koch'],
#  ['vacina', 'impedir', 'contaminacao', 'bacilo', 'koch'],
#  ['vacina', 'contra', 'tuberculose'],
#  ['prevenir', 'tuberculose'],
#  ['proteger', 'contagio', 'tuberculose'],
#  ['prevenir', 'tuberculose'],
#  ['tuberculose'],
#  ['existir', 'prevencao', 'tuberculose'],
#  ['proteger', 'tuberculose'],
#  ['prevencao', 'tuberculose'],
#  ['fator', 'risco', 'gerar', 'aumento', 'contagio', 'tuberculose'],
#  ['querer', 'saber', 'fator', 'risco', 'tuberculose'],
#  ['fator', 'risco', 'tuberculose'],
#  ['tuberculose', 'risco'],
#  ['fator', 'risco', 'tuberculose'],
#  ['risco', 'contrair', 'tuberculose'],
#  ['existir', 'fator', 'aumentar', 'risco', 'contaminacao', 'tuberculose'],
#  ['aumentar', 'risco', 'contrair', 'tuberculose'],
#  ['risco', 'tuberculose'],
#  ['fator', 'risco', 'tuberculose'],
#  ['tuberculose', 'poder', 'torax'],
#  ['tuberculose', 'ganglio'],
#  ['tuberculose', 'ganglionar'],
#  ['tuberculose', 'ganglionar'],
#  ['tuberculose', 'ganglionar', 'sistema'],
#  ['preciso', 'saber', 'sobre', 'tuberculose', 'ganglionar'],
#  ['tuberculose', 'ganglio'],
#  ['falar', 'sobre', 'tuberculose', 'ganglionar'],
#  ['querer', 'saber', 'sobre', 'tuberculose', 'ganglionar'],
#  ['preciso', 'informacao', 'sobre', 'tuberculose', 'ganglionar'],
#  ['explicar', 'sobre', 'tuberculose', 'ganglionar'],
#  ['definer', 'tuberculose', 'ganglionar'],
#  ['tuberculose', 'ganglionar', 'tratar'],
#  ['tuberculose', 'diagnostico'],
#  ['tuberculose', 'ganglionar', 'principal', 'sintoma'],
#  ['tuberculose', 'tratar'],
#  ['beber',
#   'leite',
#   'animal',
#   'contaminar',
#   'causa',
#   'tuberculose',
#   'intestino'],
#  ['comer',
#   'carne',
#   'animal',
#   'contaminar',
#   'causa',
#   'tuberculose',
#   'intestino'],
#  ['comer',
#   'carne',
#   'beber',
#   'leite',
#   'animal',
#   'contaminar',
#   'causa',
#   'tuberculose',
#   'intestino'],
#  ['tuberculose', 'intestino'],
#  ['tuberculose'],
#  ['falame', 'sobre', 'tuberculose', 'intestinal'],
#  ['existir', 'tuberculose', 'intestinal'],
#  ['tuberculose', 'intestinal'],
#  ['tuberculose', 'intestinal'],
#  ['pessoa',
#   'tuberculose',
#   'pulmonar',
#   'engoler',
#   'secrecao',
#   'bacilo',
#   'pegar',
#   'tuberculose',
#   'intestinal'],
#  ['pessoa',
#   'tuberculose',
#   'pulmonar',
#   'engoler',
#   'secrecao',
#   'poder',
#   'desenvolver',
#   'tuberculose',
#   'intestinal'],
#  ['tuberculose', 'intestinal', 'diagnostico'],
#  ['tuberculose', 'intestinal', 'principal', 'sintoma'],
#  ['tuberculose'],
#  ['tuberculose', 'miliar', 'meningea'],
#  ['definer', 'tuberculose', 'miliar', 'meningea'],
#  ['tuberculose', 'miliar', 'meningea'],
#  ['tipo', 'tuberculose', 'bacteria', 'disseminar', 'corrente', 'sanguinea'],
#  ['tuberculose', 'miliar', 'bacteria', 'disseminar', 'corrente', 'sanguinea'],
#  ['tuberculose', 'miliar', 'forma', 'grave', 'doenca'],
#  ['tuberculose', 'miliar'],
#  ['tuberculose'],
#  ['tuberculose', 'miliar', 'meningea'],
#  ['tuberculose', 'miliar', 'provocar', 'tecido', 'orgao', 'corpo'],
#  ['tuberculose', 'miliar', 'tratar'],
#  ['tuberculose', 'miliar', 'diagnostico'],
#  ['tuberculose', 'miliar', 'principal', 'sintoma'],
#  ['explicar', 'tuberculose', 'ocular'],
#  ['tuberculose', 'ocular'],
#  ['tuberculose', 'ocular'],
#  ['querer', 'saber', 'sobre', 'tuberculose', 'olho'],
#  ['tuberculose'],
#  ['querer', 'saber', 'sobre', 'tuberculose', 'ocular'],
#  ['tuberculose', 'olho'],
#  ['existir', 'tuberculose', 'olho'],
#  ['existir', 'tuberculose', 'olho'],
#  ['ter', 'tuberculose', 'ocular'],
#  ['chamar', 'tuberculose', 'olho'],
#  ['definame', 'tuberculose', 'ocular'],
#  ['ter', 'tuberculose', 'ocular'],
#  ['tuberculose', 'ocular', 'tratar'],
#  ['tuberculose', 'ocular', 'diagnostico'],
#  ['tuberculose', 'ocular', 'principal'],
#  ['diga', 'tuberculose'],
#  ['tuberculose'],
#  ['tuberculose', 'infeccao', 'grave'],
#  ['tuberculose', 'doenca', 'grave'],
#  ['tuberculose'],
#  ['tuberculose', 'doenca', 'bacteria'],
#  ['tuberculose'],
#  ['tuberculose'],
#  ['definame', 'tuberculose'],
#  ['doenca', 'tuberculose'],
#  ['tuberculose'],
#  ['tuberculose'],
#  ['tuberculose'],
#  ['aperto', 'transmite', 'tuberculose'],
#  ['tuberculose', 'transmitir', 'tuberculose'],
#  ['compartilhar', 'comida', 'bebida', 'transmiter', 'tuberculose'],
#  ['tuberculose', 'passar', 'atrave', 'beijo'],
#  ['beijo', 'causar', 'transmissao'],
#  ['passar', 'roupa', 'pessoa', 'infectar'],
#  ['tuberculose', 'passar', 'atrave'],
#  ['tuberculose', 'passar', 'atrave', 'comida'],
#  ['tuberculose', 'passar', 'atrave', 'aperto', 'mao'],
#  ['tuberculose', 'passar', 'atrave'],
#  ['usar', 'roupa', 'pessoa', 'infectar', 'transmite', 'tuberculose'],
#  ['tuberculose', 'osso'],
#  ['tuberculose', 'pegar', 'osso'],
#  ['infeccao', 'osso'],
#  ['tuberculose', 'osso'],
#  ['bacilo', 'tuberculose', 'poder', 'alojar', 'osso'],
#  ['querer', 'saber', 'sobre', 'tuberculose', 'osso'],
#  ['poder', 'ter', 'tuberculose'],
#  ['osso', 'poder', 'ter', 'tuberculose'],
#  ['osso', 'poder', 'tuberculose'],
#  ['tuberculose', 'pegar', 'osso', 'corpo'],
#  ['tuberculose', 'ossea'],
#  ['tuberculose', 'ossea'],
#  ['tuberculose', 'osso'],
#  ['tuberculose', 'ossea', 'tratar'],
#  ['tuberculose', 'ossea', 'diagnostico'],
#  ['tuberculose', 'principal', 'sintoma'],
#  ['tuberculose', 'pleural'],
#  ['chamar', 'tuberculose', 'tecido', 'pulmao'],
#  ['uso', 'poder', 'desenvolver', 'tuberculose', 'pleural'],
#  ['pegar', 'tuberculose', 'pleura'],
#  ['tuberculose', 'poder', 'contagiar', 'pleura'],
#  ['preciso', 'orientacao', 'sobre', 'tuberculose', 'pleural'],
#  ['tuberculose', 'pleural'],
#  ['existir', 'tuberculose', 'pleural'],
#  ['tuberculose', 'pegar', 'pleura'],
#  ['pleura', 'poder', 'contaminar', 'tuberculose'],
#  ['esclarecame', 'sobre', 'tuberculose', 'pleural'],
#  ['expliquar', 'tuberculose', 'pleural'],
#  ['tuberculose', 'pleural', 'tratar'],
#  ['tuberculose', 'pleural', 'diagnostico'],
#  ['tuberculose', 'pleural', 'principal', 'sintoma'],
#  ['tuberculose'],
#  ['tuberculose', 'pulmao'],
#  ['pulmao', 'tuberculose'],
#  ['tuberculose',
#   'pulmonar',
#   'ocorrer',
#   'devido',
#   'bacilo',
#   'via',
#   'respiratorio'],
#  ['tuberculose', 'pulmonar'],
#  ['forma', 'comum', 'doenca', 'tuberculose', 'pulmonar'],
#  ['preciso', 'informacao', 'sobre', 'tuberculose', 'pulmonar'],
#  ['tuberculose', 'pulmonar'],
#  ['bacteria', 'alojar', 'pulmao', 'tuberculose', 'pulmonar'],
#  ['expliqueme', 'sobre', 'bacteria', 'pulmonar'],
#  ['esclarecer', 'sobre', 'tuberculose', 'pulmonar'],
#  ['tuberculose', 'pulmonar', 'querer', 'saber'],
#  ['querer', 'saber', 'sobre', 'tuberculose', 'pulmonar'],
#  ['preciso', 'informacao', 'sobre', 'tuberculose', 'pulmonar'],
#  ['definer', 'tuberculose', 'pulmonar'],
#  ['tuberculose', 'pulmonar', 'tratar'],
#  ['tuberculose', 'pulmonar', 'diagnostico'],
#  ['tuberculose', 'pulmonar', 'principal', 'sintoma'],
#  ['ter', 'sarar', 'tuberculose'],
#  ['tuberculose', 'ter', 'cura'],
#  ['existir', 'cura', 'tuberculose'],
#  ['ir', 'ficar', 'curar', 'tuberculose'],
#  ['poder', 'curar', 'tuberculose'],
#  ['cura', 'tuberculose'],
#  ['tuberculoso', 'poder', 'curar'],
#  ['ir', 'sarar', 'tuberculose'],
#  ['tratamento', 'tuberculose', 'deixar', 'paciente', 'curar'],
#  ['paciente', 'tuberculose', 'poder', 'curar'],
#  ['doente', 'tuberculose', 'poder', 'curar'],
#  ['doenca', 'tuberculose', 'ter', 'cura'],
#  ['existir', 'cura', 'pra', 'doenca', 'tuberculose'],
#  ['doenca', 'tuberculose', 'ja', 'ter', 'cura'],
#  ['existir', 'quanto', 'tipo', 'tuberculose'],
#  ['tuberculose', 'tipo'],
#  ['tipo', 'tuberculose'],
#  ['tipo', 'tuberculose'],
#  ['tipo', 'tuberculose', 'comum'],
#  ['querer', 'saber', 'tipo', 'tuberculose'],
#  ['falar', 'tipo', 'tuberculose'],
#  ['existir', 'quanto', 'tipo', 'tuberculose'],
#  ['tipo', 'tuberculose', 'existir'],
#  ['tuberculose', 'tratamento', 'gratuito'],
#  ['custo', 'tratamento', 'tuberculose'],
#  ['tuberculoso', 'ter', 'dinheiro', 'pagar', 'tratamento'],
#  ['tuberculose', 'ir', 'ter', 'pagar', 'tratamento'],
#  ['sus', 'pagar', 'tratamento', 'tuberculose'],
#  ['ministerio', 'pagar', 'tratamento', 'tuberculose'],
#  ['governo', 'pagar', 'tratamento', 'tuberculose'],
#  ['quanto', 'custar', 'tratamento', 'tuberculose'],
#  ['despesa', 'tuberculose', 'pagar'],
#  ['pagar', 'tratamento', 'tuberculose'],
#  ['tuberculose', 'urinario'],
#  ['querer', 'saber', 'sobre', 'tuberculose', 'urinario'],
#  ['preciso', 'saber', 'sobre', 'tuberculose', 'urinario'],
#  ['tuberculose'],
#  ['querer', 'informacao', 'sobre', 'tuberculose', 'urinario'],
#  ['tuberculose'],
#  ['falar', 'sobre', 'tuberculose', 'urinario'],
#  ['tuberculose', 'urinaria'],
#  ['tuberculose', 'urinario'],
#  ['definer', 'tuberculose', 'urinario'],
#  ['esclarecer', 'sobre', 'tuberculose', 'urinario'],
#  ['falame', 'tuberculose', 'urinario'],
#  ['dizer', 'sobre', 'tuberculose', 'urinario'],
#  ['tuberculose', 'urinario'],
#  ['doenca', 'tuberculose'],
#  ['tuberculose', 'urinaria', 'tratar'],
#  ['tuberculose', 'urinaria', 'diagnostico'],
#  ['tuberculose', 'urinaria', 'principal', 'sintoma'],
#  ['fazer', 'tuberculoso'],
#  ['tuberculose'],
#  ['oximetria', 'baixo', 'poder', 'tuberculose'],
#  ['sintoma', 'tuberculose', 'fazer'],
#  ['tuberculoso', 'dever', 'fazer'],
#  ['ficar', 'doente', 'tuberculose', 'fazer'],
#  ['sentir', 'gripar', 'achar', 'tuberculose', 'fazer'],
#  ['tuberculoso', 'querer', 'orientacao'],
#  ['orientacao', 'seguir', 'caso', 'tuberculose'],
#  ['fazer', 'tuberculose'],
#  ['coronavirus'],
#  ['fazer', 'doente'],
#  ['ocorrer', 'primeiro', 'infeccao', 'humano', 'novo', 'coronavirus'],
#  ['covid', 'novo', 'coronavirus'],
#  ['pegar', 'covid'],
#  ['vulneravel', 'covid'],
#  ['quanto', 'tempo', 'virus', 'sobreviver', 'superficie'],
#  ['devo', 'usar', 'mascara', 'proteger'],
#  ['vacina', 'covid', 'seguro'],
#  ['vacinar', 'coronavirus'],
#  ['vacina', 'poder', 'imunizar', 'todo', 'coronavirus'],
#  ['poder', 'normal', 'vacina'],
#  ['necessario', 'tomar', 'vacina', 'todo', 'ano', 'gripe'],
#  ['apos', 'tomar', 'vacina'],
#  ['posso', 'voltar', 'frequentar', 'aglomeracao'],
#  ['pessoa', 'vacinar', 'poder', 'transmitir', 'virus'],
#  ['primeiro', 'receber', 'vacina'],
#  ['dever', 'tomar', 'vacina'],
#  ['vacina', 'poder', 'usar', 'crianca'],
#  ['covid', 'preciso', 'vacinar'],
#  ['pessoa', 'sintoma', 'poder', 'tomar', 'vacina'],
#  ['apos',
#   'teste',
#   'positivo',
#   'covid',
#   'quanto',
#   'tempo',
#   'deveser',
#   'esperar',
#   'tomar',
#   'vacina'],
#  ['existir',
#   'algum',
#   'tipo',
#   'bebida',
#   'comida',
#   'dever',
#   'antes',
#   'tomar',
#   'vacina'],
#  ['vacinacao', 'obrigatorio'],
#  ['ter', 'tomar', 'dois', 'dose', 'vacina'],
#  ['eficacia'],
#  ['vacina', 'ter', 'diferente', 'eficacia'],
#  ['tomar', 'vacina', 'sus', 'possivel'],
#  ['posso', 'tomar', 'todo', 'outro', 'vacina', 'junto', 'vacina', 'covid'],
#  ['posso', 'tomar', 'primeiro', 'dose', 'vacina', 'segundo', 'dose', 'outro'],
#  ['vacina', 'exterior', 'devo', 'vacinar', 'brasil'],
#  ['ter', 'sus', 'posso', 'vacinar'],
#  ['controle', 'dose', 'aplicar'],
#  ['sus', 'ter', 'vacinar', 'tanto'],
#  ['pessoa', 'comorbidade', 'precisar', 'vacinacao'],
#  ['poder', 'comprar', 'vacina', 'rede', 'privado'],
#  ['uso', 'risco', 'saude'],
#  ['anvisa', 'ainda', 'registro', 'sanitario'],
#  ['estado',
#   'poder',
#   'vacinar',
#   'populacao',
#   'ministerio',
#   'saude',
#   'anvisa',
#   'ter',
#   'aprovar',
#   'vacina'],
#  ['poder', 'tomar', 'vacina'],
#  ['tomar',
#   'vacina',
#   'poder',
#   'sentir',
#   'proteger',
#   'voltar',
#   'circular',
#   'rua',
#   'mascara'],
#  ['procedimento',
#   'dever',
#   'adotar',
#   'caso',
#   'pessoa',
#   'imunizar',
#   'vacina',
#   'diferente',
#   'primeiro',
#   'segundo',
#   'dose'],
#  ['dever', 'receber', 'dose', 'vacina'],
#  ['existir', 'risco', 'pessoa', 'tomar', 'vacina', 'diferente'],
#  ['tempo', 'vacina', 'aplicar', 'brasil', 'oferecer'],
#  ['novo', 'variante', 'sarscov'],
#  ['fazer', 'variante', 'agressivo', 'outro'],
#  ['variante', 'identificar', 'brasil'],
#  ['variante', 'vir', 'causar', 'infeccao', 'agressivo', 'circular', 'brasil'],
#  ['variante', 'responsavel', 'aumento', 'caso', 'pais'],
#  ['fazer', 'variante'],
#  ['todo', 'caso', 'covid', 'dever', 'ter'],
#  ['atualizacao', 'caso', 'variante', 'ministerio', 'saude'],
#  ['variante', 'encontrar', 'brasil', 'poder', 'afetar', 'eficacia', 'vacina'],
#  ['ministerio', 'saude', 'caso', 'reinfeccao'],
#  ['fazer', 'caso', 'reinfeccao'],
#  ['ministerio',
#   'saude',
#   'contato',
#   'saber',
#   'realizar',
#   'vacina',
#   'aprovar',
#   'brasil',
#   'eficaz',
#   'contra',
#   'variante',
#   'circular',
#   'pais'],
#  ['posso', 'tomar', 'vacina', 'gripe', 'junto', 'covid'],
#  ['ter',
#   'resultado',
#   'negativo',
#   'teste',
#   'realizar',
#   'pesquisa',
#   'significar',
#   'covid'],
#  ['ter', 'covid', 'assim', 'preciso', 'participar', 'pesquisa'],
#  ['vacinar', 'contra', 'covid', 'assim', 'preciso', 'participar', 'pesquisa'],
#  ['preciso', 'esperar', 'dose', 'outro'],
#  ['ter', 'covid', 'precisar', 'vacinar'],
#  ['poder', 'tomar', 'vacina'],
#  ['normal', 'ter', 'algum', 'apos', 'tomar', 'vacina'],
#  ['apos',
#   'ter',
#   'tomar',
#   'dose',
#   'preciso',
#   'usar',
#   'mascara',
#   'evitar',
#   'aglomeracao'],
#  ['quais', 'comorbidade', 'vacinar', 'primeiro'],
#  ['vacinacao', 'seguro', 'populacao'],
#  ['tuberculose'],
#  ['tuberculose',
#   'doenca',
#   'causar',
#   'bacteria',
#   'mycobacterium',
#   'tuberculosi',
#   'conhecer',
#   'bacilo',
#   'koch'],
#  ['doenca', 'causar', 'bacilo', 'koch'],
#  ['forma',
#   'afetar',
#   'outro',
#   'orgao',
#   'pulmao',
#   'ocorrer',
#   'pessoa',
#   'viver',
#   'hiv'],
#  ['antigo',
#   'tuberculose',
#   'continuar',
#   'importante',
#   'problema',
#   'saude',
#   'publico'],
#  ['mundo', 'cada', 'ano', 'cerca', 'pessoa', 'tuberculose'],
#  ['brasil',
#   'notificar',
#   'mil',
#   'caso',
#   'novo',
#   'ocorrer',
#   'cerca',
#   'mil',
#   'tuberculose'],
#  ['tuberculose', 'transmitir'],
#  ['transmissao', 'tuberculose', 'acontecer', 'via', 'respiratorio'],
#  ['pessoa',
#   'tuberculose',
#   'pulmonar',
#   'ativo',
#   'tratamento',
#   'poder',
#   'infectar',
#   'pessoa'],
#  ['tuberculose', 'transmitir', 'objeto', 'compartilhar'],
#  ['roupa', 'ter', 'papel', 'importante', 'transmissao', 'doenca'],
#  ['bacilo', 'luz', 'circulacao', 'ar'],
#  ['sintoma', 'tuberculose'],
#  ['principal', 'sintoma', 'tuberculose', 'pulmonar', 'tosse', 'tosse', 'poder'],
#  ['todo', 'pessoa', 'sintoma', 'respiratorio', 'tosse', 'tuberculose'],
#  ['caso',
#   'pessoa',
#   'apresentar',
#   'sintoma',
#   'tuberculose',
#   'fundamental',
#   'unidade',
#   'saude',
#   'proximo',
#   'realizacao',
#   'exame'],
#  ['resultado',
#   'positivo',
#   'tuberculose',
#   'deveser',
#   'tratamento',
#   'rapido',
#   'possivel',
#   'final'],
#  ['fazer', 'diagnostico', 'tuberculose'],
#  ['brasil',
#   'diagnostico',
#   'tb',
#   'realizar',
#   'recomendacoes',
#   'controle',
#   'tuberculose',
#   'brasil',
#   'diagnostico',
#   'diferencial',
#   'outro',
#   'teste',
#   'diagnostico'],
#  ['diagnostico',
#   'laboratorial',
#   'tuberculose',
#   'fundamental',
#   'tanto',
#   'caso',
#   'novo',
#   'quanto',
#   'controle',
#   'tratamento'],
#  ['diagnostico', 'laboratorial', 'tuberculose', 'utilizar', 'exame'],
#  ['teste', 'rapido', 'tuberculose', 'trmtb', 'baciloscopia'],
#  ['teste', 'sensibilidade'],
#  ['realizacao', 'radiografia', 'torax', 'diagnostico'],
#  ['tratamento', 'tuberculose'],
#  ['tratamento',
#   'tuberculose',
#   'pequeno',
#   'gratuito',
#   'disponivel',
#   'sistema',
#   'unico',
#   'saude',
#   'sus'],
#  [],
#  ['tuberculose', 'ter', 'cura', 'tratamento', 'fazer', 'forma', 'final'],
#  ['vacina',
#   'bacilo',
#   'sistema',
#   'unico',
#   'saude',
#   'sus',
#   'proteger',
#   'crianca',
#   'forma',
#   'grave',
#   'doenca'],
#  ['ocorrer',
#   'pessoa',
#   'encontrar',
#   'infectar',
#   'mycobacterium',
#   'tuberculosi',
#   'manifestacao',
#   'doenca',
#   'ativo'],
#  ['contato', 'pessoa', 'diagnosticar', 'tb'],
#  ['sobre',
#   'protocolo',
#   'vigilancia',
#   'infeccao',
#   'mycobacterium',
#   'tuberculosi',
#   'brasil'],
#  ['orientacao',
#   'geral',
#   'minimizar',
#   'risco',
#   'transmissao',
#   'tuberculose',
#   'ambiente',
#   'publico'],
#  ['populacao', 'risco', 'populacao', 'geral'],
#  ['populacao',
#   'vulneravel',
#   'privado',
#   'pessoa',
#   'viver',
#   'hiv',
#   'pessoa',
#   'situacao',
#   'rua',
#   'profissional',
#   'saude'],
#  ['radiografia', 'torax', 'tuberculose', 'avaliar', 'equipe', 'saude'],
#  ['baciloscopia', 'trmtb', 'cultura', 'teste', 'sensibilidade'],
#  ['nacional', 'tuberculose', 'problema', 'saude'],
#  ['situacao', 'tuberculose'],
#  ['selo', 'turismo', 'responsavel', 'programa', 'ministerio', 'turismo'],
#  ['estabelecer',
#   'bom',
#   'pratica',
#   'higienizacao',
#   'cada',
#   'segmento',
#   'setor',
#   'turismo'],
#  ['selo', 'incentivo', 'consumidor', 'seguro', 'viajar'],
#  ['empresa', 'guia', 'turismo', 'precisar', 'cadastur'],
#  ['servicos', 'turisticos', 'situacao', 'regular', 'sistema', 'cadastur'],
#  ['prestador', 'servico', 'turistico', 'situacao', 'regular'],
#  ['apos', 'adesao', 'selo', 'opcao', 'emissao', 'selo'],
#  ['baixar', 'peca', 'publicitario', 'selo', 'baixar', 'peca'],
#  ['informacao',
#   'sobre',
#   'condicao',
#   'sinalizacao',
#   'limpeza',
#   'local',
#   'atendimento'],
#  ['ministerio', 'turismo', 'selo'],
#  ['protocolo', 'higienico', 'cada', 'segmento', 'turistico'],
#  ['turismo', 'responsavel', 'ambiental', 'grande'],
#  ['incentivar', 'meio', 'ambiente', 'sustentabilidade', 'vir'],
#  ['turismo', 'destino'],
#  ['meio'],
#  ['forma', 'conhecer', 'outro', 'lugar', 'ter', 'objetivo', 'conceito'],
#  ['impacto', 'economico', 'ambiental', 'negativo'],
#  ['fazer', 'minimizar', 'impacto', 'negativo', 'turismo'],
#  ['diminuir', 'geracao'],
#  ['beneficio', 'economico', 'populacao', 'local'],
#  ['turismo', 'responsavel', 'priorizar', 'servico', 'oferecer', 'proprio'],
#  ['ir', 'alem', 'frequentar'],
#  ['guia', 'local', 'prestigiar', 'local', 'priorizar', 'hospedagem', 'local'],
#  ['conservacao', 'cultural'],
#  ['adotar',
#   'turismo',
#   'responsavel',
#   'vida',
#   'contribuir',
#   'conservacao',
#   'local'],
#  ['vida', 'local', 'respeitar', 'cultura'],
#  ['prestigiar', 'manifestacao', 'cultural', 'local'],
#  ['alem', 'priorizar', 'hospedagem', 'local', 'proximo', 'destino'],
#  ['ajudar',
#   'reduzir',
#   'emissao',
#   'poluente',
#   'alem',
#   'tornar',
#   'viagem',
#   'economico'],
#  ['reducao', 'gasto', 'energia', 'agua'],
#  ['turismo', 'responsavel', 'apenas', 'diminuir', 'geracao', 'poluente'],
#  ['cuidado', 'ajudar', 'agua', 'energia', 'sustentabilidade'],
#  ['destino', 'pessoa', 'viver', 'local'],
#  ['poder',
#   'turismo',
#   'responsavel',
#   'sustentabilidade',
#   'apenas',
#   'aplicar',
#   'destino',
#   'natureza'],
#  ['respeitar', 'evitar', 'bem', 'evitar', 'afetar'],
#  ['atender', 'sanitario', 'caso', 'turista'],
#  ['guia', 'turismo', 'dever', 'informar', 'medida', 'prevencao', 'higienico'],
#  ['sobre', 'local', 'destino', 'antes', 'viajar'],
#  ['durante', 'viagem', 'saude', 'poder', 'mudar', 'antes', 'durante', 'viagem'],
#  ['turista', 'responsavel', 'controle'],
#  ['cumprimento', 'protocolo', 'poder', 'realizar'],
#  ['equipe',
#   'area',
#   'comum',
#   'publico',
#   'funcionario',
#   'bem',
#   'fila',
#   'objetivo',
#   'garantir',
#   'distanciamento',
#   'fisico'],
#  ['sinalizacao',
#   'fila',
#   'bem',
#   'orientar',
#   'garantir',
#   'distanciamento',
#   'fisico'],
#  ['setor', 'meios', 'hospedagem', 'recomendar', 'setor'],
#  ['final', 'dever', 'realizar', 'limpeza', 'unidade'],
#  [],
#  ['protecao'],
#  ['orientar', 'consumidor', 'dar', 'aplicar', 'protocolo']]

# %%
# criação de dicionário
dictionary = corpora.Dictionary(processed_corpus)
print(dictionary)
# Out:
# Dictionary<657 unique tokens: ['covid', 'contaminar', 'objeto', 'pego', 'tocar']...>

# %%
# criação de bag of words com corpus
bow_corpus = [dictionary.doc2bow(text) for text in processed_corpus]
pprint.pprint(bow_corpus)
# Out:
# [[(0, 1)],
#  [(0, 1), (1, 1), (2, 1), (3, 1), (4, 1)],
#  [(0, 1), (3, 1), (5, 1), (6, 1)],
#  [(0, 1), (7, 1), (8, 1)],
#  [(0, 1), (8, 1)],
#  [(5, 1), (6, 1), (9, 1), (10, 1)],
#  [(0, 1), (11, 1)],
#  [(12, 1), (13, 1), (14, 1), (15, 1)],
#  [(0, 1), (10, 1), (16, 1)],
#  [(0, 1), (15, 1), (17, 1)],
#  [(0, 1), (13, 1), (18, 1), (19, 1), (20, 1)],
#  [(15, 1), (21, 1)],
#  [(0, 1), (15, 1), (18, 1), (22, 1)],
#  [(14, 1), (15, 1), (23, 1), (24, 1), (25, 1)],
#  [(26, 1), (27, 1)],
#  [(0, 1), (7, 1), (28, 1)],
#  [(0, 1), (29, 1), (30, 1)],
#  [(0, 1), (30, 1)],
#  [(0, 1), (10, 1), (31, 1)],
#  [(0, 1), (10, 1), (30, 1)],
#  [(0, 1)],
#  [(0, 1), (29, 1), (30, 1)],
#  [(0, 1), (32, 1)],
#  [(0, 1), (33, 1), (34, 1)],
#  [(0, 1), (35, 1)],
#  [(0, 1), (35, 1)],
#  [(0, 1)],
#  [(0, 1), (36, 1)],
#  [(0, 1)],
#  [(0, 1), (37, 1), (38, 1)],
#  [(0, 1), (10, 1), (16, 1)],
#  [(0, 1), (28, 1), (35, 1)],
#  [(0, 1), (10, 1), (16, 1), (39, 1)],
#  [(0, 1), (40, 1), (41, 1)],
#  [(10, 1), (39, 1), (42, 1), (43, 1)],
#  [(0, 1), (39, 1)],
#  [(41, 1), (44, 1)],
#  [(0, 1), (13, 1), (37, 1)],
#  [(0, 1), (6, 1), (45, 1)],
#  [(0, 1), (41, 1)],
#  [(0, 1)],
#  [(1, 1), (13, 1)],
#  [(0, 1), (27, 1)],
#  [(27, 1)],
#  [(0, 1), (46, 1)],
#  [(0, 1), (47, 1)],
#  [(0, 1), (25, 1), (48, 1)],
#  [(48, 1), (49, 1)],
#  [(0, 1), (50, 1)],
#  [(0, 1), (13, 1), (51, 1)],
#  [(25, 1), (52, 1), (53, 1), (54, 1)],
#  [(0, 1), (13, 1), (30, 1), (53, 1)],
#  [(53, 1), (54, 1), (55, 1)],
#  [(0, 1), (25, 1), (34, 1), (56, 1), (57, 1)],
#  [(0, 1), (25, 1), (34, 1), (47, 1), (56, 1), (57, 1)],
#  [(0, 1), (34, 1), (47, 1), (58, 1), (59, 1)],
#  [(34, 1), (46, 1), (59, 1), (60, 1)],
#  [(0, 1), (34, 1), (46, 1), (61, 1)],
#  [(0, 1), (34, 1), (46, 1), (61, 1)],
#  [(0, 1), (34, 1), (46, 1), (60, 1), (62, 1)],
#  [(0, 1), (34, 1), (46, 1), (60, 1)],
#  [(34, 1), (46, 1), (59, 1), (63, 1), (64, 1)],
#  [(44, 1), (65, 1), (66, 1), (67, 1)],
#  [(65, 1), (66, 1), (68, 1)],
#  [(60, 1), (65, 1), (66, 1)],
#  [(65, 1), (66, 1), (69, 1), (70, 1)],
#  [(7, 1), (8, 1), (57, 1)],
#  [(60, 1), (66, 1), (69, 1), (70, 1), (71, 1), (72, 1), (73, 1)],
#  [(74, 1), (75, 1)],
#  [(60, 1), (76, 1), (77, 1)],
#  [(60, 1), (78, 1), (79, 1)],
#  [(50, 1), (60, 1)],
#  [(80, 1)],
#  [(79, 1), (80, 1)],
#  [(76, 1), (81, 1), (82, 1)],
#  [(0, 1), (13, 1), (60, 1), (82, 1), (83, 1), (84, 1)],
#  [(27, 1), (85, 1)],
#  [(0, 1), (82, 1), (83, 1)],
#  [(0, 1), (41, 1), (82, 1)],
#  [(0, 1), (62, 1)],
#  [(50, 1), (86, 1)],
#  [(0, 1), (8, 1), (41, 1)],
#  [(0, 1), (41, 1)],
#  [(0, 1), (1, 1), (13, 1), (25, 1), (82, 1), (87, 1), (88, 1)],
#  [(0, 1), (13, 1), (49, 1), (89, 1), (90, 1)],
#  [(0, 1), (13, 1), (41, 1), (88, 1)],
#  [(0, 1), (50, 1)],
#  [(0, 1), (50, 1), (86, 1)],
#  [(0, 1), (25, 1), (50, 1)],
#  [(0, 1), (13, 1), (48, 1)],
#  [(0, 1), (50, 1)],
#  [(0, 1), (9, 1), (91, 1)],
#  [(0, 1), (41, 1), (73, 1), (91, 1), (92, 1)],
#  [(10, 1), (13, 1), (41, 1), (93, 1)],
#  [(1, 1), (13, 1), (41, 1), (88, 1), (94, 1)],
#  [(10, 1), (13, 1), (41, 1), (95, 1), (96, 1), (97, 1)],
#  [(10, 1), (13, 1), (41, 1), (98, 1), (99, 1)],
#  [(1, 1), (10, 1), (13, 1), (41, 1), (100, 1), (101, 1)],
#  [(1, 1), (10, 1), (13, 1), (102, 1)],
#  [(10, 1), (13, 1), (94, 1), (103, 1), (104, 1)],
#  [(0, 1), (13, 1), (41, 1), (82, 1), (95, 1)],
#  [(0, 1), (13, 1), (41, 1)],
#  [(0, 1), (13, 1), (105, 1)],
#  [(13, 1), (41, 1), (106, 1), (107, 1), (108, 1)],
#  [(0, 1), (13, 1), (41, 1), (88, 1), (109, 1)],
#  [(52, 1), (54, 1), (106, 1), (110, 1)],
#  [(0, 1), (41, 1), (50, 1), (88, 1), (111, 1), (112, 1)],
#  [(0, 1), (29, 1), (41, 1), (44, 1)],
#  [(41, 1), (44, 1), (85, 1), (113, 1), (114, 1)],
#  [(13, 1), (41, 1)],
#  [(0, 1), (41, 1), (44, 1), (115, 1), (116, 1)],
#  [(0, 1), (9, 1), (13, 1)],
#  [(0, 1), (41, 1), (117, 1)],
#  [(0, 1), (117, 1), (118, 1)],
#  [(0, 1), (25, 2), (50, 1), (119, 1)],
#  [(0, 1), (9, 1), (13, 1), (25, 1), (50, 1)],
#  [(1, 1), (13, 1), (77, 1), (120, 1)],
#  [(0, 1), (25, 2), (50, 1), (119, 1)],
#  [(0, 1), (41, 1), (73, 1), (92, 1)],
#  [(0, 1), (41, 1), (73, 1), (92, 1)],
#  [(50, 1), (85, 1)],
#  [(0, 1), (10, 1), (121, 1)],
#  [(9, 1), (13, 1), (88, 2)],
#  [(1, 1), (22, 1), (122, 1)],
#  [(1, 1), (122, 1), (123, 1)],
#  [(1, 1), (122, 1), (124, 1), (125, 1)],
#  [(10, 1), (126, 1), (127, 1)],
#  [(85, 1), (126, 1), (127, 1)],
#  [(14, 1), (28, 1), (124, 1), (128, 1), (129, 1)],
#  [(0, 1), (22, 1), (25, 1), (130, 1), (131, 1), (132, 1), (133, 1)],
#  [(22, 1), (28, 1), (80, 1), (134, 1)],
#  [(0, 1), (22, 1), (135, 1)],
#  [(1, 1), (13, 1), (35, 1), (54, 1), (129, 1), (130, 1), (136, 1)],
#  [(1, 1), (13, 1), (35, 1), (54, 1), (130, 1), (137, 1)],
#  [(1, 1), (13, 1), (54, 1), (130, 1), (136, 1), (137, 1), (138, 1)],
#  [(1, 1), (13, 1), (54, 1), (129, 1), (130, 1), (139, 1)],
#  [(1, 1), (13, 1), (43, 1), (98, 1), (129, 1), (130, 1), (136, 1)],
#  [(10, 1), (13, 1), (54, 1), (102, 1), (139, 1), (140, 1)],
#  [(10, 1), (13, 1), (28, 1), (99, 1), (102, 1), (141, 1), (142, 1), (143, 1)],
#  [(13, 1), (49, 1), (99, 1), (142, 1), (143, 1)],
#  [(1, 1), (13, 1), (28, 1), (68, 1), (99, 1), (129, 1), (138, 1), (142, 1)],
#  [(29, 1), (30, 1), (54, 1), (144, 1)],
#  [(0, 1), (54, 1), (55, 1), (142, 1), (145, 1), (146, 1)],
#  [(0, 1), (30, 1), (54, 1)],
#  [(10, 1), (13, 1), (71, 1), (73, 1), (147, 1), (148, 1), (149, 1), (150, 1)],
#  [(10, 1), (13, 1), (66, 1), (147, 1), (151, 1)],
#  [(10, 1), (13, 1), (125, 1), (152, 1), (153, 1)],
#  [(10, 1), (107, 1), (125, 1), (152, 1), (153, 1)],
#  [(10, 1), (13, 1), (125, 1), (152, 1), (153, 1), (154, 1)],
#  [(93, 1), (155, 1), (156, 1)],
#  [(2, 1), (10, 1), (24, 1), (157, 1), (158, 1)],
#  [(99, 1), (101, 1), (155, 1), (159, 1)],
#  [(85, 1), (154, 1), (160, 1)],
#  [(99, 1), (155, 1), (161, 1)],
#  [(10, 1), (24, 1), (157, 1), (158, 1), (162, 1)],
#  [(10, 1), (100, 1), (158, 1), (163, 1)],
#  [(0, 1), (4, 1), (41, 1), (52, 1), (54, 1), (162, 1)],
#  [(0, 1), (13, 1), (116, 1), (120, 1), (164, 1)],
#  [(71, 1), (138, 1), (154, 1), (161, 1), (165, 1)],
#  [(13, 1), (166, 1)],
#  [(13, 1), (93, 1), (142, 1), (166, 1)],
#  [(65, 1), (66, 1), (93, 1), (120, 1), (155, 1), (156, 1)],
#  [(4, 1),
#   (10, 1),
#   (13, 1),
#   (71, 1),
#   (73, 1),
#   (147, 1),
#   (148, 1),
#   (149, 1),
#   (150, 1)],
#  [(167, 1), (168, 1)],
#  [(168, 1), (169, 1), (170, 1)],
#  [(171, 1)],
#  [(168, 1)],
#  [(168, 1), (172, 1)],
#  [(168, 1), (173, 1)],
#  [(168, 1)],
#  [(168, 1), (174, 1)],
#  [(168, 1)],
#  [(168, 1)],
#  [(168, 1)],
#  [],
#  [],
#  [],
#  [],
#  [(168, 1), (174, 1), (175, 1)],
#  [(168, 1), (174, 1), (176, 1)],
#  [(168, 1), (174, 1)],
#  [(168, 1)],
#  [(38, 1), (167, 1)],
#  [(167, 1)],
#  [(169, 1), (170, 1)],
#  [(169, 1)],
#  [(169, 1)],
#  [(169, 1)],
#  [(169, 1), (177, 1)],
#  [(60, 1), (169, 1)],
#  [(38, 1), (167, 1)],
#  [(38, 1), (60, 1), (169, 1)],
#  [(167, 1), (178, 1)],
#  [(60, 1), (169, 1)],
#  [(60, 1), (169, 1)],
#  [(169, 1)],
#  [(38, 1), (169, 1), (170, 1)],
#  [(60, 1), (167, 1)],
#  [(167, 1)],
#  [(177, 1), (179, 1)],
#  [(60, 1), (179, 1)],
#  [(179, 1)],
#  [(33, 1), (169, 1)],
#  [(180, 1)],
#  [(181, 1), (182, 1)],
#  [(182, 1)],
#  [(36, 1), (183, 1), (184, 1), (185, 1)],
#  [(182, 1)],
#  [(182, 1), (183, 1), (184, 1)],
#  [(186, 1)],
#  [],
#  [(187, 1), (188, 1), (189, 1)],
#  [(180, 1), (183, 1), (184, 1), (185, 1)],
#  [(187, 1), (189, 1)],
#  [(187, 1)],
#  [(187, 1)],
#  [(38, 1), (181, 1), (190, 1), (191, 1), (192, 1), (193, 1), (194, 1)],
#  [(13, 1), (181, 1), (190, 1), (191, 1), (192, 1), (194, 1), (195, 1)],
#  [(190, 1), (193, 1), (195, 1), (196, 1), (197, 1), (198, 1)],
#  [(181, 1),
#   (190, 1),
#   (194, 1),
#   (195, 1),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (199, 1)],
#  [(38, 1), (181, 1), (190, 1), (191, 1), (192, 1), (194, 1), (195, 1)],
#  [(60, 1), (200, 1), (201, 1), (202, 1), (203, 1), (204, 1)],
#  [(190, 1),
#   (195, 1),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (201, 1),
#   (202, 1),
#   (203, 1)],
#  [(38, 1), (121, 1), (202, 1), (205, 1)],
#  [(38, 1), (194, 1), (202, 1), (206, 1)],
#  [(25, 1), (194, 1), (207, 1)],
#  [(38, 1), (121, 1), (194, 1), (207, 1), (208, 1), (209, 1)],
#  [(112, 1), (194, 1), (207, 1), (208, 1), (210, 1), (211, 1), (212, 1)],
#  [(25, 1), (194, 1), (202, 1), (213, 1), (214, 1)],
#  [(38, 1), (194, 1), (209, 1), (215, 1)],
#  [(121, 1), (194, 1), (209, 1), (215, 1), (216, 1)],
#  [(60, 1), (63, 1), (194, 1), (206, 1)],
#  [(38, 1), (121, 1), (194, 1), (209, 1), (215, 1)],
#  [(38, 1), (121, 1), (194, 1), (209, 1), (215, 1)],
#  [(38, 1), (121, 1), (194, 1), (209, 1), (215, 1), (217, 1)],
#  [(60, 1), (194, 1), (206, 1), (209, 1), (218, 1)],
#  [(38, 1), (194, 1), (202, 1), (209, 1), (215, 1), (217, 1)],
#  [(25, 1), (183, 1), (219, 1), (220, 1), (221, 1)],
#  [(92, 1), (194, 1), (222, 1), (223, 1)],
#  [(224, 1), (225, 1), (226, 1), (227, 1), (228, 1)],
#  [(147, 1), (222, 1), (224, 1), (225, 1), (226, 1), (227, 1), (228, 1)],
#  [(194, 1), (223, 1), (229, 1)],
#  [(194, 1), (224, 1), (230, 1)],
#  [(60, 1), (155, 1), (194, 1), (227, 1), (228, 1), (231, 1)],
#  [(224, 1), (225, 1), (227, 1), (228, 1), (232, 1)],
#  [(225, 1), (227, 1), (228, 1)],
#  [(152, 1), (194, 1), (233, 1), (234, 1)],
#  [(48, 1), (194, 1), (233, 1), (235, 1)],
#  [(48, 1), (194, 1)],
#  [(48, 1), (155, 1), (194, 1), (235, 1), (236, 1)],
#  [(136, 1), (194, 1)],
#  [(152, 1), (194, 1), (233, 1), (237, 1), (238, 1)],
#  [(152, 1), (194, 1), (237, 1), (238, 1)],
#  [(136, 1), (152, 1), (194, 1), (239, 1), (240, 1)],
#  [(48, 1), (152, 1), (194, 1), (233, 1)],
#  [(152, 1), (194, 1), (234, 1)],
#  [(48, 1), (152, 1), (194, 1), (241, 1)],
#  [(48, 1), (152, 1), (194, 1), (210, 1)],
#  [(194, 1), (235, 1), (242, 1)],
#  [(48, 1), (194, 1), (230, 1), (235, 1)],
#  [(193, 1), (196, 1), (197, 1), (198, 1), (243, 1)],
#  [(193, 1), (202, 1), (244, 1), (245, 1)],
#  [(193, 1), (244, 1)],
#  [(121, 1), (193, 1), (194, 1), (215, 1), (246, 1), (247, 1)],
#  [(121, 1), (193, 1), (194, 1), (215, 1), (247, 1), (248, 1)],
#  [(193, 1), (212, 1), (237, 1), (249, 1)],
#  [(165, 1), (193, 1), (250, 1)],
#  [(193, 1), (199, 1)],
#  [(186, 1), (193, 1)],
#  [(193, 1), (251, 1)],
#  [(193, 1)],
#  [(193, 1)],
#  [(8, 1), (193, 1), (252, 1), (253, 1)],
#  [(193, 1), (195, 1), (196, 1), (198, 1), (254, 1)],
#  [(25, 1), (124, 1), (193, 1), (250, 1), (252, 1)],
#  [(25, 1), (193, 1), (246, 1), (252, 1)],
#  [(25, 1), (193, 1), (252, 1), (255, 1)],
#  [(124, 1), (193, 1), (250, 1), (252, 1)],
#  [(21, 1), (193, 1), (254, 1), (256, 1)],
#  [(193, 1), (195, 1), (251, 1), (254, 1)],
#  [(124, 1), (193, 1), (195, 1), (250, 1), (251, 1), (252, 1)],
#  [(25, 1), (193, 1), (251, 1), (252, 1)],
#  [(6, 1), (193, 1), (251, 1), (254, 1), (257, 1)],
#  [(6, 1), (254, 1)],
#  [(193, 1), (251, 1), (258, 1), (259, 1), (260, 1)],
#  [(252, 1), (261, 1)],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [(262, 1)],
#  [(263, 1)],
#  [(264, 1)],
#  [(265, 1)],
#  [(263, 1), (265, 1)],
#  [(252, 1)],
#  [(193, 1), (254, 1), (266, 1)],
#  [(193, 1), (252, 1), (267, 1)],
#  [(193, 1), (252, 1)],
#  [(193, 1), (254, 1)],
#  [(268, 1)],
#  [(254, 1), (268, 1)],
#  [(252, 1), (268, 1)],
#  [(6, 1), (254, 1), (261, 1)],
#  [(8, 1), (193, 1), (258, 1), (260, 1), (269, 1)],
#  [(8, 1), (193, 1), (253, 1), (260, 1), (270, 1)],
#  [(8, 1), (136, 1), (193, 1), (260, 1), (270, 1)],
#  [(124, 1), (193, 1), (250, 1), (258, 1), (260, 1)],
#  [(193, 1), (250, 1), (252, 1)],
#  [(193, 1), (258, 1), (260, 1)],
#  [(193, 1), (258, 1), (259, 1), (260, 1)],
#  [(193, 1), (200, 1), (251, 1), (258, 1), (260, 1)],
#  [(6, 1), (193, 1), (199, 1), (254, 1)],
#  [(193, 1), (199, 1), (252, 1), (262, 1), (264, 1)],
#  [(193, 1), (266, 1), (271, 1)],
#  [(193, 1), (254, 1), (260, 1), (272, 1)],
#  [(58, 1),
#   (124, 1),
#   (193, 1),
#   (212, 1),
#   (273, 1),
#   (274, 1),
#   (275, 1),
#   (276, 1),
#   (277, 1)],
#  [(6, 1), (194, 1), (207, 1), (273, 1), (278, 1), (279, 1)],
#  [(25, 1), (183, 1), (194, 1), (231, 1), (280, 1), (281, 1)],
#  [(92, 1), (171, 1), (277, 1), (282, 1), (283, 1), (284, 1)],
#  [(92, 1), (193, 1), (285, 1)],
#  [(193, 1), (285, 1), (286, 1)],
#  [(193, 1), (282, 1), (287, 1)],
#  [(193, 1), (288, 1)],
#  [(13, 1), (193, 1), (282, 1), (289, 1), (290, 1)],
#  [(25, 1), (109, 1), (282, 1), (284, 1)],
#  [(171, 1), (195, 1), (284, 1), (285, 1), (287, 1), (291, 1)],
#  [(171, 1), (195, 1), (282, 1), (284, 1), (291, 1)],
#  [(171, 1), (261, 1), (282, 1), (284, 1), (291, 1)],
#  [(63, 1), (72, 1), (125, 1), (171, 1), (282, 1), (284, 1), (292, 1), (293, 1)],
#  [(63, 1), (171, 1), (194, 1), (217, 1), (282, 1), (284, 1), (293, 1)],
#  [(48, 1), (77, 1), (171, 1), (202, 1), (245, 1), (277, 1)],
#  [(48, 1), (77, 1), (171, 1), (202, 1), (245, 1), (277, 1), (284, 1)],
#  [(72, 1),
#   (108, 1),
#   (165, 1),
#   (171, 1),
#   (194, 1),
#   (209, 1),
#   (277, 1),
#   (282, 1),
#   (284, 1),
#   (294, 1)],
#  [(60, 1), (72, 1), (171, 1), (277, 1), (284, 1), (292, 1)],
#  [(108, 1), (171, 1), (194, 1), (277, 1), (282, 1), (284, 1), (295, 1)],
#  [(171, 1), (194, 1), (277, 1), (282, 1), (284, 1), (295, 1), (296, 1)],
#  [(155, 1), (171, 2), (194, 1), (277, 1), (284, 1), (295, 1), (296, 1)],
#  [(60, 1), (155, 1), (194, 1), (195, 1), (284, 1), (285, 1), (297, 1)],
#  [(155, 1),
#   (171, 1),
#   (194, 1),
#   (195, 1),
#   (284, 1),
#   (285, 1),
#   (297, 1),
#   (298, 1)],
#  [(25, 1), (193, 1), (195, 1), (284, 1), (285, 1), (286, 1), (299, 1)],
#  [(25, 1),
#   (194, 1),
#   (195, 1),
#   (199, 1),
#   (284, 1),
#   (285, 1),
#   (286, 1),
#   (297, 1)],
#  [(25, 1),
#   (194, 1),
#   (195, 1),
#   (248, 1),
#   (284, 1),
#   (285, 1),
#   (286, 1),
#   (297, 1)],
#  [(25, 1), (193, 1), (194, 1), (271, 1), (285, 1)],
#  [(193, 1), (289, 1), (290, 1)],
#  [(209, 1), (294, 1), (300, 1), (301, 1), (302, 1), (303, 1), (304, 1)],
#  [(209, 1),
#   (294, 1),
#   (300, 1),
#   (301, 1),
#   (302, 1),
#   (303, 1),
#   (304, 1),
#   (305, 1)],
#  [(292, 1), (300, 1), (301, 1), (302, 1), (303, 1), (304, 1), (305, 1)],
#  [(193, 1),
#   (204, 1),
#   (294, 1),
#   (299, 1),
#   (306, 1),
#   (307, 1),
#   (308, 1),
#   (309, 1),
#   (310, 1),
#   (311, 1),
#   (312, 1),
#   (313, 1)],
#  [(193, 1), (299, 1), (306, 1), (307, 1), (309, 1), (313, 1), (314, 1)],
#  [(150, 1),
#   (193, 1),
#   (194, 1),
#   (195, 1),
#   (255, 1),
#   (315, 1),
#   (316, 1),
#   (317, 1),
#   (318, 1),
#   (319, 1)],
#  [(96, 1),
#   (150, 1),
#   (193, 2),
#   (195, 1),
#   (255, 1),
#   (315, 1),
#   (317, 1),
#   (318, 1)],
#  [(193, 1), (204, 1), (294, 1), (310, 1), (314, 1)],
#  [(300, 1), (302, 1), (303, 1), (307, 1), (320, 1)],
#  [(193, 1)],
#  [(193, 1), (307, 1), (310, 1), (320, 1)],
#  [(193, 1), (260, 1), (321, 1)],
#  [(25, 1), (193, 1), (194, 1), (307, 1)],
#  [(150, 1),
#   (193, 1),
#   (195, 1),
#   (255, 1),
#   (316, 1),
#   (317, 1),
#   (318, 1),
#   (319, 1)],
#  [(193, 1),
#   (299, 1),
#   (306, 1),
#   (307, 1),
#   (308, 1),
#   (309, 1),
#   (311, 1),
#   (312, 1),
#   (313, 1)],
#  [(151, 1),
#   (194, 1),
#   (322, 1),
#   (323, 1),
#   (324, 1),
#   (325, 1),
#   (326, 1),
#   (327, 1)],
#  [(194, 1), (323, 1), (325, 1), (326, 1), (327, 1), (328, 1)],
#  [(13, 1),
#   (25, 1),
#   (194, 1),
#   (195, 1),
#   (211, 1),
#   (322, 1),
#   (323, 1),
#   (329, 1),
#   (330, 1)],
#  [(13, 1),
#   (25, 1),
#   (194, 1),
#   (195, 1),
#   (211, 1),
#   (212, 1),
#   (322, 1),
#   (323, 1),
#   (330, 1),
#   (331, 1)],
#  [(13, 1),
#   (191, 1),
#   (193, 1),
#   (211, 1),
#   (212, 1),
#   (322, 1),
#   (323, 1),
#   (331, 1),
#   (332, 1)],
#  [(13, 1), (194, 1), (211, 1), (284, 1), (332, 1), (333, 1), (334, 1)],
#  [(13, 1),
#   (121, 1),
#   (194, 1),
#   (209, 1),
#   (211, 1),
#   (231, 1),
#   (284, 1),
#   (332, 1),
#   (333, 1),
#   (334, 1)],
#  [(13, 1),
#   (121, 1),
#   (194, 1),
#   (209, 1),
#   (211, 1),
#   (231, 1),
#   (237, 1),
#   (284, 1),
#   (332, 1),
#   (333, 1),
#   (334, 1)],
#  [(25, 1),
#   (194, 1),
#   (195, 1),
#   (283, 1),
#   (284, 1),
#   (332, 1),
#   (335, 1),
#   (336, 1)],
#  [(60, 1),
#   (194, 1),
#   (249, 1),
#   (284, 1),
#   (332, 1),
#   (335, 1),
#   (336, 1),
#   (337, 1),
#   (338, 1)],
#  [(60, 1),
#   (194, 1),
#   (195, 1),
#   (198, 1),
#   (249, 1),
#   (284, 1),
#   (332, 1),
#   (335, 1),
#   (336, 1),
#   (338, 1)],
#  [(121, 1), (194, 1), (209, 1), (283, 1), (332, 1), (339, 1)],
#  [(151, 1),
#   (194, 1),
#   (330, 1),
#   (332, 1),
#   (335, 1),
#   (339, 1),
#   (340, 1),
#   (341, 1),
#   (342, 1)],
#  [(121, 1), (194, 1), (209, 1), (231, 1), (327, 1), (343, 1), (344, 1)],
#  [(195, 1), (284, 1), (327, 1), (332, 1), (343, 1), (344, 1)],
#  [(195, 1), (284, 1), (327, 1), (332, 1), (335, 1), (343, 1), (344, 1)],
#  [(44, 1),
#   (194, 1),
#   (195, 1),
#   (198, 1),
#   (323, 1),
#   (327, 1),
#   (343, 1),
#   (345, 1)],
#  [(44, 1),
#   (194, 1),
#   (195, 1),
#   (211, 1),
#   (284, 1),
#   (327, 1),
#   (330, 1),
#   (334, 1),
#   (345, 1)],
#  [(44, 1),
#   (194, 1),
#   (195, 1),
#   (211, 1),
#   (284, 1),
#   (327, 1),
#   (330, 1),
#   (334, 1),
#   (345, 1)],
#  [(194, 1),
#   (195, 1),
#   (249, 1),
#   (284, 1),
#   (332, 1),
#   (335, 1),
#   (336, 1),
#   (340, 1),
#   (341, 1),
#   (342, 1)],
#  [(195, 1), (211, 1), (315, 1), (327, 1), (346, 1), (347, 1), (348, 1)],
#  [(147, 1),
#   (195, 1),
#   (199, 1),
#   (211, 1),
#   (315, 1),
#   (327, 1),
#   (346, 1),
#   (347, 1),
#   (348, 1)],
#  [(147, 1),
#   (195, 1),
#   (199, 1),
#   (211, 1),
#   (315, 1),
#   (327, 1),
#   (348, 1),
#   (349, 1),
#   (350, 1)],
#  [(193, 1),
#   (322, 1),
#   (323, 1),
#   (325, 1),
#   (341, 1),
#   (351, 1),
#   (352, 1),
#   (353, 1)],
#  [(284, 1),
#   (322, 1),
#   (323, 1),
#   (325, 1),
#   (341, 1),
#   (351, 1),
#   (352, 1),
#   (353, 1),
#   (354, 1)],
#  [(351, 1), (354, 1), (355, 1), (356, 1), (357, 1)],
#  [(284, 1), (351, 1), (354, 1), (355, 1), (356, 1), (357, 1)],
#  [(284, 1), (299, 1), (323, 1), (351, 1), (357, 1)],
#  [(284, 1), (299, 1), (344, 1), (357, 1), (358, 1), (359, 1), (360, 1)],
#  [(284, 1), (344, 1), (357, 1), (358, 1), (359, 1), (360, 1), (361, 1)],
#  [(284, 1), (344, 1), (349, 1), (351, 1), (357, 1), (360, 1), (361, 1)],
#  [(194, 1), (327, 1), (343, 1), (344, 1), (362, 1)],
#  [(194, 1),
#   (323, 1),
#   (325, 1),
#   (351, 1),
#   (352, 1),
#   (353, 1),
#   (354, 1),
#   (363, 1),
#   (364, 1)],
#  [(194, 1),
#   (322, 1),
#   (323, 1),
#   (325, 1),
#   (341, 1),
#   (351, 1),
#   (352, 1),
#   (353, 1)],
#  [(194, 1), (323, 1), (325, 1), (326, 1), (327, 1), (328, 1), (352, 1)],
#  [(194, 1), (325, 1), (349, 1), (352, 1)],
#  [(194, 1), (325, 1), (352, 1), (362, 1)],
#  [(194, 1), (315, 1), (325, 1), (352, 1)],
#  [(194, 1),
#   (325, 1),
#   (351, 1),
#   (352, 1),
#   (353, 1),
#   (354, 1),
#   (363, 1),
#   (364, 1)],
#  [(8, 1), (195, 1), (202, 1), (242, 1), (245, 1), (251, 1)],
#  [(48, 1), (202, 1), (249, 1), (284, 1), (365, 1), (366, 1)],
#  [(202, 1), (249, 1), (281, 1), (284, 1), (365, 1), (366, 1)],
#  [(21, 1),
#   (212, 1),
#   (256, 1),
#   (260, 1),
#   (281, 1),
#   (365, 1),
#   (367, 1),
#   (368, 1),
#   (369, 1)],
#  [(21, 1), (249, 1), (256, 1), (281, 1), (365, 1), (368, 1), (370, 1)],
#  [(21, 1), (256, 1), (281, 1), (365, 1), (368, 1)],
#  [(48, 1), (195, 1), (202, 1), (245, 1), (370, 1)],
#  [(249, 1), (303, 1), (362, 1), (370, 1)],
#  [(194, 1), (371, 1), (372, 1)],
#  [(194, 1), (371, 1), (372, 1)],
#  [(373, 1), (374, 1)],
#  [],
#  [(375, 1)],
#  [(25, 1), (323, 1), (376, 1)],
#  [(25, 1), (323, 1)],
#  [(121, 1), (194, 1), (247, 1), (329, 1), (334, 1)],
#  [(121, 1), (155, 1), (194, 1), (202, 1), (247, 1), (373, 1), (377, 1)],
#  [(25, 1), (121, 1), (194, 1), (247, 1), (334, 1), (378, 1)],
#  [(25, 1), (121, 1), (194, 1), (214, 1), (247, 1), (334, 1)],
#  [(25, 2), (121, 1), (194, 1), (237, 1), (247, 1), (373, 1)],
#  [(121, 1),
#   (155, 1),
#   (194, 1),
#   (215, 1),
#   (231, 1),
#   (247, 1),
#   (334, 1),
#   (379, 1),
#   (380, 1)],
#  [(25, 1),
#   (121, 1),
#   (155, 1),
#   (194, 1),
#   (247, 1),
#   (334, 1),
#   (379, 1),
#   (380, 1)],
#  [(25, 1), (121, 1), (155, 1), (194, 1), (247, 1), (373, 1)],
#  [(121, 1), (194, 1), (215, 1), (231, 1), (247, 1), (352, 1)],
#  [(80, 1), (194, 1), (214, 1), (276, 1), (373, 1), (374, 1), (379, 1)],
#  [(121, 1), (194, 1), (214, 1), (247, 1), (334, 1), (373, 1), (376, 1)],
#  [(24, 1), (25, 2), (121, 1), (194, 1), (247, 1), (373, 1)],
#  [(24, 1), (25, 1), (121, 1), (194, 1), (247, 1), (373, 1), (377, 1)],
#  [(24, 1), (25, 1), (121, 1), (194, 1), (247, 1), (373, 1), (381, 1)],
#  [(25, 1), (38, 1), (121, 1), (194, 2), (247, 1), (327, 1)],
#  [(121, 1), (194, 1), (247, 1), (327, 1), (329, 1)],
#  [(80, 1), (194, 1), (276, 1), (373, 1), (376, 1), (382, 1), (383, 1)],
#  [(24, 1), (73, 1), (371, 1), (383, 1)],
#  [(24, 1), (73, 1), (373, 1), (383, 1)],
#  [(24, 1), (25, 1), (373, 1), (383, 1)],
#  [(24, 1), (194, 1), (371, 1)],
#  [(194, 1), (327, 1)],
#  [(24, 1), (194, 1), (371, 1)],
#  [(24, 1), (194, 1), (371, 1)],
#  [(24, 1), (194, 1), (371, 1), (384, 1)],
#  [(24, 1), (194, 1), (371, 1)],
#  [(372, 1), (373, 1)],
#  [(24, 1), (373, 1)],
#  [(372, 1), (373, 1)],
#  [(24, 1), (373, 1)],
#  [(193, 1), (284, 1), (385, 1)],
#  [(194, 1), (284, 1), (354, 1), (385, 1), (386, 1)],
#  [(193, 1), (194, 1), (198, 1), (385, 1), (386, 1)],
#  [(73, 1), (193, 1), (194, 1), (387, 1)],
#  [(194, 1), (280, 1), (337, 1), (388, 1)],
#  [(62, 1), (84, 1), (194, 1), (247, 1), (379, 1), (388, 1), (389, 1)],
#  [(62, 1), (230, 1), (247, 1), (379, 1), (388, 1), (390, 1), (391, 1)],
#  [(62, 1),
#   (84, 1),
#   (194, 1),
#   (247, 1),
#   (370, 1),
#   (379, 1),
#   (389, 1),
#   (390, 1),
#   (391, 1)],
#  [(8, 1), (84, 1), (194, 1), (241, 1), (388, 1), (392, 1), (393, 1)],
#  [(8, 1), (84, 1), (194, 1), (230, 1), (388, 1), (392, 1), (393, 1)],
#  [(194, 1), (226, 1), (237, 1), (394, 1)],
#  [(194, 1), (226, 1), (237, 1), (303, 1), (387, 1), (394, 1)],
#  [(194, 1), (226, 1), (237, 1), (261, 1), (387, 1), (394, 1)],
#  [(25, 1), (194, 1), (284, 1), (354, 1), (387, 1), (395, 1)],
#  [(121, 1), (151, 1), (173, 1), (194, 1), (209, 1)],
#  [(151, 1), (173, 1), (194, 1), (209, 1), (294, 1), (396, 1)],
#  [(194, 1), (397, 1)],
#  [(194, 1), (202, 1), (214, 1), (398, 1)],
#  [(399, 1)],
#  [(397, 1)],
#  [(25, 1), (121, 1), (194, 1), (247, 1), (400, 1)],
#  [(121, 1), (126, 1), (194, 1), (231, 1), (247, 1)],
#  [(25, 1), (121, 1), (194, 1), (247, 1), (398, 1), (401, 1)],
#  [(25, 1), (151, 1), (194, 1), (376, 1), (398, 1), (401, 1)],
#  [(25, 1),
#   (121, 1),
#   (151, 1),
#   (194, 1),
#   (209, 1),
#   (376, 1),
#   (398, 1),
#   (401, 1)],
#  [(121, 1), (194, 1), (215, 1), (231, 1), (237, 1), (247, 1), (402, 1)],
#  [(121, 1), (194, 1), (202, 1), (215, 1), (231, 1), (247, 1), (402, 1)],
#  [(194, 1), (398, 1)],
#  [(151, 1), (194, 1), (397, 1)],
#  [(173, 1), (194, 1), (214, 1)],
#  [(25, 2), (121, 1), (194, 1), (247, 1), (373, 1), (403, 1)],
#  [(25, 2), (121, 1), (194, 1), (247, 1), (402, 2), (403, 1)],
#  [(25, 1), (121, 1), (194, 1), (247, 1), (402, 2)],
#  [(25, 1), (121, 1), (194, 1), (247, 2), (386, 1)],
#  [(13, 1), (25, 1), (121, 1), (194, 1), (209, 1), (400, 1)],
#  [(13, 1), (25, 1), (121, 1), (194, 1), (209, 1), (404, 1)],
#  [(25, 1), (155, 1), (194, 1), (202, 1), (405, 1), (406, 1)],
#  [(121, 1), (173, 1), (194, 1), (209, 1), (214, 1), (274, 1), (406, 1)],
#  [(121, 1), (173, 1), (194, 1), (209, 1), (214, 1), (405, 1)],
#  [(194, 1), (214, 1), (237, 1), (398, 1)],
#  [(194, 1), (209, 1)],
#  [(121, 1), (194, 1), (209, 1), (215, 1)],
#  [(121, 1), (194, 1), (209, 1), (407, 1)],
#  [(194, 1)],
#  [(121, 1), (194, 1), (209, 1), (408, 1)],
#  [(121, 1), (194, 1), (209, 1), (409, 1)],
#  [(172, 1), (194, 1)],
#  [(172, 1), (194, 1), (209, 1)],
#  [(194, 1), (209, 1), (212, 1), (274, 1), (409, 1), (410, 1), (411, 1)],
#  [(121, 1), (194, 1), (195, 1), (209, 1), (215, 1), (255, 1), (412, 1)],
#  [(121, 1), (194, 1), (209, 1), (215, 1), (275, 1)],
#  [(121, 1), (172, 1), (194, 1), (209, 1), (215, 1), (271, 1)],
#  [(121, 1), (172, 1), (194, 1), (209, 1), (215, 1)],
#  [(194, 1), (340, 1), (413, 1), (414, 1)],
#  [(121, 1), (194, 1), (207, 1), (215, 1), (247, 1), (410, 1), (415, 1)],
#  [(121, 1), (151, 1), (194, 1), (247, 1), (340, 1), (415, 1)],
#  [(21, 1),
#   (100, 1),
#   (121, 1),
#   (194, 1),
#   (215, 1),
#   (247, 1),
#   (250, 1),
#   (256, 1),
#   (368, 1)],
#  [(121, 1), (194, 1), (209, 1)],
#  [(121, 1), (194, 1)],
#  [(194, 1)],
#  [(121, 1), (194, 1), (209, 1)],
#  [(194, 1)],
#  [(194, 1), (209, 1)],
#  [(22, 1), (121, 1), (194, 1)],
#  [(121, 1), (209, 1), (215, 1)],
#  [(215, 1)],
#  [(73, 1), (408, 1)],
#  [(194, 1), (408, 1)],
#  [(8, 1), (193, 1), (194, 1), (416, 1), (417, 1)],
#  [(8, 1), (13, 1), (136, 1), (194, 1), (255, 1), (257, 1), (376, 1), (418, 1)],
#  [(25, 1), (37, 1), (194, 1), (231, 1), (376, 1), (416, 1), (418, 1), (419, 1)],
#  [(8, 1), (194, 1), (209, 1), (212, 1), (231, 1), (237, 1), (269, 1), (366, 1)],
#  [(8, 1), (194, 1), (209, 1), (231, 1), (269, 1), (366, 1), (418, 1)],
#  [(8, 1),
#   (121, 1),
#   (194, 1),
#   (202, 1),
#   (209, 1),
#   (215, 1),
#   (231, 1),
#   (416, 1),
#   (420, 1)],
#  [(194, 1), (210, 1), (211, 1), (212, 1), (231, 1), (416, 1)],
#  [(194, 1), (231, 1), (416, 1)],
#  [(48, 1), (194, 1), (231, 1), (237, 1)],
#  [(194, 1), (210, 1), (211, 1), (212, 1), (253, 1), (421, 1)],
#  [(210, 1), (253, 1), (421, 1)],
#  [(194, 1), (252, 1), (253, 1), (416, 1), (422, 1)],
#  [(194, 1), (253, 1), (416, 1), (422, 1)],
#  [(280, 1), (326, 1), (416, 1), (423, 1), (424, 1), (425, 1)],
#  [(8, 1), (194, 1), (202, 1), (231, 1), (416, 1), (420, 1)],
#  [(194, 1), (349, 1), (419, 1), (426, 1), (427, 1), (428, 1)],
#  [(194, 1), (419, 1), (426, 1), (427, 1), (428, 1), (429, 1)],
#  [(194, 1), (234, 1), (280, 1), (423, 1), (425, 1)],
#  [(194, 1), (422, 1)],
#  [(194, 1), (209, 1), (215, 1), (280, 1), (423, 1)],
#  [(48, 1), (194, 1), (215, 1), (241, 1), (280, 1), (423, 1)],
#  [(121, 1),
#   (194, 1),
#   (209, 1),
#   (215, 1),
#   (253, 1),
#   (304, 1),
#   (423, 1),
#   (430, 1)],
#  [(121, 1),
#   (194, 1),
#   (209, 1),
#   (215, 1),
#   (304, 1),
#   (420, 1),
#   (423, 1),
#   (430, 1)],
#  [(194, 1), (419, 1), (431, 1)],
#  [(48, 1), (60, 1), (155, 1), (194, 1), (237, 1)],
#  [(38, 1),
#   (63, 1),
#   (121, 1),
#   (194, 1),
#   (202, 1),
#   (215, 1),
#   (247, 1),
#   (421, 1),
#   (432, 1),
#   (433, 1)],
#  [(38, 1),
#   (63, 1),
#   (121, 1),
#   (194, 1),
#   (202, 1),
#   (215, 1),
#   (247, 1),
#   (432, 1),
#   (433, 1),
#   (434, 1)],
#  [(48, 1), (155, 1), (194, 1), (202, 1), (255, 1)],
#  [(194, 1), (202, 1), (255, 1), (416, 1)],
#  [(8, 1), (194, 1), (255, 1), (416, 1), (417, 1)],
#  [(194, 1), (222, 1), (257, 1), (435, 1)],
#  [(140, 1), (435, 1)],
#  [(140, 1), (194, 1), (350, 1)],
#  [(133, 1), (194, 1), (436, 1)],
#  [(24, 1), (158, 1), (437, 1)],
#  [(24, 1), (25, 1), (158, 1), (194, 1), (436, 1)],
#  [(24, 1), (150, 1), (158, 1), (194, 1)],
#  [(24, 1), (25, 1), (133, 1), (158, 1), (194, 1), (414, 1)],
#  [(140, 1), (194, 1), (350, 1)],
#  [(24, 1), (25, 1), (133, 1), (158, 1), (194, 1), (414, 1)],
#  [(158, 1), (414, 1), (437, 1)],
#  [(25, 1), (194, 1), (350, 1), (435, 1)],
#  [(24, 1), (194, 1), (436, 1), (438, 1), (439, 1), (440, 1)],
#  [(24, 1), (158, 1), (194, 1), (438, 1), (439, 1), (440, 1), (441, 1)],
#  [(24, 1), (158, 1), (194, 1), (438, 1), (440, 1), (441, 1)],
#  [(24, 1), (158, 1), (194, 1), (438, 1), (440, 1), (441, 1)],
#  [(24, 1), (158, 1), (194, 1), (377, 1)],
#  [(133, 1), (169, 1), (194, 1)],
#  [(169, 1), (194, 1), (219, 1)],
#  [(25, 1), (183, 1), (194, 1)],
#  [(38, 1), (121, 1), (194, 1), (247, 1), (279, 1)],
#  [(38, 1), (121, 1), (194, 1), (247, 1), (377, 1)],
#  [(38, 1), (121, 1), (194, 1), (215, 1), (247, 1), (442, 1)],
#  [(121, 1), (194, 1), (247, 1), (279, 1), (443, 1)],
#  [(121, 1), (194, 1), (247, 1), (279, 1)],
#  [(25, 1), (38, 1), (194, 1)],
#  [(60, 1), (121, 1), (194, 1), (207, 1), (209, 1), (215, 1)],
#  [(60, 1), (121, 1), (194, 1), (247, 1), (279, 1)],
#  [(60, 1), (121, 1), (194, 1), (247, 1), (377, 1)],
#  [(121, 1), (194, 1), (247, 1), (437, 1), (444, 1)],
#  [(38, 1), (121, 1), (194, 1), (202, 1), (209, 1)],
#  [(38, 1), (121, 1), (202, 1), (209, 1), (219, 1)],
#  [(38, 1), (121, 1), (194, 1), (202, 1), (209, 1), (377, 1)],
#  [],
#  [(121, 1), (194, 1), (209, 1), (445, 1)],
#  [(60, 1), (121, 1), (155, 1), (194, 1), (209, 1), (440, 1)],
#  [(38, 1), (194, 1), (209, 1), (279, 1)],
#  [(121, 1), (155, 1), (194, 1), (209, 1), (377, 1), (446, 1)],
#  [(121, 1), (194, 1), (247, 1), (377, 1), (446, 1)],
#  [(121, 1), (155, 1), (194, 1), (247, 1), (277, 1), (377, 1)],
#  [(8, 1), (13, 1), (121, 1), (194, 1), (247, 1), (377, 1)],
#  [(44, 1), (121, 1), (194, 1), (247, 1), (377, 1), (395, 1)],
#  [(194, 1), (377, 1), (443, 1)],
#  [(124, 1), (194, 1), (250, 1), (277, 1), (378, 1)],
#  [(167, 1), (194, 1), (378, 1)],
#  [(121, 1), (194, 1), (209, 1), (279, 1)],
#  [(165, 1), (194, 1), (209, 1), (260, 1), (377, 1), (418, 1)],
#  [(165, 1), (194, 1), (209, 1), (260, 1), (377, 1), (418, 1)],
#  [(109, 1),
#   (124, 1),
#   (194, 1),
#   (212, 1),
#   (260, 1),
#   (279, 1),
#   (367, 1),
#   (418, 1)],
#  [(25, 1),
#   (124, 1),
#   (194, 1),
#   (212, 1),
#   (260, 1),
#   (279, 1),
#   (367, 1),
#   (418, 1)],
#  [(25, 1), (194, 1), (209, 1), (237, 1), (367, 1)],
#  [(25, 2), (155, 1), (194, 1), (202, 1), (209, 1), (338, 1), (367, 1)],
#  [(25, 1), (155, 1), (194, 1), (212, 1), (260, 1), (367, 1), (418, 1)],
#  [(25, 1), (155, 1), (194, 1), (237, 1), (367, 1)],
#  [(60, 1), (194, 1), (219, 1)],
#  [(194, 1), (437, 1), (444, 1)],
#  [(155, 1), (216, 1)],
#  [(38, 1)],
#  [(60, 1)],
#  [(244, 1)],
#  [(133, 1), (167, 1), (194, 1)],
#  [(136, 1), (280, 1), (340, 1), (354, 1), (370, 1), (404, 1), (447, 1)],
#  [(67, 1), (193, 1), (213, 1), (448, 1), (449, 1)],
#  [(67, 1), (195, 1), (196, 1), (213, 1), (299, 1), (448, 1), (449, 1)],
#  [(193, 1), (237, 1), (250, 1), (271, 1), (450, 1)],
#  [(193, 1), (237, 1), (250, 1), (261, 1), (450, 1)],
#  [(25, 1),
#   (183, 1),
#   (194, 1),
#   (238, 1),
#   (280, 1),
#   (292, 1),
#   (354, 1),
#   (447, 1),
#   (451, 1)],
#  [(25, 2),
#   (183, 1),
#   (194, 1),
#   (209, 1),
#   (280, 1),
#   (294, 1),
#   (354, 1),
#   (447, 1),
#   (451, 1),
#   (452, 1)],
#  [(193, 1), (209, 1), (280, 1), (294, 1), (354, 1), (447, 1), (451, 1)],
#  [(280, 1), (354, 1), (447, 1), (451, 1)],
#  [(280, 1), (354, 1), (447, 1), (451, 1)],
#  [(237, 1), (404, 1)],
#  [(404, 1), (418, 1)],
#  [(362, 1), (453, 1), (454, 1)],
#  [(136, 1), (193, 1), (280, 1), (453, 1), (454, 1), (455, 1)],
#  [(136, 1), (280, 1), (453, 1), (454, 1), (455, 1)],
#  [(136, 1), (261, 1), (280, 1), (453, 1), (454, 1), (455, 1)],
#  [(194, 1), (280, 1), (340, 1), (404, 1), (456, 1), (457, 1)],
#  [(194, 1), (280, 1), (453, 1), (458, 1), (459, 1)],
#  [(194, 1), (280, 1), (292, 1), (404, 1)],
#  [(194, 1), (458, 1), (460, 1)],
#  [(194, 1), (237, 1)],
#  [(194, 1), (461, 1)],
#  [(194, 1), (461, 1)],
#  [(24, 2), (158, 1), (362, 1), (460, 1)],
#  [(24, 2), (158, 1), (362, 1), (459, 1)],
#  [(194, 1), (280, 1), (292, 1), (404, 1), (456, 1), (457, 1)],
#  [(194, 1), (280, 1), (299, 1), (453, 1)],
#  [(194, 1), (280, 1), (453, 1), (454, 1), (458, 1)],
#  [],
#  [(454, 1)],
#  [(193, 1)],
#  [(193, 1), (462, 1), (463, 1)],
#  [(193, 1), (463, 1), (464, 1)],
#  [(193, 1), (465, 1)],
#  [(176, 1), (193, 1)],
#  [(193, 1), (466, 1)],
#  [(193, 1)],
#  [(193, 1)],
#  [(193, 1)],
#  [(193, 1), (383, 1)],
#  [(193, 1), (240, 1), (431, 1)],
#  [(121, 1), (194, 1), (209, 1), (292, 1)],
#  [(121, 1), (194, 1), (209, 1), (247, 1), (324, 1), (413, 1), (467, 1)],
#  [(121, 1), (194, 1), (209, 1), (247, 1), (413, 1), (468, 1)],
#  [(121, 1), (194, 1), (209, 1), (247, 1), (467, 1), (468, 1)],
#  [(121, 1), (194, 1), (247, 1), (410, 1), (469, 1), (470, 1)],
#  [(121, 1), (194, 1), (247, 1), (410, 1), (469, 1), (470, 1)],
#  [(22, 1), (194, 1), (237, 1), (247, 1), (255, 1)],
#  [(121, 1), (141, 1), (194, 1), (209, 1), (247, 1), (468, 1), (471, 1)],
#  [(35, 1), (121, 1), (194, 1), (209, 1), (247, 1), (468, 1), (471, 1)],
#  [(231, 1), (472, 1)],
#  [(22, 1),
#   (79, 1),
#   (121, 1),
#   (193, 1),
#   (194, 1),
#   (209, 1),
#   (237, 1),
#   (247, 1),
#   (248, 1),
#   (255, 1)],
#  [(22, 1),
#   (121, 1),
#   (194, 1),
#   (195, 1),
#   (197, 1),
#   (209, 1),
#   (247, 1),
#   (255, 1),
#   (284, 1)],
#  [(121, 1),
#   (194, 1),
#   (195, 1),
#   (197, 1),
#   (209, 1),
#   (247, 1),
#   (255, 1),
#   (284, 1)],
#  [(121, 1), (194, 1), (197, 1), (209, 1), (247, 1), (273, 1), (284, 1)],
#  [(472, 1), (473, 1)],
#  [(194, 1), (214, 1), (474, 1)],
#  [(194, 1), (214, 1)],
#  [(194, 1), (214, 1), (475, 1)],
#  [(151, 1), (476, 1)],
#  [(214, 1), (477, 1)],
#  [(124, 1), (214, 1), (472, 1)],
#  [(124, 1), (214, 1), (478, 1)],
#  [(194, 1), (247, 1), (467, 1), (468, 1)],
#  [(194, 1), (247, 1), (413, 1), (468, 1)],
#  [(194, 1), (209, 1)],
#  [(22, 1),
#   (121, 1),
#   (194, 1),
#   (209, 1),
#   (247, 1),
#   (315, 1),
#   (410, 1),
#   (469, 1)],
#  [(22, 1),
#   (33, 1),
#   (121, 1),
#   (171, 1),
#   (194, 1),
#   (209, 1),
#   (247, 1),
#   (469, 1),
#   (479, 1)],
#  [(22, 1),
#   (33, 1),
#   (121, 1),
#   (171, 1),
#   (194, 1),
#   (209, 1),
#   (247, 1),
#   (469, 1),
#   (479, 1)],
#  [(22, 1), (79, 1), (194, 1), (209, 1), (231, 1), (237, 1), (247, 1)],
#  [(121, 1), (194, 1), (209, 1), (237, 1), (247, 1), (255, 1), (396, 1)],
#  [(38, 1),
#   (121, 1),
#   (194, 1),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (243, 1),
#   (247, 1),
#   (410, 1),
#   (480, 1)],
#  [(38, 1),
#   (121, 1),
#   (193, 1),
#   (194, 1),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (243, 1),
#   (247, 1),
#   (271, 1),
#   (410, 1),
#   (480, 1)],
#  [(121, 1),
#   (193, 1),
#   (194, 1),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (243, 1),
#   (247, 2),
#   (271, 1)],
#  [(13, 1),
#   (38, 1),
#   (121, 1),
#   (193, 1),
#   (194, 1),
#   (195, 1),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (247, 1),
#   (271, 1),
#   (410, 1),
#   (480, 1),
#   (481, 1)],
#  [(13, 1),
#   (38, 1),
#   (121, 1),
#   (194, 1),
#   (195, 1),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (247, 1),
#   (249, 1),
#   (410, 1),
#   (480, 1),
#   (481, 1)],
#  [(22, 1),
#   (38, 1),
#   (121, 1),
#   (194, 1),
#   (195, 1),
#   (247, 1),
#   (255, 1),
#   (368, 1),
#   (410, 1),
#   (480, 1)],
#  [(13, 1),
#   (38, 1),
#   (121, 1),
#   (193, 1),
#   (194, 1),
#   (247, 1),
#   (248, 1),
#   (410, 1),
#   (480, 1),
#   (481, 1)],
#  [(13, 1), (121, 1), (193, 1), (194, 1), (247, 2), (248, 1), (481, 1)],
#  [(13, 1), (121, 1), (194, 1), (195, 1), (247, 2), (248, 1), (481, 1)],
#  [(121, 1), (194, 1), (247, 2), (413, 1), (467, 1), (477, 1)],
#  [(473, 1), (478, 1)],
#  [(231, 1), (478, 1)],
#  [(474, 1)],
#  [(25, 1), (474, 1)],
#  [(25, 1), (376, 1)],
#  [(475, 1)],
#  [(194, 1), (476, 1)],
#  [(194, 1), (476, 1)],
#  [(25, 1), (482, 1), (483, 1)],
#  [(482, 1), (483, 1)],
#  [(475, 1), (483, 1)],
#  [(194, 1), (476, 1), (483, 1)],
#  [(63, 1), (194, 1), (217, 1), (476, 1)],
#  [(476, 1), (483, 1)],
#  [(194, 1), (214, 1), (475, 1)],
#  [(194, 1), (476, 1)],
#  [(194, 1), (476, 1)],
#  [(194, 1), (482, 1), (483, 1)],
#  [(22, 1), (194, 1), (240, 1), (410, 1), (469, 1)],
#  [(22, 1), (194, 1), (410, 1), (469, 1), (484, 1)],
#  [(44, 1),
#   (132, 1),
#   (134, 1),
#   (194, 1),
#   (303, 1),
#   (455, 1),
#   (485, 1),
#   (486, 1),
#   (487, 1)],
#  [(194, 1), (212, 1), (260, 1), (410, 1), (411, 1), (484, 1)],
#  [(135, 1), (194, 1), (260, 1), (411, 1), (488, 1)],
#  [(209, 1), (410, 1), (411, 1), (489, 1)],
#  [(274, 1), (410, 1), (411, 1)],
#  [(44, 1), (132, 1), (134, 1), (194, 1), (485, 1), (486, 1), (487, 1)],
#  [(44, 1),
#   (132, 1),
#   (134, 1),
#   (194, 1),
#   (284, 1),
#   (354, 1),
#   (455, 1),
#   (485, 1),
#   (486, 1),
#   (487, 1)],
#  [(22, 1), (44, 1), (132, 1), (134, 1), (194, 1), (209, 1), (410, 1), (487, 1)],
#  [(22, 1), (44, 1), (132, 1), (134, 1), (194, 1), (209, 1), (413, 1)],
#  [(22, 1), (410, 1), (469, 1), (490, 1)],
#  [(22, 1), (240, 1), (410, 1), (469, 1), (490, 1)],
#  [(22, 1), (410, 1), (469, 1), (490, 1), (491, 1)],
#  [(22, 1), (194, 1), (240, 1), (410, 1), (469, 1), (490, 1)],
#  [(194, 1), (212, 1), (410, 1), (469, 1), (490, 1), (491, 1)],
#  [(44, 1),
#   (132, 1),
#   (134, 1),
#   (194, 1),
#   (284, 1),
#   (354, 1),
#   (455, 1),
#   (485, 1),
#   (487, 1),
#   (492, 1)],
#  [(44, 1),
#   (132, 1),
#   (134, 1),
#   (193, 1),
#   (194, 1),
#   (455, 1),
#   (485, 1),
#   (487, 1),
#   (492, 1)],
#  [(44, 1),
#   (132, 1),
#   (134, 1),
#   (193, 1),
#   (239, 1),
#   (451, 1),
#   (481, 1),
#   (487, 1)],
#  [(44, 1),
#   (132, 1),
#   (134, 1),
#   (239, 1),
#   (261, 1),
#   (284, 1),
#   (455, 1),
#   (481, 1),
#   (487, 1)],
#  [(48, 1), (193, 1), (237, 1), (241, 1), (455, 1)],
#  [(13, 1), (57, 1), (194, 1), (274, 1), (279, 1), (493, 1), (494, 1), (495, 1)],
#  [(13, 1), (57, 1), (194, 1), (274, 1), (351, 1), (377, 1), (496, 1), (497, 1)],
#  [(13, 1), (57, 1), (163, 1), (194, 1), (202, 1), (279, 1)],
#  [(13, 1), (57, 1), (163, 1), (194, 1), (202, 1), (377, 1)],
#  [(13, 1), (194, 1), (237, 1), (274, 1), (279, 1), (493, 1), (495, 1)],
#  [(38, 1), (57, 1), (194, 1), (274, 1), (493, 1), (494, 1), (497, 1)],
#  [(38, 1), (57, 1), (194, 1), (202, 1), (274, 1), (493, 1), (494, 1), (497, 1)],
#  [(13, 1), (194, 1), (202, 1), (274, 1), (378, 1), (497, 1)],
#  [(13, 1), (194, 1), (274, 1), (279, 1), (497, 1)],
#  [(57, 1), (194, 1), (274, 1), (279, 1), (351, 1), (498, 1), (499, 1)],
#  [(44, 1), (57, 1), (194, 1), (274, 1), (279, 1), (351, 1), (498, 1), (499, 1)],
#  [(168, 1), (397, 1)],
#  [(168, 1), (194, 1), (219, 1), (280, 1), (326, 1)],
#  [(168, 1), (169, 1), (174, 1), (194, 1), (278, 1), (500, 1)],
#  [(168, 1), (169, 1), (174, 1), (194, 1), (500, 1), (501, 1), (502, 1)],
#  [(25, 1), (168, 1)],
#  [(25, 1), (168, 1), (169, 1)],
#  [(168, 1), (169, 1), (174, 1), (194, 1), (279, 1), (501, 1), (502, 1)],
#  [(168, 1), (169, 1), (174, 1), (194, 1), (377, 1), (501, 1), (502, 1)],
#  [(25, 1), (155, 1), (168, 1), (194, 1), (434, 1)],
#  [(25, 1), (165, 1), (168, 1), (194, 1), (434, 1)],
#  [(25, 1), (168, 1), (194, 1), (244, 1), (434, 1)],
#  [(25, 1), (168, 1), (173, 1), (194, 1), (434, 1)],
#  [(168, 1), (169, 1), (173, 1), (174, 1), (194, 1), (500, 1)],
#  [(168, 1), (169, 1), (174, 1), (194, 1), (219, 1), (399, 1)],
#  [(168, 1), (174, 1), (178, 1), (403, 1)],
#  [(168, 1), (174, 1)],
#  [(174, 1), (503, 1), (504, 1)],
#  [(44, 1), (169, 1), (194, 1), (377, 1), (503, 1), (504, 1)],
#  [(40, 1), (168, 1), (194, 1), (377, 1), (505, 1), (506, 1), (507, 1)],
#  [(40, 1), (168, 1), (194, 1), (219, 1), (505, 1), (506, 1), (507, 1)],
#  [(155, 1), (168, 1), (194, 1), (507, 1)],
#  [(155, 1), (168, 1), (174, 1)],
#  [(114, 1), (194, 1), (362, 1), (452, 1), (508, 1)],
#  [(48, 1), (60, 1), (194, 1), (202, 1), (382, 1)],
#  [(13, 1), (25, 1), (121, 1), (194, 1), (209, 1), (377, 1)],
#  [(13, 1),
#   (121, 1),
#   (194, 1),
#   (209, 1),
#   (215, 1),
#   (221, 1),
#   (231, 1),
#   (237, 1),
#   (245, 1)],
#  [(13, 1),
#   (121, 1),
#   (194, 1),
#   (209, 1),
#   (215, 1),
#   (231, 1),
#   (237, 1),
#   (245, 1)],
#  [(13, 1), (121, 1), (194, 1), (209, 1), (377, 1)],
#  [(13, 1), (194, 1), (212, 1), (274, 1), (445, 1)],
#  [(13, 1),
#   (121, 1),
#   (194, 1),
#   (209, 1),
#   (221, 1),
#   (237, 1),
#   (245, 1),
#   (377, 1),
#   (509, 1)],
#  [(13, 1),
#   (121, 1),
#   (194, 1),
#   (209, 1),
#   (215, 1),
#   (221, 1),
#   (231, 1),
#   (245, 1),
#   (483, 1)],
#  [(13, 1), (194, 1), (237, 1), (245, 1), (279, 1)],
#  [(13, 1), (194, 1), (237, 1), (245, 1), (445, 1)],
#  [(13, 1), (194, 1), (237, 1), (245, 1), (381, 1)],
#  [(202, 1)],
#  [(237, 1)],
#  [(73, 1)],
#  [(73, 1), (275, 1)],
#  [],
#  [(13, 1), (194, 1), (202, 1), (245, 1), (377, 1)],
#  [(13, 1), (194, 1), (202, 1), (245, 1), (279, 1)],
#  [(25, 1), (121, 1), (194, 1), (209, 1), (377, 1), (510, 1), (511, 1)],
#  [(13, 1), (121, 1), (194, 1), (202, 1), (209, 1), (377, 1), (510, 1)],
#  [(38, 1), (194, 1), (202, 1), (377, 1), (511, 1)],
#  [(13, 1), (38, 1), (48, 1), (194, 1), (377, 1)],
#  [(13, 1),
#   (48, 1),
#   (60, 1),
#   (194, 1),
#   (202, 1),
#   (209, 1),
#   (215, 1),
#   (218, 1),
#   (442, 1)],
#  [(13, 1), (114, 1), (194, 1), (212, 1), (274, 1)],
#  [(13, 1), (194, 1), (202, 1), (245, 1), (279, 1)],
#  [(13, 1),
#   (121, 1),
#   (194, 1),
#   (202, 1),
#   (209, 1),
#   (214, 1),
#   (221, 1),
#   (509, 1)],
#  [(114, 1), (194, 1), (362, 1), (452, 1)],
#  [(114, 1), (194, 1), (245, 1), (362, 1), (452, 1)],
#  [(8, 1), (48, 1), (194, 1), (202, 1), (245, 1), (253, 1), (377, 1), (452, 1)],
#  [(8, 1), (48, 1), (194, 1), (202, 1), (245, 1), (377, 1), (452, 1)],
#  [(8, 1), (194, 1), (202, 1), (242, 1), (245, 1), (452, 1)],
#  [(48, 1), (155, 1), (194, 1), (214, 1), (362, 1), (452, 1), (512, 1)],
#  [(48, 1), (155, 1), (194, 1), (214, 1), (304, 1), (362, 1), (508, 1)],
#  [(48, 1), (194, 1), (202, 1), (245, 1), (377, 1), (452, 1)],
#  [(25, 1), (148, 1), (194, 1), (202, 1), (245, 1)],
#  [(194, 1), (202, 1), (245, 1), (445, 1), (452, 1)],
#  [(194, 1), (202, 1), (245, 1), (377, 1), (452, 1)],
#  [(48, 1), (194, 1), (202, 1), (214, 1), (245, 1)],
#  [(48, 1), (148, 1), (194, 1), (202, 1), (245, 1), (511, 1)],
#  [(44, 1), (48, 1), (194, 1), (214, 1), (326, 1), (362, 1), (508, 1), (513, 1)],
#  [(194, 1), (214, 1), (326, 1), (362, 1), (457, 1), (513, 1)],
#  [(114, 1), (194, 1), (280, 1), (304, 1), (513, 1)],
#  [(114, 1), (194, 1), (245, 1), (362, 1), (513, 1)],
#  [(514, 1), (515, 1), (516, 1)],
#  [(516, 1)],
#  [(516, 1)],
#  [(516, 1), (517, 1)],
#  [(518, 1)],
#  [(518, 1)],
#  [(188, 1), (514, 1), (515, 1), (516, 1)],
#  [(516, 1), (517, 1), (519, 1)],
#  [(47, 1), (516, 1), (517, 1)],
#  [(50, 1), (86, 1), (516, 1), (517, 1)],
#  [(36, 1), (88, 1), (155, 1), (516, 1), (520, 1), (521, 1)],
#  [(9, 1), (516, 1)],
#  [(26, 1), (516, 1)],
#  [(45, 1), (516, 1)],
#  [(26, 1), (516, 1)],
#  [(6, 1), (45, 1), (516, 1)],
#  [(9, 1), (516, 1)],
#  [(41, 1), (516, 1)],
#  [(1, 1), (13, 1), (516, 1)],
#  [(9, 1)],
#  [(9, 1), (516, 1)],
#  [(26, 1), (29, 1), (88, 1), (286, 1), (516, 1), (522, 1)],
#  [(45, 1), (88, 1), (516, 1)],
#  [(5, 1), (26, 1), (94, 1), (126, 1), (516, 1)],
#  [(36, 1), (77, 1), (88, 1), (94, 1), (516, 1), (520, 1), (521, 1), (523, 1)],
#  [(36, 1), (77, 1), (94, 1), (516, 1), (524, 1), (525, 1)],
#  [(1, 1), (41, 1), (94, 1), (523, 1), (526, 1)],
#  [(26, 1), (29, 1), (39, 1), (88, 1), (516, 1), (522, 1)],
#  [(103, 1), (510, 1), (523, 1), (526, 1)],
#  [(15, 1), (103, 1), (510, 1), (523, 1), (526, 1)],
#  [(15, 1), (18, 1), (516, 1)],
#  [(27, 1), (516, 1)],
#  [(26, 1), (470, 1), (516, 1)],
#  [(27, 1), (516, 1)],
#  [(516, 1)],
#  [(257, 1), (516, 1), (527, 1)],
#  [(470, 1), (516, 1)],
#  [(516, 1), (527, 1)],
#  [(26, 1), (54, 1), (170, 1), (349, 1), (516, 1), (528, 1)],
#  [(38, 1), (48, 1), (54, 1), (516, 1), (528, 1)],
#  [(54, 1), (516, 1), (528, 1)],
#  [(54, 1), (516, 1)],
#  [(54, 1), (516, 1), (528, 1)],
#  [(54, 1), (105, 1), (516, 1)],
#  [(54, 1), (103, 1), (257, 1), (345, 1), (516, 1), (528, 1)],
#  [(54, 1), (105, 1), (345, 1), (516, 1)],
#  [(54, 1), (516, 1)],
#  [(54, 1), (516, 1), (528, 1)],
#  [(13, 1), (516, 1), (529, 1)],
#  [(516, 1), (530, 1)],
#  [(516, 1), (531, 1)],
#  [(516, 1), (531, 1)],
#  [(515, 1), (516, 1), (531, 1)],
#  [(48, 1), (155, 1), (463, 1), (516, 1), (531, 1)],
#  [(516, 1), (530, 1)],
#  [(36, 1), (463, 1), (516, 1), (531, 1)],
#  [(38, 1), (48, 1), (463, 1), (516, 1), (531, 1)],
#  [(155, 1), (184, 1), (463, 1), (516, 1), (531, 1)],
#  [(463, 1), (516, 1), (531, 1), (532, 1)],
#  [(407, 1), (516, 1), (531, 1)],
#  [(516, 1), (519, 1), (531, 1)],
#  [(47, 1), (516, 1)],
#  [(50, 1), (86, 1), (516, 1), (531, 1)],
#  [(516, 1), (519, 1)],
#  [(1, 1), (516, 1), (533, 1), (534, 1), (535, 1), (536, 1), (537, 1)],
#  [(1, 1), (516, 1), (533, 1), (535, 1), (536, 1), (538, 1), (539, 1)],
#  [(1, 1),
#   (516, 1),
#   (533, 1),
#   (534, 1),
#   (535, 1),
#   (536, 1),
#   (537, 1),
#   (538, 1),
#   (539, 1)],
#  [(516, 1), (536, 1)],
#  [(516, 1)],
#  [(463, 1), (516, 1), (540, 1), (541, 1)],
#  [(257, 1), (516, 1), (541, 1)],
#  [(516, 1), (541, 1)],
#  [(516, 1), (541, 1)],
#  [(41, 1), (88, 1), (516, 2), (521, 1), (523, 1), (541, 1), (542, 1), (543, 1)],
#  [(13, 1), (88, 1), (144, 1), (516, 2), (521, 1), (541, 1), (542, 1), (543, 1)],
#  [(47, 1), (516, 1), (541, 1)],
#  [(50, 1), (86, 1), (516, 1), (541, 1)],
#  [(516, 1)],
#  [(516, 1), (544, 1), (545, 1)],
#  [(407, 1), (516, 1), (544, 1), (545, 1)],
#  [(516, 1), (544, 1), (545, 1)],
#  [(245, 1), (516, 1), (546, 1), (547, 1), (548, 1), (549, 1)],
#  [(516, 1), (545, 1), (546, 1), (547, 1), (548, 1), (549, 1)],
#  [(29, 1), (30, 1), (40, 1), (516, 1), (545, 1)],
#  [(516, 1), (545, 1)],
#  [(516, 1)],
#  [(516, 1), (544, 1), (545, 1)],
#  [(104, 1), (516, 1), (545, 1), (550, 1), (551, 1), (552, 1)],
#  [(516, 1), (519, 1), (545, 1)],
#  [(47, 1), (516, 1), (545, 1)],
#  [(50, 1), (86, 1), (516, 1), (545, 1)],
#  [(516, 1), (532, 1), (553, 1)],
#  [(516, 1), (553, 1)],
#  [(516, 1), (553, 1)],
#  [(38, 1), (48, 1), (463, 1), (516, 1), (554, 1)],
#  [(516, 1)],
#  [(38, 1), (48, 1), (463, 1), (516, 1), (553, 1)],
#  [(516, 1), (554, 1)],
#  [(257, 1), (516, 1), (554, 1)],
#  [(257, 1), (516, 1), (554, 1)],
#  [(25, 1), (516, 1), (553, 1)],
#  [(516, 1), (554, 1), (555, 1)],
#  [(176, 1), (516, 1), (553, 1)],
#  [(25, 1), (516, 1), (553, 1)],
#  [(516, 1), (519, 1), (553, 1)],
#  [(47, 1), (516, 1), (553, 1)],
#  [(86, 1), (516, 1), (553, 1)],
#  [(466, 1), (516, 1)],
#  [(516, 1)],
#  [(30, 1), (146, 1), (516, 1)],
#  [(29, 1), (30, 1), (516, 1)],
#  [(516, 1)],
#  [(29, 1), (516, 1), (546, 1)],
#  [(516, 1)],
#  [(516, 1)],
#  [(176, 1), (516, 1)],
#  [(29, 1), (516, 1)],
#  [(516, 1)],
#  [(516, 1)],
#  [(516, 1)],
#  [(516, 1), (556, 1), (557, 1)],
#  [(9, 1), (516, 2)],
#  [(118, 1), (159, 1), (164, 1), (516, 1), (558, 1)],
#  [(120, 1), (516, 1), (559, 1), (560, 1)],
#  [(45, 1), (560, 1), (561, 1)],
#  [(43, 1), (88, 1), (120, 1), (154, 1)],
#  [(120, 1), (516, 1), (559, 1)],
#  [(120, 1), (159, 1), (516, 1), (559, 1)],
#  [(115, 1), (120, 1), (516, 1), (556, 1), (559, 1)],
#  [(120, 1), (516, 1), (559, 1)],
#  [(43, 1), (88, 1), (154, 1), (214, 1), (516, 1), (557, 1)],
#  [(516, 1), (562, 1)],
#  [(41, 1), (516, 1), (562, 1)],
#  [(146, 1), (562, 1)],
#  [(516, 1), (562, 1)],
#  [(13, 1), (516, 1), (523, 1), (562, 1), (563, 1)],
#  [(38, 1), (48, 1), (463, 1), (516, 1), (562, 1)],
#  [(13, 1), (25, 1), (516, 1)],
#  [(13, 1), (25, 1), (516, 1), (562, 1)],
#  [(13, 1), (516, 1), (562, 1)],
#  [(41, 1), (516, 1), (550, 1), (562, 1)],
#  [(516, 1), (564, 1)],
#  [(516, 1), (564, 1)],
#  [(516, 1), (562, 1)],
#  [(516, 1), (519, 1), (564, 1)],
#  [(47, 1), (516, 1), (564, 1)],
#  [(50, 1), (86, 1), (516, 1)],
#  [(516, 1), (565, 1)],
#  [(516, 1), (552, 1), (555, 1), (566, 1)],
#  [(13, 1), (144, 1), (151, 1), (516, 1), (565, 1)],
#  [(41, 1), (516, 1), (567, 1)],
#  [(13, 1), (110, 1), (516, 1), (567, 1)],
#  [(155, 1), (277, 1), (463, 1), (516, 1), (565, 1)],
#  [(516, 1), (565, 1)],
#  [(257, 1), (516, 1), (565, 1)],
#  [(41, 1), (516, 1), (567, 1)],
#  [(1, 1), (13, 1), (516, 1), (567, 1)],
#  [(463, 1), (464, 1), (516, 1), (565, 1)],
#  [(462, 1), (516, 1), (565, 1)],
#  [(516, 1), (519, 1), (565, 1)],
#  [(47, 1), (516, 1), (565, 1)],
#  [(50, 1), (86, 1), (516, 1), (565, 1)],
#  [(516, 1)],
#  [(516, 1), (566, 1)],
#  [(516, 1), (566, 1)],
#  [(229, 1), (351, 1), (516, 1), (521, 1), (523, 1), (568, 1), (569, 1)],
#  [(516, 1), (521, 1)],
#  [(29, 1), (39, 1), (40, 1), (516, 1), (521, 1)],
#  [(155, 1), (184, 1), (463, 1), (516, 1), (521, 1)],
#  [(516, 1), (521, 1)],
#  [(516, 1), (521, 1), (546, 1), (563, 1), (566, 1)],
#  [(175, 1), (463, 1), (521, 1), (546, 1)],
#  [(463, 1), (465, 1), (516, 1), (521, 1)],
#  [(38, 1), (48, 1), (516, 1), (521, 1)],
#  [(38, 1), (48, 1), (463, 1), (516, 1), (521, 1)],
#  [(155, 1), (184, 1), (463, 1), (516, 1), (521, 1)],
#  [(407, 1), (516, 1), (521, 1)],
#  [(516, 1), (519, 1), (521, 1)],
#  [(47, 1), (516, 1), (521, 1)],
#  [(50, 1), (86, 1), (516, 1), (521, 1)],
#  [(25, 1), (516, 1), (570, 1)],
#  [(25, 1), (516, 1), (571, 1)],
#  [(257, 1), (516, 1), (571, 1)],
#  [(63, 1), (77, 1), (516, 1), (572, 1)],
#  [(13, 1), (516, 1), (572, 1)],
#  [(516, 1), (571, 1)],
#  [(13, 1), (525, 1), (572, 1)],
#  [(63, 1), (516, 1), (570, 1)],
#  [(90, 1), (160, 1), (516, 1), (572, 1), (573, 1)],
#  [(13, 1), (90, 1), (516, 1), (572, 1)],
#  [(13, 1), (76, 1), (516, 1), (572, 1)],
#  [(25, 1), (29, 1), (516, 1), (571, 1)],
#  [(29, 1), (73, 1), (257, 1), (516, 1), (571, 1)],
#  [(25, 1), (29, 1), (416, 1), (516, 1), (571, 1)],
#  [(24, 1), (245, 1), (257, 1), (516, 1)],
#  [(245, 1), (516, 1)],
#  [(245, 1), (516, 1)],
#  [(245, 1), (516, 1)],
#  [(39, 1), (245, 1), (516, 1)],
#  [(38, 1), (48, 1), (245, 1), (516, 1)],
#  [(36, 1), (245, 1), (516, 1)],
#  [(24, 1), (245, 1), (257, 1), (516, 1)],
#  [(245, 1), (257, 1), (516, 1)],
#  [(375, 1), (516, 1), (573, 1)],
#  [(323, 1), (516, 1), (573, 1)],
#  [(25, 1), (91, 1), (373, 1), (525, 1), (573, 1)],
#  [(25, 1), (63, 1), (373, 1), (516, 1), (573, 1)],
#  [(373, 1), (516, 1), (573, 1), (574, 1)],
#  [(294, 1), (373, 1), (516, 1), (573, 1)],
#  [(340, 1), (373, 1), (516, 1), (573, 1)],
#  [(24, 1), (371, 1), (516, 1), (573, 1)],
#  [(332, 1), (373, 1), (516, 1)],
#  [(373, 1), (516, 1), (573, 1)],
#  [(516, 1), (575, 1)],
#  [(38, 1), (48, 1), (463, 1), (516, 1), (575, 1)],
#  [(48, 1), (155, 1), (463, 1), (516, 1), (575, 1)],
#  [(516, 1)],
#  [(38, 1), (184, 1), (463, 1), (516, 1), (575, 1)],
#  [(516, 1)],
#  [(36, 1), (463, 1), (516, 1), (575, 1)],
#  [(516, 1), (576, 1)],
#  [(516, 1), (575, 1)],
#  [(407, 1), (516, 1), (575, 1)],
#  [(463, 1), (465, 1), (516, 1), (575, 1)],
#  [(516, 1), (540, 1), (575, 1)],
#  [(37, 1), (463, 1), (516, 1), (575, 1)],
#  [(516, 1), (575, 1)],
#  [(29, 1), (516, 1)],
#  [(516, 1), (519, 1), (576, 1)],
#  [(47, 1), (516, 1), (576, 1)],
#  [(50, 1), (86, 1), (516, 1), (576, 1)],
#  [(60, 1), (525, 1)],
#  [(516, 1)],
#  [(13, 1), (74, 1), (75, 1), (516, 1)],
#  [(50, 1), (60, 1), (516, 1)],
#  [(60, 1), (124, 1), (525, 1)],
#  [(60, 1), (76, 1), (77, 1), (516, 1)],
#  [(60, 1), (78, 1), (79, 1), (269, 1), (516, 1)],
#  [(38, 1), (277, 1), (525, 1)],
#  [(250, 1), (277, 1), (296, 1), (516, 1)],
#  [(60, 1), (516, 1)],
#  [(85, 1)],
#  [(60, 1), (76, 1)],
#  [(42, 1), (85, 1), (146, 1), (171, 1), (229, 1), (577, 1)],
#  [(0, 1), (85, 1), (171, 1)],
#  [(0, 1), (41, 1)],
#  [(0, 1), (578, 1)],
#  [(10, 1), (24, 1), (157, 1), (158, 1), (162, 1)],
#  [(106, 1), (165, 1), (214, 1), (470, 1)],
#  [(0, 1), (15, 1), (22, 1)],
#  [(20, 1), (85, 1)],
#  [(13, 1), (15, 1), (85, 1), (221, 1), (579, 1)],
#  [(13, 1), (15, 1), (580, 1)],
#  [(14, 1), (15, 1), (32, 1), (221, 1), (244, 1), (581, 1)],
#  [(14, 1), (15, 1), (147, 1)],
#  [(44, 1), (406, 1), (582, 1), (583, 1)],
#  [(9, 1), (10, 1), (13, 1), (20, 1), (88, 1)],
#  [(15, 1), (133, 1), (577, 1)],
#  [(14, 1), (15, 1), (124, 1)],
#  [(13, 1), (15, 1), (19, 1), (214, 1)],
#  [(0, 1), (20, 1), (155, 1)],
#  [(13, 1), (14, 1), (15, 1), (50, 1), (88, 1)],
#  [(0, 1),
#   (14, 1),
#   (15, 1),
#   (24, 1),
#   (64, 1),
#   (147, 1),
#   (158, 1),
#   (414, 1),
#   (584, 1),
#   (585, 1)],
#  [(14, 1),
#   (15, 1),
#   (124, 1),
#   (159, 1),
#   (245, 1),
#   (257, 1),
#   (376, 1),
#   (558, 1),
#   (586, 1)],
#  [(173, 1), (587, 1)],
#  [(14, 1), (15, 1), (23, 1), (25, 1), (384, 1)],
#  [(588, 1)],
#  [(15, 1), (25, 1), (588, 1), (589, 1)],
#  [(14, 1), (15, 1), (112, 1), (574, 1)],
#  [(0, 1), (14, 1), (15, 2), (44, 1), (109, 1), (221, 1), (590, 1)],
#  [(14, 1), (15, 1), (23, 2), (44, 1), (109, 1), (577, 1), (591, 1)],
#  [(15, 1), (20, 1), (165, 1), (410, 1), (471, 1)],
#  [(20, 1), (25, 1), (44, 1), (574, 1)],
#  [(23, 1), (337, 1), (592, 1)],
#  [(20, 1), (25, 1), (574, 1), (593, 1)],
#  [(12, 1), (88, 1), (382, 1), (587, 1)],
#  [(13, 1), (15, 1), (134, 1), (267, 1), (594, 1)],
#  [(54, 1), (151, 1), (204, 1)],
#  [(174, 1), (197, 1), (307, 1), (496, 1)],
#  [(13, 1),
#   (15, 1),
#   (20, 1),
#   (25, 1),
#   (204, 1),
#   (294, 1),
#   (307, 1),
#   (424, 1),
#   (595, 1),
#   (596, 1)],
#  [(13, 1), (14, 1), (15, 1)],
#  [(13, 1),
#   (14, 1),
#   (15, 1),
#   (79, 1),
#   (106, 1),
#   (406, 1),
#   (470, 1),
#   (597, 1),
#   (598, 1)],
#  [(15, 1),
#   (23, 1),
#   (88, 1),
#   (124, 1),
#   (255, 1),
#   (296, 1),
#   (443, 1),
#   (577, 1),
#   (579, 1),
#   (589, 1),
#   (591, 1)],
#  [(15, 1), (23, 1), (124, 1), (133, 1)],
#  [(14, 1), (15, 1), (54, 1), (88, 1), (257, 1), (589, 1)],
#  [(15, 1), (158, 1), (410, 1), (592, 1), (599, 1)],
#  [(31, 1), (171, 1), (600, 1)],
#  [(60, 1), (109, 1), (600, 1), (601, 1)],
#  [(62, 1), (410, 1), (600, 1)],
#  [(35, 1), (146, 1), (410, 1), (561, 1), (597, 1), (600, 1), (601, 1)],
#  [(121, 1), (135, 1), (296, 1), (349, 1), (600, 1)],
#  [(60, 1), (600, 1)],
#  [(0, 1), (25, 1), (124, 1), (221, 1), (296, 1)],
#  [(204, 1), (285, 1), (294, 1), (296, 1), (600, 1)],
#  [(13, 1), (15, 1), (410, 1), (588, 1), (600, 1), (602, 1), (603, 1)],
#  [(204, 1), (294, 1), (296, 1), (604, 1)],
#  [(60, 1), (296, 1), (604, 1)],
#  [(15, 1),
#   (18, 1),
#   (48, 1),
#   (61, 1),
#   (89, 1),
#   (135, 1),
#   (204, 1),
#   (294, 1),
#   (410, 1),
#   (412, 1),
#   (595, 1),
#   (597, 1),
#   (600, 1)],
#  [(0, 1), (14, 1), (15, 1), (32, 1), (44, 1), (590, 1)],
#  [(0, 1), (11, 1), (25, 1), (61, 1), (64, 1), (605, 1), (606, 1), (607, 1)],
#  [(0, 1), (25, 1), (155, 1), (216, 1), (493, 1), (606, 1)],
#  [(0, 1), (18, 1), (20, 1), (155, 1), (216, 1), (493, 1), (606, 1)],
#  [(23, 1), (109, 1), (155, 1), (414, 1)],
#  [(0, 1), (20, 1), (25, 1), (382, 1)],
#  [(13, 1), (14, 1), (15, 1)],
#  [(14, 1), (15, 1), (25, 1), (147, 1), (376, 1), (580, 1)],
#  [(14, 1),
#   (23, 1),
#   (25, 1),
#   (83, 1),
#   (106, 1),
#   (147, 1),
#   (155, 1),
#   (214, 1),
#   (582, 1)],
#  [(12, 1), (20, 1), (304, 1), (577, 1)],
#  [(22, 1), (587, 1), (596, 1)],
#  [(516, 1)],
#  [(29, 1),
#   (516, 1),
#   (523, 1),
#   (526, 1),
#   (546, 1),
#   (561, 1),
#   (608, 1),
#   (609, 1),
#   (610, 1)],
#  [(29, 1), (523, 1), (526, 1), (561, 1)],
#  [(40, 1),
#   (53, 1),
#   (88, 1),
#   (109, 1),
#   (229, 1),
#   (551, 1),
#   (566, 1),
#   (602, 1),
#   (611, 1)],
#  [(113, 1), (204, 1), (205, 1), (473, 1), (503, 1), (516, 1), (612, 1)],
#  [(88, 1), (367, 1), (491, 1), (516, 1), (581, 1), (613, 1)],
#  [(131, 1),
#   (171, 1),
#   (229, 1),
#   (296, 1),
#   (410, 1),
#   (516, 1),
#   (613, 1),
#   (614, 2)],
#  [(9, 1), (516, 1)],
#  [(45, 1), (126, 1), (516, 1), (568, 1), (569, 1)],
#  [(13, 1), (43, 1), (88, 2), (152, 1), (516, 1), (521, 1), (573, 1)],
#  [(2, 1), (9, 1), (164, 1), (516, 1)],
#  [(25, 1), (29, 1), (45, 1), (154, 1), (409, 1), (473, 1)],
#  [(94, 1), (97, 1), (127, 1), (523, 1)],
#  [(50, 1), (516, 1)],
#  [(13, 1), (50, 1), (86, 1), (516, 1), (521, 1), (524, 2)],
#  [(50, 1), (88, 1), (221, 1), (516, 1), (524, 1), (568, 1)],
#  [(46, 1),
#   (50, 1),
#   (88, 1),
#   (111, 1),
#   (204, 1),
#   (296, 1),
#   (516, 1),
#   (615, 1),
#   (616, 1),
#   (617, 1),
#   (618, 1)],
#  [(112, 1),
#   (516, 1),
#   (573, 1),
#   (584, 1),
#   (585, 1),
#   (607, 1),
#   (619, 1),
#   (620, 1)],
#  [(47, 1), (60, 1), (516, 1)],
#  [(47, 3),
#   (61, 1),
#   (64, 1),
#   (109, 1),
#   (261, 1),
#   (337, 1),
#   (410, 2),
#   (488, 1),
#   (516, 1),
#   (621, 1)],
#  [(24, 1),
#   (47, 1),
#   (171, 1),
#   (296, 1),
#   (337, 1),
#   (516, 1),
#   (573, 1),
#   (593, 1),
#   (615, 1),
#   (622, 1)],
#  [(46, 1), (47, 1), (114, 1), (516, 1), (622, 1)],
#  [(64, 1), (516, 1), (620, 1), (623, 1), (624, 1)],
#  [(64, 1), (625, 1)],
#  [(47, 1), (529, 1), (617, 1), (626, 1)],
#  [(516, 1), (573, 1)],
#  [(17, 1),
#   (123, 1),
#   (204, 1),
#   (290, 1),
#   (375, 1),
#   (515, 1),
#   (516, 1),
#   (573, 1),
#   (574, 1)],
#  [],
#  [(25, 1), (40, 1), (60, 1), (516, 1), (571, 1), (573, 1), (619, 1)],
#  [(15, 1),
#   (19, 1),
#   (29, 1),
#   (30, 1),
#   (40, 1),
#   (204, 1),
#   (290, 1),
#   (470, 1),
#   (515, 1),
#   (523, 1),
#   (574, 1)],
#  [(29, 1),
#   (43, 1),
#   (88, 1),
#   (152, 1),
#   (229, 1),
#   (603, 1),
#   (609, 1),
#   (610, 1),
#   (627, 1)],
#  [(87, 1), (88, 1), (89, 1), (621, 1)],
#  [(146, 1), (193, 1), (313, 1), (410, 1), (463, 1), (609, 1), (610, 1)],
#  [(45, 1), (54, 1), (100, 1), (113, 1), (186, 1), (277, 1), (516, 1), (628, 1)],
#  [(54, 1), (186, 1), (596, 2)],
#  [(53, 1),
#   (88, 2),
#   (204, 1),
#   (236, 1),
#   (321, 1),
#   (578, 1),
#   (594, 1),
#   (596, 1),
#   (598, 1),
#   (611, 1)],
#  [(204, 1), (450, 1), (516, 1), (529, 1), (626, 1), (629, 1)],
#  [(64, 1), (623, 1), (624, 1), (625, 1), (630, 1)],
#  [(204, 1), (309, 1), (516, 1), (612, 1)],
#  [(236, 1), (516, 1)],
#  [(121, 1), (194, 1), (209, 2), (215, 1), (294, 1)],
#  [(21, 1),
#   (209, 1),
#   (256, 1),
#   (260, 1),
#   (271, 1),
#   (367, 1),
#   (368, 1),
#   (369, 1)],
#  [(22, 1), (194, 1), (433, 1), (489, 1), (631, 1)],
#  [(168, 1), (209, 1), (382, 1), (418, 1), (632, 1)],
#  [(168, 1), (236, 1), (325, 1), (326, 1), (515, 1), (633, 1)],
#  [(210, 1), (211, 1), (212, 1), (236, 1), (633, 1)],
#  [(147, 1), (194, 2), (207, 1), (222, 1), (232, 1)],
#  [(194, 1), (220, 1), (227, 2), (298, 2)],
#  [(84, 1), (184, 1), (187, 1), (361, 1), (463, 1), (501, 1), (634, 1)],
#  [(194, 1), (209, 1), (294, 1)],
#  [(193, 1), (212, 1), (367, 1), (369, 1), (635, 1)],
#  [(121, 1), (145, 1), (209, 1), (636, 1)],
#  [(6, 1), (35, 1), (100, 1), (415, 1), (637, 1)],
#  [(209, 1), (469, 1)],
#  [(6, 1)],
#  [(25, 1), (40, 1), (109, 1), (395, 1), (479, 1), (608, 1), (638, 1)],
#  [(482, 1), (605, 1), (636, 1), (639, 1)],
#  [(60, 1), (209, 1), (482, 1), (605, 1), (628, 1)],
#  [(640, 1), (641, 1)],
#  [(84, 1), (474, 1), (596, 1), (639, 1)],
#  [(67, 1), (121, 1), (209, 1), (211, 1), (599, 1), (642, 1)],
#  [(63, 1), (583, 1), (643, 1)],
#  [(84, 3), (254, 1), (632, 1), (642, 1), (644, 1)],
#  [(645, 1), (646, 1)],
#  [(84, 1), (121, 1), (209, 1), (255, 1), (484, 1), (645, 1), (647, 1)],
#  [(84, 1), (630, 1), (647, 1), (648, 1)],
#  [(84, 1), (627, 1), (644, 1), (646, 1)],
#  [(84, 1), (254, 1), (469, 1), (616, 1), (642, 1), (643, 1)],
#  [(51, 1),
#   (222, 1),
#   (396, 1),
#   (487, 1),
#   (639, 1),
#   (643, 1),
#   (649, 1),
#   (650, 1)],
#  [(95, 1), (359, 1), (429, 1), (651, 1)],
#  [(121, 1), (209, 1), (640, 1), (641, 1), (650, 1), (652, 1)],
#  [(95, 1), (128, 1), (637, 1), (649, 1), (651, 1)],
#  [(84, 1), (88, 1), (469, 1), (611, 1)],
#  [(13, 1),
#   (121, 1),
#   (209, 1),
#   (469, 1),
#   (512, 1),
#   (592, 1),
#   (637, 1),
#   (652, 1)],
#  [(83, 2), (602, 1), (648, 1), (653, 1)],
#  [(197, 1), (247, 1), (273, 1), (296, 1)],
#  [(124, 1), (195, 1), (209, 1), (291, 1), (527, 1), (632, 1), (635, 1)],
#  [(84, 1), (433, 1), (463, 1), (469, 1), (586, 1)],
#  [(13, 1), (204, 1), (288, 1), (487, 2), (494, 2), (586, 1)],
#  [(121, 1), (247, 1), (337, 1)],
#  [(13, 1), (61, 1), (193, 1), (448, 1)],
#  [(39, 1),
#   (81, 1),
#   (113, 1),
#   (130, 1),
#   (243, 1),
#   (629, 1),
#   (638, 1),
#   (653, 1),
#   (654, 1),
#   (655, 1),
#   (656, 1)],
#  [(192, 1), (243, 1), (634, 1), (653, 1), (654, 1), (655, 1), (656, 1)],
#  [(199, 1), (254, 1), (260, 2), (272, 1)],
#  [(61, 1), (124, 1), (361, 1), (618, 1), (619, 1)],
#  [],
#  [(196, 1)],
#  [(92, 1), (192, 1), (193, 1), (592, 1), (631, 1)]]

# %%
# criação do setup Pycaret para NLP
setup_nlp = setup(df_all, target='input')
# Out:
# <style type="text/css">
# </style>
# <table id="T_19149">
#   <thead>
#     <tr>
#       <th id="T_19149_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_19149_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_19149_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_19149_row0_col1" class="data row0 col1" >1503</td>
#     </tr>
#     <tr>
#       <td id="T_19149_row1_col0" class="data row1 col0" >Documents</td>
#       <td id="T_19149_row1_col1" class="data row1 col1" >1199</td>
#     </tr>
#     <tr>
#       <td id="T_19149_row2_col0" class="data row2 col0" >Vocab Size</td>
#       <td id="T_19149_row2_col1" class="data row2 col1" >357</td>
#     </tr>
#     <tr>
#       <td id="T_19149_row3_col0" class="data row3 col0" >Custom Stopwords</td>
#       <td id="T_19149_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
# alteração da configuração do text, para o processado em português (por padrão o Pycaret processa em inglês)
set_config('text', processed_corpus)
get_config('text')
# Out:
# [['covid'],
#  ['pego', 'covid', 'tocar', 'objeto', 'contaminar'],
#  ['pego', 'covid', 'atraves', 'meio'],
#  ['onde', 'comecar', 'covid'],
#  ['onde', 'covid'],
#  ['virus', 'transmitir', 'atraves', 'meio'],
#  ['significar', 'covid'],
#  ['comorbidade', 'poder', 'tomar', 'vacina'],
#  ['covid', 'familia', 'virus'],
#  ['vacina', 'disponivel', 'covid'],
#  ['crianca', 'poder', 'vacinar', 'contra', 'covid'],
#  ['bom', 'vacina'],
#  ['vacina', 'contra', 'covid', 'seguro'],
#  ['ter', 'tomar', 'quanto', 'dose', 'vacina'],
#  ['prevenir', 'contagio'],
#  ['covid', 'comecar', 'china'],
#  ['covid', 'doenca', 'grave'],
#  ['covid', 'grave'],
#  ['covid', 'virus', 'sarscov'],
#  ['covid', 'virus', 'grave'],
#  ['covid'],
#  ['covid', 'doenca', 'grave'],
#  ['covid', 'gripe'],
#  ['covid', 'criar', 'laboratorio'],
#  ['covid', 'vir'],
#  ['covid', 'vir'],
#  ['covid'],
#  ['falar', 'covid'],
#  ['covid'],
#  ['querer', 'dizer', 'covid'],
#  ['virus', 'familia', 'covid'],
#  ['covid', 'vir', 'china'],
#  ['virus', 'comum', 'familia', 'covid'],
#  ['pegar', 'forma', 'covid'],
#  ['virus', 'comum', 'infectar', 'humano'],
#  ['covid', 'comum'],
#  ['posso', 'pegar'],
#  ['poder', 'dizer', 'covid'],
#  ['meio', 'transmissao', 'covid'],
#  ['pegar', 'covid'],
#  ['covid'],
#  ['poder', 'contaminar'],
#  ['prevenir', 'covid'],
#  ['prevenir'],
#  ['exame', 'covid'],
#  ['diagnostico', 'covid'],
#  ['saber', 'ter', 'covid'],
#  ['saber', 'contaminado'],
#  ['sintoma', 'covid'],
#  ['covid', 'poder', 'reduzir'],
#  ['ter', 'hiv', 'corrar', 'risco'],
#  ['hiv', 'covid', 'poder', 'grave'],
#  ['hiv', 'correr', 'risco'],
#  ['pandemia', 'ter', 'cobertura', 'laboratorio', 'covid'],
#  ['pandemia', 'ter', 'cobertura', 'laboratorio', 'diagnostico', 'covid'],
#  ['laboratorio', 'atuar', 'comprovacao', 'diagnostico', 'covid'],
#  ['laboratorio', 'fazer', 'exame', 'comprovacao'],
#  ['laboratorio', 'realizar', 'exame', 'covid'],
#  ['laboratorio', 'realizar', 'exame', 'covid'],
#  ['laboratorio', 'fazer', 'exame', 'identificar', 'covid'],
#  ['laboratorio', 'fazer', 'exame', 'covid'],
#  ['teste', 'ir', 'exame', 'comprovacao', 'laboratorio'],
#  ['posso', 'proprio', 'alcool', 'gel'],
#  ['produzir', 'alcool', 'gel'],
#  ['fazer', 'alcool', 'gel'],
#  ['receita', 'alcool', 'gel', 'oms'],
#  ['onde', 'comecar', 'pandemia'],
#  ['oms', 'divulgar', 'receita', 'gel', 'pra', 'fazer', 'casa'],
#  ['oximetria', 'baixo'],
#  ['ficar', 'doente', 'fazer'],
#  ['sentir', 'gripar', 'fazer'],
#  ['sintoma', 'fazer'],
#  ['coisa'],
#  ['sentir', 'coisa'],
#  ['funcionario', 'doente', 'trabalho'],
#  ['poder', 'fazer', 'evitar', 'covid', 'local', 'trabalho'],
#  ['prevenir', 'coronavirus'],
#  ['evitar', 'covid', 'trabalho'],
#  ['pegar', 'covid', 'trabalho'],
#  ['identificar', 'covid'],
#  ['principal', 'sintoma'],
#  ['onde', 'pegar', 'covid'],
#  ['pegar', 'covid'],
#  ['pessoa', 'trabalho', 'diagnosticar', 'covid', 'poder', 'ter', 'contaminar'],
#  ['contato', 'paciente', 'covid', 'poder', 'contaminado'],
#  ['pessoa', 'covid', 'poder', 'pegar'],
#  ['sintoma', 'covid'],
#  ['principal', 'sintoma', 'covid'],
#  ['sintoma', 'ter', 'covid'],
#  ['poder', 'saber', 'covid'],
#  ['sintoma', 'covid'],
#  ['dinheiro', 'transmitir', 'covid'],
#  ['dar', 'pra', 'pegar', 'covid', 'dinheiro'],
#  ['poder', 'pegar', 'virus', 'supermercado'],
#  ['pessoa', 'contaminar', 'poder', 'pegar', 'ar'],
#  ['poder', 'pegar', 'virus', 'conta', 'agua', 'luz'],
#  ['poder', 'pegar', 'virus', 'embalagem', 'correio'],
#  ['limpar', 'ambiente', 'contaminar', 'poder', 'pegar', 'virus'],
#  ['poder', 'conter', 'virus', 'contaminar'],
#  ['ar', 'poder', 'provocar', 'contaminacao', 'virus'],
#  ['poder', 'pegar', 'covid', 'agua', 'trabalho'],
#  ['poder', 'pegar', 'covid'],
#  ['poder', 'contrair', 'covid'],
#  ['sempre', 'mascara', 'poder', 'pegar', 'pele'],
#  ['poder', 'pegar', 'covid', 'outro', 'pessoa'],
#  ['mascara', 'corrar', 'risco', 'contagiar'],
#  ['possivel', 'pegar', 'covid', 'pessoa', 'apresentar', 'sintoma'],
#  ['posso', 'pegar', 'covid', 'doenca'],
#  ['posso', 'pegar', 'coronavirus', 'utilizar', 'publico'],
#  ['poder', 'pegar'],
#  ['posso', 'pegar', 'covid', 'mao', 'rosto'],
#  ['poder', 'transmitir', 'covid'],
#  ['pegar', 'covid', 'assintomatico'],
#  ['assintomatico', 'transmiter', 'covid'],
#  ['parente', 'ter', 'covid', 'ter', 'sintoma'],
#  ['ter', 'sintoma', 'poder', 'transmitir', 'covid'],
#  ['poder', 'ficar', 'contaminar', 'passar'],
#  ['parente', 'ter', 'covid', 'ter', 'sintoma'],
#  ['dar', 'pra', 'pegar', 'covid'],
#  ['dar', 'pra', 'pegar', 'covid'],
#  ['sintoma', 'coronavirus'],
#  ['virus', 'responsavel', 'covid'],
#  ['poder', 'transmitir', 'pessoa', 'pessoa'],
#  ['distancia', 'seguro', 'contaminar'],
#  ['distancia', 'pequeno', 'contaminar'],
#  ['distancia', 'dever', 'manter', 'contaminar'],
#  ['acontecer', 'circulacao', 'virus'],
#  ['acontecer', 'circulacao', 'coronavirus'],
#  ['encomenda', 'china', 'dever', 'tomar', 'cuidado'],
#  ['seguro', 'receber', 'pacote', 'area', 'covid', 'ter', 'notificar'],
#  ['seguro', 'comprar', 'coisa', 'china'],
#  ['seguro', 'pais', 'covid'],
#  ['encomenda', 'area', 'risco', 'ver', 'poder', 'vir', 'contaminar'],
#  ['compra', 'area', 'risco', 'poder', 'vir', 'contaminar'],
#  ['compra', 'ver', 'area', 'risco', 'poder', 'chegar', 'contaminar'],
#  ['encomenda', 'postal', 'area', 'risco', 'poder', 'contaminar'],
#  ['encomenda', 'area', 'infectar', 'ver', 'correio', 'poder', 'contaminar'],
#  ['entrega', 'postal', 'risco', 'poder', 'conter', 'virus'],
#  ['embalagem',
#   'sedex',
#   'produto',
#   'oriundo',
#   'china',
#   'poder',
#   'conter',
#   'virus'],
#  ['embalagem', 'sedex', 'produto', 'poder', 'contaminado'],
#  ['encomenda',
#   'produto',
#   'produzir',
#   'china',
#   'poder',
#   'chegar',
#   'embalagem',
#   'contaminar'],
#  ['risco', 'desenvolver', 'doenca', 'grave'],
#  ['produto', 'correr', 'grande', 'risco', 'infeccao', 'covid'],
#  ['covid', 'risco', 'grave'],
#  ['poder', 'levar', 'virus', 'pra', 'dentro', 'casa', 'apos', 'espaco'],
#  ['poder', 'virus', 'apos', 'uso', 'gel'],
#  ['poder', 'manter', 'virus', 'vivo', 'ativo'],
#  ['pele', 'manter', 'virus', 'vivo', 'ativo'],
#  ['roupa', 'poder', 'manter', 'virus', 'vivo', 'ativo'],
#  ['preciso', 'sacola', 'supermercado'],
#  ['quanto', 'tempo', 'virus', 'sobreviver', 'objeto'],
#  ['preciso', 'limpar', 'embalagem', 'comida'],
#  ['deixar', 'roupa', 'coronavirus'],
#  ['preciso', 'lavar', 'embalagem'],
#  ['quanto', 'tempo', 'virus', 'sobreviver', 'superficie'],
#  ['virus', 'ambiente', 'fechar', 'tempo'],
#  ['tocar', 'superficie', 'corrar', 'risco', 'pegar', 'covid'],
#  ['rosto', 'compartilhar', 'poder', 'passar', 'covid'],
#  ['devo', 'lavar', 'roupa', 'chegar', 'casa'],
#  ['poder', 'infectado'],
#  ['produto', 'supermercado', 'poder', 'infectado'],
#  ['preciso', 'passar', 'alcool', 'gel', 'sacola', 'supermercado'],
#  ['poder',
#   'levar',
#   'virus',
#   'pra',
#   'dentro',
#   'casa',
#   'apos',
#   'tocar',
#   'espaco'],
#  ['cadastrar', 'cadastur'],
#  ['gerar', 'cadastro', 'cadastur'],
#  ['novo'],
#  ['cadastur'],
#  ['finalidade', 'cadastur'],
#  ['cadastur', 'obrigatorio'],
#  ['cadastur'],
#  ['registro', 'cadastur'],
#  ['cadastur'],
#  ['cadastur'],
#  ['cadastur'],
#  [],
#  [],
#  [],
#  [],
#  ['expliqueme', 'registro', 'cadastur'],
#  ['definame', 'registro', 'cadastur'],
#  ['registro', 'cadastur'],
#  ['cadastur'],
#  ['querer', 'cadastrar'],
#  ['cadastrar'],
#  ['gerar', 'cadastro'],
#  ['cadastro'],
#  ['cadastro'],
#  ['cadastro'],
#  ['preencher', 'cadastro'],
#  ['fazer', 'cadastro'],
#  ['querer', 'cadastrar'],
#  ['querer', 'fazer', 'cadastro'],
#  ['cadastrar', 'agora'],
#  ['fazer', 'cadastro'],
#  ['fazer', 'cadastro'],
#  ['cadastro'],
#  ['querer', 'gerar', 'cadastro'],
#  ['fazer', 'cadastrar'],
#  ['cadastrar'],
#  ['preencher', 'cadastramento'],
#  ['fazer', 'cadastramento'],
#  ['cadastramento'],
#  ['criar', 'cadastro'],
#  ['falabr'],
#  ['denunciar', 'ouvidorio'],
#  ['ouvidorio'],
#  ['falar', 'ouvidoria', 'acesso', 'informacao'],
#  ['ouvidorio'],
#  ['ouvidorio', 'acesso', 'informacao'],
#  ['geral'],
#  [],
#  ['central', 'atendimento', 'cidadao'],
#  ['falabr', 'ouvidoria', 'acesso', 'informacao'],
#  ['atendimento', 'cidadao'],
#  ['atendimento'],
#  ['atendimento'],
#  ['querer',
#   'denunciar',
#   'descumprimento',
#   'protocolo',
#   'higiente',
#   'orientar',
#   'selo'],
#  ['poder',
#   'denunciar',
#   'descumprimento',
#   'medida',
#   'higiente',
#   'orientar',
#   'selo'],
#  ['descumprimento',
#   'protocolo',
#   'medida',
#   'protecao',
#   'seguranca',
#   'sanitario'],
#  ['denunciar',
#   'descumprimento',
#   'medida',
#   'protecao',
#   'seguranca',
#   'sanitario',
#   'recomendar',
#   'selo'],
#  ['querer',
#   'denunciar',
#   'descumprimento',
#   'medida',
#   'higiente',
#   'orientar',
#   'selo'],
#  ['fazer', 'denuncia', 'referente', 'estabelecimento', 'cumprir', 'saude'],
#  ['denuncia',
#   'referente',
#   'estabelecimento',
#   'descumprimento',
#   'medida',
#   'protecao',
#   'seguranca',
#   'sanitario'],
#  ['estabelecimento', 'querer', 'continuar', 'responsavel'],
#  ['estabelecimento', 'querer', 'cancelar', 'selo'],
#  ['ter', 'adesao', 'selo'],
#  ['querer', 'retirar', 'adesao', 'selo', 'turismo', 'responsavel'],
#  ['possivel',
#   'prestador',
#   'servico',
#   'turistico',
#   'retirar',
#   'adesao',
#   'selo'],
#  ['ter', 'interesse', 'usar', 'selo', 'estabelecimento'],
#  ['querer', 'programa', 'selo', 'turismo'],
#  ['participar', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['ir', 'cancelar', 'selo', 'fazer'],
#  ['querer', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['querer', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['querer', 'sair', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['fazer', 'cancelar', 'selo', 'turismo', 'reponsavel'],
#  ['estabelecimento', 'querer', 'sair', 'programa', 'selo', 'turismo'],
#  ['conseguir', 'ter', 'acesso', 'todo', 'publicitario'],
#  ['dar', 'erro', 'emissao', 'selo'],
#  ['aparecer', 'nada', 'exportar', 'peca', 'promocional'],
#  ['apos', 'emissao', 'exportar', 'peca', 'promocional', 'nada', 'aparecer'],
#  ['selo', 'ocorrer', 'erro'],
#  ['selo', 'aparecer', 'proceder'],
#  ['aderir', 'selo', 'preciso', 'peca', 'promocional', 'fazer'],
#  ['aparecer', 'opcao', 'exportar', 'peca', 'promocional'],
#  ['exportar', 'peca', 'promocional'],
#  ['selo', 'continua', 'ativo', 'verifico'],
#  ['saber', 'selo', 'continua', 'ativado'],
#  ['saber', 'selo'],
#  ['preciso', 'saber', 'situacao', 'selo', 'ativado'],
#  ['ver', 'selo'],
#  ['verificar', 'selo', 'empreendimento', 'continua', 'ativo'],
#  ['verificar', 'selo', 'empreendimento', 'ativo'],
#  ['quero', 'ver', 'selo', 'ativo', 'turistas'],
#  ['saber', 'selo', 'continua', 'ativo'],
#  ['verifico', 'selo', 'ativo'],
#  ['faco', 'saber', 'selo', 'ativo'],
#  ['saber', 'selo', 'ativo', 'prestador'],
#  ['vejo', 'selo', 'ativado'],
#  ['saber', 'selo', 'ativado', 'proceder'],
#  ['protocolo', 'garantir', 'protecao', 'seguranca', 'sanitario'],
#  ['protocolo', 'necessario', 'tipo', 'estabelecimento'],
#  ['protocolo', 'necessario'],
#  ['protocolo', 'praticar', 'programa', 'selo', 'turista', 'responsavel'],
#  ['protocolo', 'estabelecir', 'programa', 'selo', 'turista', 'responsavel'],
#  ['protocolo', 'exigir', 'empreendimento', 'turistico'],
#  ['protocolo', 'devo', 'seguir'],
#  ['protocolo', 'recomendar'],
#  ['protocolo', 'geral'],
#  ['protocolo', 'especifico'],
#  ['protocolo'],
#  ['protocolo'],
#  ['onde', 'pesquiso', 'protocolo', 'hotel'],
#  ['protocolo', 'medida', 'protecao', 'seguranca', 'hospedagem'],
#  ['ter', 'hotel', 'protocolo', 'dever', 'seguir'],
#  ['ter', 'hotel', 'protocolo', 'praticar'],
#  ['protocolo', 'ter', 'adotar', 'hotel'],
#  ['hotel', 'dever', 'seguir', 'protocolo'],
#  ['protocolo', 'bom', 'pratica', 'hospedagem'],
#  ['medida', 'especifico', 'protocolo', 'hospedagem'],
#  ['hotel', 'dever', 'seguir', 'medida', 'especifico', 'protocolo'],
#  ['hotel', 'ter', 'protocolo', 'especifico'],
#  ['existir', 'protocolo', 'especifico', 'meio', 'hospedagem'],
#  ['meio', 'hospedagem'],
#  ['setor', 'hoteleiro', 'possuira', 'protocolo', 'especifico'],
#  ['recomendacoes', 'hotel'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['resorts'],
#  ['pensao'],
#  ['pousada'],
#  ['estalagem'],
#  ['estalagem', 'pensao'],
#  ['hotel'],
#  ['protocolo', 'hotelaria', 'hospedagem'],
#  ['protocolo', 'rede', 'hotel'],
#  ['protocolo', 'hotel'],
#  ['protocolo', 'hospedagem'],
#  ['recomendacao'],
#  ['recomendacao', 'hospedagem'],
#  ['recomendacao', 'hotel'],
#  ['recomendacoes', 'meio', 'hospedagem'],
#  ['onde', 'achar', 'protocolo', 'setor', 'hoteleiro'],
#  ['onde', 'pesquiso', 'protocolo', 'setor', 'hoteleito'],
#  ['onde', 'ver', 'protocolo', 'setor', 'hoteleito'],
#  ['setor', 'hoteleiro', 'protocolo', 'dever', 'seguir'],
#  ['protocolo', 'seguir', 'hotel'],
#  ['protocolo', 'setor', 'hoteleiro'],
#  ['setor', 'hoteleiro', 'possuira', 'protocolo'],
#  ['setor', 'hoteleiro', 'cumprir', 'protocolo', 'especifico'],
#  ['protocolo', 'recomendar', 'meio', 'hospedagem'],
#  ['protocolo', 'recomendar', 'hotel', 'pousada', 'resorts'],
#  ['protocolo', 'estabelecer', 'hotelaria'],
#  ['protocolo', 'setor', 'meios', 'hospedagem'],
#  ['interessado',
#   'dever',
#   'atender',
#   'orientacao',
#   'protocolo',
#   'destinar',
#   'atividade',
#   'turistico',
#   'atuar'],
#  ['meio', 'atender', 'prerequisito', 'solicitar', 'adesao', 'selo'],
#  ['empreendimentos', 'poderao', 'aderir', 'ter', 'acesso', 'selo'],
#  ['dar', 'novo', 'orientacao', 'higiene', 'farei', 'atualizar'],
#  ['dar', 'atualizacao', 'protocolo'],
#  ['protocolo', 'atualizacao', 'frequente'],
#  ['protocolo', 'sera', 'atualizar'],
#  ['protocolo', 'mudar'],
#  ['protocolo', 'documento', 'unico', 'poder', 'atualizar'],
#  ['ter', 'outro', 'higiene', 'atualizar'],
#  ['sera', 'atualizacao', 'informar', 'novo', 'medida', 'higiene'],
#  ['atualizar', 'informar', 'novo', 'medida', 'higiene'],
#  ['informar', 'novo', 'recomendacoes', 'higiene', 'atualizar'],
#  ['ir',
#   'manter',
#   'atualizar',
#   'novo',
#   'orientacoes',
#   'higiene',
#   'divulgar',
#   'mtur'],
#  ['sair', 'novo', 'orientacoes', 'higiene', 'ir', 'atualizar', 'selo'],
#  ['ficar', 'saber', 'novo', 'orientacao', 'tipo', 'estabelecimento'],
#  ['ficar',
#   'saber',
#   'novo',
#   'orientacao',
#   'higiene',
#   'tipo',
#   'estabelecimento'],
#  ['sempre',
#   'ministerio',
#   'turismo',
#   'divulgar',
#   'novo',
#   'orientacao',
#   'higiene',
#   'devo',
#   'atualizar',
#   'selo'],
#  ['novo', 'orientacao', 'higiene', 'divulgar', 'mtur', 'fazer'],
#  ['selo', 'sempre', 'atualizar', 'surgir', 'novo', 'orientacao', 'higiene'],
#  ['caso', 'surgir', 'novo', 'orientacao', 'higiene', 'atualizar', 'selo'],
#  ['caso',
#   'surgir',
#   'novo',
#   'orientacao',
#   'higiene',
#   'preciso',
#   'novo',
#   'selo'],
#  ['medida', 'higiene', 'sanitar', 'atualizacao', 'preciso', 'fazer', 'selo'],
#  ['medida',
#   'higiene',
#   'sanitar',
#   'atualizacao',
#   'preciso',
#   'baixar',
#   'novo',
#   'selo'],
#  ['medida',
#   'higiene',
#   'sanitaria',
#   'protocolo',
#   'ter',
#   'atualizacao',
#   'frequente'],
#  ['medida',
#   'higiene',
#   'sanitar',
#   'recomendar',
#   'selo',
#   'ter',
#   'atualizacao',
#   'frequente'],
#  ['medida',
#   'higiene',
#   'sanitar',
#   'estabelecir',
#   'selo',
#   'ter',
#   'atualizacao',
#   'frequente'],
#  ['protocolo', 'estabelecer', 'selo', 'ter', 'atualizacao'],
#  ['protocolo', 'documento', 'unico'],
#  ['quais',
#   'criterios',
#   'ministerio',
#   'turismo',
#   'formulacao',
#   'desses',
#   'protocolos'],
#  ['quais',
#   'criterios',
#   'utilizados',
#   'ministerio',
#   'turismo',
#   'formulacao',
#   'desses',
#   'protocolos'],
#  ['quais',
#   'criterios',
#   'utilizados',
#   'mtur',
#   'formulacao',
#   'desses',
#   'protocolos'],
#  ['protocolo',
#   'propor',
#   'submetir',
#   'crivo',
#   'tecnico',
#   'agencia',
#   'nacional',
#   'vigilancia',
#   'sanitaria',
#   'anvisa',
#   'ministerio',
#   'saude'],
#  ['protocolo',
#   'validados',
#   'agencia',
#   'nacional',
#   'vigilancia',
#   'sanitaria',
#   'anvisa'],
#  ['adocao',
#   'protocolo',
#   'selo',
#   'levar',
#   'consideracao',
#   'medida',
#   'adotar',
#   'entidade',
#   'internacional',
#   'similar'],
#  ['adocao',
#   'protocolo',
#   'levar',
#   'conta',
#   'protocolo',
#   'medida',
#   'adotar',
#   'entidade',
#   'internacional'],
#  ['protocolo', 'propor', 'validados', 'ministerio', 'saude'],
#  ['criterios', 'formulacao', 'protocolos', 'validar', 'anvisa'],
#  ['protocolo'],
#  ['protocolo', 'propor', 'validar', 'anvisa'],
#  ['protocolo', 'profissional', 'setor'],
#  ['protocolo', 'selo', 'ter', 'anvisa'],
#  ['protocolo',
#   'levar',
#   'consideracao',
#   'medida',
#   'adotar',
#   'entidade',
#   'internacional',
#   'similar'],
#  ['protocolo',
#   'submetir',
#   'crivo',
#   'tecnico',
#   'agencia',
#   'nacional',
#   'vigilancia',
#   'sanitaria',
#   'anvisa'],
#  ['uso',
#   'selo',
#   'representa',
#   'custo',
#   'adicional',
#   'valor',
#   'servicos',
#   'turisticos'],
#  ['selo', 'representara', 'custo', 'valor', 'servicos', 'turisticos'],
#  ['ter',
#   'custo',
#   'adicional',
#   'medida',
#   'impor',
#   'selo',
#   'poder',
#   'cobrar',
#   'servico'],
#  ['ter',
#   'custo',
#   'adicional',
#   'medida',
#   'impor',
#   'selo',
#   'poder',
#   'embutir',
#   'servico',
#   'turistico'],
#  ['despesa',
#   'adicional',
#   'protocolo',
#   'higiente',
#   'poder',
#   'embutir',
#   'custo',
#   'servico',
#   'turistico'],
#  ['selo', 'poder', 'ratear', 'despesa', 'higiene', 'taxa', 'servico'],
#  ['poder',
#   'ratear',
#   'despesa',
#   'higiene',
#   'taxa',
#   'servico',
#   'aderir',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['poder',
#   'ratear',
#   'despesa',
#   'higiene',
#   'taxa',
#   'servico',
#   'empreendimento',
#   'aderir',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['ter',
#   'selo',
#   'farei',
#   'compensar',
#   'despesa',
#   'extro',
#   'medida',
#   'higiene'],
#  ['selo',
#   'exigir',
#   'vario',
#   'controle',
#   'higiene',
#   'fazer',
#   'compensar',
#   'despesa',
#   'extro'],
#  ['selo',
#   'exigir',
#   'vario',
#   'medida',
#   'seguranca',
#   'higiene',
#   'fazer',
#   'compensar',
#   'despesa',
#   'extro'],
#  ['farei', 'despesa', 'extraordinario', 'selo', 'turismo', 'responsavel'],
#  ['governo',
#   'reduzira',
#   'imposto',
#   'compensar',
#   'despesa',
#   'extraordinario',
#   'impor',
#   'uso',
#   'selo'],
#  ['diaria', 'valor', 'maior', 'aderir', 'selo', 'turismo', 'responsavel'],
#  ['diaria', 'valor', 'maior', 'despesa', 'medida', 'higiene'],
#  ['diaria', 'valor', 'maior', 'compensar', 'despesa', 'medida', 'higiene'],
#  ['posso',
#   'aumentar',
#   'valor',
#   'diaria',
#   'custo',
#   'medida',
#   'seguranca',
#   'selo'],
#  ['posso',
#   'aumentar',
#   'valor',
#   'taxa',
#   'servico',
#   'medida',
#   'higiene',
#   'impor',
#   'selo'],
#  ['medida',
#   'higiene',
#   'impor',
#   'selo',
#   'posso',
#   'aumentar',
#   'valor',
#   'taxa',
#   'servico'],
#  ['governo',
#   'reduzira',
#   'imposto',
#   'compensar',
#   'despesa',
#   'extro',
#   'medida',
#   'higiene',
#   'exigir',
#   'selo'],
#  ['perspectiva',
#   'acrescimo',
#   'valor',
#   'servico',
#   'prestar',
#   'adocao',
#   'medida'],
#  ['apos',
#   'adocao',
#   'medida',
#   'recomendar',
#   'perspectiva',
#   'acrescimo',
#   'valor',
#   'servico',
#   'prestar'],
#  ['apos',
#   'adocao',
#   'medida',
#   'recomendar',
#   'previsao',
#   'aumento',
#   'valor',
#   'servico',
#   'prestar'],
#  ['variacao',
#   'taxas',
#   'servicos',
#   'devido',
#   'custo',
#   'adicional',
#   'imposto',
#   'protocolo'],
#  ['variacao',
#   'taxas',
#   'servicos',
#   'devido',
#   'custo',
#   'adicional',
#   'imposto',
#   'medidas',
#   'higiene'],
#  ['precos', 'acrescimos', 'devido', 'implementacao', 'medidas'],
#  ['precos', 'acrescimos', 'devido', 'implementacao', 'medidas', 'higiene'],
#  ['precos', 'devido', 'custo', 'higiene', 'sanitaria'],
#  ['precos',
#   'comprometidos',
#   'maior',
#   'gasto',
#   'produtos',
#   'higiene',
#   'sanitaria'],
#  ['precos',
#   'comprometidos',
#   'maior',
#   'gasto',
#   'produtos',
#   'limpeza',
#   'higiene'],
#  ['precos', 'aumento', 'devido', 'maior', 'produtos', 'limpeza', 'higiene'],
#  ['diaria', 'valor', 'maior', 'estabelecimentos', 'selo'],
#  ['havera',
#   'variacao',
#   'taxas',
#   'servicos',
#   'devido',
#   'custo',
#   'medidas',
#   'impostas',
#   'selo'],
#  ['variacao',
#   'taxas',
#   'servicos',
#   'devido',
#   'custo',
#   'adicional',
#   'imposto',
#   'selo'],
#  ['selo', 'representara', 'custo', 'valor', 'taxas', 'servicos', 'turisticos'],
#  ['selo', 'aumento', 'taxas', 'servicos'],
#  ['selo', 'estabelecimentos', 'taxas', 'servicos'],
#  ['taxas', 'servicos', 'adocao', 'selo'],
#  ['havera',
#   'variacao',
#   'taxas',
#   'servicos',
#   'devido',
#   'medidas',
#   'impostas',
#   'selo'],
#  ['onde', 'vejo', 'medida', 'especifico', 'tipo', 'estabelecimento'],
#  ['clientes', 'saber', 'exigir', 'estabelecimento', 'relacao', 'higiene'],
#  ['clientes', 'poderao', 'exigir', 'estabelecimento', 'relacao', 'higiene'],
#  ['clientes',
#   'poderao',
#   'bom',
#   'pratica',
#   'higienizacao',
#   'cada',
#   'segmento',
#   'setor',
#   'turistico'],
#  ['clientes',
#   'poderao',
#   'exigir',
#   'conformidade',
#   'bom',
#   'pratica',
#   'higienizacao'],
#  ['bom', 'pratica', 'higienizacao', 'poderao', 'clientes'],
#  ['saber', 'conformidade', 'medida', 'tipo', 'estabelecimento'],
#  ['exigir', 'conformidade', 'estabelecimentos', 'protocolos'],
#  ['qto', 'custar', 'selo'],
#  ['qto', 'custar', 'selo'],
#  ['precisa', 'pagar'],
#  [],
#  ['gratuito'],
#  ['ter', 'algum', 'custo'],
#  ['ter', 'custo'],
#  ['taxa', 'cobrar', 'selo', 'turista', 'responsavel'],
#  ['preciso',
#   'pagar',
#   'pedir',
#   'selo',
#   'turista',
#   'responsavel',
#   'estabelecimento'],
#  ['ter', 'taxa', 'obter', 'selo', 'turista', 'responsavel'],
#  ['ter', 'taxa', 'usar', 'selo', 'turista', 'responsavel'],
#  ['ter', 'pagar', 'ter', 'selo', 'turista', 'responsavel', 'empreendimento'],
#  ['preciso',
#   'recolher',
#   'alguma',
#   'taxa',
#   'aderir',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['preciso',
#   'recolher',
#   'alguma',
#   'taxa',
#   'ter',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['preciso', 'pagar', 'ter', 'selo', 'turista', 'responsavel'],
#  ['taxas', 'aderir', 'programa', 'selo', 'turista', 'responsavel'],
#  ['interessado', 'usar', 'selo', 'precisa', 'pagar', 'alguma', 'coisa'],
#  ['pagar', 'algum', 'taxa', 'usar', 'selo', 'turista', 'responsavel'],
#  ['ter', 'selo', 'turista', 'responsavel', 'quanto', 'ter', 'pagar'],
#  ['pedir', 'selo', 'turista', 'responsavel', 'quanto', 'ter', 'pagar'],
#  ['requerer', 'selo', 'turista', 'responsavel', 'quanto', 'ter', 'pagar'],
#  ['querer', 'ter', 'selo', 'valor', 'selo', 'turista', 'responsavel'],
#  ['valor', 'cobrar', 'selo', 'turista', 'responsavel'],
#  ['interessado', 'tirar', 'selo', 'precisar', 'pagar', 'algum', 'coisa'],
#  ['quanto', 'custar', 'pra', 'tirar'],
#  ['quanto', 'pagar', 'pra', 'tirar'],
#  ['quanto', 'ter', 'pagar', 'tirar'],
#  ['quanto', 'custar', 'selo'],
#  ['valor', 'selo'],
#  ['quanto', 'custar', 'selo'],
#  ['quanto', 'custar', 'selo'],
#  ['quanto', 'custar', 'dois', 'selo'],
#  ['quanto', 'custar', 'selo'],
#  ['qto', 'pagar'],
#  ['quanto', 'pagar'],
#  ['qto', 'pagar'],
#  ['quanto', 'pagar'],
#  ['segue', 'protocolo', 'higiene'],
#  ['selo', 'visivel', 'segue', 'medidas', 'higiene'],
#  ['selo', 'visivel', 'segue', 'protocolo', 'seguranca'],
#  ['pra', 'selo', 'cumprindo', 'protocolo'],
#  ['irregularidade', 'controle', 'empreendimentos', 'selo'],
#  ['turista',
#   'identificar',
#   'alguma',
#   'irregularidade',
#   'local',
#   'usa',
#   'selo'],
#  ['turista',
#   'identificar',
#   'alguma',
#   'irregularidade',
#   'devera',
#   'feito',
#   'proceder'],
#  ['turista',
#   'identificar',
#   'alguma',
#   'conformidade',
#   'local',
#   'usa',
#   'selo',
#   'devera',
#   'feito'],
#  ['local', 'onde', 'hospedei', 'selo', 'cheio', 'irregularidade', 'faco'],
#  ['local', 'onde', 'hospedei', 'selo', 'cheio', 'irregularidade', 'proceder'],
#  ['selo', 'adiantou', 'nada', 'empreendimento'],
#  ['selo', 'adiantou', 'nada', 'empreendimento', 'cumprindo', 'protocolos'],
#  ['selo', 'adiantou', 'nada', 'empreendimento', 'cumprindo', 'recomendacoes'],
#  ['ter', 'selo', 'lugar', 'cumprindo', 'medidas', 'higiene'],
#  ['obrigatorio', 'uso', 'selo', 'turismo', 'responsavel'],
#  ['ministerio', 'turismo', 'tornar', 'obrigatorio', 'uso', 'selo'],
#  ['selo', 'obrigatorior'],
#  ['obrigar', 'usar', 'selo', 'estabelecimento'],
#  ['obrigatoriedade'],
#  ['obrigatorior'],
#  ['multar', 'ter', 'selo', 'turista', 'responsavel'],
#  ['aderir', 'selo', 'turista', 'responsavel', 'acontecer'],
#  ['lei', 'obrigar', 'ter', 'selo', 'turista', 'responsavel'],
#  ['ter', 'algum', 'lei', 'obrigar', 'uso', 'selo'],
#  ['ter', 'algum', 'lei', 'obrigar', 'uso', 'selo', 'turismo', 'responsavel'],
#  ['punicao',
#   'empreendimento',
#   'aderir',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['punicao',
#   'estabelecimento',
#   'aderir',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['obrigar', 'selo'],
#  ['uso', 'selo', 'obrigatorior'],
#  ['obrigatorio', 'usar', 'selo'],
#  ['nao', 'ter', 'selo', 'turista', 'responsavel', 'ter', 'pagar'],
#  ['nao', 'ter', 'selo', 'turista', 'responsavel', 'ter', 'punicao', 'punicao'],
#  ['selo', 'turista', 'responsavel', 'ter', 'punicao', 'punicao'],
#  ['ter', 'selo', 'turista', 'responsavel', 'visivel', 'turista'],
#  ['poder', 'multar', 'ter', 'selo', 'turismo', 'responsavel'],
#  ['poder', 'fiscalizar', 'ter', 'selo', 'turismo', 'responsavel'],
#  ['estabelecimento', 'voltar', 'funcionar', 'preciso', 'ter', 'selo'],
#  ['obrigatorio',
#   'usar',
#   'selo',
#   'turismo',
#   'responsavel',
#   'voltar',
#   'atividade'],
#  ['obrigatorio', 'usar', 'selo', 'turismo', 'responsavel', 'funcionar'],
#  ['obrigar', 'usar', 'selo', 'empreendimento'],
#  ['selo', 'turismo'],
#  ['programa', 'selo', 'turismo', 'responsavel'],
#  ['definer', 'selo', 'turismo', 'responsavel'],
#  ['selo'],
#  ['servir', 'selo', 'turismo', 'responsavel'],
#  ['papel', 'selo', 'turismo', 'responsavel'],
#  ['finalidade', 'selo'],
#  ['finalidade', 'selo', 'turismo'],
#  ['papel', 'selo', 'turismo', 'retomada', 'atividade', 'turistico', 'brasil'],
#  ['programa', 'selo', 'turismo', 'responsavel', 'adotar', 'medida', 'eficaz'],
#  ['destinar', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['finalidade', 'programa', 'estabelecer', 'selo', 'turismo', 'responsavel'],
#  ['finalidade', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['governo', 'brasileiro', 'esperar', 'selo'],
#  ['brasil',
#   'incentivar',
#   'adesao',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['governo', 'incentivar', 'uso', 'selo', 'turista', 'responsavel'],
#  ['programa',
#   'selo',
#   'turista',
#   'responsavel',
#   'seguir',
#   'bom',
#   'pratica',
#   'higienizacao',
#   'ambiente'],
#  ['selo', 'turismo', 'responsavel'],
#  ['selo', 'responsavel'],
#  ['selo'],
#  ['selo', 'turismo', 'responsavel'],
#  ['selo'],
#  ['selo', 'turismo'],
#  ['selo', 'responsavel', 'seguro'],
#  ['programa', 'turismo', 'responsavel'],
#  ['programa'],
#  ['pra', 'servir'],
#  ['servir', 'selo'],
#  ['onde', 'vejer', 'ja', 'protocolo', 'selo'],
#  ['existir', 'algum', 'onde', 'poder', 'ver', 'empresa', 'adotar', 'selo'],
#  ['ter', 'algum', 'painel', 'dizer', 'empresa', 'ja', 'aderir', 'selo'],
#  ['onde',
#   'achar',
#   'relacao',
#   'empreendimento',
#   'turistico',
#   'aderir',
#   'selo',
#   'turismo'],
#  ['onde', 'achar', 'relacao', 'empresa', 'aderir', 'selo', 'turismo'],
#  ['onde',
#   'consulto',
#   'estabelecimento',
#   'ja',
#   'aderir',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['prestador', 'servico', 'turistico', 'ja', 'aderir', 'selo'],
#  ['ja', 'aderir', 'selo'],
#  ['saber', 'empreendimento', 'aderir', 'selo'],
#  ['pesquiso', 'prestador', 'servico', 'turistico', 'habilitar', 'selo'],
#  ['pesquiso', 'prestador', 'habilitar'],
#  ['pesquiso', 'hotel', 'ja', 'aderiu', 'selo'],
#  ['pesquiso', 'ja', 'aderiu', 'selo'],
#  ['estado', 'quantos', 'empreendimentos', 'turisticos', 'ja', 'aderiram'],
#  ['onde', 'consulto', 'estabelecimento', 'ja', 'aderir', 'selo'],
#  ['observei', 'aumento', 'numero', 'selo', 'painel', 'acompanhamento'],
#  ['observei', 'reducao', 'numero', 'selo', 'painel', 'acompanhamento'],
#  ['verifico', 'quantos', 'empreendimentos', 'aderiram', 'selo'],
#  ['aderiu', 'selo'],
#  ['empreendimentos', 'aderiram', 'programa', 'selo', 'turismo'],
#  ['faco', 'saber', 'empreendimentos', 'aderiram', 'programa', 'selo'],
#  ['pesquiso',
#   'quais',
#   'empresas',
#   'aderiram',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['consulto',
#   'quais',
#   'empresas',
#   'aderiram',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['funciona', 'painel', 'selo'],
#  ['preciso', 'saber', 'empreendimento', 'fazer', 'selo'],
#  ['ir',
#   'viajar',
#   'querer',
#   'pequisar',
#   'estabelecimento',
#   'habilitar',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['ir',
#   'viajar',
#   'querer',
#   'pequisar',
#   'estabelecimento',
#   'cadastrado',
#   'programa',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['preciso', 'saber', 'estabelecimento', 'adotar', 'selo'],
#  ['estabelecimento', 'ja', 'adotar', 'selo'],
#  ['onde', 'vejer', 'ja', 'adotar', 'selo'],
#  ['existir', 'prazo', 'emissao', 'selo'],
#  ['prazo', 'entrega'],
#  ['previsao', 'entrega', 'selo'],
#  ['demor', 'receber', 'selo'],
#  ['quanto', 'tempo', 'solicitacao'],
#  ['quanto', 'tempo', 'demor', 'ter', 'selo'],
#  ['quanto', 'tempo', 'levar', 'selo'],
#  ['ter', 'esperar', 'quanto', 'tempo', 'receber', 'selo'],
#  ['previsao', 'entrega', 'selo'],
#  ['ter', 'esperar', 'quanto', 'tempo', 'receber', 'selo'],
#  ['solicitacao', 'esperar', 'tempo'],
#  ['previsao', 'prazo', 'ter', 'selo'],
#  ['quanto', 'demor', 'pedido', 'selo', 'ate', 'liberacao'],
#  ['quanto', 'tempo', 'gastar', 'pedido', 'ate', 'liberacao', 'selo'],
#  ['quanto', 'tempo', 'gastar', 'pedido', 'ate', 'selo'],
#  ['quanto', 'tempo', 'gastar', 'pedido', 'ate', 'selo'],
#  ['pedir', 'selo', 'quanto', 'tempo'],
#  ['cadastro', 'receber', 'selo'],
#  ['cadastro', 'conseguir', 'selo'],
#  ['ter', 'acesso', 'selo'],
#  ['querer', 'solicitar', 'selo', 'turista', 'responsavel'],
#  ['querer', 'pedir', 'selo', 'turista', 'responsavel'],
#  ['querer', 'inscrever', 'programa', 'selo', 'turista', 'responsavel'],
#  ['procedimento', 'solicitar', 'selo', 'turista', 'responsavel'],
#  ['solicitar', 'selo', 'turista', 'responsavel'],
#  ['querer', 'ter', 'selo'],
#  ['fazer', 'adesao', 'programa', 'selo', 'turismo', 'responsavel'],
#  ['fazer', 'solicitar', 'selo', 'turista', 'responsavel'],
#  ['fazer', 'pedir', 'selo', 'turista', 'responsavel'],
#  ['processo', 'solicitacao', 'selo', 'turista', 'responsavel'],
#  ['querer', 'selo', 'turismo', 'responsavel', 'estabelecimento'],
#  ['querer', 'conseguir', 'turismo', 'responsavel', 'estabelecimento'],
#  ['querer', 'pedir', 'selo', 'turismo', 'responsavel', 'estabelecimento'],
#  [],
#  ['pleitear', 'selo', 'turismo', 'responsavel'],
#  ['preciso', 'selo', 'turismo', 'responsavel', 'fazer', 'pedido'],
#  ['querer', 'solicitar', 'selo', 'turismo'],
#  ['preciso', 'ajuda', 'pedir', 'selo', 'turismo', 'responsavel'],
#  ['ajuda', 'pedir', 'selo', 'turista', 'responsavel'],
#  ['preciso', 'orientacao', 'pedir', 'selo', 'turista', 'responsavel'],
#  ['onde', 'poder', 'pedir', 'selo', 'turista', 'responsavel'],
#  ['lugar', 'posso', 'pedir', 'selo', 'turista', 'responsavel'],
#  ['procedimento', 'pedir', 'selo'],
#  ['orientacao', 'dever', 'seguir', 'obter', 'selo'],
#  ['cadastrar', 'obter', 'selo'],
#  ['solicitar', 'selo', 'turismo', 'responsavel'],
#  ['empresa', 'setor', 'turismo', 'devo', 'pedir', 'selo'],
#  ['devo', 'pedir', 'selo', 'empresa', 'setor', 'turismo'],
#  ['outro',
#   'empresa',
#   'setor',
#   'turistico',
#   'dever',
#   'solicitar',
#   'selo',
#   'cada'],
#  ['ter',
#   'empresa',
#   'setor',
#   'turistico',
#   'dever',
#   'solicitar',
#   'selo',
#   'cada'],
#  ['ter', 'empreendimento', 'turismo', 'selo', 'cada'],
#  ['ter',
#   'vario',
#   'estabelecimento',
#   'turismo',
#   'preciso',
#   'ter',
#   'selo',
#   'cada'],
#  ['ter', 'empresa', 'setor', 'turistico', 'preciso', 'selo', 'cada'],
#  ['preciso', 'ter', 'selo', 'cada', 'empreendimento'],
#  ['fazer', 'conseguir', 'selo'],
#  ['processo', 'solicitacao', 'selo'],
#  ['preciso', 'participar'],
#  ['querer'],
#  ['fazer'],
#  ['necessario'],
#  ['cadastrar', 'receber', 'selo'],
#  ['governo',
#   'fiscalizar',
#   'empreendimentos',
#   'ver',
#   'conformidade',
#   'medidas',
#   'necessarias'],
#  ['interesse', 'cumprimento', 'protocolo', 'proprio', 'empreendedor'],
#  ['interesse',
#   'cumprimento',
#   'medida',
#   'sanitaria',
#   'protecao',
#   'proprio',
#   'empreendedor'],
#  ['avaliar', 'empreendimento', 'seguir', 'protocolo', 'estabelecer'],
#  ['avaliar', 'empreendimento', 'seguir', 'recomendacoes', 'protocolo'],
#  ['mtur',
#   'verificar',
#   'empreendimentos',
#   'adotando',
#   'medidas',
#   'necessarias',
#   'ter',
#   'acesso',
#   'selo'],
#  ['ministerio',
#   'turismo',
#   'pode',
#   'ter',
#   'empreendimentos',
#   'adotando',
#   'medidas',
#   'necessarias',
#   'ter',
#   'acesso',
#   'selo'],
#  ['ministerio',
#   'turismo',
#   'empreendimentos',
#   'adotando',
#   'medidas',
#   'necessarias',
#   'protocolo'],
#  ['empreendimentos', 'adotando', 'medidas', 'necessarias'],
#  ['empreendimentos', 'adotando', 'medidas', 'necessarias'],
#  ['empreendimento', 'fiscalizar'],
#  ['empresa', 'fiscalizar'],
#  ['fara', 'fiscalizacao', 'estabelecimentos'],
#  ['fara', 'fiscalizacao', 'ver', 'empreendimentos', 'seguindo', 'protocolo'],
#  ['fara', 'fiscalizacao', 'ver', 'empreendimentos', 'seguindo'],
#  ['fara',
#   'fiscalizacao',
#   'ver',
#   'empreendimentos',
#   'seguindo',
#   'recomendacoes'],
#  ['governo', 'ira', 'fiscalizar', 'todos', 'empreendimentos', 'selo'],
#  ['fara', 'vistoria', 'empreendimentos', 'adotaram', 'selo'],
#  ['mtur', 'fiscalizar', 'empreendimentos', 'selo'],
#  ['fiscalizados', 'adotaram', 'selo'],
#  ['empreendimento', 'selo'],
#  ['periodicidade', 'selo'],
#  ['periodicidade', 'selo'],
#  ['quanto', 'quanto', 'tempo', 'estabelecimentos', 'fiscalizados'],
#  ['quanto', 'quanto', 'tempo', 'estabelecimentos', 'vistoria'],
#  ['mtur', 'ira', 'fiscalizar', 'todos', 'empreendimentos', 'selo'],
#  ['sanitaria', 'fara', 'empreendimentos', 'selo'],
#  ['fara', 'fiscalizacao', 'empreendimentos', 'adotaram', 'selo'],
#  [],
#  ['fiscalizacao'],
#  ['protocolo'],
#  ['expliquar', 'sobre', 'protocolo'],
#  ['esclarecame', 'sobre', 'protocolo'],
#  ['esclarecer', 'protocolo'],
#  ['definame', 'protocolo'],
#  ['diga', 'protocolo'],
#  ['protocolo'],
#  ['protocolo'],
#  ['protocolo'],
#  ['tirar', 'protocolo'],
#  ['funciona', 'protocolo', 'turistas'],
#  ['mtur', 'selo', 'turismo', 'responsavel'],
#  ['selo',
#   'turismo',
#   'responsavel',
#   'representa',
#   'turista',
#   'brasileiro',
#   'estrangeiro'],
#  ['representar', 'selo', 'turismo', 'responsavel', 'turista', 'brasileiro'],
#  ['representar', 'selo', 'turismo', 'responsavel', 'turista', 'estrangeiro'],
#  ['selo', 'brasil', 'destino', 'proteger', 'responsavel', 'turista'],
#  ['selo', 'brasil', 'destino', 'proteger', 'responsavel', 'turista'],
#  ['turista', 'seguro', 'empreendimento', 'adotar', 'selo'],
#  ['turista',
#   'oriundo',
#   'exterior',
#   'representar',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['turista',
#   'vir',
#   'exterior',
#   'representar',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['pq', 'aderir'],
#  ['turista',
#   'sentir',
#   'seguro',
#   'empreendimento',
#   'adotar',
#   'protocolo',
#   'estabelecir',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['selo',
#   'turismo',
#   'responsavel',
#   'adotar',
#   'medida',
#   'sanitario',
#   'higiene',
#   'seguro',
#   'turista'],
#  ['selo',
#   'turismo',
#   'responsavel',
#   'adotar',
#   'medida',
#   'sanitario',
#   'higiene',
#   'turista'],
#  ['selo',
#   'turismo',
#   'responsavel',
#   'atender',
#   'sanitario',
#   'higiene',
#   'turista'],
#  ['pq', 'importante'],
#  ['beneficio', 'usar', 'selo'],
#  ['usar', 'selo'],
#  ['vantagem', 'usar', 'selo'],
#  ['ganhar', 'uso'],
#  ['motivar', 'usar'],
#  ['pq', 'dever', 'usar'],
#  ['porque', 'dever', 'usar'],
#  ['selo', 'representar', 'turista', 'estrangeiro'],
#  ['selo', 'representar', 'turista', 'brasileiro'],
#  ['selo', 'turismo'],
#  ['adocao',
#   'selo',
#   'turismo',
#   'responsavel',
#   'brasil',
#   'destino',
#   'seguro',
#   'turista'],
#  ['turista',
#   'selo',
#   'turismo',
#   'responsavel',
#   'criar',
#   'novo',
#   'conceito',
#   'destino',
#   'seguro'],
#  ['selo',
#   'turismo',
#   'responsavel',
#   'criar',
#   'novo',
#   'conceito',
#   'destino',
#   'seguro',
#   'turista'],
#  ['turista',
#   'sentir',
#   'seguro',
#   'empreendimento',
#   'aderir',
#   'selo',
#   'turismo'],
#  ['selo',
#   'turismo',
#   'responsavel',
#   'tornar',
#   'empreendimento',
#   'adotar',
#   'turista'],
#  ['selo',
#   'turista',
#   'responsavel',
#   'garantir',
#   'protecao',
#   'seguranca',
#   'sanitario',
#   'querer',
#   'visitar',
#   'brasil'],
#  ['protocolo',
#   'estabelecer',
#   'selo',
#   'turista',
#   'responsavel',
#   'garantir',
#   'protecao',
#   'seguranca',
#   'sanitario',
#   'querer',
#   'visitar',
#   'brasil'],
#  ['protocolo',
#   'estabelecer',
#   'selo',
#   'turista',
#   'responsavel',
#   'garantir',
#   'protecao',
#   'seguranca',
#   'sanitario',
#   'turista'],
#  ['querer',
#   'visitar',
#   'brasil',
#   'poder',
#   'confiar',
#   'medida',
#   'protecao',
#   'seguranca',
#   'sanitario',
#   'protocolo',
#   'estabelecer',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['querer',
#   'visitar',
#   'brasil',
#   'poder',
#   'confiar',
#   'medida',
#   'protecao',
#   'seguranca',
#   'sanitario',
#   'exigir',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['querer',
#   'visitar',
#   'brasil',
#   'seguro',
#   'medida',
#   'higienizacao',
#   'adotar',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['querer',
#   'visitar',
#   'brasil',
#   'poder',
#   'confiar',
#   'protocolo',
#   'estabelecir',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['turista',
#   'poder',
#   'confiar',
#   'protocolo',
#   'estabelecir',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['turista',
#   'poder',
#   'confiar',
#   'medida',
#   'estabelecir',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['turista',
#   'brasileiro',
#   'estrangeiro',
#   'motivar',
#   'selo',
#   'turista',
#   'responsavel'],
#  ['porque', 'importante'],
#  ['porque', 'aderir'],
#  ['beneficio'],
#  ['ter', 'beneficio'],
#  ['ter', 'algum'],
#  ['vantagem'],
#  ['ganhar', 'selo'],
#  ['ganhar', 'selo'],
#  ['ter', 'impacto', 'negocio'],
#  ['impacto', 'negocio'],
#  ['vantagem', 'negocio'],
#  ['negocio', 'ganhar', 'selo'],
#  ['ir', 'sair', 'ganhar', 'selo'],
#  ['negocio', 'ganhar'],
#  ['vantagem', 'usar', 'selo'],
#  ['ganhar', 'selo'],
#  ['ganhar', 'selo'],
#  ['selo', 'impacto', 'negocio'],
#  ['selo', 'brasil', 'destino', 'seguro', 'turistas'],
#  ['selo', 'contribuir', 'brasil', 'destino', 'seguro'],
#  ['posso',
#   'comprar',
#   'pacote',
#   'viagem',
#   'selo',
#   'garante',
#   'locais',
#   'seguindo',
#   'protocolos'],
#  ['selo', 'contribuir', 'retomada', 'setor', 'turistico', 'brasil'],
#  ['selo', 'diferencial', 'pais', 'retomada', 'setor'],
#  ['incentivo', 'retomada', 'turismo', 'brasil'],
#  ['retomada', 'atividade', 'brasil'],
#  ['posso', 'comprar', 'pacote', 'viagem', 'selo', 'garante', 'locais'],
#  ['posso',
#   'comprar',
#   'pacote',
#   'viagem',
#   'selo',
#   'garante',
#   'locais',
#   'seguindo',
#   'medidas',
#   'higiene'],
#  ['selo',
#   'turismo',
#   'brasil',
#   'seguro',
#   'posso',
#   'comprar',
#   'pacote',
#   'viagem'],
#  ['selo', 'turismo', 'brasileiro', 'seguro', 'posso', 'comprar', 'pacote'],
#  ['brasil', 'mostrara', 'destino', 'seguro'],
#  ['brasil', 'mostrara', 'destino', 'seguro', 'turistas'],
#  ['brasil', 'mostrara', 'destino', 'seguro', 'mundo'],
#  ['selo', 'mostrara', 'turistas', 'brasil', 'destino', 'seguro'],
#  ['selo', 'mostrara', 'mundo', 'brasil', 'destino', 'turistico'],
#  ['posso',
#   'comprar',
#   'pacote',
#   'viagem',
#   'selo',
#   'garante',
#   'hotes',
#   'seguindo',
#   'medidas',
#   'higiene'],
#  ['posso',
#   'comprar',
#   'pacote',
#   'viagem',
#   'selo',
#   'garante',
#   'hotes',
#   'seguindo',
#   'protocolo'],
#  ['quero',
#   'comprar',
#   'pacote',
#   'viagem',
#   'posso',
#   'confiar',
#   'adotando',
#   'protocolo'],
#  ['quero',
#   'comprar',
#   'pacote',
#   'viagem',
#   'posso',
#   'confiar',
#   'seguindo',
#   'recomendacoes',
#   'higiene'],
#  ['faco', 'saber', 'empreendimento', 'seguindo', 'protocolo'],
#  ['suspendi',
#   'atividade',
#   'durante',
#   'pandemia',
#   'poder',
#   'solicitar',
#   'selo',
#   'assim'],
#  ['atividade',
#   'suspenso',
#   'devido',
#   'pandemia',
#   'ainda',
#   'poder',
#   'pedir',
#   'selo'],
#  ['estabelecimento', 'fechar', 'pandemia', 'poder', 'solicitar', 'selo'],
#  ['estabelecimento', 'fechar', 'pandemia', 'poder', 'pedir', 'selo'],
#  ['suspendi',
#   'atividade',
#   'empreendimento',
#   'poder',
#   'solicitar',
#   'selo',
#   'assim'],
#  ['atividade', 'suspenso', 'durante', 'pandemia', 'querer', 'selo', 'assim'],
#  ['estabelecimento',
#   'atividade',
#   'suspenso',
#   'durante',
#   'pandemia',
#   'querer',
#   'selo',
#   'assim'],
#  ['estabelecimento', 'atividade', 'suspenso', 'poder', 'obter', 'selo'],
#  ['atividade', 'suspenso', 'poder', 'solicitar', 'selo'],
#  ['solicitar',
#   'selo',
#   'estando',
#   'atividade',
#   'suspensa',
#   'devido',
#   'pandemia'],
#  ['posso',
#   'solicitar',
#   'selo',
#   'estando',
#   'atividade',
#   'suspensa',
#   'devido',
#   'pandemia'],
#  ['cadastur', 'obrigatorior'],
#  ['conseguir', 'selo', 'empreendimentos', 'turisticos', 'cadastur'],
#  ['registro', 'cadastro', 'cadastur', 'prerequisito', 'pleitar', 'selo'],
#  ['registro',
#   'cadastro',
#   'cadastur',
#   'condicao',
#   'exigida',
#   'pleitar',
#   'selo'],
#  ['ter', 'cadastur'],
#  ['ter', 'cadastro', 'cadastur'],
#  ['registro',
#   'cadastro',
#   'cadastur',
#   'condicao',
#   'exigida',
#   'solicitar',
#   'selo'],
#  ['registro', 'cadastro', 'cadastur', 'condicao', 'exigida', 'pedir', 'selo'],
#  ['preciso', 'cadastrado', 'cadastur', 'ter', 'selo'],
#  ['devo', 'cadastrado', 'cadastur', 'ter', 'selo'],
#  ['necessario', 'cadastrado', 'cadastur', 'ter', 'selo'],
#  ['obrigatorio', 'cadastrado', 'cadastur', 'ter', 'selo'],
#  ['registro', 'cadastro', 'cadastur', 'obrigatorio', 'pleitar', 'selo'],
#  ['registro', 'cadastro', 'cadastur', 'obrigatoriedade', 'conseguir', 'selo'],
#  ['nao', 'registro', 'cadastur', 'agora'],
#  ['registro', 'cadastur'],
#  ['registro', 'antigo', 'embratur'],
#  ['posso', 'pedir', 'selo', 'cadastro', 'antigo', 'embratur'],
#  ['registrado', 'cadastur', 'existe', 'outra', 'forma', 'pedir', 'selo'],
#  ['registrado', 'cadastur', 'existe', 'outra', 'forma', 'conseguir', 'selo'],
#  ['registrado', 'cadastur', 'preciso', 'selo'],
#  ['preciso', 'registro', 'cadastur'],
#  ['tipos', 'estabelecimentos', 'pode', 'utilizar', 'selo'],
#  ['fazer', 'saber', 'estabelecimento', 'precisar', 'selo'],
#  ['ter', 'poder', 'pedir', 'selo', 'turismo', 'responsavel'],
#  ['todo',
#   'tipo',
#   'empreendimento',
#   'poder',
#   'aderir',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['tipo',
#   'empreendimento',
#   'poder',
#   'aderir',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['poder', 'pedir', 'selo', 'turismo', 'responsavel'],
#  ['atividade', 'turistico', 'poder', 'pleitear', 'selo'],
#  ['todo',
#   'tipo',
#   'empreendimento',
#   'comercial',
#   'poder',
#   'pedir',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['todo',
#   'tipo',
#   'negocio',
#   'poder',
#   'aderir',
#   'programa',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['tipo', 'empreendimento', 'poder', 'solicitar', 'selo'],
#  ['tipo', 'empreendimento', 'poder', 'pleitear', 'selo'],
#  ['tipo', 'empreendimento', 'poder', 'requerer', 'selo'],
#  ['estabelecimento'],
#  ['empreendimento'],
#  ['pra'],
#  ['pra', 'destinar'],
#  [],
#  ['tipo', 'estabelecimento', 'poder', 'pedir', 'selo'],
#  ['tipo', 'estabelecimento', 'poder', 'solicitar', 'selo'],
#  ['ter', 'regra', 'impedir', 'pedir', 'selo', 'turismo', 'responsavel'],
#  ['pedir',
#   'selo',
#   'turismo',
#   'responsavel',
#   'estabelecimento',
#   'poder',
#   'impedir'],
#  ['querer', 'pedir', 'selo', 'estabelecimento', 'regra'],
#  ['querer', 'pedir', 'selo', 'saber', 'poder'],
#  ['fazer',
#   'saber',
#   'estabelecimento',
#   'poder',
#   'inscrever',
#   'programa',
#   'selo',
#   'turismo',
#   'reponsavel'],
#  ['atividade', 'turistico', 'poder', 'utilizar', 'selo'],
#  ['tipo', 'estabelecimento', 'poder', 'solicitar', 'selo'],
#  ['todo',
#   'estabelecimento',
#   'comercial',
#   'poder',
#   'usar',
#   'selo',
#   'turismo',
#   'responsavel'],
#  ['estabelecimentos', 'pode', 'utilizar', 'selo'],
#  ['tipo', 'estabelecimentos', 'pode', 'utilizar', 'selo'],
#  ['onde',
#   'pesquiso',
#   'saber',
#   'tipo',
#   'estabelecimento',
#   'pode',
#   'pedir',
#   'selo'],
#  ['onde', 'saber', 'tipo', 'estabelecimento', 'pode', 'pedir', 'selo'],
#  ['onde', 'vejo', 'tipo', 'estabelecimento', 'pode', 'selo'],
#  ['preciso', 'saber', 'natureza', 'estabelecimentos', 'pode', 'usar', 'selo'],
#  ['preciso', 'saber', 'quais', 'tipos', 'estabelecimentos', 'usar', 'selo'],
#  ['saber', 'tipo', 'estabelecimento', 'pode', 'pedir', 'selo'],
#  ['tipo', 'estabelecimento', 'dentro', 'ter', 'selo'],
#  ['tipo', 'estabelecimento', 'pode', 'pleitear', 'selo'],
#  ['tipo', 'estabelecimento', 'pode', 'pedir', 'selo'],
#  ['saber', 'tipo', 'estabelecimento', 'usar', 'selo'],
#  ['saber', 'tipo', 'estabelecimento', 'dentro', 'regra', 'selo'],
#  ['posso',
#   'saber',
#   'tipos',
#   'estabelecimentos',
#   'turisticos',
#   'podem',
#   'usar',
#   'selo'],
#  ['todos', 'estabelecimentos', 'turisticos', 'podem', 'usar', 'selo'],
#  ['quais', 'empreendimentos', 'podem', 'utilizar', 'selo'],
#  ['tipo', 'estabelecimentos', 'podem', 'utilizar', 'selo'],
#  ['tuberculose', 'sistema', 'nervoso'],
#  ['tuberculose'],
#  ['tuberculose'],
#  ['tuberculose', 'cerebral'],
#  ['neurotuberculose'],
#  ['neurotuberculose'],
#  ['tuberculose', 'sistema', 'nervoso', 'central'],
#  ['tuberculose', 'cerebral', 'tratar'],
#  ['tuberculose', 'cerebral', 'diagnostico'],
#  ['tuberculose', 'cerebral', 'principal', 'sintoma'],
#  ['preciso', 'pessoa', 'tuberculose', 'pulmonar', 'garganta', 'falar'],
#  ['transmitir', 'tuberculose'],
#  ['contagio', 'tuberculose'],
#  ['transmissao', 'tuberculose'],
#  ['contagio', 'tuberculose'],
#  ['meio', 'transmissao', 'tuberculose'],
#  ['tuberculose', 'transmitir'],
#  ['pegar', 'tuberculose'],
#  ['poder', 'contaminar', 'tuberculose'],
#  ['transmitir'],
#  ['transmitir', 'tuberculose'],
#  ['contagio', 'doenca', 'frequente', 'perto', 'pessoa', 'tuberculose'],
#  ['transmissao', 'tuberculose', 'pessoa'],
#  ['contagio', 'tuberculose', 'acontecer', 'atraves', 'ar'],
#  ['bacilo',
#   'ficar',
#   'ar',
#   'pessoa',
#   'tuberculose',
#   'pulmonar',
#   'garganta',
#   'falar'],
#  ['tuberculose', 'ficar', 'ar', 'tuberculoso', 'falar', 'tosse'],
#  ['pegar', 'ar', 'contaminar', 'bacilo', 'koch'],
#  ['contagio', 'doenca', 'comum', 'perto', 'pessoa', 'tuberculose'],
#  ['impedir', 'contaminacao', 'bacilo', 'koch'],
#  ['vacina', 'impedir', 'contaminacao', 'bacilo', 'koch'],
#  ['vacina', 'contra', 'tuberculose'],
#  ['prevenir', 'tuberculose'],
#  ['proteger', 'contagio', 'tuberculose'],
#  ['prevenir', 'tuberculose'],
#  ['tuberculose'],
#  ['existir', 'prevencao', 'tuberculose'],
#  ['proteger', 'tuberculose'],
#  ['prevencao', 'tuberculose'],
#  ['fator', 'risco', 'gerar', 'aumento', 'contagio', 'tuberculose'],
#  ['querer', 'saber', 'fator', 'risco', 'tuberculose'],
#  ['fator', 'risco', 'tuberculose'],
#  ['tuberculose', 'risco'],
#  ['fator', 'risco', 'tuberculose'],
#  ['risco', 'contrair', 'tuberculose'],
#  ['existir', 'fator', 'aumentar', 'risco', 'contaminacao', 'tuberculose'],
#  ['aumentar', 'risco', 'contrair', 'tuberculose'],
#  ['risco', 'tuberculose'],
#  ['fator', 'risco', 'tuberculose'],
#  ['tuberculose', 'poder', 'torax'],
#  ['tuberculose', 'ganglio'],
#  ['tuberculose', 'ganglionar'],
#  ['tuberculose', 'ganglionar'],
#  ['tuberculose', 'ganglionar', 'sistema'],
#  ['preciso', 'saber', 'sobre', 'tuberculose', 'ganglionar'],
#  ['tuberculose', 'ganglio'],
#  ['falar', 'sobre', 'tuberculose', 'ganglionar'],
#  ['querer', 'saber', 'sobre', 'tuberculose', 'ganglionar'],
#  ['preciso', 'informacao', 'sobre', 'tuberculose', 'ganglionar'],
#  ['explicar', 'sobre', 'tuberculose', 'ganglionar'],
#  ['definer', 'tuberculose', 'ganglionar'],
#  ['tuberculose', 'ganglionar', 'tratar'],
#  ['tuberculose', 'diagnostico'],
#  ['tuberculose', 'ganglionar', 'principal', 'sintoma'],
#  ['tuberculose', 'tratar'],
#  ['beber',
#   'leite',
#   'animal',
#   'contaminar',
#   'causa',
#   'tuberculose',
#   'intestino'],
#  ['comer',
#   'carne',
#   'animal',
#   'contaminar',
#   'causa',
#   'tuberculose',
#   'intestino'],
#  ['comer',
#   'carne',
#   'beber',
#   'leite',
#   'animal',
#   'contaminar',
#   'causa',
#   'tuberculose',
#   'intestino'],
#  ['tuberculose', 'intestino'],
#  ['tuberculose'],
#  ['falame', 'sobre', 'tuberculose', 'intestinal'],
#  ['existir', 'tuberculose', 'intestinal'],
#  ['tuberculose', 'intestinal'],
#  ['tuberculose', 'intestinal'],
#  ['pessoa',
#   'tuberculose',
#   'pulmonar',
#   'engoler',
#   'secrecao',
#   'bacilo',
#   'pegar',
#   'tuberculose',
#   'intestinal'],
#  ['pessoa',
#   'tuberculose',
#   'pulmonar',
#   'engoler',
#   'secrecao',
#   'poder',
#   'desenvolver',
#   'tuberculose',
#   'intestinal'],
#  ['tuberculose', 'intestinal', 'diagnostico'],
#  ['tuberculose', 'intestinal', 'principal', 'sintoma'],
#  ['tuberculose'],
#  ['tuberculose', 'miliar', 'meningea'],
#  ['definer', 'tuberculose', 'miliar', 'meningea'],
#  ['tuberculose', 'miliar', 'meningea'],
#  ['tipo', 'tuberculose', 'bacteria', 'disseminar', 'corrente', 'sanguinea'],
#  ['tuberculose', 'miliar', 'bacteria', 'disseminar', 'corrente', 'sanguinea'],
#  ['tuberculose', 'miliar', 'forma', 'grave', 'doenca'],
#  ['tuberculose', 'miliar'],
#  ['tuberculose'],
#  ['tuberculose', 'miliar', 'meningea'],
#  ['tuberculose', 'miliar', 'provocar', 'tecido', 'orgao', 'corpo'],
#  ['tuberculose', 'miliar', 'tratar'],
#  ['tuberculose', 'miliar', 'diagnostico'],
#  ['tuberculose', 'miliar', 'principal', 'sintoma'],
#  ['explicar', 'tuberculose', 'ocular'],
#  ['tuberculose', 'ocular'],
#  ['tuberculose', 'ocular'],
#  ['querer', 'saber', 'sobre', 'tuberculose', 'olho'],
#  ['tuberculose'],
#  ['querer', 'saber', 'sobre', 'tuberculose', 'ocular'],
#  ['tuberculose', 'olho'],
#  ['existir', 'tuberculose', 'olho'],
#  ['existir', 'tuberculose', 'olho'],
#  ['ter', 'tuberculose', 'ocular'],
#  ['chamar', 'tuberculose', 'olho'],
#  ['definame', 'tuberculose', 'ocular'],
#  ['ter', 'tuberculose', 'ocular'],
#  ['tuberculose', 'ocular', 'tratar'],
#  ['tuberculose', 'ocular', 'diagnostico'],
#  ['tuberculose', 'ocular', 'principal'],
#  ['diga', 'tuberculose'],
#  ['tuberculose'],
#  ['tuberculose', 'infeccao', 'grave'],
#  ['tuberculose', 'doenca', 'grave'],
#  ['tuberculose'],
#  ['tuberculose', 'doenca', 'bacteria'],
#  ['tuberculose'],
#  ['tuberculose'],
#  ['definame', 'tuberculose'],
#  ['doenca', 'tuberculose'],
#  ['tuberculose'],
#  ['tuberculose'],
#  ['tuberculose'],
#  ['aperto', 'transmite', 'tuberculose'],
#  ['tuberculose', 'transmitir', 'tuberculose'],
#  ['compartilhar', 'comida', 'bebida', 'transmiter', 'tuberculose'],
#  ['tuberculose', 'passar', 'atrave', 'beijo'],
#  ['beijo', 'causar', 'transmissao'],
#  ['passar', 'roupa', 'pessoa', 'infectar'],
#  ['tuberculose', 'passar', 'atrave'],
#  ['tuberculose', 'passar', 'atrave', 'comida'],
#  ['tuberculose', 'passar', 'atrave', 'aperto', 'mao'],
#  ['tuberculose', 'passar', 'atrave'],
#  ['usar', 'roupa', 'pessoa', 'infectar', 'transmite', 'tuberculose'],
#  ['tuberculose', 'osso'],
#  ['tuberculose', 'pegar', 'osso'],
#  ['infeccao', 'osso'],
#  ['tuberculose', 'osso'],
#  ['bacilo', 'tuberculose', 'poder', 'alojar', 'osso'],
#  ['querer', 'saber', 'sobre', 'tuberculose', 'osso'],
#  ['poder', 'ter', 'tuberculose'],
#  ['osso', 'poder', 'ter', 'tuberculose'],
#  ['osso', 'poder', 'tuberculose'],
#  ['tuberculose', 'pegar', 'osso', 'corpo'],
#  ['tuberculose', 'ossea'],
#  ['tuberculose', 'ossea'],
#  ['tuberculose', 'osso'],
#  ['tuberculose', 'ossea', 'tratar'],
#  ['tuberculose', 'ossea', 'diagnostico'],
#  ['tuberculose', 'principal', 'sintoma'],
#  ['tuberculose', 'pleural'],
#  ['chamar', 'tuberculose', 'tecido', 'pulmao'],
#  ['uso', 'poder', 'desenvolver', 'tuberculose', 'pleural'],
#  ['pegar', 'tuberculose', 'pleura'],
#  ['tuberculose', 'poder', 'contagiar', 'pleura'],
#  ['preciso', 'orientacao', 'sobre', 'tuberculose', 'pleural'],
#  ['tuberculose', 'pleural'],
#  ['existir', 'tuberculose', 'pleural'],
#  ['tuberculose', 'pegar', 'pleura'],
#  ['pleura', 'poder', 'contaminar', 'tuberculose'],
#  ['esclarecame', 'sobre', 'tuberculose', 'pleural'],
#  ['expliquar', 'tuberculose', 'pleural'],
#  ['tuberculose', 'pleural', 'tratar'],
#  ['tuberculose', 'pleural', 'diagnostico'],
#  ['tuberculose', 'pleural', 'principal', 'sintoma'],
#  ['tuberculose'],
#  ['tuberculose', 'pulmao'],
#  ['pulmao', 'tuberculose'],
#  ['tuberculose',
#   'pulmonar',
#   'ocorrer',
#   'devido',
#   'bacilo',
#   'via',
#   'respiratorio'],
#  ['tuberculose', 'pulmonar'],
#  ['forma', 'comum', 'doenca', 'tuberculose', 'pulmonar'],
#  ['preciso', 'informacao', 'sobre', 'tuberculose', 'pulmonar'],
#  ['tuberculose', 'pulmonar'],
#  ['bacteria', 'alojar', 'pulmao', 'tuberculose', 'pulmonar'],
#  ['expliqueme', 'sobre', 'bacteria', 'pulmonar'],
#  ['esclarecer', 'sobre', 'tuberculose', 'pulmonar'],
#  ['tuberculose', 'pulmonar', 'querer', 'saber'],
#  ['querer', 'saber', 'sobre', 'tuberculose', 'pulmonar'],
#  ['preciso', 'informacao', 'sobre', 'tuberculose', 'pulmonar'],
#  ['definer', 'tuberculose', 'pulmonar'],
#  ['tuberculose', 'pulmonar', 'tratar'],
#  ['tuberculose', 'pulmonar', 'diagnostico'],
#  ['tuberculose', 'pulmonar', 'principal', 'sintoma'],
#  ['ter', 'sarar', 'tuberculose'],
#  ['tuberculose', 'ter', 'cura'],
#  ['existir', 'cura', 'tuberculose'],
#  ['ir', 'ficar', 'curar', 'tuberculose'],
#  ['poder', 'curar', 'tuberculose'],
#  ['cura', 'tuberculose'],
#  ['tuberculoso', 'poder', 'curar'],
#  ['ir', 'sarar', 'tuberculose'],
#  ['tratamento', 'tuberculose', 'deixar', 'paciente', 'curar'],
#  ['paciente', 'tuberculose', 'poder', 'curar'],
#  ['doente', 'tuberculose', 'poder', 'curar'],
#  ['doenca', 'tuberculose', 'ter', 'cura'],
#  ['existir', 'cura', 'pra', 'doenca', 'tuberculose'],
#  ['doenca', 'tuberculose', 'ja', 'ter', 'cura'],
#  ['existir', 'quanto', 'tipo', 'tuberculose'],
#  ['tuberculose', 'tipo'],
#  ['tipo', 'tuberculose'],
#  ['tipo', 'tuberculose'],
#  ...]

# %%
# alteração da configuração do corpus, para o processado em português (por padrão o Pycaret processa em inglês)
set_config('corpus', bow_corpus)
get_config('corpus')
# Out:
# [[(0, 1)],
#  [(0, 1), (1, 1), (2, 1), (3, 1), (4, 1)],
#  [(0, 1), (3, 1), (5, 1), (6, 1)],
#  [(0, 1), (7, 1), (8, 1)],
#  [(0, 1), (8, 1)],
#  [(5, 1), (6, 1), (9, 1), (10, 1)],
#  [(0, 1), (11, 1)],
#  [(12, 1), (13, 1), (14, 1), (15, 1)],
#  [(0, 1), (10, 1), (16, 1)],
#  [(0, 1), (15, 1), (17, 1)],
#  [(0, 1), (13, 1), (18, 1), (19, 1), (20, 1)],
#  [(15, 1), (21, 1)],
#  [(0, 1), (15, 1), (18, 1), (22, 1)],
#  [(14, 1), (15, 1), (23, 1), (24, 1), (25, 1)],
#  [(26, 1), (27, 1)],
#  [(0, 1), (7, 1), (28, 1)],
#  [(0, 1), (29, 1), (30, 1)],
#  [(0, 1), (30, 1)],
#  [(0, 1), (10, 1), (31, 1)],
#  [(0, 1), (10, 1), (30, 1)],
#  [(0, 1)],
#  [(0, 1), (29, 1), (30, 1)],
#  [(0, 1), (32, 1)],
#  [(0, 1), (33, 1), (34, 1)],
#  [(0, 1), (35, 1)],
#  [(0, 1), (35, 1)],
#  [(0, 1)],
#  [(0, 1), (36, 1)],
#  [(0, 1)],
#  [(0, 1), (37, 1), (38, 1)],
#  [(0, 1), (10, 1), (16, 1)],
#  [(0, 1), (28, 1), (35, 1)],
#  [(0, 1), (10, 1), (16, 1), (39, 1)],
#  [(0, 1), (40, 1), (41, 1)],
#  [(10, 1), (39, 1), (42, 1), (43, 1)],
#  [(0, 1), (39, 1)],
#  [(41, 1), (44, 1)],
#  [(0, 1), (13, 1), (37, 1)],
#  [(0, 1), (6, 1), (45, 1)],
#  [(0, 1), (41, 1)],
#  [(0, 1)],
#  [(1, 1), (13, 1)],
#  [(0, 1), (27, 1)],
#  [(27, 1)],
#  [(0, 1), (46, 1)],
#  [(0, 1), (47, 1)],
#  [(0, 1), (25, 1), (48, 1)],
#  [(48, 1), (49, 1)],
#  [(0, 1), (50, 1)],
#  [(0, 1), (13, 1), (51, 1)],
#  [(25, 1), (52, 1), (53, 1), (54, 1)],
#  [(0, 1), (13, 1), (30, 1), (53, 1)],
#  [(53, 1), (54, 1), (55, 1)],
#  [(0, 1), (25, 1), (34, 1), (56, 1), (57, 1)],
#  [(0, 1), (25, 1), (34, 1), (47, 1), (56, 1), (57, 1)],
#  [(0, 1), (34, 1), (47, 1), (58, 1), (59, 1)],
#  [(34, 1), (46, 1), (59, 1), (60, 1)],
#  [(0, 1), (34, 1), (46, 1), (61, 1)],
#  [(0, 1), (34, 1), (46, 1), (61, 1)],
#  [(0, 1), (34, 1), (46, 1), (60, 1), (62, 1)],
#  [(0, 1), (34, 1), (46, 1), (60, 1)],
#  [(34, 1), (46, 1), (59, 1), (63, 1), (64, 1)],
#  [(44, 1), (65, 1), (66, 1), (67, 1)],
#  [(65, 1), (66, 1), (68, 1)],
#  [(60, 1), (65, 1), (66, 1)],
#  [(65, 1), (66, 1), (69, 1), (70, 1)],
#  [(7, 1), (8, 1), (57, 1)],
#  [(60, 1), (66, 1), (69, 1), (70, 1), (71, 1), (72, 1), (73, 1)],
#  [(74, 1), (75, 1)],
#  [(60, 1), (76, 1), (77, 1)],
#  [(60, 1), (78, 1), (79, 1)],
#  [(50, 1), (60, 1)],
#  [(80, 1)],
#  [(79, 1), (80, 1)],
#  [(76, 1), (81, 1), (82, 1)],
#  [(0, 1), (13, 1), (60, 1), (82, 1), (83, 1), (84, 1)],
#  [(27, 1), (85, 1)],
#  [(0, 1), (82, 1), (83, 1)],
#  [(0, 1), (41, 1), (82, 1)],
#  [(0, 1), (62, 1)],
#  [(50, 1), (86, 1)],
#  [(0, 1), (8, 1), (41, 1)],
#  [(0, 1), (41, 1)],
#  [(0, 1), (1, 1), (13, 1), (25, 1), (82, 1), (87, 1), (88, 1)],
#  [(0, 1), (13, 1), (49, 1), (89, 1), (90, 1)],
#  [(0, 1), (13, 1), (41, 1), (88, 1)],
#  [(0, 1), (50, 1)],
#  [(0, 1), (50, 1), (86, 1)],
#  [(0, 1), (25, 1), (50, 1)],
#  [(0, 1), (13, 1), (48, 1)],
#  [(0, 1), (50, 1)],
#  [(0, 1), (9, 1), (91, 1)],
#  [(0, 1), (41, 1), (73, 1), (91, 1), (92, 1)],
#  [(10, 1), (13, 1), (41, 1), (93, 1)],
#  [(1, 1), (13, 1), (41, 1), (88, 1), (94, 1)],
#  [(10, 1), (13, 1), (41, 1), (95, 1), (96, 1), (97, 1)],
#  [(10, 1), (13, 1), (41, 1), (98, 1), (99, 1)],
#  [(1, 1), (10, 1), (13, 1), (41, 1), (100, 1), (101, 1)],
#  [(1, 1), (10, 1), (13, 1), (102, 1)],
#  [(10, 1), (13, 1), (94, 1), (103, 1), (104, 1)],
#  [(0, 1), (13, 1), (41, 1), (82, 1), (95, 1)],
#  [(0, 1), (13, 1), (41, 1)],
#  [(0, 1), (13, 1), (105, 1)],
#  [(13, 1), (41, 1), (106, 1), (107, 1), (108, 1)],
#  [(0, 1), (13, 1), (41, 1), (88, 1), (109, 1)],
#  [(52, 1), (54, 1), (106, 1), (110, 1)],
#  [(0, 1), (41, 1), (50, 1), (88, 1), (111, 1), (112, 1)],
#  [(0, 1), (29, 1), (41, 1), (44, 1)],
#  [(41, 1), (44, 1), (85, 1), (113, 1), (114, 1)],
#  [(13, 1), (41, 1)],
#  [(0, 1), (41, 1), (44, 1), (115, 1), (116, 1)],
#  [(0, 1), (9, 1), (13, 1)],
#  [(0, 1), (41, 1), (117, 1)],
#  [(0, 1), (117, 1), (118, 1)],
#  [(0, 1), (25, 2), (50, 1), (119, 1)],
#  [(0, 1), (9, 1), (13, 1), (25, 1), (50, 1)],
#  [(1, 1), (13, 1), (77, 1), (120, 1)],
#  [(0, 1), (25, 2), (50, 1), (119, 1)],
#  [(0, 1), (41, 1), (73, 1), (92, 1)],
#  [(0, 1), (41, 1), (73, 1), (92, 1)],
#  [(50, 1), (85, 1)],
#  [(0, 1), (10, 1), (121, 1)],
#  [(9, 1), (13, 1), (88, 2)],
#  [(1, 1), (22, 1), (122, 1)],
#  [(1, 1), (122, 1), (123, 1)],
#  [(1, 1), (122, 1), (124, 1), (125, 1)],
#  [(10, 1), (126, 1), (127, 1)],
#  [(85, 1), (126, 1), (127, 1)],
#  [(14, 1), (28, 1), (124, 1), (128, 1), (129, 1)],
#  [(0, 1), (22, 1), (25, 1), (130, 1), (131, 1), (132, 1), (133, 1)],
#  [(22, 1), (28, 1), (80, 1), (134, 1)],
#  [(0, 1), (22, 1), (135, 1)],
#  [(1, 1), (13, 1), (35, 1), (54, 1), (129, 1), (130, 1), (136, 1)],
#  [(1, 1), (13, 1), (35, 1), (54, 1), (130, 1), (137, 1)],
#  [(1, 1), (13, 1), (54, 1), (130, 1), (136, 1), (137, 1), (138, 1)],
#  [(1, 1), (13, 1), (54, 1), (129, 1), (130, 1), (139, 1)],
#  [(1, 1), (13, 1), (43, 1), (98, 1), (129, 1), (130, 1), (136, 1)],
#  [(10, 1), (13, 1), (54, 1), (102, 1), (139, 1), (140, 1)],
#  [(10, 1), (13, 1), (28, 1), (99, 1), (102, 1), (141, 1), (142, 1), (143, 1)],
#  [(13, 1), (49, 1), (99, 1), (142, 1), (143, 1)],
#  [(1, 1), (13, 1), (28, 1), (68, 1), (99, 1), (129, 1), (138, 1), (142, 1)],
#  [(29, 1), (30, 1), (54, 1), (144, 1)],
#  [(0, 1), (54, 1), (55, 1), (142, 1), (145, 1), (146, 1)],
#  [(0, 1), (30, 1), (54, 1)],
#  [(10, 1), (13, 1), (71, 1), (73, 1), (147, 1), (148, 1), (149, 1), (150, 1)],
#  [(10, 1), (13, 1), (66, 1), (147, 1), (151, 1)],
#  [(10, 1), (13, 1), (125, 1), (152, 1), (153, 1)],
#  [(10, 1), (107, 1), (125, 1), (152, 1), (153, 1)],
#  [(10, 1), (13, 1), (125, 1), (152, 1), (153, 1), (154, 1)],
#  [(93, 1), (155, 1), (156, 1)],
#  [(2, 1), (10, 1), (24, 1), (157, 1), (158, 1)],
#  [(99, 1), (101, 1), (155, 1), (159, 1)],
#  [(85, 1), (154, 1), (160, 1)],
#  [(99, 1), (155, 1), (161, 1)],
#  [(10, 1), (24, 1), (157, 1), (158, 1), (162, 1)],
#  [(10, 1), (100, 1), (158, 1), (163, 1)],
#  [(0, 1), (4, 1), (41, 1), (52, 1), (54, 1), (162, 1)],
#  [(0, 1), (13, 1), (116, 1), (120, 1), (164, 1)],
#  [(71, 1), (138, 1), (154, 1), (161, 1), (165, 1)],
#  [(13, 1), (166, 1)],
#  [(13, 1), (93, 1), (142, 1), (166, 1)],
#  [(65, 1), (66, 1), (93, 1), (120, 1), (155, 1), (156, 1)],
#  [(4, 1),
#   (10, 1),
#   (13, 1),
#   (71, 1),
#   (73, 1),
#   (147, 1),
#   (148, 1),
#   (149, 1),
#   (150, 1)],
#  [(167, 1), (168, 1)],
#  [(168, 1), (169, 1), (170, 1)],
#  [(171, 1)],
#  [(168, 1)],
#  [(168, 1), (172, 1)],
#  [(168, 1), (173, 1)],
#  [(168, 1)],
#  [(168, 1), (174, 1)],
#  [(168, 1)],
#  [(168, 1)],
#  [(168, 1)],
#  [],
#  [],
#  [],
#  [],
#  [(168, 1), (174, 1), (175, 1)],
#  [(168, 1), (174, 1), (176, 1)],
#  [(168, 1), (174, 1)],
#  [(168, 1)],
#  [(38, 1), (167, 1)],
#  [(167, 1)],
#  [(169, 1), (170, 1)],
#  [(169, 1)],
#  [(169, 1)],
#  [(169, 1)],
#  [(169, 1), (177, 1)],
#  [(60, 1), (169, 1)],
#  [(38, 1), (167, 1)],
#  [(38, 1), (60, 1), (169, 1)],
#  [(167, 1), (178, 1)],
#  [(60, 1), (169, 1)],
#  [(60, 1), (169, 1)],
#  [(169, 1)],
#  [(38, 1), (169, 1), (170, 1)],
#  [(60, 1), (167, 1)],
#  [(167, 1)],
#  [(177, 1), (179, 1)],
#  [(60, 1), (179, 1)],
#  [(179, 1)],
#  [(33, 1), (169, 1)],
#  [(180, 1)],
#  [(181, 1), (182, 1)],
#  [(182, 1)],
#  [(36, 1), (183, 1), (184, 1), (185, 1)],
#  [(182, 1)],
#  [(182, 1), (183, 1), (184, 1)],
#  [(186, 1)],
#  [],
#  [(187, 1), (188, 1), (189, 1)],
#  [(180, 1), (183, 1), (184, 1), (185, 1)],
#  [(187, 1), (189, 1)],
#  [(187, 1)],
#  [(187, 1)],
#  [(38, 1), (181, 1), (190, 1), (191, 1), (192, 1), (193, 1), (194, 1)],
#  [(13, 1), (181, 1), (190, 1), (191, 1), (192, 1), (194, 1), (195, 1)],
#  [(190, 1), (193, 1), (195, 1), (196, 1), (197, 1), (198, 1)],
#  [(181, 1),
#   (190, 1),
#   (194, 1),
#   (195, 1),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (199, 1)],
#  [(38, 1), (181, 1), (190, 1), (191, 1), (192, 1), (194, 1), (195, 1)],
#  [(60, 1), (200, 1), (201, 1), (202, 1), (203, 1), (204, 1)],
#  [(190, 1),
#   (195, 1),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (201, 1),
#   (202, 1),
#   (203, 1)],
#  [(38, 1), (121, 1), (202, 1), (205, 1)],
#  [(38, 1), (194, 1), (202, 1), (206, 1)],
#  [(25, 1), (194, 1), (207, 1)],
#  [(38, 1), (121, 1), (194, 1), (207, 1), (208, 1), (209, 1)],
#  [(112, 1), (194, 1), (207, 1), (208, 1), (210, 1), (211, 1), (212, 1)],
#  [(25, 1), (194, 1), (202, 1), (213, 1), (214, 1)],
#  [(38, 1), (194, 1), (209, 1), (215, 1)],
#  [(121, 1), (194, 1), (209, 1), (215, 1), (216, 1)],
#  [(60, 1), (63, 1), (194, 1), (206, 1)],
#  [(38, 1), (121, 1), (194, 1), (209, 1), (215, 1)],
#  [(38, 1), (121, 1), (194, 1), (209, 1), (215, 1)],
#  [(38, 1), (121, 1), (194, 1), (209, 1), (215, 1), (217, 1)],
#  [(60, 1), (194, 1), (206, 1), (209, 1), (218, 1)],
#  [(38, 1), (194, 1), (202, 1), (209, 1), (215, 1), (217, 1)],
#  [(25, 1), (183, 1), (219, 1), (220, 1), (221, 1)],
#  [(92, 1), (194, 1), (222, 1), (223, 1)],
#  [(224, 1), (225, 1), (226, 1), (227, 1), (228, 1)],
#  [(147, 1), (222, 1), (224, 1), (225, 1), (226, 1), (227, 1), (228, 1)],
#  [(194, 1), (223, 1), (229, 1)],
#  [(194, 1), (224, 1), (230, 1)],
#  [(60, 1), (155, 1), (194, 1), (227, 1), (228, 1), (231, 1)],
#  [(224, 1), (225, 1), (227, 1), (228, 1), (232, 1)],
#  [(225, 1), (227, 1), (228, 1)],
#  [(152, 1), (194, 1), (233, 1), (234, 1)],
#  [(48, 1), (194, 1), (233, 1), (235, 1)],
#  [(48, 1), (194, 1)],
#  [(48, 1), (155, 1), (194, 1), (235, 1), (236, 1)],
#  [(136, 1), (194, 1)],
#  [(152, 1), (194, 1), (233, 1), (237, 1), (238, 1)],
#  [(152, 1), (194, 1), (237, 1), (238, 1)],
#  [(136, 1), (152, 1), (194, 1), (239, 1), (240, 1)],
#  [(48, 1), (152, 1), (194, 1), (233, 1)],
#  [(152, 1), (194, 1), (234, 1)],
#  [(48, 1), (152, 1), (194, 1), (241, 1)],
#  [(48, 1), (152, 1), (194, 1), (210, 1)],
#  [(194, 1), (235, 1), (242, 1)],
#  [(48, 1), (194, 1), (230, 1), (235, 1)],
#  [(193, 1), (196, 1), (197, 1), (198, 1), (243, 1)],
#  [(193, 1), (202, 1), (244, 1), (245, 1)],
#  [(193, 1), (244, 1)],
#  [(121, 1), (193, 1), (194, 1), (215, 1), (246, 1), (247, 1)],
#  [(121, 1), (193, 1), (194, 1), (215, 1), (247, 1), (248, 1)],
#  [(193, 1), (212, 1), (237, 1), (249, 1)],
#  [(165, 1), (193, 1), (250, 1)],
#  [(193, 1), (199, 1)],
#  [(186, 1), (193, 1)],
#  [(193, 1), (251, 1)],
#  [(193, 1)],
#  [(193, 1)],
#  [(8, 1), (193, 1), (252, 1), (253, 1)],
#  [(193, 1), (195, 1), (196, 1), (198, 1), (254, 1)],
#  [(25, 1), (124, 1), (193, 1), (250, 1), (252, 1)],
#  [(25, 1), (193, 1), (246, 1), (252, 1)],
#  [(25, 1), (193, 1), (252, 1), (255, 1)],
#  [(124, 1), (193, 1), (250, 1), (252, 1)],
#  [(21, 1), (193, 1), (254, 1), (256, 1)],
#  [(193, 1), (195, 1), (251, 1), (254, 1)],
#  [(124, 1), (193, 1), (195, 1), (250, 1), (251, 1), (252, 1)],
#  [(25, 1), (193, 1), (251, 1), (252, 1)],
#  [(6, 1), (193, 1), (251, 1), (254, 1), (257, 1)],
#  [(6, 1), (254, 1)],
#  [(193, 1), (251, 1), (258, 1), (259, 1), (260, 1)],
#  [(252, 1), (261, 1)],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [(262, 1)],
#  [(263, 1)],
#  [(264, 1)],
#  [(265, 1)],
#  [(263, 1), (265, 1)],
#  [(252, 1)],
#  [(193, 1), (254, 1), (266, 1)],
#  [(193, 1), (252, 1), (267, 1)],
#  [(193, 1), (252, 1)],
#  [(193, 1), (254, 1)],
#  [(268, 1)],
#  [(254, 1), (268, 1)],
#  [(252, 1), (268, 1)],
#  [(6, 1), (254, 1), (261, 1)],
#  [(8, 1), (193, 1), (258, 1), (260, 1), (269, 1)],
#  [(8, 1), (193, 1), (253, 1), (260, 1), (270, 1)],
#  [(8, 1), (136, 1), (193, 1), (260, 1), (270, 1)],
#  [(124, 1), (193, 1), (250, 1), (258, 1), (260, 1)],
#  [(193, 1), (250, 1), (252, 1)],
#  [(193, 1), (258, 1), (260, 1)],
#  [(193, 1), (258, 1), (259, 1), (260, 1)],
#  [(193, 1), (200, 1), (251, 1), (258, 1), (260, 1)],
#  [(6, 1), (193, 1), (199, 1), (254, 1)],
#  [(193, 1), (199, 1), (252, 1), (262, 1), (264, 1)],
#  [(193, 1), (266, 1), (271, 1)],
#  [(193, 1), (254, 1), (260, 1), (272, 1)],
#  [(58, 1),
#   (124, 1),
#   (193, 1),
#   (212, 1),
#   (273, 1),
#   (274, 1),
#   (275, 1),
#   (276, 1),
#   (277, 1)],
#  [(6, 1), (194, 1), (207, 1), (273, 1), (278, 1), (279, 1)],
#  [(25, 1), (183, 1), (194, 1), (231, 1), (280, 1), (281, 1)],
#  [(92, 1), (171, 1), (277, 1), (282, 1), (283, 1), (284, 1)],
#  [(92, 1), (193, 1), (285, 1)],
#  [(193, 1), (285, 1), (286, 1)],
#  [(193, 1), (282, 1), (287, 1)],
#  [(193, 1), (288, 1)],
#  [(13, 1), (193, 1), (282, 1), (289, 1), (290, 1)],
#  [(25, 1), (109, 1), (282, 1), (284, 1)],
#  [(171, 1), (195, 1), (284, 1), (285, 1), (287, 1), (291, 1)],
#  [(171, 1), (195, 1), (282, 1), (284, 1), (291, 1)],
#  [(171, 1), (261, 1), (282, 1), (284, 1), (291, 1)],
#  [(63, 1),
#   (72, 1),
#   (125, 1),
#   (171, 1),
#   (282, 1),
#   (284, 1),
#   (292, 1),
#   (293, 1)],
#  [(63, 1), (171, 1), (194, 1), (217, 1), (282, 1), (284, 1), (293, 1)],
#  [(48, 1), (77, 1), (171, 1), (202, 1), (245, 1), (277, 1)],
#  [(48, 1), (77, 1), (171, 1), (202, 1), (245, 1), (277, 1), (284, 1)],
#  [(72, 1),
#   (108, 1),
#   (165, 1),
#   (171, 1),
#   (194, 1),
#   (209, 1),
#   (277, 1),
#   (282, 1),
#   (284, 1),
#   (294, 1)],
#  [(60, 1), (72, 1), (171, 1), (277, 1), (284, 1), (292, 1)],
#  [(108, 1), (171, 1), (194, 1), (277, 1), (282, 1), (284, 1), (295, 1)],
#  [(171, 1), (194, 1), (277, 1), (282, 1), (284, 1), (295, 1), (296, 1)],
#  [(155, 1), (171, 2), (194, 1), (277, 1), (284, 1), (295, 1), (296, 1)],
#  [(60, 1), (155, 1), (194, 1), (195, 1), (284, 1), (285, 1), (297, 1)],
#  [(155, 1),
#   (171, 1),
#   (194, 1),
#   (195, 1),
#   (284, 1),
#   (285, 1),
#   (297, 1),
#   (298, 1)],
#  [(25, 1), (193, 1), (195, 1), (284, 1), (285, 1), (286, 1), (299, 1)],
#  [(25, 1),
#   (194, 1),
#   (195, 1),
#   (199, 1),
#   (284, 1),
#   (285, 1),
#   (286, 1),
#   (297, 1)],
#  [(25, 1),
#   (194, 1),
#   (195, 1),
#   (248, 1),
#   (284, 1),
#   (285, 1),
#   (286, 1),
#   (297, 1)],
#  [(25, 1), (193, 1), (194, 1), (271, 1), (285, 1)],
#  [(193, 1), (289, 1), (290, 1)],
#  [(209, 1), (294, 1), (300, 1), (301, 1), (302, 1), (303, 1), (304, 1)],
#  [(209, 1),
#   (294, 1),
#   (300, 1),
#   (301, 1),
#   (302, 1),
#   (303, 1),
#   (304, 1),
#   (305, 1)],
#  [(292, 1), (300, 1), (301, 1), (302, 1), (303, 1), (304, 1), (305, 1)],
#  [(193, 1),
#   (204, 1),
#   (294, 1),
#   (299, 1),
#   (306, 1),
#   (307, 1),
#   (308, 1),
#   (309, 1),
#   (310, 1),
#   (311, 1),
#   (312, 1),
#   (313, 1)],
#  [(193, 1), (299, 1), (306, 1), (307, 1), (309, 1), (313, 1), (314, 1)],
#  [(150, 1),
#   (193, 1),
#   (194, 1),
#   (195, 1),
#   (255, 1),
#   (315, 1),
#   (316, 1),
#   (317, 1),
#   (318, 1),
#   (319, 1)],
#  [(96, 1),
#   (150, 1),
#   (193, 2),
#   (195, 1),
#   (255, 1),
#   (315, 1),
#   (317, 1),
#   (318, 1)],
#  [(193, 1), (204, 1), (294, 1), (310, 1), (314, 1)],
#  [(300, 1), (302, 1), (303, 1), (307, 1), (320, 1)],
#  [(193, 1)],
#  [(193, 1), (307, 1), (310, 1), (320, 1)],
#  [(193, 1), (260, 1), (321, 1)],
#  [(25, 1), (193, 1), (194, 1), (307, 1)],
#  [(150, 1),
#   (193, 1),
#   (195, 1),
#   (255, 1),
#   (316, 1),
#   (317, 1),
#   (318, 1),
#   (319, 1)],
#  [(193, 1),
#   (299, 1),
#   (306, 1),
#   (307, 1),
#   (308, 1),
#   (309, 1),
#   (311, 1),
#   (312, 1),
#   (313, 1)],
#  [(151, 1),
#   (194, 1),
#   (322, 1),
#   (323, 1),
#   (324, 1),
#   (325, 1),
#   (326, 1),
#   (327, 1)],
#  [(194, 1), (323, 1), (325, 1), (326, 1), (327, 1), (328, 1)],
#  [(13, 1),
#   (25, 1),
#   (194, 1),
#   (195, 1),
#   (211, 1),
#   (322, 1),
#   (323, 1),
#   (329, 1),
#   (330, 1)],
#  [(13, 1),
#   (25, 1),
#   (194, 1),
#   (195, 1),
#   (211, 1),
#   (212, 1),
#   (322, 1),
#   (323, 1),
#   (330, 1),
#   (331, 1)],
#  [(13, 1),
#   (191, 1),
#   (193, 1),
#   (211, 1),
#   (212, 1),
#   (322, 1),
#   (323, 1),
#   (331, 1),
#   (332, 1)],
#  [(13, 1), (194, 1), (211, 1), (284, 1), (332, 1), (333, 1), (334, 1)],
#  [(13, 1),
#   (121, 1),
#   (194, 1),
#   (209, 1),
#   (211, 1),
#   (231, 1),
#   (284, 1),
#   (332, 1),
#   (333, 1),
#   (334, 1)],
#  [(13, 1),
#   (121, 1),
#   (194, 1),
#   (209, 1),
#   (211, 1),
#   (231, 1),
#   (237, 1),
#   (284, 1),
#   (332, 1),
#   (333, 1),
#   (334, 1)],
#  [(25, 1),
#   (194, 1),
#   (195, 1),
#   (283, 1),
#   (284, 1),
#   (332, 1),
#   (335, 1),
#   (336, 1)],
#  [(60, 1),
#   (194, 1),
#   (249, 1),
#   (284, 1),
#   (332, 1),
#   (335, 1),
#   (336, 1),
#   (337, 1),
#   (338, 1)],
#  [(60, 1),
#   (194, 1),
#   (195, 1),
#   (198, 1),
#   (249, 1),
#   (284, 1),
#   (332, 1),
#   (335, 1),
#   (336, 1),
#   (338, 1)],
#  [(121, 1), (194, 1), (209, 1), (283, 1), (332, 1), (339, 1)],
#  [(151, 1),
#   (194, 1),
#   (330, 1),
#   (332, 1),
#   (335, 1),
#   (339, 1),
#   (340, 1),
#   (341, 1),
#   (342, 1)],
#  [(121, 1), (194, 1), (209, 1), (231, 1), (327, 1), (343, 1), (344, 1)],
#  [(195, 1), (284, 1), (327, 1), (332, 1), (343, 1), (344, 1)],
#  [(195, 1), (284, 1), (327, 1), (332, 1), (335, 1), (343, 1), (344, 1)],
#  [(44, 1),
#   (194, 1),
#   (195, 1),
#   (198, 1),
#   (323, 1),
#   (327, 1),
#   (343, 1),
#   (345, 1)],
#  [(44, 1),
#   (194, 1),
#   (195, 1),
#   (211, 1),
#   (284, 1),
#   (327, 1),
#   (330, 1),
#   (334, 1),
#   (345, 1)],
#  [(44, 1),
#   (194, 1),
#   (195, 1),
#   (211, 1),
#   (284, 1),
#   (327, 1),
#   (330, 1),
#   (334, 1),
#   (345, 1)],
#  [(194, 1),
#   (195, 1),
#   (249, 1),
#   (284, 1),
#   (332, 1),
#   (335, 1),
#   (336, 1),
#   (340, 1),
#   (341, 1),
#   (342, 1)],
#  [(195, 1), (211, 1), (315, 1), (327, 1), (346, 1), (347, 1), (348, 1)],
#  [(147, 1),
#   (195, 1),
#   (199, 1),
#   (211, 1),
#   (315, 1),
#   (327, 1),
#   (346, 1),
#   (347, 1),
#   (348, 1)],
#  [(147, 1),
#   (195, 1),
#   (199, 1),
#   (211, 1),
#   (315, 1),
#   (327, 1),
#   (348, 1),
#   (349, 1),
#   (350, 1)],
#  [(193, 1),
#   (322, 1),
#   (323, 1),
#   (325, 1),
#   (341, 1),
#   (351, 1),
#   (352, 1),
#   (353, 1)],
#  [(284, 1),
#   (322, 1),
#   (323, 1),
#   (325, 1),
#   (341, 1),
#   (351, 1),
#   (352, 1),
#   (353, 1),
#   (354, 1)],
#  [(351, 1), (354, 1), (355, 1), (356, 1), (357, 1)],
#  [(284, 1), (351, 1), (354, 1), (355, 1), (356, 1), (357, 1)],
#  [(284, 1), (299, 1), (323, 1), (351, 1), (357, 1)],
#  [(284, 1), (299, 1), (344, 1), (357, 1), (358, 1), (359, 1), (360, 1)],
#  [(284, 1), (344, 1), (357, 1), (358, 1), (359, 1), (360, 1), (361, 1)],
#  [(284, 1), (344, 1), (349, 1), (351, 1), (357, 1), (360, 1), (361, 1)],
#  [(194, 1), (327, 1), (343, 1), (344, 1), (362, 1)],
#  [(194, 1),
#   (323, 1),
#   (325, 1),
#   (351, 1),
#   (352, 1),
#   (353, 1),
#   (354, 1),
#   (363, 1),
#   (364, 1)],
#  [(194, 1),
#   (322, 1),
#   (323, 1),
#   (325, 1),
#   (341, 1),
#   (351, 1),
#   (352, 1),
#   (353, 1)],
#  [(194, 1), (323, 1), (325, 1), (326, 1), (327, 1), (328, 1), (352, 1)],
#  [(194, 1), (325, 1), (349, 1), (352, 1)],
#  [(194, 1), (325, 1), (352, 1), (362, 1)],
#  [(194, 1), (315, 1), (325, 1), (352, 1)],
#  [(194, 1),
#   (325, 1),
#   (351, 1),
#   (352, 1),
#   (353, 1),
#   (354, 1),
#   (363, 1),
#   (364, 1)],
#  [(8, 1), (195, 1), (202, 1), (242, 1), (245, 1), (251, 1)],
#  [(48, 1), (202, 1), (249, 1), (284, 1), (365, 1), (366, 1)],
#  [(202, 1), (249, 1), (281, 1), (284, 1), (365, 1), (366, 1)],
#  [(21, 1),
#   (212, 1),
#   (256, 1),
#   (260, 1),
#   (281, 1),
#   (365, 1),
#   (367, 1),
#   (368, 1),
#   (369, 1)],
#  [(21, 1), (249, 1), (256, 1), (281, 1), (365, 1), (368, 1), (370, 1)],
#  [(21, 1), (256, 1), (281, 1), (365, 1), (368, 1)],
#  [(48, 1), (195, 1), (202, 1), (245, 1), (370, 1)],
#  [(249, 1), (303, 1), (362, 1), (370, 1)],
#  [(194, 1), (371, 1), (372, 1)],
#  [(194, 1), (371, 1), (372, 1)],
#  [(373, 1), (374, 1)],
#  [],
#  [(375, 1)],
#  [(25, 1), (323, 1), (376, 1)],
#  [(25, 1), (323, 1)],
#  [(121, 1), (194, 1), (247, 1), (329, 1), (334, 1)],
#  [(121, 1), (155, 1), (194, 1), (202, 1), (247, 1), (373, 1), (377, 1)],
#  [(25, 1), (121, 1), (194, 1), (247, 1), (334, 1), (378, 1)],
#  [(25, 1), (121, 1), (194, 1), (214, 1), (247, 1), (334, 1)],
#  [(25, 2), (121, 1), (194, 1), (237, 1), (247, 1), (373, 1)],
#  [(121, 1),
#   (155, 1),
#   (194, 1),
#   (215, 1),
#   (231, 1),
#   (247, 1),
#   (334, 1),
#   (379, 1),
#   (380, 1)],
#  [(25, 1),
#   (121, 1),
#   (155, 1),
#   (194, 1),
#   (247, 1),
#   (334, 1),
#   (379, 1),
#   (380, 1)],
#  [(25, 1), (121, 1), (155, 1), (194, 1), (247, 1), (373, 1)],
#  [(121, 1), (194, 1), (215, 1), (231, 1), (247, 1), (352, 1)],
#  [(80, 1), (194, 1), (214, 1), (276, 1), (373, 1), (374, 1), (379, 1)],
#  [(121, 1), (194, 1), (214, 1), (247, 1), (334, 1), (373, 1), (376, 1)],
#  [(24, 1), (25, 2), (121, 1), (194, 1), (247, 1), (373, 1)],
#  [(24, 1), (25, 1), (121, 1), (194, 1), (247, 1), (373, 1), (377, 1)],
#  [(24, 1), (25, 1), (121, 1), (194, 1), (247, 1), (373, 1), (381, 1)],
#  [(25, 1), (38, 1), (121, 1), (194, 2), (247, 1), (327, 1)],
#  [(121, 1), (194, 1), (247, 1), (327, 1), (329, 1)],
#  [(80, 1), (194, 1), (276, 1), (373, 1), (376, 1), (382, 1), (383, 1)],
#  [(24, 1), (73, 1), (371, 1), (383, 1)],
#  [(24, 1), (73, 1), (373, 1), (383, 1)],
#  [(24, 1), (25, 1), (373, 1), (383, 1)],
#  [(24, 1), (194, 1), (371, 1)],
#  [(194, 1), (327, 1)],
#  [(24, 1), (194, 1), (371, 1)],
#  [(24, 1), (194, 1), (371, 1)],
#  [(24, 1), (194, 1), (371, 1), (384, 1)],
#  [(24, 1), (194, 1), (371, 1)],
#  [(372, 1), (373, 1)],
#  [(24, 1), (373, 1)],
#  [(372, 1), (373, 1)],
#  [(24, 1), (373, 1)],
#  [(193, 1), (284, 1), (385, 1)],
#  [(194, 1), (284, 1), (354, 1), (385, 1), (386, 1)],
#  [(193, 1), (194, 1), (198, 1), (385, 1), (386, 1)],
#  [(73, 1), (193, 1), (194, 1), (387, 1)],
#  [(194, 1), (280, 1), (337, 1), (388, 1)],
#  [(62, 1), (84, 1), (194, 1), (247, 1), (379, 1), (388, 1), (389, 1)],
#  [(62, 1), (230, 1), (247, 1), (379, 1), (388, 1), (390, 1), (391, 1)],
#  [(62, 1),
#   (84, 1),
#   (194, 1),
#   (247, 1),
#   (370, 1),
#   (379, 1),
#   (389, 1),
#   (390, 1),
#   (391, 1)],
#  [(8, 1), (84, 1), (194, 1), (241, 1), (388, 1), (392, 1), (393, 1)],
#  [(8, 1), (84, 1), (194, 1), (230, 1), (388, 1), (392, 1), (393, 1)],
#  [(194, 1), (226, 1), (237, 1), (394, 1)],
#  [(194, 1), (226, 1), (237, 1), (303, 1), (387, 1), (394, 1)],
#  [(194, 1), (226, 1), (237, 1), (261, 1), (387, 1), (394, 1)],
#  [(25, 1), (194, 1), (284, 1), (354, 1), (387, 1), (395, 1)],
#  [(121, 1), (151, 1), (173, 1), (194, 1), (209, 1)],
#  [(151, 1), (173, 1), (194, 1), (209, 1), (294, 1), (396, 1)],
#  [(194, 1), (397, 1)],
#  [(194, 1), (202, 1), (214, 1), (398, 1)],
#  [(399, 1)],
#  [(397, 1)],
#  [(25, 1), (121, 1), (194, 1), (247, 1), (400, 1)],
#  [(121, 1), (126, 1), (194, 1), (231, 1), (247, 1)],
#  [(25, 1), (121, 1), (194, 1), (247, 1), (398, 1), (401, 1)],
#  [(25, 1), (151, 1), (194, 1), (376, 1), (398, 1), (401, 1)],
#  [(25, 1),
#   (121, 1),
#   (151, 1),
#   (194, 1),
#   (209, 1),
#   (376, 1),
#   (398, 1),
#   (401, 1)],
#  [(121, 1), (194, 1), (215, 1), (231, 1), (237, 1), (247, 1), (402, 1)],
#  [(121, 1), (194, 1), (202, 1), (215, 1), (231, 1), (247, 1), (402, 1)],
#  [(194, 1), (398, 1)],
#  [(151, 1), (194, 1), (397, 1)],
#  [(173, 1), (194, 1), (214, 1)],
#  [(25, 2), (121, 1), (194, 1), (247, 1), (373, 1), (403, 1)],
#  [(25, 2), (121, 1), (194, 1), (247, 1), (402, 2), (403, 1)],
#  [(25, 1), (121, 1), (194, 1), (247, 1), (402, 2)],
#  [(25, 1), (121, 1), (194, 1), (247, 2), (386, 1)],
#  [(13, 1), (25, 1), (121, 1), (194, 1), (209, 1), (400, 1)],
#  [(13, 1), (25, 1), (121, 1), (194, 1), (209, 1), (404, 1)],
#  [(25, 1), (155, 1), (194, 1), (202, 1), (405, 1), (406, 1)],
#  [(121, 1), (173, 1), (194, 1), (209, 1), (214, 1), (274, 1), (406, 1)],
#  [(121, 1), (173, 1), (194, 1), (209, 1), (214, 1), (405, 1)],
#  [(194, 1), (214, 1), (237, 1), (398, 1)],
#  [(194, 1), (209, 1)],
#  [(121, 1), (194, 1), (209, 1), (215, 1)],
#  [(121, 1), (194, 1), (209, 1), (407, 1)],
#  [(194, 1)],
#  [(121, 1), (194, 1), (209, 1), (408, 1)],
#  [(121, 1), (194, 1), (209, 1), (409, 1)],
#  [(172, 1), (194, 1)],
#  [(172, 1), (194, 1), (209, 1)],
#  [(194, 1), (209, 1), (212, 1), (274, 1), (409, 1), (410, 1), (411, 1)],
#  [(121, 1), (194, 1), (195, 1), (209, 1), (215, 1), (255, 1), (412, 1)],
#  [(121, 1), (194, 1), (209, 1), (215, 1), (275, 1)],
#  [(121, 1), (172, 1), (194, 1), (209, 1), (215, 1), (271, 1)],
#  [(121, 1), (172, 1), (194, 1), (209, 1), (215, 1)],
#  [(194, 1), (340, 1), (413, 1), (414, 1)],
#  [(121, 1), (194, 1), (207, 1), (215, 1), (247, 1), (410, 1), (415, 1)],
#  [(121, 1), (151, 1), (194, 1), (247, 1), (340, 1), (415, 1)],
#  [(21, 1),
#   (100, 1),
#   (121, 1),
#   (194, 1),
#   (215, 1),
#   (247, 1),
#   (250, 1),
#   (256, 1),
#   (368, 1)],
#  [(121, 1), (194, 1), (209, 1)],
#  [(121, 1), (194, 1)],
#  [(194, 1)],
#  [(121, 1), (194, 1), (209, 1)],
#  [(194, 1)],
#  [(194, 1), (209, 1)],
#  [(22, 1), (121, 1), (194, 1)],
#  [(121, 1), (209, 1), (215, 1)],
#  [(215, 1)],
#  [(73, 1), (408, 1)],
#  [(194, 1), (408, 1)],
#  [(8, 1), (193, 1), (194, 1), (416, 1), (417, 1)],
#  [(8, 1), (13, 1), (136, 1), (194, 1), (255, 1), (257, 1), (376, 1), (418, 1)],
#  [(25, 1),
#   (37, 1),
#   (194, 1),
#   (231, 1),
#   (376, 1),
#   (416, 1),
#   (418, 1),
#   (419, 1)],
#  [(8, 1),
#   (194, 1),
#   (209, 1),
#   (212, 1),
#   (231, 1),
#   (237, 1),
#   (269, 1),
#   (366, 1)],
#  [(8, 1), (194, 1), (209, 1), (231, 1), (269, 1), (366, 1), (418, 1)],
#  [(8, 1),
#   (121, 1),
#   (194, 1),
#   (202, 1),
#   (209, 1),
#   (215, 1),
#   (231, 1),
#   (416, 1),
#   (420, 1)],
#  [(194, 1), (210, 1), (211, 1), (212, 1), (231, 1), (416, 1)],
#  [(194, 1), (231, 1), (416, 1)],
#  [(48, 1), (194, 1), (231, 1), (237, 1)],
#  [(194, 1), (210, 1), (211, 1), (212, 1), (253, 1), (421, 1)],
#  [(210, 1), (253, 1), (421, 1)],
#  [(194, 1), (252, 1), (253, 1), (416, 1), (422, 1)],
#  [(194, 1), (253, 1), (416, 1), (422, 1)],
#  [(280, 1), (326, 1), (416, 1), (423, 1), (424, 1), (425, 1)],
#  [(8, 1), (194, 1), (202, 1), (231, 1), (416, 1), (420, 1)],
#  [(194, 1), (349, 1), (419, 1), (426, 1), (427, 1), (428, 1)],
#  [(194, 1), (419, 1), (426, 1), (427, 1), (428, 1), (429, 1)],
#  [(194, 1), (234, 1), (280, 1), (423, 1), (425, 1)],
#  [(194, 1), (422, 1)],
#  [(194, 1), (209, 1), (215, 1), (280, 1), (423, 1)],
#  [(48, 1), (194, 1), (215, 1), (241, 1), (280, 1), (423, 1)],
#  [(121, 1),
#   (194, 1),
#   (209, 1),
#   (215, 1),
#   (253, 1),
#   (304, 1),
#   (423, 1),
#   (430, 1)],
#  [(121, 1),
#   (194, 1),
#   (209, 1),
#   (215, 1),
#   (304, 1),
#   (420, 1),
#   (423, 1),
#   (430, 1)],
#  [(194, 1), (419, 1), (431, 1)],
#  [(48, 1), (60, 1), (155, 1), (194, 1), (237, 1)],
#  [(38, 1),
#   (63, 1),
#   (121, 1),
#   (194, 1),
#   (202, 1),
#   (215, 1),
#   (247, 1),
#   (421, 1),
#   (432, 1),
#   (433, 1)],
#  [(38, 1),
#   (63, 1),
#   (121, 1),
#   (194, 1),
#   (202, 1),
#   (215, 1),
#   (247, 1),
#   (432, 1),
#   (433, 1),
#   (434, 1)],
#  [(48, 1), (155, 1), (194, 1), (202, 1), (255, 1)],
#  [(194, 1), (202, 1), (255, 1), (416, 1)],
#  [(8, 1), (194, 1), (255, 1), (416, 1), (417, 1)],
#  [(194, 1), (222, 1), (257, 1), (435, 1)],
#  [(140, 1), (435, 1)],
#  [(140, 1), (194, 1), (350, 1)],
#  [(133, 1), (194, 1), (436, 1)],
#  [(24, 1), (158, 1), (437, 1)],
#  [(24, 1), (25, 1), (158, 1), (194, 1), (436, 1)],
#  [(24, 1), (150, 1), (158, 1), (194, 1)],
#  [(24, 1), (25, 1), (133, 1), (158, 1), (194, 1), (414, 1)],
#  [(140, 1), (194, 1), (350, 1)],
#  [(24, 1), (25, 1), (133, 1), (158, 1), (194, 1), (414, 1)],
#  [(158, 1), (414, 1), (437, 1)],
#  [(25, 1), (194, 1), (350, 1), (435, 1)],
#  [(24, 1), (194, 1), (436, 1), (438, 1), (439, 1), (440, 1)],
#  [(24, 1), (158, 1), (194, 1), (438, 1), (439, 1), (440, 1), (441, 1)],
#  [(24, 1), (158, 1), (194, 1), (438, 1), (440, 1), (441, 1)],
#  [(24, 1), (158, 1), (194, 1), (438, 1), (440, 1), (441, 1)],
#  [(24, 1), (158, 1), (194, 1), (377, 1)],
#  [(133, 1), (169, 1), (194, 1)],
#  [(169, 1), (194, 1), (219, 1)],
#  [(25, 1), (183, 1), (194, 1)],
#  [(38, 1), (121, 1), (194, 1), (247, 1), (279, 1)],
#  [(38, 1), (121, 1), (194, 1), (247, 1), (377, 1)],
#  [(38, 1), (121, 1), (194, 1), (215, 1), (247, 1), (442, 1)],
#  [(121, 1), (194, 1), (247, 1), (279, 1), (443, 1)],
#  [(121, 1), (194, 1), (247, 1), (279, 1)],
#  [(25, 1), (38, 1), (194, 1)],
#  [(60, 1), (121, 1), (194, 1), (207, 1), (209, 1), (215, 1)],
#  [(60, 1), (121, 1), (194, 1), (247, 1), (279, 1)],
#  [(60, 1), (121, 1), (194, 1), (247, 1), (377, 1)],
#  [(121, 1), (194, 1), (247, 1), (437, 1), (444, 1)],
#  [(38, 1), (121, 1), (194, 1), (202, 1), (209, 1)],
#  [(38, 1), (121, 1), (202, 1), (209, 1), (219, 1)],
#  [(38, 1), (121, 1), (194, 1), (202, 1), (209, 1), (377, 1)],
#  [],
#  [(121, 1), (194, 1), (209, 1), (445, 1)],
#  [(60, 1), (121, 1), (155, 1), (194, 1), (209, 1), (440, 1)],
#  [(38, 1), (194, 1), (209, 1), (279, 1)],
#  [(121, 1), (155, 1), (194, 1), (209, 1), (377, 1), (446, 1)],
#  [(121, 1), (194, 1), (247, 1), (377, 1), (446, 1)],
#  [(121, 1), (155, 1), (194, 1), (247, 1), (277, 1), (377, 1)],
#  [(8, 1), (13, 1), (121, 1), (194, 1), (247, 1), (377, 1)],
#  [(44, 1), (121, 1), (194, 1), (247, 1), (377, 1), (395, 1)],
#  [(194, 1), (377, 1), (443, 1)],
#  [(124, 1), (194, 1), (250, 1), (277, 1), (378, 1)],
#  [(167, 1), (194, 1), (378, 1)],
#  [(121, 1), (194, 1), (209, 1), (279, 1)],
#  [(165, 1), (194, 1), (209, 1), (260, 1), (377, 1), (418, 1)],
#  [(165, 1), (194, 1), (209, 1), (260, 1), (377, 1), (418, 1)],
#  [(109, 1),
#   (124, 1),
#   (194, 1),
#   (212, 1),
#   (260, 1),
#   (279, 1),
#   (367, 1),
#   (418, 1)],
#  [(25, 1),
#   (124, 1),
#   (194, 1),
#   (212, 1),
#   (260, 1),
#   (279, 1),
#   (367, 1),
#   (418, 1)],
#  [(25, 1), (194, 1), (209, 1), (237, 1), (367, 1)],
#  [(25, 2), (155, 1), (194, 1), (202, 1), (209, 1), (338, 1), (367, 1)],
#  [(25, 1), (155, 1), (194, 1), (212, 1), (260, 1), (367, 1), (418, 1)],
#  [(25, 1), (155, 1), (194, 1), (237, 1), (367, 1)],
#  [(60, 1), (194, 1), (219, 1)],
#  [(194, 1), (437, 1), (444, 1)],
#  [(155, 1), (216, 1)],
#  [(38, 1)],
#  [(60, 1)],
#  [(244, 1)],
#  [(133, 1), (167, 1), (194, 1)],
#  [(136, 1), (280, 1), (340, 1), (354, 1), (370, 1), (404, 1), (447, 1)],
#  [(67, 1), (193, 1), (213, 1), (448, 1), (449, 1)],
#  [(67, 1), (195, 1), (196, 1), (213, 1), (299, 1), (448, 1), (449, 1)],
#  [(193, 1), (237, 1), (250, 1), (271, 1), (450, 1)],
#  [(193, 1), (237, 1), (250, 1), (261, 1), (450, 1)],
#  [(25, 1),
#   (183, 1),
#   (194, 1),
#   (238, 1),
#   (280, 1),
#   (292, 1),
#   (354, 1),
#   (447, 1),
#   (451, 1)],
#  [(25, 2),
#   (183, 1),
#   (194, 1),
#   (209, 1),
#   (280, 1),
#   (294, 1),
#   (354, 1),
#   (447, 1),
#   (451, 1),
#   (452, 1)],
#  [(193, 1), (209, 1), (280, 1), (294, 1), (354, 1), (447, 1), (451, 1)],
#  [(280, 1), (354, 1), (447, 1), (451, 1)],
#  [(280, 1), (354, 1), (447, 1), (451, 1)],
#  [(237, 1), (404, 1)],
#  [(404, 1), (418, 1)],
#  [(362, 1), (453, 1), (454, 1)],
#  [(136, 1), (193, 1), (280, 1), (453, 1), (454, 1), (455, 1)],
#  [(136, 1), (280, 1), (453, 1), (454, 1), (455, 1)],
#  [(136, 1), (261, 1), (280, 1), (453, 1), (454, 1), (455, 1)],
#  [(194, 1), (280, 1), (340, 1), (404, 1), (456, 1), (457, 1)],
#  [(194, 1), (280, 1), (453, 1), (458, 1), (459, 1)],
#  [(194, 1), (280, 1), (292, 1), (404, 1)],
#  [(194, 1), (458, 1), (460, 1)],
#  [(194, 1), (237, 1)],
#  [(194, 1), (461, 1)],
#  [(194, 1), (461, 1)],
#  [(24, 2), (158, 1), (362, 1), (460, 1)],
#  [(24, 2), (158, 1), (362, 1), (459, 1)],
#  [(194, 1), (280, 1), (292, 1), (404, 1), (456, 1), (457, 1)],
#  [(194, 1), (280, 1), (299, 1), (453, 1)],
#  [(194, 1), (280, 1), (453, 1), (454, 1), (458, 1)],
#  [],
#  [(454, 1)],
#  [(193, 1)],
#  [(193, 1), (462, 1), (463, 1)],
#  [(193, 1), (463, 1), (464, 1)],
#  [(193, 1), (465, 1)],
#  [(176, 1), (193, 1)],
#  [(193, 1), (466, 1)],
#  [(193, 1)],
#  [(193, 1)],
#  [(193, 1)],
#  [(193, 1), (383, 1)],
#  [(193, 1), (240, 1), (431, 1)],
#  [(121, 1), (194, 1), (209, 1), (292, 1)],
#  [(121, 1), (194, 1), (209, 1), (247, 1), (324, 1), (413, 1), (467, 1)],
#  [(121, 1), (194, 1), (209, 1), (247, 1), (413, 1), (468, 1)],
#  [(121, 1), (194, 1), (209, 1), (247, 1), (467, 1), (468, 1)],
#  [(121, 1), (194, 1), (247, 1), (410, 1), (469, 1), (470, 1)],
#  [(121, 1), (194, 1), (247, 1), (410, 1), (469, 1), (470, 1)],
#  [(22, 1), (194, 1), (237, 1), (247, 1), (255, 1)],
#  [(121, 1), (141, 1), (194, 1), (209, 1), (247, 1), (468, 1), (471, 1)],
#  [(35, 1), (121, 1), (194, 1), (209, 1), (247, 1), (468, 1), (471, 1)],
#  [(231, 1), (472, 1)],
#  [(22, 1),
#   (79, 1),
#   (121, 1),
#   (193, 1),
#   (194, 1),
#   (209, 1),
#   (237, 1),
#   (247, 1),
#   (248, 1),
#   (255, 1)],
#  [(22, 1),
#   (121, 1),
#   (194, 1),
#   (195, 1),
#   (197, 1),
#   (209, 1),
#   (247, 1),
#   (255, 1),
#   (284, 1)],
#  [(121, 1),
#   (194, 1),
#   (195, 1),
#   (197, 1),
#   (209, 1),
#   (247, 1),
#   (255, 1),
#   (284, 1)],
#  [(121, 1), (194, 1), (197, 1), (209, 1), (247, 1), (273, 1), (284, 1)],
#  [(472, 1), (473, 1)],
#  [(194, 1), (214, 1), (474, 1)],
#  [(194, 1), (214, 1)],
#  [(194, 1), (214, 1), (475, 1)],
#  [(151, 1), (476, 1)],
#  [(214, 1), (477, 1)],
#  [(124, 1), (214, 1), (472, 1)],
#  [(124, 1), (214, 1), (478, 1)],
#  [(194, 1), (247, 1), (467, 1), (468, 1)],
#  [(194, 1), (247, 1), (413, 1), (468, 1)],
#  [(194, 1), (209, 1)],
#  [(22, 1),
#   (121, 1),
#   (194, 1),
#   (209, 1),
#   (247, 1),
#   (315, 1),
#   (410, 1),
#   (469, 1)],
#  [(22, 1),
#   (33, 1),
#   (121, 1),
#   (171, 1),
#   (194, 1),
#   (209, 1),
#   (247, 1),
#   (469, 1),
#   (479, 1)],
#  [(22, 1),
#   (33, 1),
#   (121, 1),
#   (171, 1),
#   (194, 1),
#   (209, 1),
#   (247, 1),
#   (469, 1),
#   (479, 1)],
#  [(22, 1), (79, 1), (194, 1), (209, 1), (231, 1), (237, 1), (247, 1)],
#  [(121, 1), (194, 1), (209, 1), (237, 1), (247, 1), (255, 1), (396, 1)],
#  [(38, 1),
#   (121, 1),
#   (194, 1),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (243, 1),
#   (247, 1),
#   (410, 1),
#   (480, 1)],
#  [(38, 1),
#   (121, 1),
#   (193, 1),
#   (194, 1),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (243, 1),
#   (247, 1),
#   (271, 1),
#   (410, 1),
#   (480, 1)],
#  [(121, 1),
#   (193, 1),
#   (194, 1),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (243, 1),
#   (247, 2),
#   (271, 1)],
#  [(13, 1),
#   (38, 1),
#   (121, 1),
#   (193, 1),
#   (194, 1),
#   (195, 1),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (247, 1),
#   (271, 1),
#   (410, 1),
#   (480, 1),
#   (481, 1)],
#  [(13, 1),
#   (38, 1),
#   (121, 1),
#   (194, 1),
#   (195, 1),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (247, 1),
#   (249, 1),
#   (410, 1),
#   (480, 1),
#   (481, 1)],
#  [(22, 1),
#   (38, 1),
#   (121, 1),
#   (194, 1),
#   (195, 1),
#   (247, 1),
#   (255, 1),
#   (368, 1),
#   (410, 1),
#   (480, 1)],
#  [(13, 1),
#   (38, 1),
#   (121, 1),
#   (193, 1),
#   (194, 1),
#   (247, 1),
#   (248, 1),
#   (410, 1),
#   (480, 1),
#   (481, 1)],
#  [(13, 1), (121, 1), (193, 1), (194, 1), (247, 2), (248, 1), (481, 1)],
#  [(13, 1), (121, 1), (194, 1), (195, 1), (247, 2), (248, 1), (481, 1)],
#  [(121, 1), (194, 1), (247, 2), (413, 1), (467, 1), (477, 1)],
#  [(473, 1), (478, 1)],
#  [(231, 1), (478, 1)],
#  [(474, 1)],
#  [(25, 1), (474, 1)],
#  [(25, 1), (376, 1)],
#  [(475, 1)],
#  [(194, 1), (476, 1)],
#  [(194, 1), (476, 1)],
#  [(25, 1), (482, 1), (483, 1)],
#  [(482, 1), (483, 1)],
#  [(475, 1), (483, 1)],
#  [(194, 1), (476, 1), (483, 1)],
#  [(63, 1), (194, 1), (217, 1), (476, 1)],
#  [(476, 1), (483, 1)],
#  [(194, 1), (214, 1), (475, 1)],
#  [(194, 1), (476, 1)],
#  [(194, 1), (476, 1)],
#  [(194, 1), (482, 1), (483, 1)],
#  [(22, 1), (194, 1), (240, 1), (410, 1), (469, 1)],
#  [(22, 1), (194, 1), (410, 1), (469, 1), (484, 1)],
#  [(44, 1),
#   (132, 1),
#   (134, 1),
#   (194, 1),
#   (303, 1),
#   (455, 1),
#   (485, 1),
#   (486, 1),
#   (487, 1)],
#  [(194, 1), (212, 1), (260, 1), (410, 1), (411, 1), (484, 1)],
#  [(135, 1), (194, 1), (260, 1), (411, 1), (488, 1)],
#  [(209, 1), (410, 1), (411, 1), (489, 1)],
#  [(274, 1), (410, 1), (411, 1)],
#  [(44, 1), (132, 1), (134, 1), (194, 1), (485, 1), (486, 1), (487, 1)],
#  [(44, 1),
#   (132, 1),
#   (134, 1),
#   (194, 1),
#   (284, 1),
#   (354, 1),
#   (455, 1),
#   (485, 1),
#   (486, 1),
#   (487, 1)],
#  [(22, 1),
#   (44, 1),
#   (132, 1),
#   (134, 1),
#   (194, 1),
#   (209, 1),
#   (410, 1),
#   (487, 1)],
#  [(22, 1), (44, 1), (132, 1), (134, 1), (194, 1), (209, 1), (413, 1)],
#  [(22, 1), (410, 1), (469, 1), (490, 1)],
#  [(22, 1), (240, 1), (410, 1), (469, 1), (490, 1)],
#  [(22, 1), (410, 1), (469, 1), (490, 1), (491, 1)],
#  [(22, 1), (194, 1), (240, 1), (410, 1), (469, 1), (490, 1)],
#  [(194, 1), (212, 1), (410, 1), (469, 1), (490, 1), (491, 1)],
#  [(44, 1),
#   (132, 1),
#   (134, 1),
#   (194, 1),
#   (284, 1),
#   (354, 1),
#   (455, 1),
#   (485, 1),
#   (487, 1),
#   (492, 1)],
#  [(44, 1),
#   (132, 1),
#   (134, 1),
#   (193, 1),
#   (194, 1),
#   (455, 1),
#   (485, 1),
#   (487, 1),
#   (492, 1)],
#  [(44, 1),
#   (132, 1),
#   (134, 1),
#   (193, 1),
#   (239, 1),
#   (451, 1),
#   (481, 1),
#   (487, 1)],
#  [(44, 1),
#   (132, 1),
#   (134, 1),
#   (239, 1),
#   (261, 1),
#   (284, 1),
#   (455, 1),
#   (481, 1),
#   (487, 1)],
#  [(48, 1), (193, 1), (237, 1), (241, 1), (455, 1)],
#  [(13, 1),
#   (57, 1),
#   (194, 1),
#   (274, 1),
#   (279, 1),
#   (493, 1),
#   (494, 1),
#   (495, 1)],
#  [(13, 1),
#   (57, 1),
#   (194, 1),
#   (274, 1),
#   (351, 1),
#   (377, 1),
#   (496, 1),
#   (497, 1)],
#  [(13, 1), (57, 1), (163, 1), (194, 1), (202, 1), (279, 1)],
#  [(13, 1), (57, 1), (163, 1), (194, 1), (202, 1), (377, 1)],
#  [(13, 1), (194, 1), (237, 1), (274, 1), (279, 1), (493, 1), (495, 1)],
#  [(38, 1), (57, 1), (194, 1), (274, 1), (493, 1), (494, 1), (497, 1)],
#  [(38, 1),
#   (57, 1),
#   (194, 1),
#   (202, 1),
#   (274, 1),
#   (493, 1),
#   (494, 1),
#   (497, 1)],
#  [(13, 1), (194, 1), (202, 1), (274, 1), (378, 1), (497, 1)],
#  [(13, 1), (194, 1), (274, 1), (279, 1), (497, 1)],
#  [(57, 1), (194, 1), (274, 1), (279, 1), (351, 1), (498, 1), (499, 1)],
#  [(44, 1),
#   (57, 1),
#   (194, 1),
#   (274, 1),
#   (279, 1),
#   (351, 1),
#   (498, 1),
#   (499, 1)],
#  [(168, 1), (397, 1)],
#  [(168, 1), (194, 1), (219, 1), (280, 1), (326, 1)],
#  [(168, 1), (169, 1), (174, 1), (194, 1), (278, 1), (500, 1)],
#  [(168, 1), (169, 1), (174, 1), (194, 1), (500, 1), (501, 1), (502, 1)],
#  [(25, 1), (168, 1)],
#  [(25, 1), (168, 1), (169, 1)],
#  [(168, 1), (169, 1), (174, 1), (194, 1), (279, 1), (501, 1), (502, 1)],
#  [(168, 1), (169, 1), (174, 1), (194, 1), (377, 1), (501, 1), (502, 1)],
#  [(25, 1), (155, 1), (168, 1), (194, 1), (434, 1)],
#  [(25, 1), (165, 1), (168, 1), (194, 1), (434, 1)],
#  [(25, 1), (168, 1), (194, 1), (244, 1), (434, 1)],
#  [(25, 1), (168, 1), (173, 1), (194, 1), (434, 1)],
#  [(168, 1), (169, 1), (173, 1), (174, 1), (194, 1), (500, 1)],
#  [(168, 1), (169, 1), (174, 1), (194, 1), (219, 1), (399, 1)],
#  [(168, 1), (174, 1), (178, 1), (403, 1)],
#  [(168, 1), (174, 1)],
#  [(174, 1), (503, 1), (504, 1)],
#  [(44, 1), (169, 1), (194, 1), (377, 1), (503, 1), (504, 1)],
#  [(40, 1), (168, 1), (194, 1), (377, 1), (505, 1), (506, 1), (507, 1)],
#  [(40, 1), (168, 1), (194, 1), (219, 1), (505, 1), (506, 1), (507, 1)],
#  [(155, 1), (168, 1), (194, 1), (507, 1)],
#  [(155, 1), (168, 1), (174, 1)],
#  [(114, 1), (194, 1), (362, 1), (452, 1), (508, 1)],
#  [(48, 1), (60, 1), (194, 1), (202, 1), (382, 1)],
#  [(13, 1), (25, 1), (121, 1), (194, 1), (209, 1), (377, 1)],
#  [(13, 1),
#   (121, 1),
#   (194, 1),
#   (209, 1),
#   (215, 1),
#   (221, 1),
#   (231, 1),
#   (237, 1),
#   (245, 1)],
#  [(13, 1),
#   (121, 1),
#   (194, 1),
#   (209, 1),
#   (215, 1),
#   (231, 1),
#   (237, 1),
#   (245, 1)],
#  [(13, 1), (121, 1), (194, 1), (209, 1), (377, 1)],
#  [(13, 1), (194, 1), (212, 1), (274, 1), (445, 1)],
#  [(13, 1),
#   (121, 1),
#   (194, 1),
#   (209, 1),
#   (221, 1),
#   (237, 1),
#   (245, 1),
#   (377, 1),
#   (509, 1)],
#  [(13, 1),
#   (121, 1),
#   (194, 1),
#   (209, 1),
#   (215, 1),
#   (221, 1),
#   (231, 1),
#   (245, 1),
#   (483, 1)],
#  [(13, 1), (194, 1), (237, 1), (245, 1), (279, 1)],
#  [(13, 1), (194, 1), (237, 1), (245, 1), (445, 1)],
#  [(13, 1), (194, 1), (237, 1), (245, 1), (381, 1)],
#  [(202, 1)],
#  [(237, 1)],
#  [(73, 1)],
#  [(73, 1), (275, 1)],
#  [],
#  [(13, 1), (194, 1), (202, 1), (245, 1), (377, 1)],
#  [(13, 1), (194, 1), (202, 1), (245, 1), (279, 1)],
#  [(25, 1), (121, 1), (194, 1), (209, 1), (377, 1), (510, 1), (511, 1)],
#  [(13, 1), (121, 1), (194, 1), (202, 1), (209, 1), (377, 1), (510, 1)],
#  [(38, 1), (194, 1), (202, 1), (377, 1), (511, 1)],
#  [(13, 1), (38, 1), (48, 1), (194, 1), (377, 1)],
#  [(13, 1),
#   (48, 1),
#   (60, 1),
#   (194, 1),
#   (202, 1),
#   (209, 1),
#   (215, 1),
#   (218, 1),
#   (442, 1)],
#  [(13, 1), (114, 1), (194, 1), (212, 1), (274, 1)],
#  [(13, 1), (194, 1), (202, 1), (245, 1), (279, 1)],
#  [(13, 1),
#   (121, 1),
#   (194, 1),
#   (202, 1),
#   (209, 1),
#   (214, 1),
#   (221, 1),
#   (509, 1)],
#  [(114, 1), (194, 1), (362, 1), (452, 1)],
#  [(114, 1), (194, 1), (245, 1), (362, 1), (452, 1)],
#  [(8, 1), (48, 1), (194, 1), (202, 1), (245, 1), (253, 1), (377, 1), (452, 1)],
#  [(8, 1), (48, 1), (194, 1), (202, 1), (245, 1), (377, 1), (452, 1)],
#  [(8, 1), (194, 1), (202, 1), (242, 1), (245, 1), (452, 1)],
#  [(48, 1), (155, 1), (194, 1), (214, 1), (362, 1), (452, 1), (512, 1)],
#  [(48, 1), (155, 1), (194, 1), (214, 1), (304, 1), (362, 1), (508, 1)],
#  [(48, 1), (194, 1), (202, 1), (245, 1), (377, 1), (452, 1)],
#  [(25, 1), (148, 1), (194, 1), (202, 1), (245, 1)],
#  [(194, 1), (202, 1), (245, 1), (445, 1), (452, 1)],
#  [(194, 1), (202, 1), (245, 1), (377, 1), (452, 1)],
#  [(48, 1), (194, 1), (202, 1), (214, 1), (245, 1)],
#  [(48, 1), (148, 1), (194, 1), (202, 1), (245, 1), (511, 1)],
#  [(44, 1),
#   (48, 1),
#   (194, 1),
#   (214, 1),
#   (326, 1),
#   (362, 1),
#   (508, 1),
#   (513, 1)],
#  [(194, 1), (214, 1), (326, 1), (362, 1), (457, 1), (513, 1)],
#  [(114, 1), (194, 1), (280, 1), (304, 1), (513, 1)],
#  [(114, 1), (194, 1), (245, 1), (362, 1), (513, 1)],
#  [(514, 1), (515, 1), (516, 1)],
#  [(516, 1)],
#  [(516, 1)],
#  [(516, 1), (517, 1)],
#  [(518, 1)],
#  [(518, 1)],
#  [(188, 1), (514, 1), (515, 1), (516, 1)],
#  [(516, 1), (517, 1), (519, 1)],
#  [(47, 1), (516, 1), (517, 1)],
#  [(50, 1), (86, 1), (516, 1), (517, 1)],
#  [(36, 1), (88, 1), (155, 1), (516, 1), (520, 1), (521, 1)],
#  [(9, 1), (516, 1)],
#  [(26, 1), (516, 1)],
#  [(45, 1), (516, 1)],
#  [(26, 1), (516, 1)],
#  [(6, 1), (45, 1), (516, 1)],
#  [(9, 1), (516, 1)],
#  [(41, 1), (516, 1)],
#  [(1, 1), (13, 1), (516, 1)],
#  [(9, 1)],
#  [(9, 1), (516, 1)],
#  [(26, 1), (29, 1), (88, 1), (286, 1), (516, 1), (522, 1)],
#  [(45, 1), (88, 1), (516, 1)],
#  [(5, 1), (26, 1), (94, 1), (126, 1), (516, 1)],
#  [(36, 1), (77, 1), (88, 1), (94, 1), (516, 1), (520, 1), (521, 1), (523, 1)],
#  [(36, 1), (77, 1), (94, 1), (516, 1), (524, 1), (525, 1)],
#  [(1, 1), (41, 1), (94, 1), (523, 1), (526, 1)],
#  [(26, 1), (29, 1), (39, 1), (88, 1), (516, 1), (522, 1)],
#  [(103, 1), (510, 1), (523, 1), (526, 1)],
#  [(15, 1), (103, 1), (510, 1), (523, 1), (526, 1)],
#  [(15, 1), (18, 1), (516, 1)],
#  [(27, 1), (516, 1)],
#  [(26, 1), (470, 1), (516, 1)],
#  [(27, 1), (516, 1)],
#  [(516, 1)],
#  [(257, 1), (516, 1), (527, 1)],
#  [(470, 1), (516, 1)],
#  [(516, 1), (527, 1)],
#  [(26, 1), (54, 1), (170, 1), (349, 1), (516, 1), (528, 1)],
#  [(38, 1), (48, 1), (54, 1), (516, 1), (528, 1)],
#  [(54, 1), (516, 1), (528, 1)],
#  [(54, 1), (516, 1)],
#  [(54, 1), (516, 1), (528, 1)],
#  [(54, 1), (105, 1), (516, 1)],
#  [(54, 1), (103, 1), (257, 1), (345, 1), (516, 1), (528, 1)],
#  [(54, 1), (105, 1), (345, 1), (516, 1)],
#  [(54, 1), (516, 1)],
#  [(54, 1), (516, 1), (528, 1)],
#  [(13, 1), (516, 1), (529, 1)],
#  [(516, 1), (530, 1)],
#  [(516, 1), (531, 1)],
#  [(516, 1), (531, 1)],
#  [(515, 1), (516, 1), (531, 1)],
#  [(48, 1), (155, 1), (463, 1), (516, 1), (531, 1)],
#  [(516, 1), (530, 1)],
#  [(36, 1), (463, 1), (516, 1), (531, 1)],
#  [(38, 1), (48, 1), (463, 1), (516, 1), (531, 1)],
#  [(155, 1), (184, 1), (463, 1), (516, 1), (531, 1)],
#  [(463, 1), (516, 1), (531, 1), (532, 1)],
#  [(407, 1), (516, 1), (531, 1)],
#  [(516, 1), (519, 1), (531, 1)],
#  [(47, 1), (516, 1)],
#  [(50, 1), (86, 1), (516, 1), (531, 1)],
#  [(516, 1), (519, 1)],
#  [(1, 1), (516, 1), (533, 1), (534, 1), (535, 1), (536, 1), (537, 1)],
#  [(1, 1), (516, 1), (533, 1), (535, 1), (536, 1), (538, 1), (539, 1)],
#  [(1, 1),
#   (516, 1),
#   (533, 1),
#   (534, 1),
#   (535, 1),
#   (536, 1),
#   (537, 1),
#   (538, 1),
#   (539, 1)],
#  [(516, 1), (536, 1)],
#  [(516, 1)],
#  [(463, 1), (516, 1), (540, 1), (541, 1)],
#  [(257, 1), (516, 1), (541, 1)],
#  [(516, 1), (541, 1)],
#  [(516, 1), (541, 1)],
#  [(41, 1),
#   (88, 1),
#   (516, 2),
#   (521, 1),
#   (523, 1),
#   (541, 1),
#   (542, 1),
#   (543, 1)],
#  [(13, 1),
#   (88, 1),
#   (144, 1),
#   (516, 2),
#   (521, 1),
#   (541, 1),
#   (542, 1),
#   (543, 1)],
#  [(47, 1), (516, 1), (541, 1)],
#  [(50, 1), (86, 1), (516, 1), (541, 1)],
#  [(516, 1)],
#  [(516, 1), (544, 1), (545, 1)],
#  [(407, 1), (516, 1), (544, 1), (545, 1)],
#  [(516, 1), (544, 1), (545, 1)],
#  [(245, 1), (516, 1), (546, 1), (547, 1), (548, 1), (549, 1)],
#  [(516, 1), (545, 1), (546, 1), (547, 1), (548, 1), (549, 1)],
#  [(29, 1), (30, 1), (40, 1), (516, 1), (545, 1)],
#  [(516, 1), (545, 1)],
#  [(516, 1)],
#  [(516, 1), (544, 1), (545, 1)],
#  [(104, 1), (516, 1), (545, 1), (550, 1), (551, 1), (552, 1)],
#  [(516, 1), (519, 1), (545, 1)],
#  [(47, 1), (516, 1), (545, 1)],
#  [(50, 1), (86, 1), (516, 1), (545, 1)],
#  [(516, 1), (532, 1), (553, 1)],
#  [(516, 1), (553, 1)],
#  [(516, 1), (553, 1)],
#  [(38, 1), (48, 1), (463, 1), (516, 1), (554, 1)],
#  [(516, 1)],
#  [(38, 1), (48, 1), (463, 1), (516, 1), (553, 1)],
#  [(516, 1), (554, 1)],
#  [(257, 1), (516, 1), (554, 1)],
#  [(257, 1), (516, 1), (554, 1)],
#  [(25, 1), (516, 1), (553, 1)],
#  [(516, 1), (554, 1), (555, 1)],
#  [(176, 1), (516, 1), (553, 1)],
#  [(25, 1), (516, 1), (553, 1)],
#  [(516, 1), (519, 1), (553, 1)],
#  [(47, 1), (516, 1), (553, 1)],
#  [(86, 1), (516, 1), (553, 1)],
#  [(466, 1), (516, 1)],
#  [(516, 1)],
#  [(30, 1), (146, 1), (516, 1)],
#  [(29, 1), (30, 1), (516, 1)],
#  [(516, 1)],
#  [(29, 1), (516, 1), (546, 1)],
#  [(516, 1)],
#  [(516, 1)],
#  [(176, 1), (516, 1)],
#  [(29, 1), (516, 1)],
#  [(516, 1)],
#  [(516, 1)],
#  [(516, 1)],
#  [(516, 1), (556, 1), (557, 1)],
#  [(9, 1), (516, 2)],
#  [(118, 1), (159, 1), (164, 1), (516, 1), (558, 1)],
#  [(120, 1), (516, 1), (559, 1), (560, 1)],
#  [(45, 1), (560, 1), (561, 1)],
#  [(43, 1), (88, 1), (120, 1), (154, 1)],
#  [(120, 1), (516, 1), (559, 1)],
#  [(120, 1), (159, 1), (516, 1), (559, 1)],
#  [(115, 1), (120, 1), (516, 1), (556, 1), (559, 1)],
#  [(120, 1), (516, 1), (559, 1)],
#  [(43, 1), (88, 1), (154, 1), (214, 1), (516, 1), (557, 1)],
#  [(516, 1), (562, 1)],
#  [(41, 1), (516, 1), (562, 1)],
#  [(146, 1), (562, 1)],
#  [(516, 1), (562, 1)],
#  [(13, 1), (516, 1), (523, 1), (562, 1), (563, 1)],
#  [(38, 1), (48, 1), (463, 1), (516, 1), (562, 1)],
#  [(13, 1), (25, 1), (516, 1)],
#  [(13, 1), (25, 1), (516, 1), (562, 1)],
#  [(13, 1), (516, 1), (562, 1)],
#  [(41, 1), (516, 1), (550, 1), (562, 1)],
#  [(516, 1), (564, 1)],
#  [(516, 1), (564, 1)],
#  [(516, 1), (562, 1)],
#  [(516, 1), (519, 1), (564, 1)],
#  [(47, 1), (516, 1), (564, 1)],
#  [(50, 1), (86, 1), (516, 1)],
#  [(516, 1), (565, 1)],
#  [(516, 1), (552, 1), (555, 1), (566, 1)],
#  [(13, 1), (144, 1), (151, 1), (516, 1), (565, 1)],
#  [(41, 1), (516, 1), (567, 1)],
#  [(13, 1), (110, 1), (516, 1), (567, 1)],
#  [(155, 1), (277, 1), (463, 1), (516, 1), (565, 1)],
#  [(516, 1), (565, 1)],
#  [(257, 1), (516, 1), (565, 1)],
#  [(41, 1), (516, 1), (567, 1)],
#  [(1, 1), (13, 1), (516, 1), (567, 1)],
#  [(463, 1), (464, 1), (516, 1), (565, 1)],
#  [(462, 1), (516, 1), (565, 1)],
#  [(516, 1), (519, 1), (565, 1)],
#  [(47, 1), (516, 1), (565, 1)],
#  [(50, 1), (86, 1), (516, 1), (565, 1)],
#  [(516, 1)],
#  [(516, 1), (566, 1)],
#  [(516, 1), (566, 1)],
#  [(229, 1), (351, 1), (516, 1), (521, 1), (523, 1), (568, 1), (569, 1)],
#  [(516, 1), (521, 1)],
#  [(29, 1), (39, 1), (40, 1), (516, 1), (521, 1)],
#  [(155, 1), (184, 1), (463, 1), (516, 1), (521, 1)],
#  [(516, 1), (521, 1)],
#  [(516, 1), (521, 1), (546, 1), (563, 1), (566, 1)],
#  [(175, 1), (463, 1), (521, 1), (546, 1)],
#  [(463, 1), (465, 1), (516, 1), (521, 1)],
#  [(38, 1), (48, 1), (516, 1), (521, 1)],
#  [(38, 1), (48, 1), (463, 1), (516, 1), (521, 1)],
#  [(155, 1), (184, 1), (463, 1), (516, 1), (521, 1)],
#  [(407, 1), (516, 1), (521, 1)],
#  [(516, 1), (519, 1), (521, 1)],
#  [(47, 1), (516, 1), (521, 1)],
#  [(50, 1), (86, 1), (516, 1), (521, 1)],
#  [(25, 1), (516, 1), (570, 1)],
#  [(25, 1), (516, 1), (571, 1)],
#  [(257, 1), (516, 1), (571, 1)],
#  [(63, 1), (77, 1), (516, 1), (572, 1)],
#  [(13, 1), (516, 1), (572, 1)],
#  [(516, 1), (571, 1)],
#  [(13, 1), (525, 1), (572, 1)],
#  [(63, 1), (516, 1), (570, 1)],
#  [(90, 1), (160, 1), (516, 1), (572, 1), (573, 1)],
#  [(13, 1), (90, 1), (516, 1), (572, 1)],
#  [(13, 1), (76, 1), (516, 1), (572, 1)],
#  [(25, 1), (29, 1), (516, 1), (571, 1)],
#  [(29, 1), (73, 1), (257, 1), (516, 1), (571, 1)],
#  [(25, 1), (29, 1), (416, 1), (516, 1), (571, 1)],
#  [(24, 1), (245, 1), (257, 1), (516, 1)],
#  [(245, 1), (516, 1)],
#  [(245, 1), (516, 1)],
#  [(245, 1), (516, 1)],
#  ...]

# %%
# alteração da configuração do data_, para o processado em português (por padrão o Pycaret processa em inglês)
set_config('data_', df_all)
get_config('data_')
# Out:
#                                           input     category
# 0                                         covid        covid
# 1            pego covid tocar objeto contaminar        covid
# 2                       pego covid atraves meio        covid
# 3                            onde comecar covid        covid
# 4                                    onde covid        covid
# ...                                         ...          ...
# 1194    setor meios hospedagem recomendar setor  seloturismo
# 1195       final dever realizar limpeza unidade  seloturismo
# 1196                                             seloturismo
# 1197                                   protecao  seloturismo
# 1198  orientar consumidor dar aplicar protocolo  seloturismo
#
# [1199 rows x 2 columns]

# %%
# alteração da configuração do dicionário, para o processado em português (por padrão o Pycaret processa em inglês)
set_config('id2word', dictionary)
d = get_config('id2word')
print(d)
# Out:
# Dictionary<657 unique tokens: ['covid', 'contaminar', 'objeto', 'pego', 'tocar']...>

# %%
# modelos disponíveis no Pycaret
models()
# Out:
#                                   Name                  Reference
# ID
# lda        Latent Dirichlet Allocation     gensim/models/ldamodel
# lsi           Latent Semantic Indexing     gensim/models/lsimodel
# hdp     Hierarchical Dirichlet Process     gensim/models/hdpmodel
# rp                  Random Projections      gensim/models/rpmodel
# nmf  Non-Negative Matrix Factorization  sklearn.decomposition.NMF

# %%
# Latent Dirichlet Allocation
lda = create_model('lda', num_topics=3, multi_core=True)
print(lda)
# Out:
# LdaMulticore<num_terms=657, num_topics=3, decay=0.5, chunksize=100>

# %%
# Latent Semantic Indexing
# aparentemente algum erro no pacote
lsi = create_model('lsi', num_topics=3, multi_core=True)
print(lsi)
# Out:
# LsiModel<num_terms=657, num_topics=3, decay=1.0, chunksize=20000>

# %%
# Hierarchical Dirichlet Process
hdp = create_model('hdp', num_topics=3, multi_core=True)
print(hdp)
# Out:
# <gensim.models.hdpmodel.HdpModel object at 0x000002CDF32D5850>

# %%
# Random Projections
rp = create_model('rp', num_topics=3, multi_core=True)
print(rp)
# Out:
# RpModel<num_terms=657, num_topics=3>

# %%
# Non-Negative Matrix Factorization
nmf = create_model('nmf', num_topics=3, multi_core=True)
print(nmf)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init='nndsvd', l1_ratio=0.0, max_iter=200,
#     n_components=3, random_state=1503, shuffle=False, solver='cd', tol=0.0001,
#     verbose=0)

# %%
# Avaliação do modelo
evaluate_model(lda)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Frequency Plot', 'freque…

# %%
# Avaliação do modelo
#evaluate_model(lsi)

# %%
# Avaliação do modelo
evaluate_model(hdp)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Frequency Plot', 'freque…

# %%
# Avaliação do modelo
evaluate_model(rp)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Frequency Plot', 'freque…

# %%
# Avaliação do modelo
evaluate_model(nmf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Frequency Plot', 'freque…

# %%
# Resultados do modelo
lda_results = assign_model(lda)
lda_results
# Out:
#                                           input     category   Topic_0  \
# 0                                         covid        covid  0.185142
# 1            pego covid tocar objeto contaminar        covid  0.057223
# 2                       pego covid atraves meio        covid  0.068073
# 3                            onde comecar covid        covid  0.085708
# 4                                    onde covid        covid  0.115830
# ...                                         ...          ...       ...
# 1194    setor meios hospedagem recomendar setor  seloturismo  0.055598
# 1195       final dever realizar limpeza unidade  seloturismo  0.825220
# 1196                                             seloturismo  0.333333
# 1197                                   protecao  seloturismo  0.166773
# 1198  orientar consumidor dar aplicar protocolo  seloturismo  0.058702
#
#        Topic_1   Topic_2 Dominant_Topic  Perc_Dominant_Topic
# 0     0.648167  0.166691        Topic 1                 0.65
# 1     0.887099  0.055678        Topic 1                 0.89
# 2     0.865104  0.066822        Topic 1                 0.87
# 3     0.830843  0.083449        Topic 1                 0.83
# 4     0.773017  0.111153        Topic 1                 0.77
# ...        ...       ...            ...                  ...
# 1194  0.888786  0.055616        Topic 1                 0.89
# 1195  0.056066  0.118714        Topic 0                 0.83
# 1196  0.333333  0.333333        Topic 0                 0.33
# 1197  0.666357  0.166870        Topic 1                 0.67
# 1198  0.881355  0.059944        Topic 1                 0.88
#
# [1199 rows x 7 columns]

# %%
# Resultados do modelo
#lsi_results = assign_model(lsi)
#lsi_results

# %%
# Resultados do modelo
hdp_results = assign_model(hdp)
hdp_results
# Out:
#                                           input     category   Topic_0  \
# 0                                         covid        covid  0.164791
# 1            pego covid tocar objeto contaminar        covid  0.297691
# 2                       pego covid atraves meio        covid  0.076817
# 3                            onde comecar covid        covid  0.640749
# 4                                    onde covid        covid  0.128802
# ...                                         ...          ...       ...
# 1194    setor meios hospedagem recomendar setor  seloturismo  0.853460
# 1195       final dever realizar limpeza unidade  seloturismo  0.862665
# 1196                                             seloturismo       NaN
# 1197                                   protecao  seloturismo  0.172949
# 1198  orientar consumidor dar aplicar protocolo  seloturismo  0.056799
#
#        Topic_1   Topic_2 Dominant_Topic
# 0     0.644363  0.190846        Topic 1
# 1     0.472568  0.229741        Topic 1
# 2     0.345622  0.577561        Topic 2
# 3     0.264275  0.094977        Topic 0
# 4     0.748667  0.122531        Topic 1
# ...        ...       ...            ...
# 1194  0.070993  0.075547        Topic 0
# 1195  0.074345  0.062991        Topic 0
# 1196       NaN       NaN            NaN
# 1197  0.604878  0.222173        Topic 1
# 1198  0.869537  0.073664        Topic 1
#
# [1199 rows x 6 columns]

# %%
# Resultados do modelo
rp_results = assign_model(rp)
rp_results
# Out:
#                                           input     category   Topic_0  \
# 0                                         covid        covid  0.577350
# 1            pego covid tocar objeto contaminar        covid  0.577350
# 2                       pego covid atraves meio        covid -1.154701
# 3                            onde comecar covid        covid  0.577350
# 4                                    onde covid        covid  1.154701
# ...                                         ...          ...       ...
# 1194    setor meios hospedagem recomendar setor  seloturismo -0.577350
# 1195       final dever realizar limpeza unidade  seloturismo -0.577350
# 1196                                             seloturismo       NaN
# 1197                                   protecao  seloturismo  0.577350
# 1198  orientar consumidor dar aplicar protocolo  seloturismo  0.577350
#
#        Topic_1   Topic_2 Dominant_Topic
# 0     0.577350 -0.577350        Topic 0
# 1     0.577350  0.577350        Topic 0
# 2     0.000000 -1.154701        Topic 1
# 3     1.732051 -0.577350        Topic 1
# 4     1.154701 -1.154701        Topic 0
# ...        ...       ...            ...
# 1194  0.577350  1.732051        Topic 2
# 1195 -0.577350 -1.732051        Topic 0
# 1196       NaN       NaN            NaN
# 1197  0.577350  0.577350        Topic 0
# 1198 -0.577350  1.732051        Topic 2
#
# [1199 rows x 6 columns]

# %%
# Resultados do modelo
nmf_results = assign_model(nmf)
nmf_results
# Out:
#                                           input     category   Topic_0  \
# 0                                         covid        covid  0.000000
# 1            pego covid tocar objeto contaminar        covid  0.000000
# 2                       pego covid atraves meio        covid  0.000000
# 3                            onde comecar covid        covid  0.000000
# 4                                    onde covid        covid  0.000000
# ...                                         ...          ...       ...
# 1194    setor meios hospedagem recomendar setor  seloturismo  0.000000
# 1195       final dever realizar limpeza unidade  seloturismo  0.000066
# 1196                                             seloturismo  0.000000
# 1197                                   protecao  seloturismo  0.000000
# 1198  orientar consumidor dar aplicar protocolo  seloturismo  0.000000
#
#        Topic_1   Topic_2 Dominant_Topic  Perc_Dominant_Topic
# 0     0.473615  0.000000        Topic 1                 1.00
# 1     0.058017  0.000000        Topic 1                 1.00
# 2     0.073348  0.000000        Topic 1                 1.00
# 3     0.117244  0.001173        Topic 1                 0.99
# 4     0.206631  0.002319        Topic 1                 0.99
# ...        ...       ...            ...                  ...
# 1194  0.000000  0.009162        Topic 2                 1.00
# 1195  0.001263  0.001381        Topic 2                 0.51
# 1196  0.000000  0.000000        Topic 0                  NaN
# 1197  0.000000  0.005243        Topic 2                 1.00
# 1198  0.001091  0.026287        Topic 2                 0.96
#
# [1199 rows x 7 columns]

# %%
# Criação de dataset para classificação
nmf_results.drop(['input','Dominant_Topic', 'Perc_Dominant_Topic'], axis=1, inplace=True)
nmf_results
# Out:
#          category   Topic_0   Topic_1   Topic_2
# 0           covid  0.000000  0.473615  0.000000
# 1           covid  0.000000  0.058017  0.000000
# 2           covid  0.000000  0.073348  0.000000
# 3           covid  0.000000  0.117244  0.001173
# 4           covid  0.000000  0.206631  0.002319
# ...           ...       ...       ...       ...
# 1194  seloturismo  0.000000  0.000000  0.009162
# 1195  seloturismo  0.000066  0.001263  0.001381
# 1196  seloturismo  0.000000  0.000000  0.000000
# 1197  seloturismo  0.000000  0.000000  0.005243
# 1198  seloturismo  0.000000  0.001091  0.026287
#
# [1199 rows x 4 columns]

# %%
from pycaret.classification import *

# # criação do setup Pycaret para Classificação
setup_class = setup(data=nmf_results, target='category', train_size=0.7)
# Out:
# <style type="text/css">
# #T_9a844_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9a844">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a844_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9a844_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a844_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a844_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_9a844_row0_col1" class="data row0 col1" >3895</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9a844_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9a844_row1_col1" class="data row1 col1" >category</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9a844_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_9a844_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9a844_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_9a844_row3_col1" class="data row3 col1" >covid: 0, seloturismo: 1, tuberculose: 2</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9a844_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_9a844_row4_col1" class="data row4 col1" >(1199, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9a844_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_9a844_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9a844_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_9a844_row6_col1" class="data row6 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9a844_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_9a844_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9a844_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_9a844_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9a844_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_9a844_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9a844_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_9a844_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9a844_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_9a844_row11_col1" class="data row11 col1" >(839, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9a844_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_9a844_row12_col1" class="data row12 col1" >(360, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9a844_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_9a844_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9a844_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_9a844_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9a844_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_9a844_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9a844_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_9a844_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9a844_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_9a844_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9a844_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_9a844_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9a844_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_9a844_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_9a844_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_9a844_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_9a844_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_9a844_row21_col1" class="data row21 col1" >79ad</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_9a844_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_9a844_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_9a844_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_9a844_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_9a844_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_9a844_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_9a844_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_9a844_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_9a844_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_9a844_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_9a844_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_9a844_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_9a844_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_9a844_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_9a844_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_9a844_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9a844_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_9a844_row30_col0" class="data row30 col0" >Normalize Method</td>

# %%
# comparação de modelos e salva o de maior Accuracy
best = compare_models()
# Out:
# <style type="text/css">
# #T_eb276 th {
#   text-align: left;
# }
# #T_eb276_row0_col0, #T_eb276_row0_col2, #T_eb276_row1_col0, #T_eb276_row1_col1, #T_eb276_row1_col3, #T_eb276_row1_col4, #T_eb276_row1_col5, #T_eb276_row1_col6, #T_eb276_row1_col7, #T_eb276_row2_col0, #T_eb276_row2_col1, #T_eb276_row2_col2, #T_eb276_row2_col3, #T_eb276_row2_col4, #T_eb276_row2_col5, #T_eb276_row2_col6, #T_eb276_row2_col7, #T_eb276_row3_col0, #T_eb276_row3_col1, #T_eb276_row3_col2, #T_eb276_row3_col3, #T_eb276_row3_col4, #T_eb276_row3_col5, #T_eb276_row3_col6, #T_eb276_row3_col7, #T_eb276_row4_col0, #T_eb276_row4_col1, #T_eb276_row4_col2, #T_eb276_row4_col3, #T_eb276_row4_col4, #T_eb276_row4_col5, #T_eb276_row4_col6, #T_eb276_row4_col7, #T_eb276_row5_col0, #T_eb276_row5_col1, #T_eb276_row5_col2, #T_eb276_row5_col3, #T_eb276_row5_col4, #T_eb276_row5_col5, #T_eb276_row5_col6, #T_eb276_row5_col7, #T_eb276_row6_col0, #T_eb276_row6_col1, #T_eb276_row6_col2, #T_eb276_row6_col3, #T_eb276_row6_col4, #T_eb276_row6_col5, #T_eb276_row6_col6, #T_eb276_row6_col7, #T_eb276_row7_col0, #T_eb276_row7_col1, #T_eb276_row7_col2, #T_eb276_row7_col3, #T_eb276_row7_col4, #T_eb276_row7_col5, #T_eb276_row7_col6, #T_eb276_row7_col7, #T_eb276_row8_col0, #T_eb276_row8_col1, #T_eb276_row8_col2, #T_eb276_row8_col3, #T_eb276_row8_col4, #T_eb276_row8_col5, #T_eb276_row8_col6, #T_eb276_row8_col7, #T_eb276_row9_col0, #T_eb276_row9_col1, #T_eb276_row9_col2, #T_eb276_row9_col3, #T_eb276_row9_col4, #T_eb276_row9_col5, #T_eb276_row9_col6, #T_eb276_row9_col7, #T_eb276_row10_col0, #T_eb276_row10_col1, #T_eb276_row10_col2, #T_eb276_row10_col3, #T_eb276_row10_col4, #T_eb276_row10_col5, #T_eb276_row10_col6, #T_eb276_row10_col7, #T_eb276_row11_col0, #T_eb276_row11_col1, #T_eb276_row11_col2, #T_eb276_row11_col3, #T_eb276_row11_col4, #T_eb276_row11_col5, #T_eb276_row11_col6, #T_eb276_row11_col7, #T_eb276_row12_col0, #T_eb276_row12_col1, #T_eb276_row12_col2, #T_eb276_row12_col3, #T_eb276_row12_col4, #T_eb276_row12_col5, #T_eb276_row12_col6, #T_eb276_row12_col7, #T_eb276_row13_col0, #T_eb276_row13_col1, #T_eb276_row13_col2, #T_eb276_row13_col3, #T_eb276_row13_col4, #T_eb276_row13_col5, #T_eb276_row13_col6, #T_eb276_row13_col7, #T_eb276_row14_col0, #T_eb276_row14_col1, #T_eb276_row14_col2, #T_eb276_row14_col3, #T_eb276_row14_col4, #T_eb276_row14_col5, #T_eb276_row14_col6, #T_eb276_row14_col7, #T_eb276_row15_col0, #T_eb276_row15_col1, #T_eb276_row15_col2, #T_eb276_row15_col3, #T_eb276_row15_col4, #T_eb276_row15_col5, #T_eb276_row15_col6, #T_eb276_row15_col7 {
#   text-align: left;
# }
# #T_eb276_row0_col1, #T_eb276_row0_col3, #T_eb276_row0_col4, #T_eb276_row0_col5, #T_eb276_row0_col6, #T_eb276_row0_col7, #T_eb276_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_eb276_row0_col8, #T_eb276_row1_col8, #T_eb276_row2_col8, #T_eb276_row3_col8, #T_eb276_row4_col8, #T_eb276_row5_col8, #T_eb276_row6_col8, #T_eb276_row7_col8, #T_eb276_row8_col8, #T_eb276_row10_col8, #T_eb276_row11_col8, #T_eb276_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_eb276_row9_col8, #T_eb276_row12_col8, #T_eb276_row13_col8, #T_eb276_row15_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_eb276">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb276_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_eb276_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_eb276_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_eb276_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_eb276_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_eb276_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_eb276_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_eb276_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_eb276_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb276_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_eb276_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_eb276_row0_col1" class="data row0 col1" >0.9464</td>
#       <td id="T_eb276_row0_col2" class="data row0 col2" >0.9900</td>
#       <td id="T_eb276_row0_col3" class="data row0 col3" >0.9242</td>
#       <td id="T_eb276_row0_col4" class="data row0 col4" >0.9478</td>
#       <td id="T_eb276_row0_col5" class="data row0 col5" >0.9459</td>
#       <td id="T_eb276_row0_col6" class="data row0 col6" >0.9061</td>
#       <td id="T_eb276_row0_col7" class="data row0 col7" >0.9073</td>
#       <td id="T_eb276_row0_col8" class="data row0 col8" >0.0420</td>
#     </tr>
#     <tr>
#       <th id="T_eb276_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_eb276_row1_col0" class="data row1 col0" >CatBoost Classifier</td>
#       <td id="T_eb276_row1_col1" class="data row1 col1" >0.9392</td>
#       <td id="T_eb276_row1_col2" class="data row1 col2" >0.9905</td>
#       <td id="T_eb276_row1_col3" class="data row1 col3" >0.9210</td>
#       <td id="T_eb276_row1_col4" class="data row1 col4" >0.9412</td>
#       <td id="T_eb276_row1_col5" class="data row1 col5" >0.9390</td>
#       <td id="T_eb276_row1_col6" class="data row1 col6" >0.8944</td>
#       <td id="T_eb276_row1_col7" class="data row1 col7" >0.8955</td>
#       <td id="T_eb276_row1_col8" class="data row1 col8" >0.7620</td>
#     </tr>
#     <tr>
#       <th id="T_eb276_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_eb276_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_eb276_row2_col1" class="data row2 col1" >0.9380</td>
#       <td id="T_eb276_row2_col2" class="data row2 col2" >0.9894</td>
#       <td id="T_eb276_row2_col3" class="data row2 col3" >0.9172</td>
#       <td id="T_eb276_row2_col4" class="data row2 col4" >0.9399</td>
#       <td id="T_eb276_row2_col5" class="data row2 col5" >0.9378</td>
#       <td id="T_eb276_row2_col6" class="data row2 col6" >0.8921</td>
#       <td id="T_eb276_row2_col7" class="data row2 col7" >0.8932</td>
#       <td id="T_eb276_row2_col8" class="data row2 col8" >0.0490</td>
#     </tr>
#     <tr>
#       <th id="T_eb276_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_eb276_row3_col0" class="data row3 col0" >K Neighbors Classifier</td>
#       <td id="T_eb276_row3_col1" class="data row3 col1" >0.9356</td>
#       <td id="T_eb276_row3_col2" class="data row3 col2" >0.9769</td>
#       <td id="T_eb276_row3_col3" class="data row3 col3" >0.9087</td>
#       <td id="T_eb276_row3_col4" class="data row3 col4" >0.9368</td>
#       <td id="T_eb276_row3_col5" class="data row3 col5" >0.9349</td>
#       <td id="T_eb276_row3_col6" class="data row3 col6" >0.8867</td>
#       <td id="T_eb276_row3_col7" class="data row3 col7" >0.8882</td>
#       <td id="T_eb276_row3_col8" class="data row3 col8" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_eb276_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_eb276_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_eb276_row4_col1" class="data row4 col1" >0.9356</td>
#       <td id="T_eb276_row4_col2" class="data row4 col2" >0.9901</td>
#       <td id="T_eb276_row4_col3" class="data row4 col3" >0.9184</td>
#       <td id="T_eb276_row4_col4" class="data row4 col4" >0.9382</td>
#       <td id="T_eb276_row4_col5" class="data row4 col5" >0.9357</td>
#       <td id="T_eb276_row4_col6" class="data row4 col6" >0.8883</td>
#       <td id="T_eb276_row4_col7" class="data row4 col7" >0.8893</td>
#       <td id="T_eb276_row4_col8" class="data row4 col8" >0.0690</td>
#     </tr>
#     <tr>
#       <th id="T_eb276_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_eb276_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_eb276_row5_col1" class="data row5 col1" >0.9344</td>
#       <td id="T_eb276_row5_col2" class="d

# %%
# Avaliação do modelo
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
# Predição com os dados de validação
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c25f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c25f3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c25f3_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_c25f3_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_c25f3_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_c25f3_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_c25f3_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_c25f3_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_c25f3_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c25f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c25f3_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_c25f3_row0_col1" class="data row0 col1" >0.9500</td>
#       <td id="T_c25f3_row0_col2" class="data row0 col2" >0.9937</td>
#       <td id="T_c25f3_row0_col3" class="data row0 col3" >0.9455</td>
#       <td id="T_c25f3_row0_col4" class="data row0 col4" >0.9530</td>
#       <td id="T_c25f3_row0_col5" class="data row0 col5" >0.9506</td>
#       <td id="T_c25f3_row0_col6" class="data row0 col6" >0.9141</td>
#       <td id="T_c25f3_row0_col7" class="data row0 col7" >0.9148</td>
#     </tr>
#   </tbody>
# </table>
#       Topic_0   Topic_1   Topic_2     category        Label  Score
# 0    0.040895  0.000118  0.000023  tuberculose  tuberculose   0.98
# 1    0.000085  0.110319  0.000000        covid        covid   1.00
# 2    0.000000  0.000000  0.026939  seloturismo  seloturismo   1.00
# 3    0.000000  0.000000  0.063151  seloturismo  seloturismo   1.00
# 4    0.056054  0.002482  0.000000  tuberculose  tuberculose   0.98
# ..        ...       ...       ...          ...          ...    ...
# 355  0.000000  0.000000  0.051404  seloturismo  seloturismo   1.00
# 356  0.061643  0.007615  0.006979  tuberculose  tuberculose   0.97
# 357  0.142097  0.000000  0.000000  tuberculose  tuberculose   1.00
# 358  0.000000  0.001884  0.052354  seloturismo  seloturismo   1.00
# 359  0.000000  0.002548  0.150076  seloturismo  seloturismo   1.00
#
# [360 rows x 6 columns]
