# %%
# Import packages
import numpy as np
import pandas as pd
import nltk
import spacy

from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import OneClassSVM
from pycaret.classification import *

# download das stopwords para o idioma português
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bruno\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Import data
df_traindata = pd.read_csv('../data/traindata.csv', delimiter=';')
df_testdata = pd.read_csv('../data/testdata.csv', delimiter=';')

# Data preparation for Binary
df_traindata['category'] = df_traindata.reset_index().category.map({'covid':0, 'seloturismo':1, 'tuberculose':2})
df_testdata['category'] = df_testdata.reset_index().category.map({'covid':0, 'seloturismo':1, 'tuberculose':2})

# Data separation for One-Class
#traindata_covid = df_traindata[df_traindata['category']=='covid']
#traindata_tuberculose = df_traindata[df_traindata['category']=='tuberculose']
#traindata_seloturismo = df_traindata[df_traindata['category']=='seloturismo']

# %%
# Lemmatizing input string
nlp = spacy.load("pt_core_news_lg")
lem = nlp.get_pipe("lemmatizer")

def lemmatize(data):
    inputs = []
    for doc in data.input:
        d = nlp(doc)
        s = ' '.join([token.lemma_ for token in d])       
        inputs.append(s)
    data['input'] = inputs
    return data

traindata = lemmatize(df_traindata)
testdata = lemmatize(df_testdata)

# %%
# Normalizing and TF-IDF preparation
stop_words = stopwords.words('portuguese')

tv = TfidfVectorizer(lowercase=True, stop_words=stop_words, strip_accents='unicode', token_pattern="[A-Za-z]+")
train_tf_idf = tv.fit_transform(traindata['input'])
test_tf_idf = tv.transform(testdata['input'])

traindata_vect = pd.DataFrame(train_tf_idf.toarray(), columns=tv.get_feature_names())
traindata_vect['target_cat'] = traindata.reset_index().category

testdata_vect = pd.DataFrame(test_tf_idf.toarray(), columns=tv.get_feature_names())
testdata_vect['target_cat'] = testdata.reset_index().category
#testdata_vect.head()
#traindata_vect.head()

# %%
s = setup(data=traindata_vect, target='target_cat', session_id=9999, fold=10, test_data=testdata_vect, silent=True)
# Out:
# <style type="text/css">
# #T_d412f_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d412f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d412f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d412f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d412f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d412f_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_d412f_row0_col1" class="data row0 col1" >9999</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d412f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d412f_row1_col1" class="data row1 col1" >target_cat</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d412f_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_d412f_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d412f_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_d412f_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d412f_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_d412f_row4_col1" class="data row4 col1" >(1199, 1286)</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d412f_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_d412f_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d412f_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_d412f_row6_col1" class="data row6 col1" >665</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d412f_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_d412f_row7_col1" class="data row7 col1" >620</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d412f_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_d412f_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d412f_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_d412f_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d412f_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_d412f_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d412f_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_d412f_row11_col1" class="data row11 col1" >(1199, 946)</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d412f_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_d412f_row12_col1" class="data row12 col1" >(477, 946)</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d412f_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_d412f_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d412f_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_d412f_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d412f_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_d412f_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d412f_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_d412f_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d412f_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_d412f_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d412f_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_d412f_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d412f_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_d412f_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d412f_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_d412f_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d412f_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_d412f_row21_col1" class="data row21 col1" >2938</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d412f_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_d412f_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_d412f_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_d412f_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_d412f_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_d412f_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_d412f_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_d412f_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_d412f_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_d412f_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_d412f_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_d412f_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_d412f_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_d412f_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_d412f_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_d412f_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d412f_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_d412f_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_d412f_row

# %%
model = compare_models()
# Out:
# IntProgress(value=0, description='Processing: ', max=84)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             14:14:14
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Classifier
# <style type="text/css">
# #T_d1a7a th {
#   text-align: left;
# }
# #T_d1a7a_row0_col0, #T_d1a7a_row0_col1, #T_d1a7a_row0_col2, #T_d1a7a_row0_col3, #T_d1a7a_row0_col4, #T_d1a7a_row0_col5, #T_d1a7a_row0_col6, #T_d1a7a_row0_col7, #T_d1a7a_row0_col8, #T_d1a7a_row1_col0, #T_d1a7a_row1_col1, #T_d1a7a_row1_col2, #T_d1a7a_row1_col3, #T_d1a7a_row1_col4, #T_d1a7a_row1_col5, #T_d1a7a_row1_col6, #T_d1a7a_row1_col7, #T_d1a7a_row1_col8, #T_d1a7a_row2_col0, #T_d1a7a_row2_col1, #T_d1a7a_row2_col2, #T_d1a7a_row2_col3, #T_d1a7a_row2_col4, #T_d1a7a_row2_col5, #T_d1a7a_row2_col6, #T_d1a7a_row2_col7, #T_d1a7a_row2_col8, #T_d1a7a_row3_col0, #T_d1a7a_row3_col1, #T_d1a7a_row3_col2, #T_d1a7a_row3_col3, #T_d1a7a_row3_col4, #T_d1a7a_row3_col5, #T_d1a7a_row3_col6, #T_d1a7a_row3_col7, #T_d1a7a_row3_col8, #T_d1a7a_row4_col0, #T_d1a7a_row4_col1, #T_d1a7a_row4_col2, #T_d1a7a_row4_col3, #T_d1a7a_row4_col4, #T_d1a7a_row4_col5, #T_d1a7a_row4_col6, #T_d1a7a_row4_col7, #T_d1a7a_row4_col8, #T_d1a7a_row5_col0, #T_d1a7a_row5_col1, #T_d1a7a_row5_col2, #T_d1a7a_row5_col3, #T_d1a7a_row5_col4, #T_d1a7a_row5_col5, #T_d1a7a_row5_col6, #T_d1a7a_row5_col7, #T_d1a7a_row5_col8, #T_d1a7a_row6_col0, #T_d1a7a_row6_col1, #T_d1a7a_row6_col2, #T_d1a7a_row6_col3, #T_d1a7a_row6_col4, #T_d1a7a_row6_col5, #T_d1a7a_row6_col6, #T_d1a7a_row6_col7, #T_d1a7a_row6_col8, #T_d1a7a_row7_col0, #T_d1a7a_row7_col1, #T_d1a7a_row7_col2, #T_d1a7a_row7_col3, #T_d1a7a_row7_col4, #T_d1a7a_row7_col5, #T_d1a7a_row7_col6, #T_d1a7a_row7_col7, #T_d1a7a_row7_col8, #T_d1a7a_row8_col0, #T_d1a7a_row8_col1, #T_d1a7a_row8_col2, #T_d1a7a_row8_col3, #T_d1a7a_row8_col4, #T_d1a7a_row8_col5, #T_d1a7a_row8_col6, #T_d1a7a_row8_col7, #T_d1a7a_row8_col8, #T_d1a7a_row9_col0, #T_d1a7a_row9_col1, #T_d1a7a_row9_col2, #T_d1a7a_row9_col3, #T_d1a7a_row9_col4, #T_d1a7a_row9_col5, #T_d1a7a_row9_col6, #T_d1a7a_row9_col7, #T_d1a7a_row9_col8, #T_d1a7a_row10_col0, #T_d1a7a_row10_col1, #T_d1a7a_row10_col2, #T_d1a7a_row10_col3, #T_d1a7a_row10_col4, #T_d1a7a_row10_col5, #T_d1a7a_row10_col6, #T_d1a7a_row10_col7, #T_d1a7a_row10_col8, #T_d1a7a_row11_col0, #T_d1a7a_row11_col1, #T_d1a7a_row11_col2, #T_d1a7a_row11_col3, #T_d1a7a_row11_col4, #T_d1a7a_row11_col5, #T_d1a7a_row11_col6, #T_d1a7a_row11_col7, #T_d1a7a_row11_col8, #T_d1a7a_row12_col0, #T_d1a7a_row12_col1, #T_d1a7a_row12_col2, #T_d1a7a_row12_col3, #T_d1a7a_row12_col4, #T_d1a7a_row12_col5, #T_d1a7a_row12_col6, #T_d1a7a_row12_col7, #T_d1a7a_row12_col8, #T_d1a7a_row13_col0, #T_d1a7a_row13_col1, #T_d1a7a_row13_col2, #T_d1a7a_row13_col3, #T_d1a7a_row13_col4, #T_d1a7a_row13_col5, #T_d1a7a_row13_col6, #T_d1a7a_row13_col7, #T_d1a7a_row13_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_d1a7a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1a7a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d1a7a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d1a7a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_d1a7a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d1a7a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_d1a7a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_d1a7a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_d1a7a_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_d1a7a_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1a7a_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_d1a7a_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_d1a7a_row0_col1" class="data row0 col1" >0.9508</td>
#       <td id="T_d1a7a_row0_col2" class="data row0 col2" >0.9899</td>
#       <td id="T_d1a7a_row0_col3" class="data row0 col3" >0.9331</td>
#       <td id="T_d1a7a_row0_col4" class="data row0 col4" >0.9537</td>
#       <td id="T_d1a7a_row0_col5" class="data row0 col5" >0.9496</td>
#       <td id="T_d1a7a_row0_col6" class="data row0 col6" >0.9141</td>
#       <td id="T_d1a7a_row0_col7" class="data row0 col7" >0.9165</td>
#       <td id="T_d1a7a_row0_col8" class="data row0 col8" >0.1450</td>
#     </tr>
#     <tr>
#       <th id="T_d1a7a_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_d1a7a_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_d1a7a_row1_col1" class="data row1 col1" >0.9391</td>
#       <td id="T_d1a7a_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_d1a7a_row1_col3" class="data row1 col3" >0.9013</td>
#       <td id="T_d1a7a_row1_col4" class="data row1 col4" >0.9435</td>
#       <td id="T_d1a7a_row1_col5" class="data row1 col5" >0.9363</td>
#       <td id="T_d1a7a_row1_col6" class="data row1 col6" >0.8900</td>
#       <td id="T_d1a7a_row1_col7" class="data row1 col7" >0.8961</td>
#       <td id="T_d1a7a_row1_col8" class="data row1 col8" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_d1a7a_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_d1a7a_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_d1a7a_row2_col1" class="data row2 col1" >0.9383</td>
#       <td id="T_d1a7a_row2_col2" class="data row2 col2" >0.9844</td>
#       <td id="T_d1a7a_row2_col3" class="data row2 col3" >0.8999</td>
#       <td id="T_d1a7a_row2_col4" class="data row2 col4" >0.9444</td>
#       <td id="T_d1a7a_row2_col5" class="data row2 col5" >0.9350</td>
#       <td id="T_d1a7a_row2_col6" class="data row2 col6" >0.8884</td>
#       <td id="T_d1a7a_row2_col7" class="data row2 col7" >0.8952</td>
#       <td id="T_d1a7a_row2_col8" class="data row2 col8" >0.6250</td>
#     </tr>
#     <tr>
#       <th id="T_d1a7a_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_d1a7a_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_d1a7a_row3_col1" class="data row3 col1" >0.9374</td>
#       <td id="T_d1a7a_row3_col2" class="data row3 col2" >0.9898</td>
#       <td id="T_d1a7a_row3_col3" class="data row3 col3" >0.9164</td>
#       <td id="T_d1a7a_row3_col4" class="data row3 col4" >0.9421</td>
#       <td id="T_d1a7a_row3_col5" class="data row3 col5" >0.9362</td>
#       <td id="T_d1a7a_row3_col6" class="data row3 col6" >0.8905</td>
#       <td id="T_d1a7a_row3_col7" class="data row3 col7" >0.8937</td>
#       <td id="T_d1a7a_row3_col8" class="data row3 col8" >0.1100</td>
#     </tr>
#     <tr>
#       <th id="T_d1a7a_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_d1a7a_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_d1a7a_row4_col1" class="data row4 col1" >0.9324</td>
#       <td id="T_d1a7a_row4_col2" class="data row4 col2" >0.9812</td>
#       <td id="T_d1a7a_row4_col3" class="data row4 col3" >0.9043</td>
#       <td id="T_d1a7a_row4_col4" class="data row4 col4" >0.9340</td>
#       <td id="T_d1a7a_row4_col5" class="data row4 col5" >0.9304</td>
#       <td id="T_d1a7a_row4_col6" class="data row4 col6" >0.8803</td>
#       <td id="T_d1a7a_row4_col7" class="data row4 col7" >0.8835</td>
#       <td id="T_d1a7a_row4_col8" class="data row4 col8" >1.5170</td>
#     </tr>
#     <tr>
#       <th id="T_d1a7a_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_d1a7a_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_d1a7a_row5_col1" class="data row5 col1" >0.9282</td>
#       <td id="T_d1a7a_row5_col2" class="data row5 col2" >0.9502</td>
#       <td id="T_d1a7a_row5_col3" class="data row5 col3" >0.9107</td>
#       <td id="T_d1a7a_row5_col4" class="data row5 col4" >0.9325</td>
#       <td id="T_d1a7a_row5_col5" class="data row5 col5" >0.9274</td>
#       <td id="T_d1a7a_row5_col6" class="data row5 col6" >0.8761</td>
#       <td id="T_d1a7a_row5_col7" class="data row5 col7" >0.8794</td>
#       <td id="T_d1a7a_row5_col8" class="data row5 col8" >0.0260</td>
#     </tr>
#     <tr>
#       <th id="T_d1a7a_level0_row6" class="row_heading level0 row6" >ada</th>
#       <td id="T_d1a7a_row6_col0"

# %%
# tune models
#tuned = [tune_model(i) for i in top5]

# %%
# ensemble models
#bagged = [ensemble_model(i) for i in tuned]

# %%
# blend models
#blended = blend_models(estimator_list = top5)

# %%
# stack models
#stacked = stack_models(estimator_list = top5)

# %%
# automl 
#best = automl(optimize = 'Accuracy')

# %%
# calibrate model
#model = calibrate_model(best)

# %%
predict_model(model, probability_threshold=0.75)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5044a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5044a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5044a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_5044a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_5044a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_5044a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_5044a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_5044a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_5044a_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5044a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5044a_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_5044a_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_5044a_row0_col2" class="data row0 col2" >0.9688</td>
#       <td id="T_5044a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5044a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5044a_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_5044a_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_5044a_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 predict_model(model, probability_threshold=0.75)
#
# File c:\Users\bruno\anaconda3\envs\chatbot_env\lib\site-packages\pycaret\classification.py:2126, in predict_model(estimator, data, probability_threshold, encoded_labels, raw_score, drift_report, round, verbose, drift_kwargs)
#    2047 def predict_model(
#    2048     estimator,
#    2049     data: Optional[pd.DataFrame] = None,
#    (...)
#    2056     drift_kwargs: Optional[dict] = None,
#    2057 ) -> pd.DataFrame:
#    2059     """
#    2060     This function predicts ``Label`` and ``Score`` (probability of predicted
#    2061     class) using a trained model. When ``data`` is None, it predicts label and
#    (...)
#    2123
#    2124     """
# -> 2126     return pycaret.internal.tabular.predict_model(
#    2127         estimator=estimator,
#    2128         data=data,
#    2129         probability_threshold=probability_threshold,
#    2130         encoded_labels=encoded_labels,
#    2131         raw_score=raw_score,
#    2132         drift_report=drift_report,
#    2133         round=round,
#    2134         verbose=verbose,
#    2135         ml_usecase=MLUsecase.CLASSIFICATION,
#    2136         drift_kwargs=drift_kwargs,
#    2137     )
#
# File c:\Users\bruno\anaconda3\envs\chatbot_env\lib\site-packages\pycaret\internal\tabular.py:9151, in predict_model(estimator, data, probability_threshold, encoded_labels, drift_report, raw_score, round, verbose, ml_usecase, display, drift_kwargs)
#    9148     display.display(df_score.style.set_precision(round), clear=False)
#    9150 label = pd.DataFrame(pred)
# -> 9151 label.columns = ["Label"]
#    9152 if not encoded_labels:
#    9153     replace_lables_in_column(label["Label"])
#
# File c:\Users\bruno\anaconda3\envs\chatbot_env\lib\site-packages\pandas\core\generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File c:\Users\bruno\anaconda3\envs\chatbot_env\lib\site-packages\pandas\_libs\properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\bruno\anaconda3\envs\chatbot_env\lib\site-packages\pandas\core\generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
#     768     labels = ensure_index(labels)
# --> 769     self._mgr.set_axis(axis, labels)
#     770     self._clear_item_cache()
#
# File c:\Users\bruno\anaconda3\envs\chatbot_env\lib\site-packages\pandas\core\internals\managers.py:214, in BaseBlockManager.set_axis(self, axis, new_labels)
#     212 def set_axis(self, axis: int, new_labels: Index) -> None:
#     213     # Caller is responsible for ensuring we have an Index object.
# --> 214     self._validate_set_axis(axis, new_labels)
#     215     self.axes[axis] = new_labels
#
# File c:\Users\bruno\anaconda3\envs\chatbot_env\lib\site-packages\pandas\core\internals\base.py:69, in DataManager._validate_set_axis(self, axis, new_labels)
#      66     pass
#      68 elif new_len != old_len:
# ---> 69     raise ValueError(
#      70         f"Length mismatch: Expected axis has {old_len} elements, new "
#      71         f"values have {new_len} elements"
#      72     )
#
# ValueError: Length mismatch: Expected axis has 3 elements, new values have 1 elements
